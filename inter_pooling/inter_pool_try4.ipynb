# %%
import mdtraj as md
from ase import Atoms
import nglview as nv
import networkx as nx

import torch
import torch_geometric.transforms as T
from torch_geometric.loader import DataLoader
from torch_geometric.nn import GCNConv, SAGPooling, InnerProductDecoder
import torch_geometric.data as data
from torch_geometric.utils.convert import to_networkx

import numpy as np
import matplotlib.pyplot as plt

# %%
all_frames = md.load_xtc("../simulation/npt.xtc", top="../simulation/box.gro")

# %%
all_frames_fatures = []

for i in range(all_frames.xyz.shape[0]):
    mol_com_pos = []

    for res in all_frames.top.residues:
        # print(res.index,end=" ")
        pos = []
        for atom in res.atoms:
            # print(atom.index,"-->" , frame.xyz[0][atom.index],end=" ")
            pos.append(all_frames.xyz[i][atom.index])
        mol_com_pos.append(np.mean(pos,axis=0))
        
        # print()
    mol_com_pos = np.array(mol_com_pos).astype(np.float32)  
    all_frames_fatures.append(mol_com_pos)

all_frames_fatures = np.array(all_frames_fatures).astype(np.float32)
print(all_frames_fatures.shape)
# Out:
# (51, 101, 3)

# %%
print(dir(all_frames.topology.residue(0)))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_atoms', 'atom', 'atoms', 'atoms_by_name', 'chain', 'code', 'index', 'is_nucleic', 'is_protein', 'is_water', 'n_atoms', 'name', 'resSeq', 'segment_id']

# %%
n_frames = all_frames.xyz.shape[0]
n_atoms = all_frames.topology.residue(0).n_atoms
n_mols = all_frames.topology.n_residues

# %%
print("number of molecules",n_mols)
print("number of atoms in molecule",n_atoms)
print("number of frames",n_frames)
# Out:
# number of molecules 101
# number of atoms in molecule 4
# number of frames 51

# %%
# %matplotlib widget

frame = 10

fig = plt.figure(figsize=(5,4))
ax1 = fig.add_subplot(projection='3d')
ax1.scatter(all_frames_fatures[frame][:,0],all_frames_fatures[frame][:,1],all_frames_fatures[frame][:,2])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def convert_to_adj(edge_index, num_nodes=None):
    if num_nodes is None:
        num_nodes = edge_index.max() + 1
    adj = torch.zeros(num_nodes, num_nodes)
    adj[edge_index[0], edge_index[1]] = 1
    return adj

def convert_to_edge_index(adj):
    edge_index = adj.nonzero().t()
    return edge_index

# %%
cutoff = 0.5

all_edge_list = []
for frame_i in range(n_frames):
    from_list = []
    to_list = []

    for i in range(len(all_frames_fatures[frame_i])):
        for j in range(i+1,len(all_frames_fatures[frame_i])):
            if np.linalg.norm(all_frames_fatures[frame_i][i]-all_frames_fatures[frame_i][j]) < cutoff:
                # print(i,j,np.linalg.norm(mol_com_pos[i]-mol_com_pos[j]))
                from_list.append(i)
                to_list.append(j)

                to_list.append(i)
                from_list.append(j)

    edge_list = np.array([from_list,to_list]).astype(np.int64)
    all_edge_list.append(edge_list)

print(len(all_edge_list))
# Out:
# 51

# %%
# %matplotlib widget

frame = 10

plt.figure(figsize=(8,10))
adj_binary = convert_to_adj(all_edge_list[frame], num_nodes=101)
indices = torch.where(adj_binary)
G = nx.Graph()
edges = [(i, j) for i, j in zip(indices[0].tolist(), indices[1].tolist()) if i != j]
G.add_edges_from(edges)
nx.draw_networkx(G)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Converting to pytorch graph object

# %%
graphs = []
for frame in range(n_frames):
    g = data.Data(x=torch.tensor(all_frames_fatures[frame]).float(), edge_index=torch.tensor(all_edge_list[frame]).long(), y=torch.tensor([0]))
    graphs.append(g)

print(graphs[0])
# Out:
# Data(x=[101, 3], edge_index=[2, 1158], y=[1])

# %% [markdown]
# ## Model

# %%
from typing import Optional, Tuple

import torch
from torch import Tensor
from torch.nn import Module

from torch_geometric.nn.inits import reset
from torch_geometric.utils import negative_sampling

EPS = 1e-15
MAX_LOGSTD = 10


class InnerProductDecoder(torch.nn.Module):
    r"""The inner product decoder from the `"Variational Graph Auto-Encoders"
    <https://arxiv.org/abs/1611.07308>`_ paper

    .. math::
        \sigma(\mathbf{Z}\mathbf{Z}^{\top})

    where :math:`\mathbf{Z} \in \mathbb{R}^{N \times d}` denotes the latent
    space produced by the encoder."""

    def forward(self, z: Tensor, edge_index: Tensor,
                sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into edge probabilities for
        the given node-pairs :obj:`edge_index`.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        value = (z[edge_index[0]] * z[edge_index[1]]).sum(dim=1)
        return torch.sigmoid(value) if sigmoid else value

    def forward_all(self, z: Tensor, sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into a probabilistic dense
        adjacency matrix.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        adj = torch.matmul(z, z.t())
        return torch.sigmoid(adj) if sigmoid else adj


class GAE(torch.nn.Module):
    r"""The Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper based on user-defined encoder and decoder models.

    Args:
        encoder (torch.nn.Module): The encoder module.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__()
        self.encoder = encoder
        self.decoder = InnerProductDecoder() if decoder is None else decoder
        GAE.reset_parameters(self)

    def reset_parameters(self):
        r"""Resets all learnable parameters of the module."""
        reset(self.encoder)
        reset(self.decoder)

    def forward(self, *args, **kwargs) -> Tensor:  # pragma: no cover
        r"""Alias for :meth:`encode`."""
        return self.encoder(*args, **kwargs)

    def encode(self, *args, **kwargs) -> Tensor:
        r"""Runs the encoder and computes node-wise latent variables."""
        return self.encoder(*args, **kwargs)

    def decode(self, *args, **kwargs) -> Tensor:
        r"""Runs the decoder and computes edge probabilities."""
        return self.decoder(*args, **kwargs)

    def recon_loss(self, z: Tensor, pos_edge_index: Tensor,
                   neg_edge_index: Optional[Tensor] = None) -> Tensor:
        r"""Given latent variables :obj:`z`, computes the binary cross
        entropy loss for positive edges :obj:`pos_edge_index` and negative
        sampled edges.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to train against.
            neg_edge_index (torch.Tensor, optional): The negative edges to
                train against. If not given, uses negative sampling to
                calculate negative edges. (default: :obj:`None`)
        """
        pos_loss = -torch.log(
            self.decoder(z, pos_edge_index, sigmoid=True)[0] + EPS).mean()

        if neg_edge_index is None:
            neg_edge_index = negative_sampling(pos_edge_index, z.size(0))
        neg_loss = -torch.log(1 -
                              self.decoder(z, neg_edge_index.long(), sigmoid=True)[0] +
                              EPS).mean()

        return pos_loss + neg_loss

    def test(self, z: Tensor, pos_edge_index: Tensor,
             neg_edge_index: Tensor) -> Tuple[Tensor, Tensor]:
        r"""Given latent variables :obj:`z`, positive edges
        :obj:`pos_edge_index` and negative edges :obj:`neg_edge_index`,
        computes area under the ROC curve (AUC) and average precision (AP)
        
        scores.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to evaluate
                against.
            neg_edge_index (torch.Tensor): The negative edges to evaluate
                against.
        """
        from sklearn.metrics import average_precision_score, roc_auc_score

        pos_y = z.new_ones(pos_edge_index.size(1))
        neg_y = z.new_zeros(neg_edge_index.size(1))
        y = torch.cat([pos_y, neg_y], dim=0)

        pos_pred = self.decoder(z, pos_edge_index, sigmoid=True)
        neg_pred = self.decoder(z, neg_edge_index, sigmoid=True)
        pred = torch.cat([pos_pred, neg_pred], dim=0)

        y, pred = y.detach().cpu().numpy(), pred.detach().cpu().numpy()

        return roc_auc_score(y, pred), average_precision_score(y, pred)


class VGAE(GAE):
    r"""The Variational Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper.

    Args:
        encoder (torch.nn.Module): The encoder module to compute :math:`\mu`
            and :math:`\log\sigma^2`.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__(encoder, decoder)

    def reparametrize(self, mu: Tensor, logstd: Tensor) -> Tensor:
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu

    def encode(self, *args, **kwargs) -> Tensor:
        """"""
        self.__mu__, self.__logstd__, self.edge_index = self.encoder(
            *args, **kwargs)
        self.__logstd__ = self.__logstd__.clamp(max=MAX_LOGSTD)
        z = self.reparametrize(self.__mu__, self.__logstd__)
        return z, self.edge_index

    def kl_loss(self, mu: Optional[Tensor] = None,
                logstd: Optional[Tensor] = None) -> Tensor:
        r"""Computes the KL loss, either for the passed arguments :obj:`mu`
        and :obj:`logstd`, or based on latent variables from last encoding.

        Args:
            mu (torch.Tensor, optional): The latent space for :math:`\mu`. If
                set to :obj:`None`, uses the last computation of :math:`\mu`.
                (default: :obj:`None`)
            logstd (torch.Tensor, optional): The latent space for
                :math:`\log\sigma`.  If set to :obj:`None`, uses the last
                computation of :math:`\log\sigma^2`. (default: :obj:`None`)
        """
        mu = self.__mu__ if mu is None else mu
        logstd = self.__logstd__ if logstd is None else logstd.clamp(
            max=MAX_LOGSTD)
        return -0.5 * torch.mean(
            torch.sum(1 + 2 * logstd - mu**2 - logstd.exp()**2, dim=1))

# %%
import torch.nn.functional as F

class VariationalGCNEncoder(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.conv1 = GCNConv(in_channels, 2 * out_channels)
        self.conv2 = GCNConv(2*out_channels, 1 * out_channels)
        self.conv_mu = GCNConv(1 * out_channels, out_channels)
        self.conv_logstd = GCNConv(1 * out_channels, out_channels)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = F.silu(x)
        x = self.conv2(x, edge_index)
        x = F.silu(x)
        return self.conv_mu(x, edge_index), self.conv_logstd(x, edge_index), edge_index

# %%
class VariationalGCNDecoder(torch.nn.Module):
    def __init__(self,in_channels,out_channels):
        super().__init__()
        self.conv1 = GCNConv(in_channels, 2 * out_channels)
        self.conv2 = GCNConv(2 * out_channels, 1 * out_channels)
    def forward(self, x, edge_index, sigmoid=True):
        x = self.conv1(x.float(), edge_index)
        x = F.silu(x)
        x = self.conv2(x, edge_index)
        x = F.silu(x)
        return x, edge_index

# %%
in_channels = graphs[0].num_features
out_channels = 2
lr = 1e-4
n_epochs = 500
batch_size=2

model = VGAE(VariationalGCNEncoder(in_channels, out_channels),
             VariationalGCNDecoder(out_channels, in_channels))
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %%
train_loader = DataLoader(graphs, batch_size=batch_size)

# %%
for data in train_loader:
    print((data.x.type()))
    print((data.edge_index.type()))
    break
# Out:
# torch.FloatTensor
# torch.LongTensor

# %%
lossFxn = torch.nn.MSELoss()
def train():
    model.train()
    model.zero_grad()
    model.float()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0

    for data in train_loader:
        optimizer.zero_grad()
        z,encoded_edge_index = model.encode(data.x, data.edge_index)
        decoded_x, decoded_edge_index = model.decode(z, encoded_edge_index)

        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        loss = FeatureLoss + EdgeLoss
        loss = loss + (1 / data.num_nodes) * model.kl_loss()

        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        kl_loss_all += float(model.kl_loss()/data.num_nodes)

        loss.backward()
        optimizer.step()

    return loss_all / len(train_loader.dataset), feature_loss_all / len(train_loader.dataset), edge_loss_all / len(train_loader.dataset), kl_loss_all / len(train_loader.dataset)

# %%
total_losses = []
feature_losses = []
edge_losses = []
kl_losses = []

for epoch in range(1, n_epochs + 1):
    total_loss, feature_loss, edge_loss, kl_loss = train()
    print(f'Epoch: {epoch:03d}, Total Loss: {total_loss:.4f}, Feature Loss: {feature_loss:.4f}, Edge Loss: {edge_loss:.4f}, KL Loss: {kl_loss:.4f}')
    total_losses.append(total_loss)
    feature_losses.append(feature_loss)
    edge_losses.append(edge_loss)
    kl_losses.append(kl_loss)
# Out:
# Epoch: 001, Total Loss: 121628.3341, Feature Loss: 99205.9998, Edge Loss: 0.0000, KL Loss: 22422.3331
# Epoch: 002, Total Loss: 77291.9862, Feature Loss: 55254.7673, Edge Loss: 0.0000, KL Loss: 22037.2225
# Epoch: 003, Total Loss: 114653.3186, Feature Loss: 92852.5946, Edge Loss: 0.0000, KL Loss: 21800.7216
# Epoch: 004, Total Loss: 143423.4284, Feature Loss: 121832.2078, Edge Loss: 0.0000, KL Loss: 21591.2224
# Epoch: 005, Total Loss: 129448.4615, Feature Loss: 108255.2493, Edge Loss: 0.0000, KL Loss: 21193.2085
# Epoch: 006, Total Loss: 112693.2011, Feature Loss: 91820.5138, Edge Loss: 0.0000, KL Loss: 20872.6873
# Epoch: 007, Total Loss: 80081.3602, Feature Loss: 59484.9412, Edge Loss: 0.0000, KL Loss: 20596.4183
# Epoch: 008, Total Loss: 89251.3406, Feature Loss: 68997.3661, Edge Loss: 0.0000, KL Loss: 20253.9724
# Epoch: 009, Total Loss: 77888.2553, Feature Loss: 57940.3443, Edge Loss: 0.0000, KL Loss: 19947.9135
# Epoch: 010, Total Loss: 72996.3463, Feature Loss: 53327.0682, Edge Loss: 0.0000, KL Loss: 19669.2750
# Epoch: 011, Total Loss: 61393.9333, Feature Loss: 41928.6259, Edge Loss: 0.0000, KL Loss: 19465.3064
# Epoch: 012, Total Loss: 81828.7012, Feature Loss: 62571.3745, Edge Loss: 0.0000, KL Loss: 19257.3267
# Epoch: 013, Total Loss: 82316.4632, Feature Loss: 63343.1947, Edge Loss: 0.0000, KL Loss: 18973.2669
# Epoch: 014, Total Loss: 72130.9392, Feature Loss: 53562.9906, Edge Loss: 0.0000, KL Loss: 18567.9504
# Epoch: 015, Total Loss: 117447.0331, Feature Loss: 99082.3371, Edge Loss: 0.0000, KL Loss: 18364.6938
# Epoch: 016, Total Loss: 68329.3346, Feature Loss: 50303.9581, Edge Loss: 0.0000, KL Loss: 18025.3761
# Epoch: 017, Total Loss: 72793.0196, Feature Loss: 55013.3953, Edge Loss: 0.0000, KL Loss: 17779.6250
# Epoch: 018, Total Loss: 123003.8901, Feature Loss: 105470.3358, Edge Loss: 0.0000, KL Loss: 17533.5527
# Epoch: 019, Total Loss: 136967.0960, Feature Loss: 119637.1252, Edge Loss: 0.0000, KL Loss: 17329.9748
# Epoch: 020, Total Loss: 99174.1143, Feature Loss: 82250.0298, Edge Loss: 0.0000, KL Loss: 16924.0872
# Epoch: 021, Total Loss: 64484.9622, Feature Loss: 47960.9995, Edge Loss: 0.0000, KL Loss: 16523.9652
# Epoch: 022, Total Loss: 90571.4656, Feature Loss: 74279.4035, Edge Loss: 0.0000, KL Loss: 16292.0623
# Epoch: 023, Total Loss: 66988.8786, Feature Loss: 51110.9722, Edge Loss: 0.0000, KL Loss: 15877.9043
# Epoch: 024, Total Loss: 101923.3682, Feature Loss: 86336.4863, Edge Loss: 0.0000, KL Loss: 15586.8862
# Epoch: 025, Total Loss: 84011.2175, Feature Loss: 68735.6198, Edge Loss: 0.0000, KL Loss: 15275.6005
# Epoch: 026, Total Loss: 41580.9642, Feature Loss: 26575.3136, Edge Loss: 0.0000, KL Loss: 15005.6509
# Epoch: 027, Total Loss: 59653.2674, Feature Loss: 44876.1445, Edge Loss: 0.0000, KL Loss: 14777.1238
# Epoch: 028, Total Loss: 72947.9391, Feature Loss: 58387.0615, Edge Loss: 0.0000, KL Loss: 14560.8749
# Epoch: 029, Total Loss: 65356.3741, Feature Loss: 51196.9700, Edge Loss: 0.0000, KL Loss: 14159.4029
# Epoch: 030, Total Loss: 56386.0111, Feature Loss: 42568.7002, Edge Loss: 0.0000, KL Loss: 13817.3119
# Epoch: 031, Total Loss: 61369.8896, Feature Loss: 47902.8755, Edge Loss: 0.0000, KL Loss: 13467.0164
# Epoch: 032, Total Loss: 56161.2740, Feature Loss: 43016.0928, Edge Loss: 0.0000, KL Loss: 13145.1829
# Epoch: 033, Total Loss: 39268.4037, Feature Loss: 26413.3438, Edge Loss: 0.0000, KL Loss: 12855.0602
# Epoch: 034, Total Loss: 69528.7283, Feature Loss: 56933.4912, Edge Loss: 0.0000, KL Loss: 12595.2359
# Epoch: 035, Total Loss: 45739.3537, Feature Loss: 33536.3223, Edge Loss: 0.0000, KL Loss: 12203.0321
# Epoch: 036, Total Loss: 66882.2834, Feature Loss: 55120.9033, Edge Loss: 0.0000, KL Loss: 11761.3810
# Epoch: 037, Total Loss: 47244.7541, Feature Loss: 36129.3954, Edge Loss: 0.0000, KL Loss: 11115.3580
# Epoch: 038, Total Loss: 73503.2366, Feature Loss: 62745.3627, Edge Loss: 0.0000, KL Loss: 10757.8750
# Epoch: 039, Total Loss: 35424.8944, Feature Loss: 25072.5523, Edge Loss: 0.0000, KL Loss: 10352.3422
# Epoch: 040, Total Loss: 62239.5030, Feature Loss: 52058.3786, Edge Loss: 0.0000, KL Loss: 10181.1248
# Epoch: 041, Total Loss: 44758.3621, Feature Loss: 34878.9538, Edge Loss: 0.0000, KL Loss: 9879.4092
# Epoch: 042, Total Loss: 35231.5984, Feature Loss: 25585.9965, Edge Loss: 0.0000, KL Loss: 9645.6015
# Epoch: 043, Total Loss: 47204.3847, Feature Loss: 37692.0569, Edge Loss: 0.0000, KL Loss: 9512.3298
# Epoch: 044, Total Loss: 59044.8566, Feature Loss: 49783.2622, Edge Loss: 0.0000, KL Loss: 9261.5925
# Epoch: 045, Total Loss: 51381.4019, Feature Loss: 42397.3187, Edge Loss: 0.0000, KL Loss: 8984.0819
# Epoch: 046, Total Loss: 43223.6244, Feature Loss: 34539.0400, Edge Loss: 0.0000, KL Loss: 8684.5840
# Epoch: 047, Total Loss: 45105.2201, Feature Loss: 36671.3113, Edge Loss: 0.0000, KL Loss: 8433.9076
# Epoch: 048, Total Loss: 46923.7733, Feature Loss: 38868.4160, Edge Loss: 0.0000, KL Loss: 8055.3585
# Epoch: 049, Total Loss: 27392.8851, Feature Loss: 19653.8168, Edge Loss: 0.0000, KL Loss: 7739.0678
# Epoch: 050, Total Loss: 43454.6526, Feature Loss: 35853.9034, Edge Loss: 0.0000, KL Loss: 7600.7488
# Epoch: 051, Total Loss: 21124.4132, Feature Loss: 13788.5340, Edge Loss: 0.0000, KL Loss: 7335.8793
# Epoch: 052, Total Loss: 29714.0240, Feature Loss: 22558.7169, Edge Loss: 0.0000, KL Loss: 7155.3084
# Epoch: 053, Total Loss: 27366.0661, Feature Loss: 20451.6362, Edge Loss: 0.0000, KL Loss: 6914.4311
# Epoch: 054, Total Loss: 17970.4139, Feature Loss: 11210.9552, Edge Loss: 0.0000, KL Loss: 6759.4579
# Epoch: 055, Total Loss: 22051.7920, Feature Loss: 15429.8284, Edge Loss: 0.0000, KL Loss: 6621.9630
# Epoch: 056, Total Loss: 31090.2517, Feature Loss: 24592.0625, Edge Loss: 0.0000, KL Loss: 6498.1899
# Epoch: 057, Total Loss: 24541.8818, Feature Loss: 18298.6335, Edge Loss: 0.0000, KL Loss: 6243.2490
# Epoch: 058, Total Loss: 28552.1826, Feature Loss: 22480.5932, Edge Loss: 0.0000, KL Loss: 6071.5900
# Epoch: 059, Total Loss: 21400.5649, Feature Loss: 15535.0239, Edge Loss: 0.0000, KL Loss: 5865.5404
# Epoch: 060, Total Loss: 38199.3887, Feature Loss: 32524.2510, Edge Loss: 0.0000, KL Loss: 5675.1390
# Epoch: 061, Total Loss: 36221.0917, Feature Loss: 30761.1084, Edge Loss: 0.0000, KL Loss: 5459.9845
# Epoch: 062, Total Loss: 14266.5457, Feature Loss: 9048.4395, Edge Loss: 0.0000, KL Loss: 5218.1065
# Epoch: 063, Total Loss: 21256.5374, Feature Loss: 16228.7750, Edge Loss: 0.0000, KL Loss: 5027.7622
# Epoch: 064, Total Loss: 39190.9703, Feature Loss: 34412.9425, Edge Loss: 0.0000, KL Loss: 4778.0281
# Epoch: 065, Total Loss: 27943.9193, Feature Loss: 23427.1182, Edge Loss: 0.0000, KL Loss: 4516.8004
# Epoch: 066, Total Loss: 41285.3334, Feature Loss: 36931.4787, Edge Loss: 0.0000, KL Loss: 4353.8541
# Epoch: 067, Total Loss: 18979.9494, Feature Loss: 14791.3799, Edge Loss: 0.0000, KL Loss: 4188.5702
# Epoch: 068, Total Loss: 14619.6649, Feature Loss: 10605.2218, Edge Loss: 0.0000, KL Loss: 4014.4430
# Epoch: 069, Total Loss: 18786.7470, Feature Loss: 14873.3178, Edge Loss: 0.0000, KL Loss: 3913.4295
# Epoch: 070, Total Loss: 54515.1755, Feature Loss: 50757.1329, Edge Loss: 0.0000, KL Loss: 3758.0419
# Epoch: 071, Total Loss: 10675.8078, Feature Loss: 6996.0334, Edge Loss: 0.0000, KL Loss: 3679.7747
# Epoch: 072, Total Loss: 18094.3244, Feature Loss: 14500.2028, Edge Loss: 0.0000, KL Loss: 3594.1220
# Epoch: 073, Total Loss: 12956.9442, Feature Loss: 9434.3102, Edge Loss: 0.0000, KL Loss: 3522.6346
# Epoch: 074, Total Loss: 34266.8739, Feature Loss: 30868.8122, Edge Loss: 0.0000, KL Loss: 3398.0617
# Epoch: 075, Total Loss: 9421.1990, Feature Loss: 6329.2838, Edge Loss: 0.0000, KL Loss: 3091.9155
# Epoch: 076, Total Loss: 13369.0751, Feature Loss: 10376.1214, Edge Loss: 0.0000, KL Loss: 2992.9540
# Epoch: 077, Total Loss: 27534.3902, Feature Loss: 24639.7366, Edge Loss: 0.0000, KL Loss: 2894.6536
# Epoch: 078, Total Loss: 8742.4996, Feature Loss: 5970.5507, Edge Loss: 0.0000, KL Loss: 2771.9489
# Epoch: 079, Total Loss: 14488.5670, Feature Loss: 11791.2192, Edge Loss: 0.0000, KL Loss: 2697.3483
# Epoch: 080, Total Loss: 13942.6899, Feature Loss: 11309.7772, Edge Loss: 0.0000, KL Loss: 2632.9127
# Epoch: 081, Total Loss: 24313.1888, Feature Loss: 21754.4628, Edge Loss: 0.0000, KL Loss: 2558.7256
# Epoch: 082, Total Loss: 7211.4068, Feature Loss: 4727.0589, Edge Loss: 0.0000, KL Loss: 2484.3476
# Epoch: 083, Total Loss: 14876.0710, Feature Loss: 12456.8012, Edge Loss: 0.0000, KL Loss: 2419.2700
# Epoch: 084, Total Loss: 10377.7570, Feature Loss: 8070.0680, Edge Loss: 0.0000, KL Loss: 2307.6890
# Epoch: 085, Total Loss: 9410.1308, Feature Loss: 7170.1884, Edge Loss: 0.0000, KL Loss: 2239.9421
# Epoch: 086, Total Loss: 8287.4967, Feature Loss: 6152.4976, Edge Loss: 0.0000, KL Loss: 2134.9989
# Epoch: 087, Total Loss: 8522.0933, Feature Loss: 6459.4229, Edge Loss: 0.0000, KL Loss: 2062.6702
# Epoch: 088, Total Loss: 7045.3156, Feature Loss: 5052.4952, Edge Loss: 0.0000, KL Loss: 1992.8207
# Epoch: 089, Total Loss: 23786.2972, Feature Loss: 21853.2145, Edge Loss: 0.0000, KL Loss: 1933.0838
# Epoch: 090, Total Loss: 7815.9379, Feature Loss: 5984.3616, Edge Loss: 0.0000, KL Loss: 1831.5761
# Epoch: 091, Total Loss: 6208.4259, Feature Loss: 4448.9340, Edge Loss: 0.0000, KL Loss: 1759.4921
# Epoch: 092, Total Loss: 4928.8002, Feature Loss: 3222.7856, Edge Loss: 0.0000, KL Loss: 1706.0144
# Epoch: 093, Total Loss: 5503.1433, Feature Loss: 3842.6607, Edge Loss: 0.0000, KL Loss: 1660.4823
# Epoch: 094, Total Loss: 29506.1569, Feature Loss: 27893.1713, Edge Loss: 0.0000, KL Loss: 1612.9856
# Epoch: 095, Total Loss: 11568.8906, Feature Loss: 10011.4115, Edge Loss: 0.0000, KL Loss: 1557.4791
# Epoch: 096, Total Loss: 7212.4608, Feature Loss: 5694.9242, Edge Loss: 0.0000, KL Loss: 1517.5367
# Epoch: 097, Total Loss: 6649.8249, Feature Loss: 5181.6836, Edge Loss: 0.0000, KL Loss: 1468.1411
# Epoch: 098, Total Loss: 6193.9983, Feature Loss: 4782.0028, Edge Loss: 0.0000, KL Loss: 1411.9953
# Epoch: 099, Total Loss: 6009.0867, Feature Loss: 4632.4495, Edge Loss: 0.0000, KL Loss: 1376.6374
# Epoch: 100, Total Loss: 17576.7893, Feature Loss: 16240.4329, Edge Loss: 0.0000, KL Loss: 1336.3563
# Epoch: 101, Total Loss: 16027.4370, Feature Loss: 14725.7992, Edge Loss: 0.0000, KL Loss: 1301.6376
# Epoch: 102, Total Loss: 19090.1432, Feature Loss: 17811.6739, Edge Loss: 0.0000, KL Loss: 1278.4698
# Epoch: 103, Total Loss: 4792.3231, Feature Loss: 3538.7182, Edge Loss: 0.0000, KL Loss: 1253.6051
# Epoch: 104, Total Loss: 18124.1693, Feature Loss: 16896.7049, Edge Loss: 0.0000, KL Loss: 1227.4645
# Epoch: 105, Total Loss: 5843.9756, Feature Loss: 4644.0512, Edge Loss: 0.0000, KL Loss: 1199.9243
# Epoch: 106, Total Loss: 5562.8125, Feature Loss: 4393.4595, Edge Loss: 0.0000, KL Loss: 1169.3530
# Epoch: 107, Total Loss: 4756.2788, Feature Loss: 3619.1322, Edge Loss: 0.0000, KL Loss: 1137.1464
# Epoch: 108, Total Loss: 6110.8078, Feature Loss: 4996.8007, Edge Loss: 0.0000, KL Loss: 1114.0070
# Epoch: 109, Total Loss: 3950.4792, Feature Loss: 2865.1777, Edge Loss: 0.0000, KL Loss: 1085.3016
# Epoch: 110, Total Loss: 6787.1913, Feature Loss: 5722.8926, Edge Loss: 0.0000, KL Loss: 1064.2985
# Epoch: 111, Total Loss: 4143.0454, Feature Loss: 3101.3631, Edge Loss: 0.0000, KL Loss: 1041.6822
# Epoch: 112, Total Loss: 8125.4585, Feature Loss: 7102.1515, Edge Loss: 0.0000, KL Loss: 1023.3068
# Epoch: 113, Total Loss: 22468.5475, Feature Loss: 21470.8811, Edge Loss: 0.0000, KL Loss: 997.6669
# Epoch: 114, Total Loss: 7348.2837, Feature Loss: 6369.9395, Edge Loss: 0.0000, KL Loss: 978.3444
# Epoch: 115, Total Loss: 3799.6172, Feature Loss: 2846.0615, Edge Loss: 0.0000, KL Loss: 953.5558
# Epoch: 116, Total Loss: 7804.6117, Feature Loss: 6866.2269, Edge Loss: 0.0000, KL Loss: 938.3849
# Epoch: 117, Total Loss: 9787.4069, Feature Loss: 8864.7207, Edge Loss: 0.0000, KL Loss: 922.6862
# Epoch: 118, Total Loss: 6095.7096, Feature Loss: 5194.5974, Edge Loss: 0.0000, KL Loss: 901.1121
# Epoch: 119, Total Loss: 9519.3309, Feature Loss: 8633.0943, Edge Loss: 0.0000, KL Loss: 886.2367
# Epoch: 120, Total Loss: 19770.6492, Feature Loss: 18905.7284, Edge Loss: 0.0000, KL Loss: 864.9208
# Epoch: 121, Total Loss: 3329.5206, Feature Loss: 2478.0415, Edge Loss: 0.0000, KL Loss: 851.4789
# Epoch: 122, Total Loss: 3034.5040, Feature Loss: 2194.4004, Edge Loss: 0.0000, KL Loss: 840.1035
# Epoch: 123, Total Loss: 11493.9863, Feature Loss: 10670.2525, Edge Loss: 0.0000, KL Loss: 823.7339
# Epoch: 124, Total Loss: 3491.6680, Feature Loss: 2688.1125, Edge Loss: 0.0000, KL Loss: 803.5554
# Epoch: 125, Total Loss: 5413.9983, Feature Loss: 4624.6488, Edge Loss: 0.0000, KL Loss: 789.3493
# Epoch: 126, Total Loss: 2010.3956, Feature Loss: 1231.7048, Edge Loss: 0.0000, KL Loss: 778.6908
# Epoch: 127, Total Loss: 2703.7636, Feature Loss: 1935.1899, Edge Loss: 0.0000, KL Loss: 768.5739
# Epoch: 128, Total Loss: 1751.4784, Feature Loss: 995.6501, Edge Loss: 0.0000, KL Loss: 755.8283
# Epoch: 129, Total Loss: 12603.9499, Feature Loss: 11856.7971, Edge Loss: 0.0000, KL Loss: 747.1536
# Epoch: 130, Total Loss: 3676.8929, Feature Loss: 2940.9864, Edge Loss: 0.0000, KL Loss: 735.9066
# Epoch: 131, Total Loss: 2727.5783, Feature Loss: 2002.0644, Edge Loss: 0.0000, KL Loss: 725.5139
# Epoch: 132, Total Loss: 5726.0975, Feature Loss: 5011.6861, Edge Loss: 0.0000, KL Loss: 714.4112
# Epoch: 133, Total Loss: 4136.5845, Feature Loss: 3434.2353, Edge Loss: 0.0000, KL Loss: 702.3492
# Epoch: 134, Total Loss: 3050.9748, Feature Loss: 2360.9343, Edge Loss: 0.0000, KL Loss: 690.0405
# Epoch: 135, Total Loss: 2007.6742, Feature Loss: 1332.8937, Edge Loss: 0.0000, KL Loss: 674.7805
# Epoch: 136, Total Loss: 2567.5654, Feature Loss: 1903.4368, Edge Loss: 0.0000, KL Loss: 664.1286
# Epoch: 137, Total Loss: 2118.9644, Feature Loss: 1464.5347, Edge Loss: 0.0000, KL Loss: 654.4297
# Epoch: 138, Total Loss: 10012.4010, Feature Loss: 9367.3700, Edge Loss: 0.0000, KL Loss: 645.0310
# Epoch: 139, Total Loss: 6965.9992, Feature Loss: 6333.0951, Edge Loss: 0.0000, KL Loss: 632.9040
# Epoch: 140, Total Loss: 6528.1421, Feature Loss: 5951.6687, Edge Loss: 0.0000, KL Loss: 576.4731
# Epoch: 141, Total Loss: 2020.0864, Feature Loss: 1489.7299, Edge Loss: 0.0000, KL Loss: 530.3565
# Epoch: 142, Total Loss: 6837.5172, Feature Loss: 6319.6020, Edge Loss: 0.0000, KL Loss: 517.9152
# Epoch: 143, Total Loss: 3860.9859, Feature Loss: 3382.3818, Edge Loss: 0.0000, KL Loss: 478.6043
# Epoch: 144, Total Loss: 22019.5942, Feature Loss: 21563.7065, Edge Loss: 0.0000, KL Loss: 455.8871
# Epoch: 145, Total Loss: 6784.6413, Feature Loss: 6414.1882, Edge Loss: 0.0000, KL Loss: 370.4532
# Epoch: 146, Total Loss: 14524.1001, Feature Loss: 14179.8989, Edge Loss: 0.0000, KL Loss: 344.2008
# Epoch: 147, Total Loss: 2221.6500, Feature Loss: 1917.7382, Edge Loss: 0.0000, KL Loss: 303.9118
# Epoch: 148, Total Loss: 780.3944, Feature Loss: 484.1714, Edge Loss: 0.0000, KL Loss: 296.2230
# Epoch: 149, Total Loss: 2601.6987, Feature Loss: 2307.7405, Edge Loss: 0.0000, KL Loss: 293.9582
# Epoch: 150, Total Loss: 8929.3575, Feature Loss: 8641.8322, Edge Loss: 0.0000, KL Loss: 287.5253
# Epoch: 151, Total Loss: 6822.7378, Feature Loss: 6556.1449, Edge Loss: 0.0000, KL Loss: 266.5931
# Epoch: 152, Total Loss: 3667.3523, Feature Loss: 3416.5320, Edge Loss: 0.0000, KL Loss: 250.8203
# Epoch: 153, Total Loss: 1071.7022, Feature Loss: 828.8495, Edge Loss: 0.0000, KL Loss: 242.8527
# Epoch: 154, Total Loss: 1364.8208, Feature Loss: 1124.5501, Edge Loss: 0.0000, KL Loss: 240.2708
# Epoch: 155, Total Loss: 756.4076, Feature Loss: 518.9796, Edge Loss: 0.0000, KL Loss: 237.4279
# Epoch: 156, Total Loss: 910.0291, Feature Loss: 674.2249, Edge Loss: 0.0000, KL Loss: 235.8042
# Epoch: 157, Total Loss: 1210.0248, Feature Loss: 976.0750, Edge Loss: 0.0000, KL Loss: 233.9498
# Epoch: 158, Total Loss: 1704.9404, Feature Loss: 1473.5056, Edge Loss: 0.0000, KL Loss: 231.4349
# Epoch: 159, Total Loss: 813.4816, Feature Loss: 585.5599, Edge Loss: 0.0000, KL Loss: 227.9217
# Epoch: 160, Total Loss: 1683.5860, Feature Loss: 1457.4623, Edge Loss: 0.0000, KL Loss: 226.1237
# Epoch: 161, Total Loss: 811.2694, Feature Loss: 588.6319, Edge Loss: 0.0000, KL Loss: 222.6374
# Epoch: 162, Total Loss: 638.0395, Feature Loss: 417.1604, Edge Loss: 0.0000, KL Loss: 220.8791
# Epoch: 163, Total Loss: 839.2982, Feature Loss: 619.7470, Edge Loss: 0.0000, KL Loss: 219.5511
# Epoch: 164, Total Loss: 776.0583, Feature Loss: 558.1816, Edge Loss: 0.0000, KL Loss: 217.8767
# Epoch: 165, Total Loss: 830.3607, Feature Loss: 614.1554, Edge Loss: 0.0000, KL Loss: 216.2052
# Epoch: 166, Total Loss: 605.9190, Feature Loss: 391.4927, Edge Loss: 0.0000, KL Loss: 214.4264
# Epoch: 167, Total Loss: 1168.1073, Feature Loss: 954.9943, Edge Loss: 0.0000, KL Loss: 213.1130
# Epoch: 168, Total Loss: 1141.3422, Feature Loss: 930.6544, Edge Loss: 0.0000, KL Loss: 210.6878
# Epoch: 169, Total Loss: 1328.8095, Feature Loss: 1120.5122, Edge Loss: 0.0000, KL Loss: 208.2972
# Epoch: 170, Total Loss: 1125.1123, Feature Loss: 919.5396, Edge Loss: 0.0000, KL Loss: 205.5727
# Epoch: 171, Total Loss: 3096.7620, Feature Loss: 2893.7264, Edge Loss: 0.0000, KL Loss: 203.0357
# Epoch: 172, Total Loss: 2350.7440, Feature Loss: 2154.1708, Edge Loss: 0.0000, KL Loss: 196.5732
# Epoch: 173, Total Loss: 1738.6514, Feature Loss: 1547.1912, Edge Loss: 0.0000, KL Loss: 191.4603
# Epoch: 174, Total Loss: 1774.4071, Feature Loss: 1586.6328, Edge Loss: 0.0000, KL Loss: 187.7743
# Epoch: 175, Total Loss: 638.7830, Feature Loss: 454.6766, Edge Loss: 0.0000, KL Loss: 184.1064
# Epoch: 176, Total Loss: 757.0289, Feature Loss: 574.3641, Edge Loss: 0.0000, KL Loss: 182.6647
# Epoch: 177, Total Loss: 1105.1468, Feature Loss: 923.9937, Edge Loss: 0.0000, KL Loss: 181.1531
# Epoch: 178, Total Loss: 784.5615, Feature Loss: 605.6666, Edge Loss: 0.0000, KL Loss: 178.8948
# Epoch: 179, Total Loss: 427.4618, Feature Loss: 250.2474, Edge Loss: 0.0000, KL Loss: 177.2144
# Epoch: 180, Total Loss: 528.3662, Feature Loss: 352.0608, Edge Loss: 0.0000, KL Loss: 176.3055
# Epoch: 181, Total Loss: 1836.2194, Feature Loss: 1661.0008, Edge Loss: 0.0000, KL Loss: 175.2185
# Epoch: 182, Total Loss: 1472.0581, Feature Loss: 1300.5734, Edge Loss: 0.0000, KL Loss: 171.4846
# Epoch: 183, Total Loss: 490.6013, Feature Loss: 322.2038, Edge Loss: 0.0000, KL Loss: 168.3975
# Epoch: 184, Total Loss: 1587.8008, Feature Loss: 1420.5534, Edge Loss: 0.0000, KL Loss: 167.2473
# Epoch: 185, Total Loss: 2274.7842, Feature Loss: 2110.6195, Edge Loss: 0.0000, KL Loss: 164.1646
# Epoch: 186, Total Loss: 650.2577, Feature Loss: 490.6691, Edge Loss: 0.0000, KL Loss: 159.5886
# Epoch: 187, Total Loss: 1149.7830, Feature Loss: 991.7176, Edge Loss: 0.0000, KL Loss: 158.0653
# Epoch: 188, Total Loss: 2208.3993, Feature Loss: 2052.4737, Edge Loss: 0.0000, KL Loss: 155.9256
# Epoch: 189, Total Loss: 2782.0345, Feature Loss: 2630.4714, Edge Loss: 0.0000, KL Loss: 151.5631
# Epoch: 190, Total Loss: 522.0438, Feature Loss: 375.8950, Edge Loss: 0.0000, KL Loss: 146.1487
# Epoch: 191, Total Loss: 303.7390, Feature Loss: 158.8429, Edge Loss: 0.0000, KL Loss: 144.8961
# Epoch: 192, Total Loss: 1257.6814, Feature Loss: 1113.4124, Edge Loss: 0.0000, KL Loss: 144.2690
# Epoch: 193, Total Loss: 890.7478, Feature Loss: 748.7694, Edge Loss: 0.0000, KL Loss: 141.9785
# Epoch: 194, Total Loss: 1268.4557, Feature Loss: 1128.2332, Edge Loss: 0.0000, KL Loss: 140.2225
# Epoch: 195, Total Loss: 412.2960, Feature Loss: 274.4943, Edge Loss: 0.0000, KL Loss: 137.8018
# Epoch: 196, Total Loss: 1174.7859, Feature Loss: 1037.8839, Edge Loss: 0.0000, KL Loss: 136.9020
# Epoch: 197, Total Loss: 608.6426, Feature Loss: 473.9394, Edge Loss: 0.0000, KL Loss: 134.7032
# Epoch: 198, Total Loss: 429.8498, Feature Loss: 296.3554, Edge Loss: 0.0000, KL Loss: 133.4944
# Epoch: 199, Total Loss: 996.4159, Feature Loss: 863.7754, Edge Loss: 0.0000, KL Loss: 132.6405
# Epoch: 200, Total Loss: 710.9746, Feature Loss: 580.1777, Edge Loss: 0.0000, KL Loss: 130.7969
# Epoch: 201, Total Loss: 466.5393, Feature Loss: 337.0873, Edge Loss: 0.0000, KL Loss: 129.4520
# Epoch: 202, Total Loss: 555.6705, Feature Loss: 427.1348, Edge Loss: 0.0000, KL Loss: 128.5357
# Epoch: 203, Total Loss: 584.8787, Feature Loss: 457.4342, Edge Loss: 0.0000, KL Loss: 127.4445
# Epoch: 204, Total Loss: 548.4313, Feature Loss: 422.1133, Edge Loss: 0.0000, KL Loss: 126.3180
# Epoch: 205, Total Loss: 1058.8983, Feature Loss: 933.6705, Edge Loss: 0.0000, KL Loss: 125.2279
# Epoch: 206, Total Loss: 1140.4287, Feature Loss: 1017.1223, Edge Loss: 0.0000, KL Loss: 123.3064
# Epoch: 207, Total Loss: 504.5643, Feature Loss: 383.5042, Edge Loss: 0.0000, KL Loss: 121.0601
# Epoch: 208, Total Loss: 986.9997, Feature Loss: 867.0155, Edge Loss: 0.0000, KL Loss: 119.9842
# Epoch: 209, Total Loss: 246.2498, Feature Loss: 128.1612, Edge Loss: 0.0000, KL Loss: 118.0886
# Epoch: 210, Total Loss: 495.5825, Feature Loss: 378.0591, Edge Loss: 0.0000, KL Loss: 117.5233
# Epoch: 211, Total Loss: 830.1520, Feature Loss: 713.5420, Edge Loss: 0.0000, KL Loss: 116.6100
# Epoch: 212, Total Loss: 507.4638, Feature Loss: 392.3936, Edge Loss: 0.0000, KL Loss: 115.0702
# Epoch: 213, Total Loss: 408.8335, Feature Loss: 294.7797, Edge Loss: 0.0000, KL Loss: 114.0539
# Epoch: 214, Total Loss: 1418.3714, Feature Loss: 1305.1622, Edge Loss: 0.0000, KL Loss: 113.2093
# Epoch: 215, Total Loss: 1197.9504, Feature Loss: 1087.4508, Edge Loss: 0.0000, KL Loss: 110.4997
# Epoch: 216, Total Loss: 395.2243, Feature Loss: 287.0055, Edge Loss: 0.0000, KL Loss: 108.2188
# Epoch: 217, Total Loss: 278.0708, Feature Loss: 170.6996, Edge Loss: 0.0000, KL Loss: 107.3712
# Epoch: 218, Total Loss: 1398.9762, Feature Loss: 1292.1845, Edge Loss: 0.0000, KL Loss: 106.7917
# Epoch: 219, Total Loss: 1197.1222, Feature Loss: 1092.9426, Edge Loss: 0.0000, KL Loss: 104.1796
# Epoch: 220, Total Loss: 654.7776, Feature Loss: 552.7822, Edge Loss: 0.0000, KL Loss: 101.9954
# Epoch: 221, Total Loss: 891.7986, Feature Loss: 791.1106, Edge Loss: 0.0000, KL Loss: 100.6880
# Epoch: 222, Total Loss: 774.4443, Feature Loss: 675.4404, Edge Loss: 0.0000, KL Loss: 99.0040
# Epoch: 223, Total Loss: 393.0188, Feature Loss: 295.4932, Edge Loss: 0.0000, KL Loss: 97.5256
# Epoch: 224, Total Loss: 240.6354, Feature Loss: 143.8978, Edge Loss: 0.0000, KL Loss: 96.7376
# Epoch: 225, Total Loss: 297.2590, Feature Loss: 201.0057, Edge Loss: 0.0000, KL Loss: 96.2533
# Epoch: 226, Total Loss: 275.9775, Feature Loss: 180.2924, Edge Loss: 0.0000, KL Loss: 95.6851
# Epoch: 227, Total Loss: 373.4412, Feature Loss: 278.2811, Edge Loss: 0.0000, KL Loss: 95.1602
# Epoch: 228, Total Loss: 1229.9437, Feature Loss: 1135.5160, Edge Loss: 0.0000, KL Loss: 94.4277
# Epoch: 229, Total Loss: 230.7286, Feature Loss: 138.5438, Edge Loss: 0.0000, KL Loss: 92.1848
# Epoch: 230, Total Loss: 406.2235, Feature Loss: 314.6034, Edge Loss: 0.0000, KL Loss: 91.6201
# Epoch: 231, Total Loss: 483.7514, Feature Loss: 392.9003, Edge Loss: 0.0000, KL Loss: 90.8511
# Epoch: 232, Total Loss: 553.8002, Feature Loss: 463.8510, Edge Loss: 0.0000, KL Loss: 89.9493
# Epoch: 233, Total Loss: 320.5810, Feature Loss: 231.7050, Edge Loss: 0.0000, KL Loss: 88.8760
# Epoch: 234, Total Loss: 968.1274, Feature Loss: 879.9017, Edge Loss: 0.0000, KL Loss: 88.2257
# Epoch: 235, Total Loss: 924.5079, Feature Loss: 838.1195, Edge Loss: 0.0000, KL Loss: 86.3884
# Epoch: 236, Total Loss: 1155.2930, Feature Loss: 1070.7046, Edge Loss: 0.0000, KL Loss: 84.5884
# Epoch: 237, Total Loss: 682.9808, Feature Loss: 600.5885, Edge Loss: 0.0000, KL Loss: 82.3923
# Epoch: 238, Total Loss: 351.1521, Feature Loss: 270.1171, Edge Loss: 0.0000, KL Loss: 81.0350
# Epoch: 239, Total Loss: 339.2456, Feature Loss: 258.9159, Edge Loss: 0.0000, KL Loss: 80.3298
# Epoch: 240, Total Loss: 306.5707, Feature Loss: 226.8736, Edge Loss: 0.0000, KL Loss: 79.6971
# Epoch: 241, Total Loss: 342.6769, Feature Loss: 263.5628, Edge Loss: 0.0000, KL Loss: 79.1141
# Epoch: 242, Total Loss: 1495.6980, Feature Loss: 1417.2445, Edge Loss: 0.0000, KL Loss: 78.4535
# Epoch: 243, Total Loss: 348.9746, Feature Loss: 273.1716, Edge Loss: 0.0000, KL Loss: 75.8031
# Epoch: 244, Total Loss: 1706.2483, Feature Loss: 1631.2456, Edge Loss: 0.0000, KL Loss: 75.0028
# Epoch: 245, Total Loss: 333.8133, Feature Loss: 261.7841, Edge Loss: 0.0000, KL Loss: 72.0292
# Epoch: 246, Total Loss: 928.9914, Feature Loss: 857.7162, Edge Loss: 0.0000, KL Loss: 71.2752
# Epoch: 247, Total Loss: 579.0048, Feature Loss: 509.3354, Edge Loss: 0.0000, KL Loss: 69.6694
# Epoch: 248, Total Loss: 660.6000, Feature Loss: 591.9968, Edge Loss: 0.0000, KL Loss: 68.6032
# Epoch: 249, Total Loss: 406.8721, Feature Loss: 339.4284, Edge Loss: 0.0000, KL Loss: 67.4437
# Epoch: 250, Total Loss: 274.6511, Feature Loss: 207.9524, Edge Loss: 0.0000, KL Loss: 66.6988
# Epoch: 251, Total Loss: 607.3915, Feature Loss: 541.1990, Edge Loss: 0.0000, KL Loss: 66.1925
# Epoch: 252, Total Loss: 504.7427, Feature Loss: 439.5595, Edge Loss: 0.0000, KL Loss: 65.1832
# Epoch: 253, Total Loss: 279.6253, Feature Loss: 215.3392, Edge Loss: 0.0000, KL Loss: 64.2861
# Epoch: 254, Total Loss: 269.8137, Feature Loss: 206.0515, Edge Loss: 0.0000, KL Loss: 63.7621
# Epoch: 255, Total Loss: 174.6953, Feature Loss: 111.4185, Edge Loss: 0.0000, KL Loss: 63.2767
# Epoch: 256, Total Loss: 202.6866, Feature Loss: 139.7299, Edge Loss: 0.0000, KL Loss: 62.9567
# Epoch: 257, Total Loss: 196.6248, Feature Loss: 134.0344, Edge Loss: 0.0000, KL Loss: 62.5904
# Epoch: 258, Total Loss: 1563.7917, Feature Loss: 1501.5760, Edge Loss: 0.0000, KL Loss: 62.2157
# Epoch: 259, Total Loss: 366.2783, Feature Loss: 306.6609, Edge Loss: 0.0000, KL Loss: 59.6175
# Epoch: 260, Total Loss: 166.3858, Feature Loss: 107.5325, Edge Loss: 0.0000, KL Loss: 58.8532
# Epoch: 261, Total Loss: 532.8386, Feature Loss: 474.3169, Edge Loss: 0.0000, KL Loss: 58.5218
# Epoch: 262, Total Loss: 689.3831, Feature Loss: 631.7385, Edge Loss: 0.0000, KL Loss: 57.6446
# Epoch: 263, Total Loss: 179.7608, Feature Loss: 123.2799, Edge Loss: 0.0000, KL Loss: 56.4810
# Epoch: 264, Total Loss: 166.0435, Feature Loss: 109.9230, Edge Loss: 0.0000, KL Loss: 56.1205
# Epoch: 265, Total Loss: 150.9442, Feature Loss: 95.1208, Edge Loss: 0.0000, KL Loss: 55.8233
# Epoch: 266, Total Loss: 339.7070, Feature Loss: 284.1529, Edge Loss: 0.0000, KL Loss: 55.5542
# Epoch: 267, Total Loss: 351.6583, Feature Loss: 296.6887, Edge Loss: 0.0000, KL Loss: 54.9696
# Epoch: 268, Total Loss: 219.3269, Feature Loss: 164.9749, Edge Loss: 0.0000, KL Loss: 54.3520
# Epoch: 269, Total Loss: 294.0193, Feature Loss: 240.0767, Edge Loss: 0.0000, KL Loss: 53.9426
# Epoch: 270, Total Loss: 863.4325, Feature Loss: 810.0158, Edge Loss: 0.0000, KL Loss: 53.4166
# Epoch: 271, Total Loss: 250.2253, Feature Loss: 198.2140, Edge Loss: 0.0000, KL Loss: 52.0113
# Epoch: 272, Total Loss: 226.2821, Feature Loss: 174.7728, Edge Loss: 0.0000, KL Loss: 51.5093
# Epoch: 273, Total Loss: 143.7996, Feature Loss: 92.7081, Edge Loss: 0.0000, KL Loss: 51.0915
# Epoch: 274, Total Loss: 406.1579, Feature Loss: 355.3325, Edge Loss: 0.0000, KL Loss: 50.8253
# Epoch: 275, Total Loss: 384.4454, Feature Loss: 334.3157, Edge Loss: 0.0000, KL Loss: 50.1297
# Epoch: 276, Total Loss: 549.7192, Feature Loss: 500.2625, Edge Loss: 0.0000, KL Loss: 49.4567
# Epoch: 277, Total Loss: 250.5473, Feature Loss: 202.0373, Edge Loss: 0.0000, KL Loss: 48.5101
# Epoch: 278, Total Loss: 267.2509, Feature Loss: 219.2122, Edge Loss: 0.0000, KL Loss: 48.0387
# Epoch: 279, Total Loss: 215.9785, Feature Loss: 168.4036, Edge Loss: 0.0000, KL Loss: 47.5749
# Epoch: 280, Total Loss: 131.8633, Feature Loss: 84.6758, Edge Loss: 0.0000, KL Loss: 47.1875
# Epoch: 281, Total Loss: 174.0825, Feature Loss: 127.1419, Edge Loss: 0.0000, KL Loss: 46.9406
# Epoch: 282, Total Loss: 167.7362, Feature Loss: 121.1048, Edge Loss: 0.0000, KL Loss: 46.6314
# Epoch: 283, Total Loss: 506.7754, Feature Loss: 460.4528, Edge Loss: 0.0000, KL Loss: 46.3226
# Epoch: 284, Total Loss: 365.3143, Feature Loss: 319.8540, Edge Loss: 0.0000, KL Loss: 45.4603
# Epoch: 285, Total Loss: 1051.3953, Feature Loss: 1006.6116, Edge Loss: 0.0000, KL Loss: 44.7836
# Epoch: 286, Total Loss: 253.3560, Feature Loss: 210.3194, Edge Loss: 0.0000, KL Loss: 43.0366
# Epoch: 287, Total Loss: 334.0759, Feature Loss: 291.5624, Edge Loss: 0.0000, KL Loss: 42.5136
# Epoch: 288, Total Loss: 399.5639, Feature Loss: 357.6238, Edge Loss: 0.0000, KL Loss: 41.9401
# Epoch: 289, Total Loss: 587.2050, Feature Loss: 545.9526, Edge Loss: 0.0000, KL Loss: 41.2524
# Epoch: 290, Total Loss: 241.2500, Feature Loss: 200.9644, Edge Loss: 0.0000, KL Loss: 40.2857
# Epoch: 291, Total Loss: 466.2046, Feature Loss: 426.3660, Edge Loss: 0.0000, KL Loss: 39.8387
# Epoch: 292, Total Loss: 109.5678, Feature Loss: 70.4839, Edge Loss: 0.0000, KL Loss: 39.0839
# Epoch: 293, Total Loss: 108.4285, Feature Loss: 69.5684, Edge Loss: 0.0000, KL Loss: 38.8601
# Epoch: 294, Total Loss: 657.9821, Feature Loss: 619.3215, Edge Loss: 0.0000, KL Loss: 38.6606
# Epoch: 295, Total Loss: 97.6223, Feature Loss: 60.0028, Edge Loss: 0.0000, KL Loss: 37.6194
# Epoch: 296, Total Loss: 128.0642, Feature Loss: 90.6624, Edge Loss: 0.0000, KL Loss: 37.4018
# Epoch: 297, Total Loss: 156.2078, Feature Loss: 119.0256, Edge Loss: 0.0000, KL Loss: 37.1823
# Epoch: 298, Total Loss: 126.6388, Feature Loss: 89.7152, Edge Loss: 0.0000, KL Loss: 36.9236
# Epoch: 299, Total Loss: 365.2720, Feature Loss: 328.5684, Edge Loss: 0.0000, KL Loss: 36.7036
# Epoch: 300, Total Loss: 361.9925, Feature Loss: 325.8923, Edge Loss: 0.0000, KL Loss: 36.1002
# Epoch: 301, Total Loss: 171.9239, Feature Loss: 136.4333, Edge Loss: 0.0000, KL Loss: 35.4906
# Epoch: 302, Total Loss: 174.5025, Feature Loss: 139.3283, Edge Loss: 0.0000, KL Loss: 35.1741
# Epoch: 303, Total Loss: 281.9343, Feature Loss: 247.0602, Edge Loss: 0.0000, KL Loss: 34.8741
# Epoch: 304, Total Loss: 71.5982, Feature Loss: 37.1896, Edge Loss: 0.0000, KL Loss: 34.4086
# Epoch: 305, Total Loss: 68.4559, Feature Loss: 34.1902, Edge Loss: 0.0000, KL Loss: 34.2657
# Epoch: 306, Total Loss: 117.6521, Feature Loss: 83.5080, Edge Loss: 0.0000, KL Loss: 34.1440
# Epoch: 307, Total Loss: 243.8092, Feature Loss: 209.8646, Edge Loss: 0.0000, KL Loss: 33.9446
# Epoch: 308, Total Loss: 173.0234, Feature Loss: 139.4789, Edge Loss: 0.0000, KL Loss: 33.5445
# Epoch: 309, Total Loss: 85.9184, Feature Loss: 52.6863, Edge Loss: 0.0000, KL Loss: 33.2321
# Epoch: 310, Total Loss: 198.6769, Feature Loss: 165.6089, Edge Loss: 0.0000, KL Loss: 33.0679
# Epoch: 311, Total Loss: 185.3205, Feature Loss: 152.5848, Edge Loss: 0.0000, KL Loss: 32.7357
# Epoch: 312, Total Loss: 60.5322, Feature Loss: 28.1180, Edge Loss: 0.0000, KL Loss: 32.4142
# Epoch: 313, Total Loss: 281.5891, Feature Loss: 249.3001, Edge Loss: 0.0000, KL Loss: 32.2890
# Epoch: 314, Total Loss: 177.0114, Feature Loss: 145.2059, Edge Loss: 0.0000, KL Loss: 31.8055
# Epoch: 315, Total Loss: 118.0063, Feature Loss: 86.5293, Edge Loss: 0.0000, KL Loss: 31.4769
# Epoch: 316, Total Loss: 125.3759, Feature Loss: 94.1263, Edge Loss: 0.0000, KL Loss: 31.2496
# Epoch: 317, Total Loss: 347.2136, Feature Loss: 316.1954, Edge Loss: 0.0000, KL Loss: 31.0182
# Epoch: 318, Total Loss: 257.1731, Feature Loss: 226.7474, Edge Loss: 0.0000, KL Loss: 30.4257
# Epoch: 319, Total Loss: 61.4601, Feature Loss: 31.4937, Edge Loss: 0.0000, KL Loss: 29.9664
# Epoch: 320, Total Loss: 58.8633, Feature Loss: 29.0316, Edge Loss: 0.0000, KL Loss: 29.8317
# Epoch: 321, Total Loss: 253.0185, Feature Loss: 223.2971, Edge Loss: 0.0000, KL Loss: 29.7214
# Epoch: 322, Total Loss: 68.5451, Feature Loss: 39.2554, Edge Loss: 0.0000, KL Loss: 29.2897
# Epoch: 323, Total Loss: 290.7137, Feature Loss: 261.5749, Edge Loss: 0.0000, KL Loss: 29.1388
# Epoch: 324, Total Loss: 110.6408, Feature Loss: 82.0052, Edge Loss: 0.0000, KL Loss: 28.6356
# Epoch: 325, Total Loss: 166.9505, Feature Loss: 138.5356, Edge Loss: 0.0000, KL Loss: 28.4149
# Epoch: 326, Total Loss: 216.0450, Feature Loss: 187.9293, Edge Loss: 0.0000, KL Loss: 28.1158
# Epoch: 327, Total Loss: 139.4288, Feature Loss: 111.7007, Edge Loss: 0.0000, KL Loss: 27.7281
# Epoch: 328, Total Loss: 272.6123, Feature Loss: 245.1530, Edge Loss: 0.0000, KL Loss: 27.4593
# Epoch: 329, Total Loss: 84.2363, Feature Loss: 57.2551, Edge Loss: 0.0000, KL Loss: 26.9812
# Epoch: 330, Total Loss: 92.5877, Feature Loss: 65.7859, Edge Loss: 0.0000, KL Loss: 26.8018
# Epoch: 331, Total Loss: 153.9875, Feature Loss: 127.3579, Edge Loss: 0.0000, KL Loss: 26.6297
# Epoch: 332, Total Loss: 179.8987, Feature Loss: 153.5482, Edge Loss: 0.0000, KL Loss: 26.3505
# Epoch: 333, Total Loss: 84.2742, Feature Loss: 58.2487, Edge Loss: 0.0000, KL Loss: 26.0254
# Epoch: 334, Total Loss: 83.4871, Feature Loss: 57.6297, Edge Loss: 0.0000, KL Loss: 25.8574
# Epoch: 335, Total Loss: 54.6629, Feature Loss: 28.9670, Edge Loss: 0.0000, KL Loss: 25.6959
# Epoch: 336, Total Loss: 76.0441, Feature Loss: 50.4539, Edge Loss: 0.0000, KL Loss: 25.5902
# Epoch: 337, Total Loss: 363.4783, Feature Loss: 338.0339, Edge Loss: 0.0000, KL Loss: 25.4444
# Epoch: 338, Total Loss: 358.1327, Feature Loss: 333.3326, Edge Loss: 0.0000, KL Loss: 24.8000
# Epoch: 339, Total Loss: 381.7027, Feature Loss: 357.5577, Edge Loss: 0.0000, KL Loss: 24.1450
# Epoch: 340, Total Loss: 149.5534, Feature Loss: 126.0858, Edge Loss: 0.0000, KL Loss: 23.4675
# Epoch: 341, Total Loss: 126.3364, Feature Loss: 103.1641, Edge Loss: 0.0000, KL Loss: 23.1723
# Epoch: 342, Total Loss: 175.7687, Feature Loss: 152.8267, Edge Loss: 0.0000, KL Loss: 22.9420
# Epoch: 343, Total Loss: 88.4813, Feature Loss: 65.8480, Edge Loss: 0.0000, KL Loss: 22.6333
# Epoch: 344, Total Loss: 144.6601, Feature Loss: 122.1895, Edge Loss: 0.0000, KL Loss: 22.4706
# Epoch: 345, Total Loss: 92.9520, Feature Loss: 70.7336, Edge Loss: 0.0000, KL Loss: 22.2184
# Epoch: 346, Total Loss: 84.9447, Feature Loss: 62.8982, Edge Loss: 0.0000, KL Loss: 22.0465
# Epoch: 347, Total Loss: 45.8590, Feature Loss: 23.9698, Edge Loss: 0.0000, KL Loss: 21.8892
# Epoch: 348, Total Loss: 249.7377, Feature Loss: 227.9414, Edge Loss: 0.0000, KL Loss: 21.7963
# Epoch: 349, Total Loss: 45.2542, Feature Loss: 23.8878, Edge Loss: 0.0000, KL Loss: 21.3664
# Epoch: 350, Total Loss: 63.0057, Feature Loss: 41.7471, Edge Loss: 0.0000, KL Loss: 21.2587
# Epoch: 351, Total Loss: 128.3734, Feature Loss: 107.2322, Edge Loss: 0.0000, KL Loss: 21.1412
# Epoch: 352, Total Loss: 105.2864, Feature Loss: 84.3704, Edge Loss: 0.0000, KL Loss: 20.9159
# Epoch: 353, Total Loss: 58.2185, Feature Loss: 37.5016, Edge Loss: 0.0000, KL Loss: 20.7170
# Epoch: 354, Total Loss: 122.0069, Feature Loss: 101.4049, Edge Loss: 0.0000, KL Loss: 20.6021
# Epoch: 355, Total Loss: 73.9291, Feature Loss: 53.5461, Edge Loss: 0.0000, KL Loss: 20.3830
# Epoch: 356, Total Loss: 83.4698, Feature Loss: 63.2299, Edge Loss: 0.0000, KL Loss: 20.2399
# Epoch: 357, Total Loss: 49.3296, Feature Loss: 29.2471, Edge Loss: 0.0000, KL Loss: 20.0825
# Epoch: 358, Total Loss: 72.7744, Feature Loss: 52.7900, Edge Loss: 0.0000, KL Loss: 19.9844
# Epoch: 359, Total Loss: 47.3012, Feature Loss: 27.4534, Edge Loss: 0.0000, KL Loss: 19.8478
# Epoch: 360, Total Loss: 103.6239, Feature Loss: 83.8702, Edge Loss: 0.0000, KL Loss: 19.7537
# Epoch: 361, Total Loss: 94.6874, Feature Loss: 75.1231, Edge Loss: 0.0000, KL Loss: 19.5643
# Epoch: 362, Total Loss: 122.7905, Feature Loss: 103.4121, Edge Loss: 0.0000, KL Loss: 19.3785
# Epoch: 363, Total Loss: 153.8118, Feature Loss: 134.6695, Edge Loss: 0.0000, KL Loss: 19.1423
# Epoch: 364, Total Loss: 86.5147, Feature Loss: 67.6632, Edge Loss: 0.0000, KL Loss: 18.8514
# Epoch: 365, Total Loss: 439.6686, Feature Loss: 420.9988, Edge Loss: 0.0000, KL Loss: 18.6698
# Epoch: 366, Total Loss: 288.0738, Feature Loss: 270.1847, Edge Loss: 0.0000, KL Loss: 17.8891
# Epoch: 367, Total Loss: 81.1307, Feature Loss: 63.7748, Edge Loss: 0.0000, KL Loss: 17.3559
# Epoch: 368, Total Loss: 94.1296, Feature Loss: 76.9466, Edge Loss: 0.0000, KL Loss: 17.1830
# Epoch: 369, Total Loss: 112.3379, Feature Loss: 95.3254, Edge Loss: 0.0000, KL Loss: 17.0125
# Epoch: 370, Total Loss: 61.3603, Feature Loss: 44.5497, Edge Loss: 0.0000, KL Loss: 16.8106
# Epoch: 371, Total Loss: 83.1818, Feature Loss: 66.4898, Edge Loss: 0.0000, KL Loss: 16.6919
# Epoch: 372, Total Loss: 38.5260, Feature Loss: 21.9836, Edge Loss: 0.0000, KL Loss: 16.5424
# Epoch: 373, Total Loss: 103.2190, Feature Loss: 86.7567, Edge Loss: 0.0000, KL Loss: 16.4624
# Epoch: 374, Total Loss: 61.8754, Feature Loss: 45.6008, Edge Loss: 0.0000, KL Loss: 16.2746
# Epoch: 375, Total Loss: 147.0364, Feature Loss: 130.8889, Edge Loss: 0.0000, KL Loss: 16.1475
# Epoch: 376, Total Loss: 136.4063, Feature Loss: 120.5226, Edge Loss: 0.0000, KL Loss: 15.8838
# Epoch: 377, Total Loss: 83.1269, Feature Loss: 67.4971, Edge Loss: 0.0000, KL Loss: 15.6298
# Epoch: 378, Total Loss: 35.4926, Feature Loss: 20.0253, Edge Loss: 0.0000, KL Loss: 15.4673
# Epoch: 379, Total Loss: 49.7126, Feature Loss: 34.3192, Edge Loss: 0.0000, KL Loss: 15.3934
# Epoch: 380, Total Loss: 33.2326, Feature Loss: 17.9319, Edge Loss: 0.0000, KL Loss: 15.3007
# Epoch: 381, Total Loss: 112.4302, Feature Loss: 97.1949, Edge Loss: 0.0000, KL Loss: 15.2353
# Epoch: 382, Total Loss: 59.3203, Feature Loss: 44.2876, Edge Loss: 0.0000, KL Loss: 15.0328
# Epoch: 383, Total Loss: 136.2843, Feature Loss: 121.3714, Edge Loss: 0.0000, KL Loss: 14.9129
# Epoch: 384, Total Loss: 63.0355, Feature Loss: 48.3649, Edge Loss: 0.0000, KL Loss: 14.6706
# Epoch: 385, Total Loss: 34.1242, Feature Loss: 19.5818, Edge Loss: 0.0000, KL Loss: 14.5424
# Epoch: 386, Total Loss: 93.4440, Feature Loss: 78.9710, Edge Loss: 0.0000, KL Loss: 14.4729
# Epoch: 387, Total Loss: 40.6001, Feature Loss: 26.2972, Edge Loss: 0.0000, KL Loss: 14.3029
# Epoch: 388, Total Loss: 26.4555, Feature Loss: 12.2351, Edge Loss: 0.0000, KL Loss: 14.2204
# Epoch: 389, Total Loss: 42.3922, Feature Loss: 28.2245, Edge Loss: 0.0000, KL Loss: 14.1677
# Epoch: 390, Total Loss: 48.1552, Feature Loss: 34.0678, Edge Loss: 0.0000, KL Loss: 14.0875
# Epoch: 391, Total Loss: 51.7625, Feature Loss: 37.7671, Edge Loss: 0.0000, KL Loss: 13.9954
# Epoch: 392, Total Loss: 33.9353, Feature Loss: 20.0386, Edge Loss: 0.0000, KL Loss: 13.8967
# Epoch: 393, Total Loss: 79.9043, Feature Loss: 66.0765, Edge Loss: 0.0000, KL Loss: 13.8278
# Epoch: 394, Total Loss: 61.4359, Feature Loss: 47.7618, Edge Loss: 0.0000, KL Loss: 13.6741
# Epoch: 395, Total Loss: 33.6498, Feature Loss: 20.1007, Edge Loss: 0.0000, KL Loss: 13.5491
# Epoch: 396, Total Loss: 37.4050, Feature Loss: 23.9253, Edge Loss: 0.0000, KL Loss: 13.4797
# Epoch: 397, Total Loss: 38.7841, Feature Loss: 25.3795, Edge Loss: 0.0000, KL Loss: 13.4047
# Epoch: 398, Total Loss: 135.0152, Feature Loss: 121.6906, Edge Loss: 0.0000, KL Loss: 13.3246
# Epoch: 399, Total Loss: 175.4790, Feature Loss: 162.4143, Edge Loss: 0.0000, KL Loss: 13.0647
# Epoch: 400, Total Loss: 37.7006, Feature Loss: 24.9796, Edge Loss: 0.0000, KL Loss: 12.7210
# Epoch: 401, Total Loss: 146.1003, Feature Loss: 133.4732, Edge Loss: 0.0000, KL Loss: 12.6271
# Epoch: 402, Total Loss: 35.3464, Feature Loss: 22.9883, Edge Loss: 0.0000, KL Loss: 12.3581
# Epoch: 403, Total Loss: 32.2178, Feature Loss: 19.9430, Edge Loss: 0.0000, KL Loss: 12.2748
# Epoch: 404, Total Loss: 60.8451, Feature Loss: 48.6364, Edge Loss: 0.0000, KL Loss: 12.2087
# Epoch: 405, Total Loss: 34.0762, Feature Loss: 21.9844, Edge Loss: 0.0000, KL Loss: 12.0918
# Epoch: 406, Total Loss: 168.1753, Feature Loss: 156.1579, Edge Loss: 0.0000, KL Loss: 12.0174
# Epoch: 407, Total Loss: 57.3750, Feature Loss: 45.6659, Edge Loss: 0.0000, KL Loss: 11.7091
# Epoch: 408, Total Loss: 136.3268, Feature Loss: 124.7444, Edge Loss: 0.0000, KL Loss: 11.5824
# Epoch: 409, Total Loss: 100.4746, Feature Loss: 89.1496, Edge Loss: 0.0000, KL Loss: 11.3251
# Epoch: 410, Total Loss: 44.6238, Feature Loss: 33.4991, Edge Loss: 0.0000, KL Loss: 11.1247
# Epoch: 411, Total Loss: 50.3232, Feature Loss: 39.2931, Edge Loss: 0.0000, KL Loss: 11.0301
# Epoch: 412, Total Loss: 83.2907, Feature Loss: 72.3586, Edge Loss: 0.0000, KL Loss: 10.9321
# Epoch: 413, Total Loss: 26.2428, Feature Loss: 15.4704, Edge Loss: 0.0000, KL Loss: 10.7724
# Epoch: 414, Total Loss: 70.9535, Feature Loss: 60.2385, Edge Loss: 0.0000, KL Loss: 10.7150
# Epoch: 415, Total Loss: 103.8939, Feature Loss: 93.3151, Edge Loss: 0.0000, KL Loss: 10.5789
# Epoch: 416, Total Loss: 65.1348, Feature Loss: 54.7531, Edge Loss: 0.0000, KL Loss: 10.3818
# Epoch: 417, Total Loss: 54.6344, Feature Loss: 44.3820, Edge Loss: 0.0000, KL Loss: 10.2524
# Epoch: 418, Total Loss: 49.6809, Feature Loss: 39.5376, Edge Loss: 0.0000, KL Loss: 10.1433
# Epoch: 419, Total Loss: 41.0790, Feature Loss: 31.0336, Edge Loss: 0.0000, KL Loss: 10.0455
# Epoch: 420, Total Loss: 28.6404, Feature Loss: 18.6766, Edge Loss: 0.0000, KL Loss: 9.9639
# Epoch: 421, Total Loss: 82.9714, Feature Loss: 73.0663, Edge Loss: 0.0000, KL Loss: 9.9051
# Epoch: 422, Total Loss: 34.1034, Feature Loss: 24.3545, Edge Loss: 0.0000, KL Loss: 9.7489
# Epoch: 423, Total Loss: 39.2342, Feature Loss: 29.5576, Edge Loss: 0.0000, KL Loss: 9.6766
# Epoch: 424, Total Loss: 106.0644, Feature Loss: 96.4668, Edge Loss: 0.0000, KL Loss: 9.5977
# Epoch: 425, Total Loss: 31.8408, Feature Loss: 22.4420, Edge Loss: 0.0000, KL Loss: 9.3987
# Epoch: 426, Total Loss: 34.4667, Feature Loss: 25.1387, Edge Loss: 0.0000, KL Loss: 9.3280
# Epoch: 427, Total Loss: 63.2400, Feature Loss: 53.9819, Edge Loss: 0.0000, KL Loss: 9.2581
# Epoch: 428, Total Loss: 27.6009, Feature Loss: 18.4609, Edge Loss: 0.0000, KL Loss: 9.1400
# Epoch: 429, Total Loss: 43.8748, Feature Loss: 34.7952, Edge Loss: 0.0000, KL Loss: 9.0797
# Epoch: 430, Total Loss: 24.9806, Feature Loss: 15.9854, Edge Loss: 0.0000, KL Loss: 8.9952
# Epoch: 431, Total Loss: 21.1366, Feature Loss: 12.1947, Edge Loss: 0.0000, KL Loss: 8.9419
# Epoch: 432, Total Loss: 75.9181, Feature Loss: 67.0192, Edge Loss: 0.0000, KL Loss: 8.8988
# Epoch: 433, Total Loss: 50.7344, Feature Loss: 41.9822, Edge Loss: 0.0000, KL Loss: 8.7521
# Epoch: 434, Total Loss: 35.9256, Feature Loss: 27.2784, Edge Loss: 0.0000, KL Loss: 8.6472
# Epoch: 435, Total Loss: 19.4485, Feature Loss: 10.8740, Edge Loss: 0.0000, KL Loss: 8.5745
# Epoch: 436, Total Loss: 91.6507, Feature Loss: 83.1188, Edge Loss: 0.0000, KL Loss: 8.5319
# Epoch: 437, Total Loss: 31.5982, Feature Loss: 23.2417, Edge Loss: 0.0000, KL Loss: 8.3565
# Epoch: 438, Total Loss: 51.7251, Feature Loss: 43.4394, Edge Loss: 0.0000, KL Loss: 8.2857
# Epoch: 439, Total Loss: 25.4118, Feature Loss: 17.2291, Edge Loss: 0.0000, KL Loss: 8.1827
# Epoch: 440, Total Loss: 50.0499, Feature Loss: 41.9228, Edge Loss: 0.0000, KL Loss: 8.1271
# Epoch: 441, Total Loss: 25.0308, Feature Loss: 17.0023, Edge Loss: 0.0000, KL Loss: 8.0285
# Epoch: 442, Total Loss: 42.9542, Feature Loss: 34.9801, Edge Loss: 0.0000, KL Loss: 7.9740
# Epoch: 443, Total Loss: 21.7940, Feature Loss: 13.9037, Edge Loss: 0.0000, KL Loss: 7.8904
# Epoch: 444, Total Loss: 30.7825, Feature Loss: 22.9398, Edge Loss: 0.0000, KL Loss: 7.8428
# Epoch: 445, Total Loss: 28.0548, Feature Loss: 20.2735, Edge Loss: 0.0000, KL Loss: 7.7813
# Epoch: 446, Total Loss: 72.0839, Feature Loss: 64.3610, Edge Loss: 0.0000, KL Loss: 7.7228
# Epoch: 447, Total Loss: 25.6558, Feature Loss: 18.0771, Edge Loss: 0.0000, KL Loss: 7.5787
# Epoch: 448, Total Loss: 27.5763, Feature Loss: 20.0565, Edge Loss: 0.0000, KL Loss: 7.5198
# Epoch: 449, Total Loss: 43.5421, Feature Loss: 36.0796, Edge Loss: 0.0000, KL Loss: 7.4625
# Epoch: 450, Total Loss: 41.7401, Feature Loss: 34.3661, Edge Loss: 0.0000, KL Loss: 7.3740
# Epoch: 451, Total Loss: 19.7418, Feature Loss: 12.4537, Edge Loss: 0.0000, KL Loss: 7.2881
# Epoch: 452, Total Loss: 69.7191, Feature Loss: 62.4762, Edge Loss: 0.0000, KL Loss: 7.2429
# Epoch: 453, Total Loss: 95.8413, Feature Loss: 88.7372, Edge Loss: 0.0000, KL Loss: 7.1040
# Epoch: 454, Total Loss: 20.2006, Feature Loss: 13.2874, Edge Loss: 0.0000, KL Loss: 6.9132
# Epoch: 455, Total Loss: 47.4735, Feature Loss: 40.6105, Edge Loss: 0.0000, KL Loss: 6.8630
# Epoch: 456, Total Loss: 24.9503, Feature Loss: 18.1808, Edge Loss: 0.0000, KL Loss: 6.7695
# Epoch: 457, Total Loss: 28.8048, Feature Loss: 22.0896, Edge Loss: 0.0000, KL Loss: 6.7152
# Epoch: 458, Total Loss: 46.9464, Feature Loss: 40.2904, Edge Loss: 0.0000, KL Loss: 6.6560
# Epoch: 459, Total Loss: 26.8960, Feature Loss: 20.3334, Edge Loss: 0.0000, KL Loss: 6.5626
# Epoch: 460, Total Loss: 21.8133, Feature Loss: 15.3087, Edge Loss: 0.0000, KL Loss: 6.5046
# Epoch: 461, Total Loss: 20.1080, Feature Loss: 13.6482, Edge Loss: 0.0000, KL Loss: 6.4598
# Epoch: 462, Total Loss: 32.5219, Feature Loss: 26.1064, Edge Loss: 0.0000, KL Loss: 6.4155
# Epoch: 463, Total Loss: 46.9567, Feature Loss: 40.6065, Edge Loss: 0.0000, KL Loss: 6.3503
# Epoch: 464, Total Loss: 13.9162, Feature Loss: 7.6590, Edge Loss: 0.0000, KL Loss: 6.2572
# Epoch: 465, Total Loss: 30.6886, Feature Loss: 24.4639, Edge Loss: 0.0000, KL Loss: 6.2247
# Epoch: 466, Total Loss: 16.1389, Feature Loss: 9.9761, Edge Loss: 0.0000, KL Loss: 6.1628
# Epoch: 467, Total Loss: 34.0739, Feature Loss: 27.9466, Edge Loss: 0.0000, KL Loss: 6.1272
# Epoch: 468, Total Loss: 17.1181, Feature Loss: 11.0601, Edge Loss: 0.0000, KL Loss: 6.0581
# Epoch: 469, Total Loss: 56.0048, Feature Loss: 49.9863, Edge Loss: 0.0000, KL Loss: 6.0186
# Epoch: 470, Total Loss: 15.6921, Feature Loss: 9.7842, Edge Loss: 0.0000, KL Loss: 5.9079
# Epoch: 471, Total Loss: 31.9382, Feature Loss: 26.0677, Edge Loss: 0.0000, KL Loss: 5.8705
# Epoch: 472, Total Loss: 17.3450, Feature Loss: 11.5408, Edge Loss: 0.0000, KL Loss: 5.8042
# Epoch: 473, Total Loss: 15.4824, Feature Loss: 9.7175, Edge Loss: 0.0000, KL Loss: 5.7649
# Epoch: 474, Total Loss: 17.8984, Feature Loss: 12.1683, Edge Loss: 0.0000, KL Loss: 5.7300
# Epoch: 475, Total Loss: 43.8379, Feature Loss: 38.1467, Edge Loss: 0.0000, KL Loss: 5.6912
# Epoch: 476, Total Loss: 9.7739, Feature Loss: 4.1732, Edge Loss: 0.0000, KL Loss: 5.6007
# Epoch: 477, Total Loss: 17.2130, Feature Loss: 11.6362, Edge Loss: 0.0000, KL Loss: 5.5767
# Epoch: 478, Total Loss: 17.9531, Feature Loss: 12.4131, Edge Loss: 0.0000, KL Loss: 5.5401
# Epoch: 479, Total Loss: 27.2564, Feature Loss: 21.7556, Edge Loss: 0.0000, KL Loss: 5.5009
# Epoch: 480, Total Loss: 36.5025, Feature Loss: 31.0602, Edge Loss: 0.0000, KL Loss: 5.4424
# Epoch: 481, Total Loss: 22.6324, Feature Loss: 17.2676, Edge Loss: 0.0000, KL Loss: 5.3648
# Epoch: 482, Total Loss: 11.0477, Feature Loss: 5.7342, Edge Loss: 0.0000, KL Loss: 5.3135
# Epoch: 483, Total Loss: 16.1386, Feature Loss: 10.8501, Edge Loss: 0.0000, KL Loss: 5.2885
# Epoch: 484, Total Loss: 15.5749, Feature Loss: 10.3213, Edge Loss: 0.0000, KL Loss: 5.2536
# Epoch: 485, Total Loss: 13.9893, Feature Loss: 8.7705, Edge Loss: 0.0000, KL Loss: 5.2188
# Epoch: 486, Total Loss: 18.6214, Feature Loss: 13.4345, Edge Loss: 0.0000, KL Loss: 5.1869
# Epoch: 487, Total Loss: 22.4670, Feature Loss: 17.3207, Edge Loss: 0.0000, KL Loss: 5.1463
# Epoch: 488, Total Loss: 33.1527, Feature Loss: 28.0565, Edge Loss: 0.0000, KL Loss: 5.0962
# Epoch: 489, Total Loss: 13.2766, Feature Loss: 8.2546, Edge Loss: 0.0000, KL Loss: 5.0220
# Epoch: 490, Total Loss: 20.4064, Feature Loss: 15.4172, Edge Loss: 0.0000, KL Loss: 4.9892
# Epoch: 491, Total Loss: 21.8536, Feature Loss: 16.9089, Edge Loss: 0.0000, KL Loss: 4.9447
# Epoch: 492, Total Loss: 12.4678, Feature Loss: 7.5716, Edge Loss: 0.0000, KL Loss: 4.8961
# Epoch: 493, Total Loss: 15.4988, Feature Loss: 10.6320, Edge Loss: 0.0000, KL Loss: 4.8669
# Epoch: 494, Total Loss: 13.3972, Feature Loss: 8.5664, Edge Loss: 0.0000, KL Loss: 4.8307
# Epoch: 495, Total Loss: 14.5708, Feature Loss: 9.7694, Edge Loss: 0.0000, KL Loss: 4.8014
# Epoch: 496, Total Loss: 25.8196, Feature Loss: 21.0512, Edge Loss: 0.0000, KL Loss: 4.7683
# Epoch: 497, Total Loss: 26.6275, Feature Loss: 21.9170, Edge Loss: 0.0000, KL Loss: 4.7105
# Epoch: 498, Total Loss: 49.7181, Feature Loss: 45.0704, Edge Loss: 0.0000, KL Loss: 4.6478
# Epoch: 499, Total Loss: 28.9285, Feature Loss: 24.3928, Edge Loss: 0.0000, KL Loss: 4.5357
# Epoch: 500, Total Loss: 10.5271, Feature Loss: 6.0597, Edge Loss: 0.0000, KL Loss: 4.4675

# %%
plt.figure(figsize=(10, 5))
plt.plot(total_losses, label='Total Loss')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure(figsize=(8, 5))
plt.plot(feature_losses, label='Feature Loss')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from typing import Optional, Tuple

import torch
from torch import Tensor
from torch.nn import Module

from torch_geometric.nn.inits import reset
from torch_geometric.utils import negative_sampling

EPS = 1e-15
MAX_LOGSTD = 10


class InnerProductDecoder(torch.nn.Module):
    r"""The inner product decoder from the `"Variational Graph Auto-Encoders"
    <https://arxiv.org/abs/1611.07308>`_ paper

    .. math::
        \sigma(\mathbf{Z}\mathbf{Z}^{\top})

    where :math:`\mathbf{Z} \in \mathbb{R}^{N \times d}` denotes the latent
    space produced by the encoder."""

    def forward(self, z: Tensor, edge_index: Tensor,
                sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into edge probabilities for
        the given node-pairs :obj:`edge_index`.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            edge_index (torch.Tensor): The edge indices.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        value = (z[edge_index[0]] * z[edge_index[1]]).sum(dim=1)
        return torch.sigmoid(value) if sigmoid else value

    def forward_all(self, z: Tensor, sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into a probabilistic dense
        adjacency matrix.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        adj = torch.matmul(z, z.t())
        return torch.sigmoid(adj) if sigmoid else adj


class GAE(torch.nn.Module):
    r"""The Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper based on user-defined encoder and decoder models.

    Args:
        encoder (torch.nn.Module): The encoder module.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super(GAE, self).__init__()
        self.encoder = encoder
        self.decoder = InnerProductDecoder() if decoder is None else decoder
        self.reset_parameters()

    def reset_parameters(self):
        r"""Resets all learnable parameters of the module."""
        reset(self.encoder)
        reset(self.decoder)

    def forward(self, *args, **kwargs) -> Tensor:
        r"""Alias for :meth:`encode`."""
        return self.encode(*args, **kwargs)

    def encode(self, *args, **kwargs) -> Tensor:
        r"""Runs the encoder and computes node-wise latent variables."""
        return self.encoder(*args, **kwargs)

    def decode(self, *args, **kwargs) -> Tensor:
        r"""Runs the decoder and computes edge probabilities."""
        return self.decoder(*args, **kwargs)

    def recon_loss(self, z: Tensor, pos_edge_index: Tensor,
                   neg_edge_index: Tensor) -> Tensor:
        r"""Computes the reconstruction loss for positive and negative edges."""
        pos_loss = -torch.log(
            self.decoder(z, pos_edge_index, sigmoid=True) + EPS).mean()
        neg_loss = -torch.log(
            1 - self.decoder(z, neg_edge_index, sigmoid=True) + EPS).mean()
        return pos_loss + neg_loss

    def __repr__(self) -> str:
        return '{}(\n\tencoder={},\n\tdecoder={}\n)'.format(
            self.__class__.__name__, self.encoder, self.decoder)


class GCNEncoder(torch.nn.Module):
    def __init__(self, in_channels: int, hidden_channels: int, out_channels: int):
        super(GCNEncoder, self).__init__()
        self.conv1 = torch_geometric.nn.GCNConv(in_channels, hidden_channels)
        self.conv2 = torch_geometric.nn.GCNConv(hidden_channels, out_channels)
        self.reset_parameters()

    def reset_parameters(self):
        reset(self.conv1)
        reset(self.conv2)

    def forward(self, x: Tensor, edge_index: Tensor) -> Tensor:
        x = torch.relu(self.conv1(x, edge_index))
        x = self.conv2(x, edge_index)
        return x


def train(model: Module, data: Tuple[Tensor, Tensor],
          optimizer: torch.optim.Optimizer):
    model.train()
    optimizer.zero_grad()
    z = model.encode(data.x, data.edge_index)
    loss = model.recon_loss(z, data.train_pos_edge_index,
                            data.train_neg_edge_index)
    loss.backward()
    optimizer.step()


def test(model: Module, data: Tuple[Tensor, Tensor]):
    model.eval()
    with torch.no_grad():
        z = model.encode(data.x, data.edge_index)
    auc_scores = []
    ap_scores = []
    for prefix in ["val", "test"]:
        pos_edge_index = data[f'{prefix}_pos_edge_index']
        neg_edge_index = data[f'{prefix}_neg_edge_index']
        y_pred = model.decode(z, pos_edge_index, sigmoid=True)
        y_true = torch.cat(
            [torch.ones(pos_edge_index.size(1)), torch.zeros(neg_edge_index.size(1))],
            dim=0).to(y_pred.device)
        auc_scores.append(roc_auc_score(y_true, y_pred.detach()))
        ap_scores.append(average_precision_score(y_true, y_pred.detach()))
    return auc_scores, ap_scores
