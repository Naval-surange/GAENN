# %%
import mdtraj as md
from ase import Atoms
from nglview import show_ase
import networkx as nx

import torch
import torch_geometric.transforms as T
from torch_geometric.loader import DataLoader
from torch_geometric.nn import GCNConv, SAGPooling, InnerProductDecoder
import torch_geometric.data as data
from torch_geometric.utils.convert import to_networkx

import numpy as np
import matplotlib.pyplot as plt

# %%
all_frames = md.load_xtc("../simulation/npt.xtc", top="../simulation/box.gro")

# %%
all_frames_fatures = []

for i in range(all_frames.xyz.shape[0]):
    mol_com_pos = []

    for res in all_frames.top.residues:
        # print(res.index,end=" ")
        pos = []
        for atom in res.atoms:
            # print(atom.index,"-->" , frame.xyz[0][atom.index],end=" ")
            pos.append(all_frames.xyz[i][atom.index])
        mol_com_pos.append(np.mean(pos,axis=0))
        
        # print()
    mol_com_pos = np.array(mol_com_pos).astype(np.float32)  
    all_frames_fatures.append(mol_com_pos)

all_frames_fatures = np.array(all_frames_fatures).astype(np.float32)
print(all_frames_fatures.shape)
# Out:
# (51, 101, 3)

# %%
print(dir(all_frames.topology.residue(0)))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_atoms', 'atom', 'atoms', 'atoms_by_name', 'chain', 'code', 'index', 'is_nucleic', 'is_protein', 'is_water', 'n_atoms', 'name', 'resSeq', 'segment_id']

# %%
n_frames = all_frames.xyz.shape[0]
n_atoms = all_frames.topology.residue(0).n_atoms
n_mols = all_frames.topology.n_residues

# %%
# %matplotlib widget

frame = 10

fig = plt.figure(figsize=(5,4))
ax1 = fig.add_subplot(projection='3d')
ax1.scatter(all_frames_fatures[frame][:,0],all_frames_fatures[frame][:,1],all_frames_fatures[frame][:,2])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def convert_to_adj(edge_index, num_nodes=None):
    if num_nodes is None:
        num_nodes = edge_index.max() + 1
    adj = torch.zeros(num_nodes, num_nodes)
    adj[edge_index[0], edge_index[1]] = 1
    return adj

def convert_to_edge_index(adj):
    edge_index = adj.nonzero().t()
    return edge_index

# %%
cutoff = 0.5

all_edge_list = []
for frame_i in range(n_frames):
    from_list = []
    to_list = []

    for i in range(len(all_frames_fatures[frame_i])):
        for j in range(i+1,len(all_frames_fatures[frame_i])):
            if np.linalg.norm(all_frames_fatures[frame_i][i]-all_frames_fatures[frame_i][j]) < cutoff:
                # print(i,j,np.linalg.norm(mol_com_pos[i]-mol_com_pos[j]))
                from_list.append(i)
                to_list.append(j)

                to_list.append(i)
                from_list.append(j)

    edge_list = np.array([from_list,to_list]).astype(np.int64)
    all_edge_list.append(edge_list)

print(len(all_edge_list))
# Out:
# 51

# %%
# %matplotlib widget

frame = 10

plt.figure(figsize=(10,10))
adj_binary = convert_to_adj(all_edge_list[frame], num_nodes=101)
indices = torch.where(adj_binary)
G = nx.Graph()
edges = [(i, j) for i, j in zip(indices[0].tolist(), indices[1].tolist()) if i != j]
G.add_edges_from(edges)
nx.draw_networkx(G)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
graphs = []
for frame in range(n_frames):
    g = data.Data(x=torch.tensor(all_frames_fatures[frame]).float(), edge_index=torch.tensor(all_edge_list[frame]).long(), y=torch.tensor([0]))
    graphs.append(g)

print(graphs[0])
# Out:
# Data(x=[101, 3], edge_index=[2, 1158], y=[1])

# %%
graphs
# Out:
# [Data(x=[101, 3], edge_index=[2, 1158], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1182], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1092], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1144], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1132], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1114], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1128], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1094], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1082], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1156], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1098], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1106], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1050], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1038], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 988], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1062], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1066], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1052], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1038], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1106], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1134], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1122], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1092], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1080], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1010], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1052], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1084], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1126], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1034], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1042], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1062], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1008], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1126], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1110], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1092], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1106], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1070], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1038], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1068], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1098], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1080], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1056], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1052], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1046], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1072], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1044], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1112], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1052], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1088], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1136], y=[1]),
#  Data(x=[101, 3], edge_index=[2, 1020], y=[1])]

# %%
from typing import Optional, Tuple

import torch
from torch import Tensor
from torch.nn import Module

from torch_geometric.nn.inits import reset
from torch_geometric.utils import negative_sampling

EPS = 1e-15
MAX_LOGSTD = 10


class InnerProductDecoder(torch.nn.Module):
    r"""The inner product decoder from the `"Variational Graph Auto-Encoders"
    <https://arxiv.org/abs/1611.07308>`_ paper

    .. math::
        \sigma(\mathbf{Z}\mathbf{Z}^{\top})

    where :math:`\mathbf{Z} \in \mathbb{R}^{N \times d}` denotes the latent
    space produced by the encoder."""

    def forward(self, z: Tensor, edge_index: Tensor,
                sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into edge probabilities for
        the given node-pairs :obj:`edge_index`.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        value = (z[edge_index[0]] * z[edge_index[1]]).sum(dim=1)
        return torch.sigmoid(value) if sigmoid else value

    def forward_all(self, z: Tensor, sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into a probabilistic dense
        adjacency matrix.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        adj = torch.matmul(z, z.t())
        return torch.sigmoid(adj) if sigmoid else adj


class GAE(torch.nn.Module):
    r"""The Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper based on user-defined encoder and decoder models.

    Args:
        encoder (torch.nn.Module): The encoder module.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__()
        self.encoder = encoder
        self.decoder = InnerProductDecoder() if decoder is None else decoder
        GAE.reset_parameters(self)

    def reset_parameters(self):
        r"""Resets all learnable parameters of the module."""
        reset(self.encoder)
        reset(self.decoder)

    def forward(self, *args, **kwargs) -> Tensor:  # pragma: no cover
        r"""Alias for :meth:`encode`."""
        return self.encoder(*args, **kwargs)

    def encode(self, *args, **kwargs) -> Tensor:
        r"""Runs the encoder and computes node-wise latent variables."""
        return self.encoder(*args, **kwargs)

    def decode(self, *args, **kwargs) -> Tensor:
        r"""Runs the decoder and computes edge probabilities."""
        return self.decoder(*args, **kwargs)

    def recon_loss(self, z: Tensor, pos_edge_index: Tensor,
                   neg_edge_index: Optional[Tensor] = None) -> Tensor:
        r"""Given latent variables :obj:`z`, computes the binary cross
        entropy loss for positive edges :obj:`pos_edge_index` and negative
        sampled edges.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to train against.
            neg_edge_index (torch.Tensor, optional): The negative edges to
                train against. If not given, uses negative sampling to
                calculate negative edges. (default: :obj:`None`)
        """
        pos_loss = -torch.log(
            self.decoder(z, pos_edge_index, sigmoid=True)[0] + EPS).mean()

        if neg_edge_index is None:
            neg_edge_index = negative_sampling(pos_edge_index, z.size(0))
        neg_loss = -torch.log(1 -
                              self.decoder(z, neg_edge_index.long(), sigmoid=True)[0] +
                              EPS).mean()

        return pos_loss + neg_loss

    def test(self, z: Tensor, pos_edge_index: Tensor,
             neg_edge_index: Tensor) -> Tuple[Tensor, Tensor]:
        r"""Given latent variables :obj:`z`, positive edges
        :obj:`pos_edge_index` and negative edges :obj:`neg_edge_index`,
        computes area under the ROC curve (AUC) and average precision (AP)
        
        scores.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to evaluate
                against.
            neg_edge_index (torch.Tensor): The negative edges to evaluate
                against.
        """
        from sklearn.metrics import average_precision_score, roc_auc_score

        pos_y = z.new_ones(pos_edge_index.size(1))
        neg_y = z.new_zeros(neg_edge_index.size(1))
        y = torch.cat([pos_y, neg_y], dim=0)

        pos_pred = self.decoder(z, pos_edge_index, sigmoid=True)
        neg_pred = self.decoder(z, neg_edge_index, sigmoid=True)
        pred = torch.cat([pos_pred, neg_pred], dim=0)

        y, pred = y.detach().cpu().numpy(), pred.detach().cpu().numpy()

        return roc_auc_score(y, pred), average_precision_score(y, pred)


class VGAE(GAE):
    r"""The Variational Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper.

    Args:
        encoder (torch.nn.Module): The encoder module to compute :math:`\mu`
            and :math:`\log\sigma^2`.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__(encoder, decoder)

    def reparametrize(self, mu: Tensor, logstd: Tensor) -> Tensor:
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu

    def encode(self, *args, **kwargs) -> Tensor:
        """"""
        self.__mu__, self.__logstd__, self.edge_index = self.encoder(
            *args, **kwargs)
        self.__logstd__ = self.__logstd__.clamp(max=MAX_LOGSTD)
        z = self.reparametrize(self.__mu__, self.__logstd__)
        return z, self.edge_index

    def kl_loss(self, mu: Optional[Tensor] = None,
                logstd: Optional[Tensor] = None) -> Tensor:
        r"""Computes the KL loss, either for the passed arguments :obj:`mu`
        and :obj:`logstd`, or based on latent variables from last encoding.

        Args:
            mu (torch.Tensor, optional): The latent space for :math:`\mu`. If
                set to :obj:`None`, uses the last computation of :math:`\mu`.
                (default: :obj:`None`)
            logstd (torch.Tensor, optional): The latent space for
                :math:`\log\sigma`.  If set to :obj:`None`, uses the last
                computation of :math:`\log\sigma^2`. (default: :obj:`None`)
        """
        mu = self.__mu__ if mu is None else mu
        logstd = self.__logstd__ if logstd is None else logstd.clamp(
            max=MAX_LOGSTD)
        return -0.5 * torch.mean(
            torch.sum(1 + 2 * logstd - mu**2 - logstd.exp()**2, dim=1))

# %% [markdown]
# checkpoint-1

# %% [markdown]
# import torch.nn.functional as F
# from torch_geometric.nn import global_mean_pool, global_add_pool, avg_pool, max_pool, global_max_pool
#
#
# class VariationalGCNEncoder(torch.nn.Module):
#     def __init__(self, in_channels, out_channels, pool_ratio):
#         super().__init__()
#         self.conv1 = GCNConv(in_channels, 2 * out_channels)
#         self.conv2 = GCNConv(2 * out_channels, 1 * out_channels)
#         self.conv_mu = GCNConv(1 * out_channels, out_channels)
#         self.conv_logstd = GCNConv(1 * out_channels, out_channels)
#         self.pool_ratio = pool_ratio
#
#     def forward(self, x, edge_index, batch):
#         x = self.conv1(x, edge_index)
#         x = F.silu(x)
#         x = self.conv2(x, edge_index)
#         x = F.silu(x)
#
#         # Pooling
#         x_pooled = global_mean_pool(x, batch=batch)
#         edge_index, batch = self.pool_edges(edge_index, batch, self.pool_ratio)
#
#         return self.conv_mu(x_pooled, edge_index), self.conv_logstd(x_pooled, edge_index), edge_index, batch
#
#     def pool_edges(self, edge_index, batch, pool_ratio):
#         num_nodes = batch[-1].item() + 1
#         num_graphs = batch[-1].item() + 1
#         edge_index, edge_attr = dropout_adj(edge_index, edge_attr=None, p=1 - pool_ratio, force_undirected=False,
#                                             num_nodes=num_nodes, training=self.training)
#         batch = batch.repeat_interleave(pool_ratio)
#         edge_index, edge_attr, _ = add_self_loops(edge_index, edge_weight=edge_attr, fill_value=1,
#                                                   num_nodes=num_nodes)
#         return edge_index, batch
#
#
# class VariationalGCNDecoder(torch.nn.Module):
#     def __init__(self, in_channels, out_channels, unpool_ratio):
#         super().__init__()
#         self.conv1 = GCNConv(in_channels, 2 * out_channels)
#         self.conv2 = GCNConv(2 * out_channels, 1 * out_channels)
#         self.unpool_ratio = unpool_ratio
#
#     def forward(self, x, edge_index, batch, sigmoid=True):
#         # Unpooling
#         x_unpooled = self.unpool_nodes(x, batch, self.unpool_ratio)
#
#         x = self.conv1(x_unpooled, edge_index)
#         x = F.silu(x)
#         x = self.conv2(x, edge_index)
#         x = F.silu(x)
#
#         return x, edge_index
#
#     def unpool_nodes(self, x, batch, unpool_ratio):
#         num_nodes = batch[-1].item() + 1
#         x = x.view(-1, unpool_ratio, x.size(1)).mean(dim=1)
#         batch = batch.view(-1, unpool_ratio)[:, 0]
#         return x, batch
#
#
# # Example usage:
# in_channels = graphs[0].num_features
# out_channels = 2
# lr = 1e-4
# n_epochs = 500
# batch_size = 2
# pool_ratio = 0.5
# unpool_ratio = 2
#
# model = VGAE(
#     VariationalGCNEncoder(in_channels, out_channels, pool_ratio),
#     VariationalGCNDecoder(out_channels, in_channels, unpool_ratio)
# )
# optimizer = torch.optim.Adam(model.parameters(), lr=lr)
#
# # Training loop
# for epoch in range(n_epochs):
#     # Forward pass
#     batch_vals = [data.y for data in graphs]
#     x_values = [data.x for data in graphs]
#     edge_index_values = [data.edge_index for data in graphs]
#     z, mu, logstd, edge_index, batch = model(graphs[0].x, graphs[0].edge_index,graphs[0].y)
#     reconstructed_x, _, _ = model.decode(z, edge_index, batch)
#
#     # Compute loss and perform backpropagation
#     loss = model.loss(reconstructed_x, graph.x, mu, logstd)
#     optimizer.zero_grad()
#     loss.backward()
#     optimizer.step()

# %% [markdown]
# import torch.nn.functional as F
# from torch_geometric.nn import GCNConv, global_mean_pool, dropout_adj
#
# class VariationalGCNEncoder(torch.nn.Module):
#     def __init__(self, in_channels, out_channels, pool_ratio):
#         super().__init__()
#         self.conv1 = GCNConv(in_channels, 2 * out_channels)
#         self.conv2 = GCNConv(2 * out_channels, 1 * out_channels)
#         self.conv_mu = GCNConv(1 * out_channels, out_channels)
#         self.conv_logstd = GCNConv(1 * out_channels, out_channels)
#         self.pool_ratio = pool_ratio
#
#     def forward(self, x, edge_index, batch):
#         x = self.conv1(x, edge_index)
#         x = F.silu(x)
#         x = self.conv2(x, edge_index)
#         x = F.silu(x)
#
#         # Pooling
#         x_pooled = global_mean_pool(x, batch=batch)
#         edge_index, _, _ = dropout_adj(edge_index, p=1 - self.pool_ratio, training=self.training)
#
#         return self.conv_mu(x_pooled, edge_index), self.conv_logstd(x_pooled, edge_index), edge_index, batch
#
#
# class VariationalGCNDecoder(torch.nn.Module):
#     def __init__(self, in_channels, out_channels, unpool_ratio):
#         super().__init__()
#         self.conv1 = GCNConv(in_channels, 2 * out_channels)
#         self.conv2 = GCNConv(2 * out_channels, 1 * out_channels)
#         self.unpool_ratio = unpool_ratio
#
#     def forward(self, x, edge_index, batch, sigmoid=True):
#         # Unpooling
#         x_unpooled = self.unpool_nodes(x, batch, self.unpool_ratio)
#
#         x = self.conv1(x_unpooled, edge_index)
#         x = F.silu(x)
#         x = self.conv2(x, edge_index)
#         x = F.silu(x)
#
#         return x, edge_index
#
#     def unpool_nodes(self, x, batch, unpool_ratio):
#         num_nodes = batch[-1].item() + 1
#         x = x.view(-1, unpool_ratio, x.size(1)).mean(dim=1)
#         batch = batch.view(-1, unpool_ratio)[:, 0]
#         return x, batch
#
#
# # Example usage:
# in_channels = graphs[0].num_features
# out_channels = 2
# lr = 1e-4
# n_epochs = 500
# batch_size = 2
# pool_ratio = 0.5
# unpool_ratio = 2
#
# model = VGAE(
#     VariationalGCNEncoder(in_channels, out_channels, pool_ratio),
#     VariationalGCNDecoder(out_channels, in_channels, unpool_ratio)
# )
# optimizer = torch.optim.Adam(model.parameters(), lr=lr)
#
# # Training loop
# for epoch in range(n_epochs):
#     # Forward pass
#     z, mu, logstd, edge_index, batch = model(graph.x, graph.edge_index, graph.batch)
#     reconstructed_x, _, _ = model.decode(z, edge_index, batch)
#
#     # Compute loss and perform backpropagation
#     loss = model.loss(reconstructed_x, graph.x, mu, logstd)
#     optimizer.zero_grad()
#     loss.backward()
#     optimizer.step()

# %%
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, global_mean_pool

class VariationalGCNEncoder(torch.nn.Module):
    def __init__(self, in_channels, out_channels, pool_ratio):
        super().__init__()
        self.conv1 = GCNConv(in_channels, 2 * out_channels)
        self.conv2 = GCNConv(2 * out_channels, 1 * out_channels)
        self.conv_mu = GCNConv(1 * out_channels, out_channels)
        self.conv_logstd = GCNConv(1 * out_channels, out_channels)
        self.pool_ratio = pool_ratio

        def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = F.silu(x)
        x = self.conv2(x, edge_index)
        x = F.silu(x)

        # Pooling
        x_pooled = global_mean_pool(x)  # Perform global mean pooling
        
        return self.conv_mu(x_pooled, edge_index), self.conv_logstd(x_pooled, edge_index), edge_index, batch


class VariationalGCNDecoder(torch.nn.Module):
    def __init__(self, in_channels, out_channels, unpool_ratio):
        super().__init__()
        self.conv1 = GCNConv(in_channels, 2 * out_channels)
        self.conv2 = GCNConv(2 * out_channels, 1 * out_channels)
        self.unpool_ratio = unpool_ratio

    def forward(self, x, edge_index, batch, sigmoid=True):
        # Unpooling
        x_unpooled = self.unpool_nodes(x, batch, self.unpool_ratio)

        x = self.conv1(x_unpooled, edge_index)
        x = F.silu(x)
        x = self.conv2(x, edge_index)
        x = F.silu(x)

        return x, edge_index

    def unpool_nodes(self, x, batch, unpool_ratio):
        num_nodes = batch[-1].item() + 1
        expanded_x = x.unsqueeze(1).repeat(1, unpool_ratio, 1)  # Repeat node features
        expanded_batch = batch.unsqueeze(1).repeat(1, unpool_ratio)  # Repeat batch indices
        expanded_batch = expanded_batch.view(-1)  # Flatten the batch indices
        return expanded_x, expanded_batch


# Example usage:
in_channels = graphs[0].num_features
out_channels = 2
lr = 1e-4
n_epochs = 500
batch_size = 2
pool_ratio = 0.5
unpool_ratio = 2

model = VGAE(
    VariationalGCNEncoder(in_channels, out_channels, pool_ratio),
    VariationalGCNDecoder(out_channels, in_channels, unpool_ratio)
)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# Training loop
for epoch in range(n_epochs):
    # Forward pass
    z, mu, logstd, edge_index, batch = model(graphs[0].x, graphs[0].edge_index, graphs[0].y)
    reconstructed_x, _, _ = model.decode(z, edge_index, batch)
    
    # Compute loss and perform backpropagation
    loss = model.loss(reconstructed_x, graph.x, mu, logstd)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[26], line 69
#      66 # Training loop
#      67 for epoch in range(n_epochs):
#      68     # Forward pass
# ---> 69     z, mu, logstd, edge_index, batch = model(graphs[0].x, graphs[0].edge_index, graphs[0].y)
#      70     reconstructed_x, _, _ = model.decode(z, edge_index, batch)
#      72     # Compute loss and perform backpropagation
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[12], line 78, in GAE.forward(self, *args, **kwargs)
#      76 def forward(self, *args, **kwargs) -> Tensor:  # pragma: no cover
#      77     r"""Alias for :meth:`encode`."""
# ---> 78     return self.encoder(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[26], line 22, in VariationalGCNEncoder.forward(self, x, edge_index, batch)
#      19 # Pooling
#      20 x_pooled = global_mean_pool(x, batch)  # Perform global mean pooling
# ---> 22 return self.conv_mu(x_pooled, edge_index), self.conv_logstd(x_pooled, edge_index), edge_index, batch
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/lib/python3.10/site-packages/torch_geometric/nn/conv/gcn_conv.py:210, in GCNConv.forward(self, x, edge_index, edge_weight)
#     208 cache = self._cached_edge_index
#     209 if cache is None:
# --> 210     edge_index, edge_weight = gcn_norm(  # yapf: disable
#     211         edge_index, edge_weight, x.size(self.node_dim),
#     212         self.improved, self.add_self_loops, self.flow, x.dtype)
#     213     if self.cached:
#     214         self._cached_edge_index = (edge_index, edge_weight)
#
# File ~/anaconda3/lib/python3.10/site-packages/torch_geometric/nn/conv/gcn_conv.py:100, in gcn_norm(edge_index, edge_weight, num_nodes, improved, add_self_loops, flow, dtype)
#      98 row, col = edge_index[0], edge_index[1]
#      99 idx = col if flow == 'source_to_target' else row
# --> 100 deg = scatter(edge_weight, idx, dim=0, dim_size=num_nodes, reduce='sum')
#     101 deg_inv_sqrt = deg.pow_(-0.5)
#     102 deg_inv_sqrt.masked_fill_(deg_inv_sqrt == float('inf'), 0)
#
# File ~/anaconda3/lib/python3.10/site-packages/torch_geometric/utils/scatter.py:74, in scatter(src, index, dim, dim_size, reduce)
#      72 if reduce == 'sum' or reduce == 'add':
#      73     index = broadcast(index, src, dim)
# ---> 74     return src.new_zeros(size).scatter_add_(dim, index, src)
#      76 if reduce == 'mean':
#      77     count = src.new_zeros(dim_size)
#
# RuntimeError: index 17 is out of bounds for dimension 0 with size 1

# %%
graphs[0]
# Out:
# Data(x=[101, 3], edge_index=[2, 1158], y=[1])
