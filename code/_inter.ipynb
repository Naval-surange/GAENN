# %%
import mdtraj as md
from ase import Atoms
import nglview as nv
import networkx as nx

import torch
import torch_geometric.transforms as T
from torch_geometric.loader import DataLoader
from torch_geometric.nn import GCNConv, SAGPooling, InnerProductDecoder
import torch_geometric.data as data
from torch_geometric.utils.convert import to_networkx

import numpy as np
import matplotlib.pyplot as plt

# %%
all_frames = md.load_xtc("../simulation/npt.xtc", top="../simulation/box.gro")

# %%
all_frames_fatures = []

for i in range(all_frames.xyz.shape[0]):
    mol_com_pos = []

    for res in all_frames.top.residues:
        # print(res.index,end=" ")
        pos = []
        for atom in res.atoms:
            # print(atom.index,"-->" , frame.xyz[0][atom.index],end=" ")
            pos.append(all_frames.xyz[i][atom.index])
        mol_com_pos.append(np.mean(pos,axis=0))
        
        # print()
    mol_com_pos = np.array(mol_com_pos).astype(np.float32)  
    all_frames_fatures.append(mol_com_pos)

all_frames_fatures = np.array(all_frames_fatures).astype(np.float32)
print(all_frames_fatures.shape)
# Out:
# (51, 101, 3)

# %%
print(dir(all_frames.topology.residue(0)))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_atoms', 'atom', 'atoms', 'atoms_by_name', 'chain', 'code', 'index', 'is_nucleic', 'is_protein', 'is_water', 'n_atoms', 'name', 'resSeq', 'segment_id']

# %%
n_frames = all_frames.xyz.shape[0]
n_atoms = all_frames.topology.residue(0).n_atoms
n_mols = all_frames.topology.n_residues

# %%
print("number of molecules",n_mols)
print("number of atoms in molecule",n_atoms)
print("number of frames",n_frames)
# Out:
# number of molecules 101
# number of atoms in molecule 4
# number of frames 51

# %%
# %matplotlib widget

frame = 10

fig = plt.figure(figsize=(15,4))
ax1 = fig.add_subplot(projection='3d')
ax1.scatter(all_frames_fatures[frame][:,0],all_frames_fatures[frame][:,1],all_frames_fatures[frame][:,2])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def convert_to_adj(edge_index, num_nodes=None):
    if num_nodes is None:
        num_nodes = edge_index.max() + 1
    adj = torch.zeros(num_nodes, num_nodes)
    adj[edge_index[0], edge_index[1]] = 1
    return adj

def convert_to_edge_index(adj):
    edge_index = adj.nonzero().t()
    return edge_index

# %%
cutoff = 0.5

all_edge_list = []
for frame_i in range(n_frames):
    from_list = []
    to_list = []

    for i in range(len(all_frames_fatures[frame_i])):
        for j in range(i+1,len(all_frames_fatures[frame_i])):
            if np.linalg.norm(all_frames_fatures[frame_i][i]-all_frames_fatures[frame_i][j]) < cutoff:
                # print(i,j,np.linalg.norm(mol_com_pos[i]-mol_com_pos[j]))
                from_list.append(i)
                to_list.append(j)

                to_list.append(i)
                from_list.append(j)

    edge_list = np.array([from_list,to_list]).astype(np.int64)
    all_edge_list.append(edge_list)

print(len(all_edge_list))
# Out:
# 51

# %%
# %matplotlib widget

frame = 10

plt.figure(figsize=(15,10))
adj_binary = convert_to_adj(all_edge_list[frame], num_nodes=101)
indices = torch.where(adj_binary)
G = nx.Graph()
edges = [(i, j) for i, j in zip(indices[0].tolist(), indices[1].tolist()) if i != j]
G.add_edges_from(edges)
nx.draw_networkx(G)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Converting to pytorch graph object

# %%
graphs = []
for frame in range(n_frames):
    g = data.Data(x=torch.tensor(all_frames_fatures[frame]).float(), edge_index=torch.tensor(all_edge_list[frame]).long(), y=torch.tensor([0]))
    graphs.append(g)

print(graphs[0])
# Out:
# Data(x=[101, 3], edge_index=[2, 1158], y=[1])

# %% [markdown]
# ## Model

# %%
from typing import Optional, Tuple

import torch
from torch import Tensor
from torch.nn import Module

from torch_geometric.nn.inits import reset
from torch_geometric.utils import negative_sampling

EPS = 1e-15
MAX_LOGSTD = 10
edgeShape = None
featureShape = None


class InnerProductDecoder(torch.nn.Module):
    r"""The inner product decoder from the `"Variational Graph Auto-Encoders"
    <https://arxiv.org/abs/1611.07308>`_ paper

    .. math::
        \sigma(\mathbf{Z}\mathbf{Z}^{\top})

    where :math:`\mathbf{Z} \in \mathbb{R}^{N \times d}` denotes the latent
    space produced by the encoder."""

    def forward(self, z: Tensor, edge_index: Tensor,
                sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into edge probabilities for
        the given node-pairs :obj:`edge_index`.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        value = (z[edge_index[0]] * z[edge_index[1]]).sum(dim=1)
        return torch.sigmoid(value) if sigmoid else value

    def forward_all(self, z: Tensor, sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into a probabilistic dense
        adjacency matrix.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        adj = torch.matmul(z, z.t())
        return torch.sigmoid(adj) if sigmoid else adj


class GAE(torch.nn.Module):
    r"""The Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper based on user-defined encoder and decoder models.

    Args:
        encoder (torch.nn.Module): The encoder module.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__()
        self.encoder = encoder
        self.decoder = InnerProductDecoder() if decoder is None else decoder
        GAE.reset_parameters(self)

    def reset_parameters(self):
        r"""Resets all learnable parameters of the module."""
        reset(self.encoder)
        reset(self.decoder)

    def forward(self, *args, **kwargs) -> Tensor:  # pragma: no cover
        r"""Alias for :meth:`encode`."""
        return self.encoder(*args, **kwargs)

    def encode(self, *args, **kwargs) -> Tensor:
        r"""Runs the encoder and computes node-wise latent variables."""
        return self.encoder(*args, **kwargs)

    def decode(self, *args, **kwargs) -> Tensor:
        r"""Runs the decoder and computes edge probabilities."""
        return self.decoder(*args, **kwargs)

    def recon_loss(self, z: Tensor, pos_edge_index: Tensor,
                   neg_edge_index: Optional[Tensor] = None) -> Tensor:
        r"""Given latent variables :obj:`z`, computes the binary cross
        entropy loss for positive edges :obj:`pos_edge_index` and negative
        sampled edges.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to train against.
            neg_edge_index (torch.Tensor, optional): The negative edges to
                train against. If not given, uses negative sampling to
                calculate negative edges. (default: :obj:`None`)
        """
        pos_loss = -torch.log(
            self.decoder(z, pos_edge_index, sigmoid=True)[0] + EPS).mean()

        if neg_edge_index is None:
            neg_edge_index = negative_sampling(pos_edge_index, z.size(0))
        neg_loss = -torch.log(1 -
                              self.decoder(z, neg_edge_index.long(), sigmoid=True)[0] +
                              EPS).mean()

        return pos_loss + neg_loss

    def test(self, z: Tensor, pos_edge_index: Tensor,
             neg_edge_index: Tensor) -> Tuple[Tensor, Tensor]:
        r"""Given latent variables :obj:`z`, positive edges
        :obj:`pos_edge_index` and negative edges :obj:`neg_edge_index`,
        computes area under the ROC curve (AUC) and average precision (AP)
        
        scores.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to evaluate
                against.
            neg_edge_index (torch.Tensor): The negative edges to evaluate
                against.
        """
        from sklearn.metrics import average_precision_score, roc_auc_score

        pos_y = z.new_ones(pos_edge_index.size(1))
        neg_y = z.new_zeros(neg_edge_index.size(1))
        y = torch.cat([pos_y, neg_y], dim=0)

        pos_pred = self.decoder(z, pos_edge_index, sigmoid=True)
        neg_pred = self.decoder(z, neg_edge_index, sigmoid=True)
        pred = torch.cat([pos_pred, neg_pred], dim=0)

        y, pred = y.detach().cpu().numpy(), pred.detach().cpu().numpy()

        return roc_auc_score(y, pred), average_precision_score(y, pred)


class VGAE(GAE):
    r"""The Variational Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper.

    Args:
        encoder (torch.nn.Module): The encoder module to compute :math:`\mu`
            and :math:`\log\sigma^2`.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__(encoder, decoder)

    def reparametrize(self, mu: Tensor, logstd: Tensor) -> Tensor:
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def encode(self, *args, **kwargs) -> Tensor:
        """"""
        self.__mu__, self.__logstd__, self.edge_index = self.encoder(
            *args, **kwargs)
        self.__logstd__ = self.__logstd__.clamp(max=MAX_LOGSTD)
        z = self.reparametrize(self.__mu__, self.__logstd__)
        return z, self.edge_index

    def kl_loss(self, mu: Optional[Tensor] = None,
                logstd: Optional[Tensor] = None) -> Tensor:
        r"""Computes the KL loss, either for the passed arguments :obj:`mu`
        and :obj:`logstd`, or based on latent variables from last encoding.

        Args:
            mu (torch.Tensor, optional): The latent space for :math:`\mu`. If
                set to :obj:`None`, uses the last computation of :math:`\mu`.
                (default: :obj:`None`)
            logstd (torch.Tensor, optional): The latent space for
                :math:`\log\sigma`.  If set to :obj:`None`, uses the last
                computation of :math:`\log\sigma^2`. (default: :obj:`None`)
        """
        mu = self.__mu__ if mu is None else mu
        logstd = self.__logstd__ if logstd is None else logstd.clamp(
            max=MAX_LOGSTD)
        return -0.5 * torch.mean(
            torch.sum(1 + 2 * logstd - mu**2 - logstd.exp()**2, dim=1))

# %%
def norm_g(g):
    degrees = torch.sum(g, 1)
    g = g / degrees
    return g


def top_k_graph(scores, g, h, k):
    num_nodes = g.shape[0]
    values, idx = torch.topk(scores, max(2, int(k*num_nodes)))
    new_h = h[idx, :]
    values = torch.unsqueeze(values, -1)
    new_h = torch.mul(new_h, values)
    un_g = g.bool().float()
    un_g = torch.matmul(un_g, un_g).bool().float()
    un_g = un_g[idx, :]
    un_g = un_g[:, idx]
    g = norm_g(un_g)
    return g, new_h, idx

class Pool(torch.nn.Module):

    def __init__(self, k, in_dim, p):
        super(Pool, self).__init__()
        self.k = k
        self.sigmoid = torch.nn.Sigmoid()
        self.proj = torch.nn.Linear(in_dim, 1)
        self.drop = torch.nn.Dropout(p=p) if p > 0 else torch.nn.Identity()

    def forward(self, g, h):
        Z = self.drop(h)
        weights = self.proj(Z).squeeze()
        scores = self.sigmoid(weights)
        return top_k_graph(scores, g, h, self.k)


class Unpool(torch.nn.Module):

    def __init__(self, *args):
        super(Unpool, self).__init__()

    def forward(self, h, edge_indices,factor=1):
        # add zeros to h factor times
        global featureShape
        h = torch.cat([h, torch.zeros(max(featureShape[0]- h.shape[0],0), h.shape[1]).to(h.device)], dim=0)
        return h

class Unpool2(torch.nn.Module):
    def __init__(self, *args):
        super(Unpool2, self).__init__()

    def forward(self, batch, unpool_ratio):
        num_nodes = batch[-1].item() + 1
        expanded_batch = batch.unsqueeze(1).repeat(1, unpool_ratio)  # Repeat batch indices
        expanded_batch = expanded_batch.view(-1)  # Flatten the batch indices
        return  expanded_batch

# %%
import torch.nn.functional as F



class VariationalGCNEncoder(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.conv1 = GCNConv(in_channels, 2 * out_channels)
        self.conv2 = GCNConv(2*out_channels, 1 * out_channels)
        self.conv_mu = GCNConv(1 * out_channels, out_channels)
        self.conv_logstd = GCNConv(1 * out_channels, out_channels)

    def forward(self, x, edge_index):
        global edgeShape, featureShape
        # print("input:",x.shape, edge_index.shape)
        x = self.conv1(x, edge_index)
        x = F.silu(x)
        # print("conv1:",x.shape, edge_index.shape)
        x = self.conv2(x, edge_index)
        x = F.silu(x)
        # print("conv2:",x.shape, edge_index.shape)
        
        return self.conv_mu(x, edge_index), self.conv_logstd(x, edge_index), edge_index

# %%
class VariationalGCNDecoder(torch.nn.Module):
    def __init__(self,in_channels,out_channels):
        super().__init__()
        self.conv1 = GCNConv(in_channels, 2 * out_channels)
        self.conv2 = GCNConv(2 * out_channels, 1 * out_channels)
    def forward(self, x, edge_index, sigmoid=True):
        global edgeShape, featureShape
        # print("input:",x.shape, edge_index.shape)
        x = self.conv1(x, edge_index)
        x = F.silu(x)
        # print("conv1:",x.shape, edge_index.shape)
        x = self.conv2(x, edge_index)
        x = F.silu(x)
        # print("conv2:",x.shape, edge_index.shape)
        return x, edge_index

# %%
import os
in_channels = graphs[0].num_features
out_channels = 2
lr = 1e-4
n_epochs = 500
batch_size=2
model_name = 'InterGVAE_large20.pt'
model_loaded=False
force_train=True
if os.path.exists("./models/"+model_name) and not force_train:
    model = torch.load("./models/"+model_name)
    model_loaded=True
else:
    model = VGAE(VariationalGCNEncoder(in_channels, out_channels),
                 VariationalGCNDecoder(out_channels, in_channels))
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %%
train_loader = DataLoader(graphs, batch_size=batch_size)

# %%
lossFxn = torch.nn.MSELoss()
def train():
    model.train()
    model.zero_grad()
    model.float()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0

    for data in train_loader:
        optimizer.zero_grad()
        z,encoded_edge_index = model.encode(data.x, data.edge_index)
        decoded_x, decoded_edge_index = model.decode(z, encoded_edge_index)

        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        loss = FeatureLoss + EdgeLoss
        loss = loss 

        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        kl_loss_all += float(model.kl_loss()/data.num_nodes)

        loss.backward()
        optimizer.step()

        

    return loss_all / len(train_loader.dataset), feature_loss_all / len(train_loader.dataset), edge_loss_all / len(train_loader.dataset), kl_loss_all / len(train_loader.dataset)

# %%
total_losses = []
feature_losses = []
edge_losses = []
kl_losses = []

for epoch in range(1, n_epochs + 1):
    total_loss, feature_loss, edge_loss, kl_loss = train()
    print(f'Epoch: {epoch:03d}, Total Loss: {total_loss:.4f}, Feature Loss: {feature_loss:.4f}, Edge Loss: {edge_loss:.4f}')
    total_losses.append(total_loss)
    feature_losses.append(feature_loss)
    edge_losses.append(edge_loss)
    kl_losses.append(kl_loss)
    
    

torch.save(model,"./models/"+model_name)
# Out:
# Epoch: 001, Total Loss: 3.1885, Feature Loss: 3.1885, Edge Loss: 0.0000
# Epoch: 002, Total Loss: 2.7301, Feature Loss: 2.7301, Edge Loss: 0.0000
# Epoch: 003, Total Loss: 2.9309, Feature Loss: 2.9309, Edge Loss: 0.0000
# Epoch: 004, Total Loss: 3.8834, Feature Loss: 3.8834, Edge Loss: 0.0000
# Epoch: 005, Total Loss: 3.4422, Feature Loss: 3.4422, Edge Loss: 0.0000
# Epoch: 006, Total Loss: 2.6203, Feature Loss: 2.6203, Edge Loss: 0.0000
# Epoch: 007, Total Loss: 2.9741, Feature Loss: 2.9741, Edge Loss: 0.0000
# Epoch: 008, Total Loss: 5.4616, Feature Loss: 5.4616, Edge Loss: 0.0000
# Epoch: 009, Total Loss: 3.0298, Feature Loss: 3.0298, Edge Loss: 0.0000
# Epoch: 010, Total Loss: 2.5364, Feature Loss: 2.5364, Edge Loss: 0.0000
# Epoch: 011, Total Loss: 2.4899, Feature Loss: 2.4899, Edge Loss: 0.0000
# Epoch: 012, Total Loss: 3.5832, Feature Loss: 3.5832, Edge Loss: 0.0000
# Epoch: 013, Total Loss: 2.6329, Feature Loss: 2.6329, Edge Loss: 0.0000
# Epoch: 014, Total Loss: 4.0476, Feature Loss: 4.0476, Edge Loss: 0.0000
# Epoch: 015, Total Loss: 3.9545, Feature Loss: 3.9545, Edge Loss: 0.0000
# Epoch: 016, Total Loss: 2.5907, Feature Loss: 2.5907, Edge Loss: 0.0000
# Epoch: 017, Total Loss: 3.1050, Feature Loss: 3.1050, Edge Loss: 0.0000
# Epoch: 018, Total Loss: 2.5293, Feature Loss: 2.5293, Edge Loss: 0.0000
# Epoch: 019, Total Loss: 2.5346, Feature Loss: 2.5346, Edge Loss: 0.0000
# Epoch: 020, Total Loss: 3.1864, Feature Loss: 3.1864, Edge Loss: 0.0000
# Epoch: 021, Total Loss: 2.5358, Feature Loss: 2.5358, Edge Loss: 0.0000
# Epoch: 022, Total Loss: 2.5651, Feature Loss: 2.5651, Edge Loss: 0.0000
# Epoch: 023, Total Loss: 3.6418, Feature Loss: 3.6418, Edge Loss: 0.0000
# Epoch: 024, Total Loss: 2.5258, Feature Loss: 2.5258, Edge Loss: 0.0000
# Epoch: 025, Total Loss: 2.5640, Feature Loss: 2.5640, Edge Loss: 0.0000
# Epoch: 026, Total Loss: 2.5490, Feature Loss: 2.5490, Edge Loss: 0.0000
# Epoch: 027, Total Loss: 2.9135, Feature Loss: 2.9135, Edge Loss: 0.0000
# Epoch: 028, Total Loss: 2.5117, Feature Loss: 2.5117, Edge Loss: 0.0000
# Epoch: 029, Total Loss: 2.6490, Feature Loss: 2.6490, Edge Loss: 0.0000
# Epoch: 030, Total Loss: 2.5100, Feature Loss: 2.5100, Edge Loss: 0.0000
# Epoch: 031, Total Loss: 2.5258, Feature Loss: 2.5258, Edge Loss: 0.0000
# Epoch: 032, Total Loss: 2.4880, Feature Loss: 2.4880, Edge Loss: 0.0000
# Epoch: 033, Total Loss: 2.9007, Feature Loss: 2.9007, Edge Loss: 0.0000
# Epoch: 034, Total Loss: 4.0634, Feature Loss: 4.0634, Edge Loss: 0.0000
# Epoch: 035, Total Loss: 3.5764, Feature Loss: 3.5764, Edge Loss: 0.0000
# Epoch: 036, Total Loss: 2.4791, Feature Loss: 2.4791, Edge Loss: 0.0000
# Epoch: 037, Total Loss: 2.7282, Feature Loss: 2.7282, Edge Loss: 0.0000
# Epoch: 038, Total Loss: 2.4878, Feature Loss: 2.4878, Edge Loss: 0.0000
# Epoch: 039, Total Loss: 2.6049, Feature Loss: 2.6049, Edge Loss: 0.0000
# Epoch: 040, Total Loss: 2.4485, Feature Loss: 2.4485, Edge Loss: 0.0000
# Epoch: 041, Total Loss: 2.5068, Feature Loss: 2.5068, Edge Loss: 0.0000
# Epoch: 042, Total Loss: 3.4732, Feature Loss: 3.4732, Edge Loss: 0.0000
# Epoch: 043, Total Loss: 2.9224, Feature Loss: 2.9224, Edge Loss: 0.0000
# Epoch: 044, Total Loss: 4.3034, Feature Loss: 4.3034, Edge Loss: 0.0000
# Epoch: 045, Total Loss: 2.6350, Feature Loss: 2.6350, Edge Loss: 0.0000
# Epoch: 046, Total Loss: 2.7044, Feature Loss: 2.7044, Edge Loss: 0.0000
# Epoch: 047, Total Loss: 2.4498, Feature Loss: 2.4498, Edge Loss: 0.0000
# Epoch: 048, Total Loss: 2.7287, Feature Loss: 2.7287, Edge Loss: 0.0000
# Epoch: 049, Total Loss: 3.9926, Feature Loss: 3.9926, Edge Loss: 0.0000
# Epoch: 050, Total Loss: 2.5818, Feature Loss: 2.5818, Edge Loss: 0.0000
# Epoch: 051, Total Loss: 2.4141, Feature Loss: 2.4141, Edge Loss: 0.0000
# Epoch: 052, Total Loss: 2.6549, Feature Loss: 2.6549, Edge Loss: 0.0000
# Epoch: 053, Total Loss: 2.4244, Feature Loss: 2.4244, Edge Loss: 0.0000
# Epoch: 054, Total Loss: 2.3996, Feature Loss: 2.3996, Edge Loss: 0.0000
# Epoch: 055, Total Loss: 2.3506, Feature Loss: 2.3506, Edge Loss: 0.0000
# Epoch: 056, Total Loss: 2.4182, Feature Loss: 2.4182, Edge Loss: 0.0000
# Epoch: 057, Total Loss: 2.6735, Feature Loss: 2.6735, Edge Loss: 0.0000
# Epoch: 058, Total Loss: 2.6383, Feature Loss: 2.6383, Edge Loss: 0.0000
# Epoch: 059, Total Loss: 2.7062, Feature Loss: 2.7062, Edge Loss: 0.0000
# Epoch: 060, Total Loss: 2.4363, Feature Loss: 2.4363, Edge Loss: 0.0000
# Epoch: 061, Total Loss: 2.9482, Feature Loss: 2.9482, Edge Loss: 0.0000
# Epoch: 062, Total Loss: 3.1999, Feature Loss: 3.1999, Edge Loss: 0.0000
# Epoch: 063, Total Loss: 2.4054, Feature Loss: 2.4054, Edge Loss: 0.0000
# Epoch: 064, Total Loss: 2.6308, Feature Loss: 2.6308, Edge Loss: 0.0000
# Epoch: 065, Total Loss: 2.4536, Feature Loss: 2.4536, Edge Loss: 0.0000
# Epoch: 066, Total Loss: 2.4788, Feature Loss: 2.4788, Edge Loss: 0.0000
# Epoch: 067, Total Loss: 2.4760, Feature Loss: 2.4760, Edge Loss: 0.0000
# Epoch: 068, Total Loss: 2.3488, Feature Loss: 2.3488, Edge Loss: 0.0000
# Epoch: 069, Total Loss: 2.6311, Feature Loss: 2.6311, Edge Loss: 0.0000
# Epoch: 070, Total Loss: 4.9881, Feature Loss: 4.9881, Edge Loss: 0.0000
# Epoch: 071, Total Loss: 2.5611, Feature Loss: 2.5611, Edge Loss: 0.0000
# Epoch: 072, Total Loss: 2.4370, Feature Loss: 2.4370, Edge Loss: 0.0000
# Epoch: 073, Total Loss: 2.5265, Feature Loss: 2.5265, Edge Loss: 0.0000
# Epoch: 074, Total Loss: 2.3758, Feature Loss: 2.3758, Edge Loss: 0.0000
# Epoch: 075, Total Loss: 2.7431, Feature Loss: 2.7431, Edge Loss: 0.0000
# Epoch: 076, Total Loss: 2.3879, Feature Loss: 2.3879, Edge Loss: 0.0000
# Epoch: 077, Total Loss: 2.2950, Feature Loss: 2.2950, Edge Loss: 0.0000
# Epoch: 078, Total Loss: 2.4748, Feature Loss: 2.4748, Edge Loss: 0.0000
# Epoch: 079, Total Loss: 2.3477, Feature Loss: 2.3477, Edge Loss: 0.0000
# Epoch: 080, Total Loss: 2.7729, Feature Loss: 2.7729, Edge Loss: 0.0000
# Epoch: 081, Total Loss: 2.3272, Feature Loss: 2.3272, Edge Loss: 0.0000
# Epoch: 082, Total Loss: 2.3031, Feature Loss: 2.3031, Edge Loss: 0.0000
# Epoch: 083, Total Loss: 2.4211, Feature Loss: 2.4211, Edge Loss: 0.0000
# Epoch: 084, Total Loss: 2.3564, Feature Loss: 2.3564, Edge Loss: 0.0000
# Epoch: 085, Total Loss: 4.6749, Feature Loss: 4.6749, Edge Loss: 0.0000
# Epoch: 086, Total Loss: 2.8448, Feature Loss: 2.8448, Edge Loss: 0.0000
# Epoch: 087, Total Loss: 2.3123, Feature Loss: 2.3123, Edge Loss: 0.0000
# Epoch: 088, Total Loss: 2.2853, Feature Loss: 2.2853, Edge Loss: 0.0000
# Epoch: 089, Total Loss: 2.2269, Feature Loss: 2.2269, Edge Loss: 0.0000
# Epoch: 090, Total Loss: 2.4974, Feature Loss: 2.4974, Edge Loss: 0.0000
# Epoch: 091, Total Loss: 2.4725, Feature Loss: 2.4725, Edge Loss: 0.0000
# Epoch: 092, Total Loss: 2.1505, Feature Loss: 2.1505, Edge Loss: 0.0000
# Epoch: 093, Total Loss: 2.1258, Feature Loss: 2.1258, Edge Loss: 0.0000
# Epoch: 094, Total Loss: 2.1508, Feature Loss: 2.1508, Edge Loss: 0.0000
# Epoch: 095, Total Loss: 2.1611, Feature Loss: 2.1611, Edge Loss: 0.0000
# Epoch: 096, Total Loss: 2.1341, Feature Loss: 2.1341, Edge Loss: 0.0000
# Epoch: 097, Total Loss: 2.1589, Feature Loss: 2.1589, Edge Loss: 0.0000
# Epoch: 098, Total Loss: 2.1264, Feature Loss: 2.1264, Edge Loss: 0.0000
# Epoch: 099, Total Loss: 2.0712, Feature Loss: 2.0712, Edge Loss: 0.0000
# Epoch: 100, Total Loss: 2.1532, Feature Loss: 2.1532, Edge Loss: 0.0000
# Epoch: 101, Total Loss: 2.0535, Feature Loss: 2.0535, Edge Loss: 0.0000
# Epoch: 102, Total Loss: 2.1773, Feature Loss: 2.1773, Edge Loss: 0.0000
# Epoch: 103, Total Loss: 1.9978, Feature Loss: 1.9978, Edge Loss: 0.0000
# Epoch: 104, Total Loss: 2.2991, Feature Loss: 2.2991, Edge Loss: 0.0000
# Epoch: 105, Total Loss: 2.0676, Feature Loss: 2.0676, Edge Loss: 0.0000
# Epoch: 106, Total Loss: 2.0346, Feature Loss: 2.0346, Edge Loss: 0.0000
# Epoch: 107, Total Loss: 2.0824, Feature Loss: 2.0824, Edge Loss: 0.0000
# Epoch: 108, Total Loss: 1.9545, Feature Loss: 1.9545, Edge Loss: 0.0000
# Epoch: 109, Total Loss: 2.0300, Feature Loss: 2.0300, Edge Loss: 0.0000
# Epoch: 110, Total Loss: 2.1437, Feature Loss: 2.1437, Edge Loss: 0.0000
# Epoch: 111, Total Loss: 1.9719, Feature Loss: 1.9719, Edge Loss: 0.0000
# Epoch: 112, Total Loss: 2.0060, Feature Loss: 2.0060, Edge Loss: 0.0000
# Epoch: 113, Total Loss: 1.9847, Feature Loss: 1.9847, Edge Loss: 0.0000
# Epoch: 114, Total Loss: 2.0147, Feature Loss: 2.0147, Edge Loss: 0.0000
# Epoch: 115, Total Loss: 1.8733, Feature Loss: 1.8733, Edge Loss: 0.0000
# Epoch: 116, Total Loss: 2.0189, Feature Loss: 2.0189, Edge Loss: 0.0000
# Epoch: 117, Total Loss: 2.3178, Feature Loss: 2.3178, Edge Loss: 0.0000
# Epoch: 118, Total Loss: 1.9876, Feature Loss: 1.9876, Edge Loss: 0.0000
# Epoch: 119, Total Loss: 2.0107, Feature Loss: 2.0107, Edge Loss: 0.0000
# Epoch: 120, Total Loss: 1.9383, Feature Loss: 1.9383, Edge Loss: 0.0000
# Epoch: 121, Total Loss: 2.1345, Feature Loss: 2.1345, Edge Loss: 0.0000
# Epoch: 122, Total Loss: 1.8805, Feature Loss: 1.8805, Edge Loss: 0.0000
# Epoch: 123, Total Loss: 2.4486, Feature Loss: 2.4486, Edge Loss: 0.0000
# Epoch: 124, Total Loss: 1.8404, Feature Loss: 1.8404, Edge Loss: 0.0000
# Epoch: 125, Total Loss: 1.9427, Feature Loss: 1.9427, Edge Loss: 0.0000
# Epoch: 126, Total Loss: 1.8478, Feature Loss: 1.8478, Edge Loss: 0.0000
# Epoch: 127, Total Loss: 1.8193, Feature Loss: 1.8193, Edge Loss: 0.0000
# Epoch: 128, Total Loss: 1.9368, Feature Loss: 1.9368, Edge Loss: 0.0000
# Epoch: 129, Total Loss: 2.1856, Feature Loss: 2.1856, Edge Loss: 0.0000
# Epoch: 130, Total Loss: 1.8556, Feature Loss: 1.8556, Edge Loss: 0.0000
# Epoch: 131, Total Loss: 1.8570, Feature Loss: 1.8570, Edge Loss: 0.0000
# Epoch: 132, Total Loss: 1.8705, Feature Loss: 1.8705, Edge Loss: 0.0000
# Epoch: 133, Total Loss: 1.9940, Feature Loss: 1.9940, Edge Loss: 0.0000
# Epoch: 134, Total Loss: 1.9327, Feature Loss: 1.9327, Edge Loss: 0.0000
# Epoch: 135, Total Loss: 1.8669, Feature Loss: 1.8669, Edge Loss: 0.0000
# Epoch: 136, Total Loss: 1.7321, Feature Loss: 1.7321, Edge Loss: 0.0000
# Epoch: 137, Total Loss: 2.6612, Feature Loss: 2.6612, Edge Loss: 0.0000
# Epoch: 138, Total Loss: 1.8443, Feature Loss: 1.8443, Edge Loss: 0.0000
# Epoch: 139, Total Loss: 1.7991, Feature Loss: 1.7991, Edge Loss: 0.0000
# Epoch: 140, Total Loss: 1.7403, Feature Loss: 1.7403, Edge Loss: 0.0000
# Epoch: 141, Total Loss: 1.7236, Feature Loss: 1.7236, Edge Loss: 0.0000
# Epoch: 142, Total Loss: 1.8485, Feature Loss: 1.8485, Edge Loss: 0.0000
# Epoch: 143, Total Loss: 1.7875, Feature Loss: 1.7875, Edge Loss: 0.0000
# Epoch: 144, Total Loss: 1.8243, Feature Loss: 1.8243, Edge Loss: 0.0000
# Epoch: 145, Total Loss: 1.7293, Feature Loss: 1.7293, Edge Loss: 0.0000
# Epoch: 146, Total Loss: 2.1750, Feature Loss: 2.1750, Edge Loss: 0.0000
# Epoch: 147, Total Loss: 1.8116, Feature Loss: 1.8116, Edge Loss: 0.0000
# Epoch: 148, Total Loss: 1.8115, Feature Loss: 1.8115, Edge Loss: 0.0000
# Epoch: 149, Total Loss: 1.7339, Feature Loss: 1.7339, Edge Loss: 0.0000
# Epoch: 150, Total Loss: 1.7612, Feature Loss: 1.7612, Edge Loss: 0.0000
# Epoch: 151, Total Loss: 2.0309, Feature Loss: 2.0309, Edge Loss: 0.0000
# Epoch: 152, Total Loss: 1.8525, Feature Loss: 1.8525, Edge Loss: 0.0000
# Epoch: 153, Total Loss: 1.9599, Feature Loss: 1.9599, Edge Loss: 0.0000
# Epoch: 154, Total Loss: 1.7757, Feature Loss: 1.7757, Edge Loss: 0.0000
# Epoch: 155, Total Loss: 1.7554, Feature Loss: 1.7554, Edge Loss: 0.0000
# Epoch: 156, Total Loss: 1.8725, Feature Loss: 1.8725, Edge Loss: 0.0000
# Epoch: 157, Total Loss: 1.8008, Feature Loss: 1.8008, Edge Loss: 0.0000
# Epoch: 158, Total Loss: 1.8940, Feature Loss: 1.8940, Edge Loss: 0.0000
# Epoch: 159, Total Loss: 1.7084, Feature Loss: 1.7084, Edge Loss: 0.0000
# Epoch: 160, Total Loss: 1.8264, Feature Loss: 1.8264, Edge Loss: 0.0000
# Epoch: 161, Total Loss: 1.7502, Feature Loss: 1.7502, Edge Loss: 0.0000
# Epoch: 162, Total Loss: 1.6754, Feature Loss: 1.6754, Edge Loss: 0.0000
# Epoch: 163, Total Loss: 1.8079, Feature Loss: 1.8079, Edge Loss: 0.0000
# Epoch: 164, Total Loss: 1.8411, Feature Loss: 1.8411, Edge Loss: 0.0000
# Epoch: 165, Total Loss: 1.7130, Feature Loss: 1.7130, Edge Loss: 0.0000
# Epoch: 166, Total Loss: 1.7425, Feature Loss: 1.7425, Edge Loss: 0.0000
# Epoch: 167, Total Loss: 1.6955, Feature Loss: 1.6955, Edge Loss: 0.0000
# Epoch: 168, Total Loss: 1.6840, Feature Loss: 1.6840, Edge Loss: 0.0000
# Epoch: 169, Total Loss: 1.8065, Feature Loss: 1.8065, Edge Loss: 0.0000
# Epoch: 170, Total Loss: 1.7244, Feature Loss: 1.7244, Edge Loss: 0.0000
# Epoch: 171, Total Loss: 1.6478, Feature Loss: 1.6478, Edge Loss: 0.0000
# Epoch: 172, Total Loss: 1.6590, Feature Loss: 1.6590, Edge Loss: 0.0000
# Epoch: 173, Total Loss: 1.6852, Feature Loss: 1.6852, Edge Loss: 0.0000
# Epoch: 174, Total Loss: 1.7137, Feature Loss: 1.7137, Edge Loss: 0.0000
# Epoch: 175, Total Loss: 1.7169, Feature Loss: 1.7169, Edge Loss: 0.0000
# Epoch: 176, Total Loss: 1.6557, Feature Loss: 1.6557, Edge Loss: 0.0000
# Epoch: 177, Total Loss: 1.7005, Feature Loss: 1.7005, Edge Loss: 0.0000
# Epoch: 178, Total Loss: 1.7289, Feature Loss: 1.7289, Edge Loss: 0.0000
# Epoch: 179, Total Loss: 1.6332, Feature Loss: 1.6332, Edge Loss: 0.0000
# Epoch: 180, Total Loss: 1.6928, Feature Loss: 1.6928, Edge Loss: 0.0000
# Epoch: 181, Total Loss: 2.1173, Feature Loss: 2.1173, Edge Loss: 0.0000
# Epoch: 182, Total Loss: 1.7166, Feature Loss: 1.7166, Edge Loss: 0.0000
# Epoch: 183, Total Loss: 1.6934, Feature Loss: 1.6934, Edge Loss: 0.0000
# Epoch: 184, Total Loss: 1.8258, Feature Loss: 1.8258, Edge Loss: 0.0000
# Epoch: 185, Total Loss: 1.6511, Feature Loss: 1.6511, Edge Loss: 0.0000
# Epoch: 186, Total Loss: 1.6019, Feature Loss: 1.6019, Edge Loss: 0.0000
# Epoch: 187, Total Loss: 1.6627, Feature Loss: 1.6627, Edge Loss: 0.0000
# Epoch: 188, Total Loss: 1.5977, Feature Loss: 1.5977, Edge Loss: 0.0000
# Epoch: 189, Total Loss: 1.6344, Feature Loss: 1.6344, Edge Loss: 0.0000
# Epoch: 190, Total Loss: 1.6661, Feature Loss: 1.6661, Edge Loss: 0.0000
# Epoch: 191, Total Loss: 1.6636, Feature Loss: 1.6636, Edge Loss: 0.0000
# Epoch: 192, Total Loss: 1.6385, Feature Loss: 1.6385, Edge Loss: 0.0000
# Epoch: 193, Total Loss: 1.6698, Feature Loss: 1.6698, Edge Loss: 0.0000
# Epoch: 194, Total Loss: 1.5697, Feature Loss: 1.5697, Edge Loss: 0.0000
# Epoch: 195, Total Loss: 2.0140, Feature Loss: 2.0140, Edge Loss: 0.0000
# Epoch: 196, Total Loss: 1.5456, Feature Loss: 1.5456, Edge Loss: 0.0000
# Epoch: 197, Total Loss: 1.5673, Feature Loss: 1.5673, Edge Loss: 0.0000
# Epoch: 198, Total Loss: 1.5610, Feature Loss: 1.5610, Edge Loss: 0.0000
# Epoch: 199, Total Loss: 1.5482, Feature Loss: 1.5482, Edge Loss: 0.0000
# Epoch: 200, Total Loss: 1.8896, Feature Loss: 1.8896, Edge Loss: 0.0000
# Epoch: 201, Total Loss: 1.4944, Feature Loss: 1.4944, Edge Loss: 0.0000
# Epoch: 202, Total Loss: 1.4151, Feature Loss: 1.4151, Edge Loss: 0.0000
# Epoch: 203, Total Loss: 1.4515, Feature Loss: 1.4515, Edge Loss: 0.0000
# Epoch: 204, Total Loss: 1.4394, Feature Loss: 1.4394, Edge Loss: 0.0000
# Epoch: 205, Total Loss: 1.4696, Feature Loss: 1.4696, Edge Loss: 0.0000
# Epoch: 206, Total Loss: 1.3642, Feature Loss: 1.3642, Edge Loss: 0.0000
# Epoch: 207, Total Loss: 1.4083, Feature Loss: 1.4083, Edge Loss: 0.0000
# Epoch: 208, Total Loss: 1.4175, Feature Loss: 1.4175, Edge Loss: 0.0000
# Epoch: 209, Total Loss: 1.3074, Feature Loss: 1.3074, Edge Loss: 0.0000
# Epoch: 210, Total Loss: 1.2915, Feature Loss: 1.2915, Edge Loss: 0.0000
# Epoch: 211, Total Loss: 1.2861, Feature Loss: 1.2861, Edge Loss: 0.0000
# Epoch: 212, Total Loss: 1.3427, Feature Loss: 1.3427, Edge Loss: 0.0000
# Epoch: 213, Total Loss: 1.4734, Feature Loss: 1.4734, Edge Loss: 0.0000
# Epoch: 214, Total Loss: 1.3819, Feature Loss: 1.3819, Edge Loss: 0.0000
# Epoch: 215, Total Loss: 1.2859, Feature Loss: 1.2859, Edge Loss: 0.0000
# Epoch: 216, Total Loss: 1.3395, Feature Loss: 1.3395, Edge Loss: 0.0000
# Epoch: 217, Total Loss: 1.2852, Feature Loss: 1.2852, Edge Loss: 0.0000
# Epoch: 218, Total Loss: 1.2792, Feature Loss: 1.2792, Edge Loss: 0.0000
# Epoch: 219, Total Loss: 1.2812, Feature Loss: 1.2812, Edge Loss: 0.0000
# Epoch: 220, Total Loss: 1.4743, Feature Loss: 1.4743, Edge Loss: 0.0000
# Epoch: 221, Total Loss: 1.2024, Feature Loss: 1.2024, Edge Loss: 0.0000
# Epoch: 222, Total Loss: 1.3220, Feature Loss: 1.3220, Edge Loss: 0.0000
# Epoch: 223, Total Loss: 1.2691, Feature Loss: 1.2691, Edge Loss: 0.0000
# Epoch: 224, Total Loss: 1.2449, Feature Loss: 1.2449, Edge Loss: 0.0000
# Epoch: 225, Total Loss: 1.2571, Feature Loss: 1.2571, Edge Loss: 0.0000
# Epoch: 226, Total Loss: 1.2472, Feature Loss: 1.2472, Edge Loss: 0.0000
# Epoch: 227, Total Loss: 1.2239, Feature Loss: 1.2239, Edge Loss: 0.0000
# Epoch: 228, Total Loss: 1.1626, Feature Loss: 1.1626, Edge Loss: 0.0000
# Epoch: 229, Total Loss: 1.1065, Feature Loss: 1.1065, Edge Loss: 0.0000
# Epoch: 230, Total Loss: 1.1339, Feature Loss: 1.1339, Edge Loss: 0.0000
# Epoch: 231, Total Loss: 1.1338, Feature Loss: 1.1338, Edge Loss: 0.0000
# Epoch: 232, Total Loss: 1.0983, Feature Loss: 1.0983, Edge Loss: 0.0000
# Epoch: 233, Total Loss: 1.2972, Feature Loss: 1.2972, Edge Loss: 0.0000
# Epoch: 234, Total Loss: 1.1778, Feature Loss: 1.1778, Edge Loss: 0.0000
# Epoch: 235, Total Loss: 1.2781, Feature Loss: 1.2781, Edge Loss: 0.0000
# Epoch: 236, Total Loss: 1.1650, Feature Loss: 1.1650, Edge Loss: 0.0000
# Epoch: 237, Total Loss: 1.2532, Feature Loss: 1.2532, Edge Loss: 0.0000
# Epoch: 238, Total Loss: 1.0945, Feature Loss: 1.0945, Edge Loss: 0.0000
# Epoch: 239, Total Loss: 1.1026, Feature Loss: 1.1026, Edge Loss: 0.0000
# Epoch: 240, Total Loss: 1.1076, Feature Loss: 1.1076, Edge Loss: 0.0000
# Epoch: 241, Total Loss: 1.1547, Feature Loss: 1.1547, Edge Loss: 0.0000
# Epoch: 242, Total Loss: 1.1684, Feature Loss: 1.1684, Edge Loss: 0.0000
# Epoch: 243, Total Loss: 1.1397, Feature Loss: 1.1397, Edge Loss: 0.0000
# Epoch: 244, Total Loss: 1.1600, Feature Loss: 1.1600, Edge Loss: 0.0000
# Epoch: 245, Total Loss: 1.1601, Feature Loss: 1.1601, Edge Loss: 0.0000
# Epoch: 246, Total Loss: 1.0861, Feature Loss: 1.0861, Edge Loss: 0.0000
# Epoch: 247, Total Loss: 1.1160, Feature Loss: 1.1160, Edge Loss: 0.0000
# Epoch: 248, Total Loss: 1.0922, Feature Loss: 1.0922, Edge Loss: 0.0000
# Epoch: 249, Total Loss: 1.1175, Feature Loss: 1.1175, Edge Loss: 0.0000
# Epoch: 250, Total Loss: 1.1554, Feature Loss: 1.1554, Edge Loss: 0.0000
# Epoch: 251, Total Loss: 1.0745, Feature Loss: 1.0745, Edge Loss: 0.0000
# Epoch: 252, Total Loss: 1.1425, Feature Loss: 1.1425, Edge Loss: 0.0000
# Epoch: 253, Total Loss: 1.1206, Feature Loss: 1.1206, Edge Loss: 0.0000
# Epoch: 254, Total Loss: 1.0754, Feature Loss: 1.0754, Edge Loss: 0.0000
# Epoch: 255, Total Loss: 1.2700, Feature Loss: 1.2700, Edge Loss: 0.0000
# Epoch: 256, Total Loss: 1.3109, Feature Loss: 1.3109, Edge Loss: 0.0000
# Epoch: 257, Total Loss: 1.2073, Feature Loss: 1.2073, Edge Loss: 0.0000
# Epoch: 258, Total Loss: 1.0987, Feature Loss: 1.0987, Edge Loss: 0.0000
# Epoch: 259, Total Loss: 1.1005, Feature Loss: 1.1005, Edge Loss: 0.0000
# Epoch: 260, Total Loss: 1.1561, Feature Loss: 1.1561, Edge Loss: 0.0000
# Epoch: 261, Total Loss: 1.0527, Feature Loss: 1.0527, Edge Loss: 0.0000
# Epoch: 262, Total Loss: 1.0906, Feature Loss: 1.0906, Edge Loss: 0.0000
# Epoch: 263, Total Loss: 1.1230, Feature Loss: 1.1230, Edge Loss: 0.0000
# Epoch: 264, Total Loss: 1.2110, Feature Loss: 1.2110, Edge Loss: 0.0000
# Epoch: 265, Total Loss: 1.0930, Feature Loss: 1.0930, Edge Loss: 0.0000
# Epoch: 266, Total Loss: 1.1839, Feature Loss: 1.1839, Edge Loss: 0.0000
# Epoch: 267, Total Loss: 1.0636, Feature Loss: 1.0636, Edge Loss: 0.0000
# Epoch: 268, Total Loss: 1.0740, Feature Loss: 1.0740, Edge Loss: 0.0000
# Epoch: 269, Total Loss: 1.2794, Feature Loss: 1.2794, Edge Loss: 0.0000
# Epoch: 270, Total Loss: 1.0569, Feature Loss: 1.0569, Edge Loss: 0.0000
# Epoch: 271, Total Loss: 1.0975, Feature Loss: 1.0975, Edge Loss: 0.0000
# Epoch: 272, Total Loss: 1.1274, Feature Loss: 1.1274, Edge Loss: 0.0000
# Epoch: 273, Total Loss: 1.0813, Feature Loss: 1.0813, Edge Loss: 0.0000
# Epoch: 274, Total Loss: 1.2548, Feature Loss: 1.2548, Edge Loss: 0.0000
# Epoch: 275, Total Loss: 1.1114, Feature Loss: 1.1114, Edge Loss: 0.0000
# Epoch: 276, Total Loss: 1.0582, Feature Loss: 1.0582, Edge Loss: 0.0000
# Epoch: 277, Total Loss: 1.0856, Feature Loss: 1.0856, Edge Loss: 0.0000
# Epoch: 278, Total Loss: 1.1152, Feature Loss: 1.1152, Edge Loss: 0.0000
# Epoch: 279, Total Loss: 1.1025, Feature Loss: 1.1025, Edge Loss: 0.0000
# Epoch: 280, Total Loss: 1.0605, Feature Loss: 1.0605, Edge Loss: 0.0000
# Epoch: 281, Total Loss: 1.0678, Feature Loss: 1.0678, Edge Loss: 0.0000
# Epoch: 282, Total Loss: 1.0701, Feature Loss: 1.0701, Edge Loss: 0.0000
# Epoch: 283, Total Loss: 1.0524, Feature Loss: 1.0524, Edge Loss: 0.0000
# Epoch: 284, Total Loss: 1.0684, Feature Loss: 1.0684, Edge Loss: 0.0000
# Epoch: 285, Total Loss: 1.1068, Feature Loss: 1.1068, Edge Loss: 0.0000
# Epoch: 286, Total Loss: 1.0442, Feature Loss: 1.0442, Edge Loss: 0.0000
# Epoch: 287, Total Loss: 1.1109, Feature Loss: 1.1109, Edge Loss: 0.0000
# Epoch: 288, Total Loss: 1.1298, Feature Loss: 1.1298, Edge Loss: 0.0000
# Epoch: 289, Total Loss: 1.0556, Feature Loss: 1.0556, Edge Loss: 0.0000
# Epoch: 290, Total Loss: 1.1942, Feature Loss: 1.1942, Edge Loss: 0.0000
# Epoch: 291, Total Loss: 1.0387, Feature Loss: 1.0387, Edge Loss: 0.0000
# Epoch: 292, Total Loss: 1.0269, Feature Loss: 1.0269, Edge Loss: 0.0000
# Epoch: 293, Total Loss: 1.0543, Feature Loss: 1.0543, Edge Loss: 0.0000
# Epoch: 294, Total Loss: 1.1164, Feature Loss: 1.1164, Edge Loss: 0.0000
# Epoch: 295, Total Loss: 1.0754, Feature Loss: 1.0754, Edge Loss: 0.0000
# Epoch: 296, Total Loss: 1.0862, Feature Loss: 1.0862, Edge Loss: 0.0000
# Epoch: 297, Total Loss: 1.0629, Feature Loss: 1.0629, Edge Loss: 0.0000
# Epoch: 298, Total Loss: 1.0680, Feature Loss: 1.0680, Edge Loss: 0.0000
# Epoch: 299, Total Loss: 1.0573, Feature Loss: 1.0573, Edge Loss: 0.0000
# Epoch: 300, Total Loss: 1.0485, Feature Loss: 1.0485, Edge Loss: 0.0000
# Epoch: 301, Total Loss: 1.0462, Feature Loss: 1.0462, Edge Loss: 0.0000
# Epoch: 302, Total Loss: 1.0482, Feature Loss: 1.0482, Edge Loss: 0.0000
# Epoch: 303, Total Loss: 1.0176, Feature Loss: 1.0176, Edge Loss: 0.0000
# Epoch: 304, Total Loss: 1.2007, Feature Loss: 1.2007, Edge Loss: 0.0000
# Epoch: 305, Total Loss: 1.0866, Feature Loss: 1.0866, Edge Loss: 0.0000
# Epoch: 306, Total Loss: 1.1142, Feature Loss: 1.1142, Edge Loss: 0.0000
# Epoch: 307, Total Loss: 1.1113, Feature Loss: 1.1113, Edge Loss: 0.0000
# Epoch: 308, Total Loss: 1.0775, Feature Loss: 1.0775, Edge Loss: 0.0000
# Epoch: 309, Total Loss: 1.0525, Feature Loss: 1.0525, Edge Loss: 0.0000
# Epoch: 310, Total Loss: 1.0731, Feature Loss: 1.0731, Edge Loss: 0.0000
# Epoch: 311, Total Loss: 1.0245, Feature Loss: 1.0245, Edge Loss: 0.0000
# Epoch: 312, Total Loss: 1.0375, Feature Loss: 1.0375, Edge Loss: 0.0000
# Epoch: 313, Total Loss: 1.0774, Feature Loss: 1.0774, Edge Loss: 0.0000
# Epoch: 314, Total Loss: 1.0835, Feature Loss: 1.0835, Edge Loss: 0.0000
# Epoch: 315, Total Loss: 1.1280, Feature Loss: 1.1280, Edge Loss: 0.0000
# Epoch: 316, Total Loss: 1.0602, Feature Loss: 1.0602, Edge Loss: 0.0000
# Epoch: 317, Total Loss: 1.0828, Feature Loss: 1.0828, Edge Loss: 0.0000
# Epoch: 318, Total Loss: 1.0417, Feature Loss: 1.0417, Edge Loss: 0.0000
# Epoch: 319, Total Loss: 1.0383, Feature Loss: 1.0383, Edge Loss: 0.0000
# Epoch: 320, Total Loss: 1.0982, Feature Loss: 1.0982, Edge Loss: 0.0000
# Epoch: 321, Total Loss: 1.0153, Feature Loss: 1.0153, Edge Loss: 0.0000
# Epoch: 322, Total Loss: 1.0146, Feature Loss: 1.0146, Edge Loss: 0.0000
# Epoch: 323, Total Loss: 1.0112, Feature Loss: 1.0112, Edge Loss: 0.0000
# Epoch: 324, Total Loss: 1.0084, Feature Loss: 1.0084, Edge Loss: 0.0000
# Epoch: 325, Total Loss: 1.0510, Feature Loss: 1.0510, Edge Loss: 0.0000
# Epoch: 326, Total Loss: 1.0372, Feature Loss: 1.0372, Edge Loss: 0.0000
# Epoch: 327, Total Loss: 1.0603, Feature Loss: 1.0603, Edge Loss: 0.0000
# Epoch: 328, Total Loss: 1.0081, Feature Loss: 1.0081, Edge Loss: 0.0000
# Epoch: 329, Total Loss: 1.0272, Feature Loss: 1.0272, Edge Loss: 0.0000
# Epoch: 330, Total Loss: 1.0108, Feature Loss: 1.0108, Edge Loss: 0.0000
# Epoch: 331, Total Loss: 1.0577, Feature Loss: 1.0577, Edge Loss: 0.0000
# Epoch: 332, Total Loss: 1.0076, Feature Loss: 1.0076, Edge Loss: 0.0000
# Epoch: 333, Total Loss: 1.0239, Feature Loss: 1.0239, Edge Loss: 0.0000
# Epoch: 334, Total Loss: 1.0435, Feature Loss: 1.0435, Edge Loss: 0.0000
# Epoch: 335, Total Loss: 1.0454, Feature Loss: 1.0454, Edge Loss: 0.0000
# Epoch: 336, Total Loss: 1.0097, Feature Loss: 1.0097, Edge Loss: 0.0000
# Epoch: 337, Total Loss: 1.0131, Feature Loss: 1.0131, Edge Loss: 0.0000
# Epoch: 338, Total Loss: 1.0348, Feature Loss: 1.0348, Edge Loss: 0.0000
# Epoch: 339, Total Loss: 1.0828, Feature Loss: 1.0828, Edge Loss: 0.0000
# Epoch: 340, Total Loss: 1.0429, Feature Loss: 1.0429, Edge Loss: 0.0000
# Epoch: 341, Total Loss: 1.0222, Feature Loss: 1.0222, Edge Loss: 0.0000
# Epoch: 342, Total Loss: 1.0357, Feature Loss: 1.0357, Edge Loss: 0.0000
# Epoch: 343, Total Loss: 1.0139, Feature Loss: 1.0139, Edge Loss: 0.0000
# Epoch: 344, Total Loss: 1.0474, Feature Loss: 1.0474, Edge Loss: 0.0000
# Epoch: 345, Total Loss: 1.0204, Feature Loss: 1.0204, Edge Loss: 0.0000
# Epoch: 346, Total Loss: 1.0109, Feature Loss: 1.0109, Edge Loss: 0.0000
# Epoch: 347, Total Loss: 1.0160, Feature Loss: 1.0160, Edge Loss: 0.0000
# Epoch: 348, Total Loss: 1.0205, Feature Loss: 1.0205, Edge Loss: 0.0000
# Epoch: 349, Total Loss: 1.0244, Feature Loss: 1.0244, Edge Loss: 0.0000
# Epoch: 350, Total Loss: 1.0362, Feature Loss: 1.0362, Edge Loss: 0.0000
# Epoch: 351, Total Loss: 1.0044, Feature Loss: 1.0044, Edge Loss: 0.0000
# Epoch: 352, Total Loss: 1.0347, Feature Loss: 1.0347, Edge Loss: 0.0000
# Epoch: 353, Total Loss: 1.0062, Feature Loss: 1.0062, Edge Loss: 0.0000
# Epoch: 354, Total Loss: 1.0142, Feature Loss: 1.0142, Edge Loss: 0.0000
# Epoch: 355, Total Loss: 1.0039, Feature Loss: 1.0039, Edge Loss: 0.0000
# Epoch: 356, Total Loss: 1.0192, Feature Loss: 1.0192, Edge Loss: 0.0000
# Epoch: 357, Total Loss: 1.0270, Feature Loss: 1.0270, Edge Loss: 0.0000
# Epoch: 358, Total Loss: 1.0259, Feature Loss: 1.0259, Edge Loss: 0.0000
# Epoch: 359, Total Loss: 1.0194, Feature Loss: 1.0194, Edge Loss: 0.0000
# Epoch: 360, Total Loss: 1.0106, Feature Loss: 1.0106, Edge Loss: 0.0000
# Epoch: 361, Total Loss: 1.0099, Feature Loss: 1.0099, Edge Loss: 0.0000
# Epoch: 362, Total Loss: 0.9989, Feature Loss: 0.9989, Edge Loss: 0.0000
# Epoch: 363, Total Loss: 1.0024, Feature Loss: 1.0024, Edge Loss: 0.0000
# Epoch: 364, Total Loss: 1.0057, Feature Loss: 1.0057, Edge Loss: 0.0000
# Epoch: 365, Total Loss: 1.0015, Feature Loss: 1.0015, Edge Loss: 0.0000
# Epoch: 366, Total Loss: 1.0233, Feature Loss: 1.0233, Edge Loss: 0.0000
# Epoch: 367, Total Loss: 1.0223, Feature Loss: 1.0223, Edge Loss: 0.0000
# Epoch: 368, Total Loss: 1.0135, Feature Loss: 1.0135, Edge Loss: 0.0000
# Epoch: 369, Total Loss: 1.0041, Feature Loss: 1.0041, Edge Loss: 0.0000
# Epoch: 370, Total Loss: 1.0080, Feature Loss: 1.0080, Edge Loss: 0.0000
# Epoch: 371, Total Loss: 1.0109, Feature Loss: 1.0109, Edge Loss: 0.0000
# Epoch: 372, Total Loss: 1.0014, Feature Loss: 1.0014, Edge Loss: 0.0000
# Epoch: 373, Total Loss: 1.0135, Feature Loss: 1.0135, Edge Loss: 0.0000
# Epoch: 374, Total Loss: 1.0457, Feature Loss: 1.0457, Edge Loss: 0.0000
# Epoch: 375, Total Loss: 1.0015, Feature Loss: 1.0015, Edge Loss: 0.0000
# Epoch: 376, Total Loss: 1.0155, Feature Loss: 1.0155, Edge Loss: 0.0000
# Epoch: 377, Total Loss: 1.0145, Feature Loss: 1.0145, Edge Loss: 0.0000
# Epoch: 378, Total Loss: 0.9965, Feature Loss: 0.9965, Edge Loss: 0.0000
# Epoch: 379, Total Loss: 1.0073, Feature Loss: 1.0073, Edge Loss: 0.0000
# Epoch: 380, Total Loss: 0.9985, Feature Loss: 0.9985, Edge Loss: 0.0000
# Epoch: 381, Total Loss: 0.9984, Feature Loss: 0.9984, Edge Loss: 0.0000
# Epoch: 382, Total Loss: 0.9991, Feature Loss: 0.9991, Edge Loss: 0.0000
# Epoch: 383, Total Loss: 0.9896, Feature Loss: 0.9896, Edge Loss: 0.0000
# Epoch: 384, Total Loss: 1.0213, Feature Loss: 1.0213, Edge Loss: 0.0000
# Epoch: 385, Total Loss: 1.0098, Feature Loss: 1.0098, Edge Loss: 0.0000
# Epoch: 386, Total Loss: 0.9935, Feature Loss: 0.9935, Edge Loss: 0.0000
# Epoch: 387, Total Loss: 0.9983, Feature Loss: 0.9983, Edge Loss: 0.0000
# Epoch: 388, Total Loss: 1.0073, Feature Loss: 1.0073, Edge Loss: 0.0000
# Epoch: 389, Total Loss: 1.0113, Feature Loss: 1.0113, Edge Loss: 0.0000
# Epoch: 390, Total Loss: 0.9997, Feature Loss: 0.9997, Edge Loss: 0.0000
# Epoch: 391, Total Loss: 0.9851, Feature Loss: 0.9851, Edge Loss: 0.0000
# Epoch: 392, Total Loss: 1.0023, Feature Loss: 1.0023, Edge Loss: 0.0000
# Epoch: 393, Total Loss: 0.9945, Feature Loss: 0.9945, Edge Loss: 0.0000
# Epoch: 394, Total Loss: 0.9868, Feature Loss: 0.9868, Edge Loss: 0.0000
# Epoch: 395, Total Loss: 0.9966, Feature Loss: 0.9966, Edge Loss: 0.0000
# Epoch: 396, Total Loss: 0.9958, Feature Loss: 0.9958, Edge Loss: 0.0000
# Epoch: 397, Total Loss: 1.0054, Feature Loss: 1.0054, Edge Loss: 0.0000
# Epoch: 398, Total Loss: 0.9956, Feature Loss: 0.9956, Edge Loss: 0.0000
# Epoch: 399, Total Loss: 0.9844, Feature Loss: 0.9844, Edge Loss: 0.0000
# Epoch: 400, Total Loss: 0.9921, Feature Loss: 0.9921, Edge Loss: 0.0000
# Epoch: 401, Total Loss: 1.0041, Feature Loss: 1.0041, Edge Loss: 0.0000
# Epoch: 402, Total Loss: 0.9955, Feature Loss: 0.9955, Edge Loss: 0.0000
# Epoch: 403, Total Loss: 0.9969, Feature Loss: 0.9969, Edge Loss: 0.0000
# Epoch: 404, Total Loss: 0.9988, Feature Loss: 0.9988, Edge Loss: 0.0000
# Epoch: 405, Total Loss: 0.9972, Feature Loss: 0.9972, Edge Loss: 0.0000
# Epoch: 406, Total Loss: 0.9890, Feature Loss: 0.9890, Edge Loss: 0.0000
# Epoch: 407, Total Loss: 0.9967, Feature Loss: 0.9967, Edge Loss: 0.0000
# Epoch: 408, Total Loss: 1.0126, Feature Loss: 1.0126, Edge Loss: 0.0000
# Epoch: 409, Total Loss: 0.9933, Feature Loss: 0.9933, Edge Loss: 0.0000
# Epoch: 410, Total Loss: 0.9866, Feature Loss: 0.9866, Edge Loss: 0.0000
# Epoch: 411, Total Loss: 0.9832, Feature Loss: 0.9832, Edge Loss: 0.0000
# Epoch: 412, Total Loss: 1.0028, Feature Loss: 1.0028, Edge Loss: 0.0000
# Epoch: 413, Total Loss: 1.0093, Feature Loss: 1.0093, Edge Loss: 0.0000
# Epoch: 414, Total Loss: 0.9899, Feature Loss: 0.9899, Edge Loss: 0.0000
# Epoch: 415, Total Loss: 1.0056, Feature Loss: 1.0056, Edge Loss: 0.0000
# Epoch: 416, Total Loss: 0.9897, Feature Loss: 0.9897, Edge Loss: 0.0000
# Epoch: 417, Total Loss: 0.9790, Feature Loss: 0.9790, Edge Loss: 0.0000
# Epoch: 418, Total Loss: 0.9865, Feature Loss: 0.9865, Edge Loss: 0.0000
# Epoch: 419, Total Loss: 0.9934, Feature Loss: 0.9934, Edge Loss: 0.0000
# Epoch: 420, Total Loss: 0.9895, Feature Loss: 0.9895, Edge Loss: 0.0000
# Epoch: 421, Total Loss: 1.0019, Feature Loss: 1.0019, Edge Loss: 0.0000
# Epoch: 422, Total Loss: 0.9946, Feature Loss: 0.9946, Edge Loss: 0.0000
# Epoch: 423, Total Loss: 0.9989, Feature Loss: 0.9989, Edge Loss: 0.0000
# Epoch: 424, Total Loss: 0.9861, Feature Loss: 0.9861, Edge Loss: 0.0000
# Epoch: 425, Total Loss: 0.9913, Feature Loss: 0.9913, Edge Loss: 0.0000
# Epoch: 426, Total Loss: 0.9835, Feature Loss: 0.9835, Edge Loss: 0.0000
# Epoch: 427, Total Loss: 0.9835, Feature Loss: 0.9835, Edge Loss: 0.0000
# Epoch: 428, Total Loss: 0.9795, Feature Loss: 0.9795, Edge Loss: 0.0000
# Epoch: 429, Total Loss: 0.9858, Feature Loss: 0.9858, Edge Loss: 0.0000
# Epoch: 430, Total Loss: 0.9898, Feature Loss: 0.9898, Edge Loss: 0.0000
# Epoch: 431, Total Loss: 0.9846, Feature Loss: 0.9846, Edge Loss: 0.0000
# Epoch: 432, Total Loss: 0.9814, Feature Loss: 0.9814, Edge Loss: 0.0000
# Epoch: 433, Total Loss: 0.9875, Feature Loss: 0.9875, Edge Loss: 0.0000
# Epoch: 434, Total Loss: 0.9902, Feature Loss: 0.9902, Edge Loss: 0.0000
# Epoch: 435, Total Loss: 0.9922, Feature Loss: 0.9922, Edge Loss: 0.0000
# Epoch: 436, Total Loss: 0.9839, Feature Loss: 0.9839, Edge Loss: 0.0000
# Epoch: 437, Total Loss: 0.9755, Feature Loss: 0.9755, Edge Loss: 0.0000
# Epoch: 438, Total Loss: 1.0213, Feature Loss: 1.0213, Edge Loss: 0.0000
# Epoch: 439, Total Loss: 0.9895, Feature Loss: 0.9895, Edge Loss: 0.0000
# Epoch: 440, Total Loss: 0.9852, Feature Loss: 0.9852, Edge Loss: 0.0000
# Epoch: 441, Total Loss: 0.9859, Feature Loss: 0.9859, Edge Loss: 0.0000
# Epoch: 442, Total Loss: 0.9894, Feature Loss: 0.9894, Edge Loss: 0.0000
# Epoch: 443, Total Loss: 0.9853, Feature Loss: 0.9853, Edge Loss: 0.0000
# Epoch: 444, Total Loss: 0.9839, Feature Loss: 0.9839, Edge Loss: 0.0000
# Epoch: 445, Total Loss: 0.9908, Feature Loss: 0.9908, Edge Loss: 0.0000
# Epoch: 446, Total Loss: 0.9932, Feature Loss: 0.9932, Edge Loss: 0.0000
# Epoch: 447, Total Loss: 0.9917, Feature Loss: 0.9917, Edge Loss: 0.0000
# Epoch: 448, Total Loss: 0.9849, Feature Loss: 0.9849, Edge Loss: 0.0000
# Epoch: 449, Total Loss: 0.9865, Feature Loss: 0.9865, Edge Loss: 0.0000
# Epoch: 450, Total Loss: 0.9865, Feature Loss: 0.9865, Edge Loss: 0.0000
# Epoch: 451, Total Loss: 0.9967, Feature Loss: 0.9967, Edge Loss: 0.0000
# Epoch: 452, Total Loss: 0.9928, Feature Loss: 0.9928, Edge Loss: 0.0000
# Epoch: 453, Total Loss: 0.9870, Feature Loss: 0.9870, Edge Loss: 0.0000
# Epoch: 454, Total Loss: 0.9797, Feature Loss: 0.9797, Edge Loss: 0.0000
# Epoch: 455, Total Loss: 0.9852, Feature Loss: 0.9852, Edge Loss: 0.0000
# Epoch: 456, Total Loss: 0.9834, Feature Loss: 0.9834, Edge Loss: 0.0000
# Epoch: 457, Total Loss: 0.9808, Feature Loss: 0.9808, Edge Loss: 0.0000
# Epoch: 458, Total Loss: 0.9839, Feature Loss: 0.9839, Edge Loss: 0.0000
# Epoch: 459, Total Loss: 0.9789, Feature Loss: 0.9789, Edge Loss: 0.0000
# Epoch: 460, Total Loss: 0.9805, Feature Loss: 0.9805, Edge Loss: 0.0000
# Epoch: 461, Total Loss: 0.9859, Feature Loss: 0.9859, Edge Loss: 0.0000
# Epoch: 462, Total Loss: 0.9843, Feature Loss: 0.9843, Edge Loss: 0.0000
# Epoch: 463, Total Loss: 0.9824, Feature Loss: 0.9824, Edge Loss: 0.0000
# Epoch: 464, Total Loss: 0.9848, Feature Loss: 0.9848, Edge Loss: 0.0000
# Epoch: 465, Total Loss: 0.9930, Feature Loss: 0.9930, Edge Loss: 0.0000
# Epoch: 466, Total Loss: 0.9879, Feature Loss: 0.9879, Edge Loss: 0.0000
# Epoch: 467, Total Loss: 0.9736, Feature Loss: 0.9736, Edge Loss: 0.0000
# Epoch: 468, Total Loss: 0.9834, Feature Loss: 0.9834, Edge Loss: 0.0000
# Epoch: 469, Total Loss: 0.9795, Feature Loss: 0.9795, Edge Loss: 0.0000
# Epoch: 470, Total Loss: 0.9853, Feature Loss: 0.9853, Edge Loss: 0.0000
# Epoch: 471, Total Loss: 0.9819, Feature Loss: 0.9819, Edge Loss: 0.0000
# Epoch: 472, Total Loss: 0.9760, Feature Loss: 0.9760, Edge Loss: 0.0000
# Epoch: 473, Total Loss: 0.9802, Feature Loss: 0.9802, Edge Loss: 0.0000
# Epoch: 474, Total Loss: 0.9822, Feature Loss: 0.9822, Edge Loss: 0.0000
# Epoch: 475, Total Loss: 0.9761, Feature Loss: 0.9761, Edge Loss: 0.0000
# Epoch: 476, Total Loss: 0.9730, Feature Loss: 0.9730, Edge Loss: 0.0000
# Epoch: 477, Total Loss: 0.9785, Feature Loss: 0.9785, Edge Loss: 0.0000
# Epoch: 478, Total Loss: 0.9752, Feature Loss: 0.9752, Edge Loss: 0.0000
# Epoch: 479, Total Loss: 0.9860, Feature Loss: 0.9860, Edge Loss: 0.0000
# Epoch: 480, Total Loss: 0.9840, Feature Loss: 0.9840, Edge Loss: 0.0000
# Epoch: 481, Total Loss: 0.9728, Feature Loss: 0.9728, Edge Loss: 0.0000
# Epoch: 482, Total Loss: 0.9717, Feature Loss: 0.9717, Edge Loss: 0.0000
# Epoch: 483, Total Loss: 0.9822, Feature Loss: 0.9822, Edge Loss: 0.0000
# Epoch: 484, Total Loss: 0.9794, Feature Loss: 0.9794, Edge Loss: 0.0000
# Epoch: 485, Total Loss: 0.9816, Feature Loss: 0.9816, Edge Loss: 0.0000
# Epoch: 486, Total Loss: 0.9842, Feature Loss: 0.9842, Edge Loss: 0.0000
# Epoch: 487, Total Loss: 0.9764, Feature Loss: 0.9764, Edge Loss: 0.0000
# Epoch: 488, Total Loss: 0.9942, Feature Loss: 0.9942, Edge Loss: 0.0000
# Epoch: 489, Total Loss: 0.9743, Feature Loss: 0.9743, Edge Loss: 0.0000
# Epoch: 490, Total Loss: 0.9768, Feature Loss: 0.9768, Edge Loss: 0.0000
# Epoch: 491, Total Loss: 0.9793, Feature Loss: 0.9793, Edge Loss: 0.0000
# Epoch: 492, Total Loss: 0.9757, Feature Loss: 0.9757, Edge Loss: 0.0000
# Epoch: 493, Total Loss: 0.9721, Feature Loss: 0.9721, Edge Loss: 0.0000
# Epoch: 494, Total Loss: 0.9790, Feature Loss: 0.9790, Edge Loss: 0.0000
# Epoch: 495, Total Loss: 0.9765, Feature Loss: 0.9765, Edge Loss: 0.0000
# Epoch: 496, Total Loss: 0.9763, Feature Loss: 0.9763, Edge Loss: 0.0000
# Epoch: 497, Total Loss: 0.9789, Feature Loss: 0.9789, Edge Loss: 0.0000
# Epoch: 498, Total Loss: 0.9787, Feature Loss: 0.9787, Edge Loss: 0.0000
# Epoch: 499, Total Loss: 0.9763, Feature Loss: 0.9763, Edge Loss: 0.0000
# Epoch: 500, Total Loss: 0.9809, Feature Loss: 0.9809, Edge Loss: 0.0000

# %% [markdown]
# plt.figure(figsize=(14, 5))
# plt.plot(total_losses, label='Total Loss')
# plt.legend()
# plt.title('Total Loss')
# plt.show()

# %% [markdown]
# plt.figure(figsize=(14, 5))
# plt.plot(feature_losses, label='Feature Loss')
# plt.legend()
# plt.title('Feature Loss')
# plt.show()

# %%
if not model_loaded:
    plt.figure(figsize=(14, 5))
    plt.plot(total_losses, label='Total Loss')
    plt.legend()
    plt.title('Total Loss')
    plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
if not model_loaded:
    plt.figure(figsize=(14, 5))
    plt.plot(feature_losses, label='Feature Loss')
    plt.legend()
    plt.title('Feature Loss')
    plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
train_loader = DataLoader(graphs, batch_size=1)

# %%
decoded_data=[]
for data in train_loader:
    model.eval()
    z,encoded_edge_index = model.encode(data.x, data.edge_index)
    decoded_data.append(z.detach().numpy())

decoded_data = np.array(decoded_data)

# %%
decoded_data.shape
# Out:
# (51, 101, 2)

# %%
frame = 49
plt.figure(figsize=(14, 5))
data = decoded_data[frame]
plt.scatter(data[:,0], data[:,1])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
