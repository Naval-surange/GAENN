# %%
import mdtraj as md
from ase import Atoms
import nglview as nv
import networkx as nx

import numpy as np
import matplotlib.pyplot as plt
import torch
from tqdm import tqdm

import torch_geometric.transforms as T
from torch_geometric.loader import DataLoader
from torch_geometric.nn import GCNConv, SAGPooling, InnerProductDecoder
import torch_geometric.data as data
from torch_geometric.utils.convert import to_networkx
import torch.optim.lr_scheduler as lr_scheduler
from torch.nn import Linear
import sys

# %%
all_frames_cry = md.load_xtc("../simulation/para_crystal.xtc", top="../simulation/para_crystal.gro")
all_frames_melt = md.load_xtc("../simulation/para_melt.xtc", top="../simulation/para_melt.gro")

# %%
all_frames_cry = all_frames_cry[::100]
all_frames_melt = all_frames_melt[::100]

# %%
n_frames = all_frames_cry.xyz.shape[0]
n_atoms = all_frames_cry.topology.residue(0).n_atoms
n_mols = all_frames_cry.topology.n_residues

# %%
def createGraph(all_frames,structure_type="crystal"):
    all_frames_fatures = []

    print("Creating Feature matrix")
    for i in tqdm(range(all_frames.xyz.shape[0])):
        mol_com_pos = []

        for res in all_frames.top.residues:
            pos = []
            for atom in res.atoms:
                pos.append(all_frames.xyz[i][atom.index])
            mol_com_pos.append(np.mean(pos,axis=0))
            
            # print()
        mol_com_pos = np.array(mol_com_pos).astype(np.float32)  
        all_frames_fatures.append(mol_com_pos)

    all_frames_fatures = np.array(all_frames_fatures).astype(np.float32)



    cutoff = 0.8

    print("Creating Edge list")
    all_edge_list = []
    # with open("edge_list.txt","w") as f:
    for frame_i in tqdm(range(n_frames)):
        from_list = []
        to_list = []

        for i in range(len(all_frames_fatures[frame_i])):
            for j in range(i+1,len(all_frames_fatures[frame_i])):
                if np.linalg.norm(all_frames_fatures[frame_i][i]-all_frames_fatures[frame_i][j]) < cutoff:
                    # f.write(str(i)+" "+str(j)+" "+str(np.linalg.norm(all_frames_fatures[frame_i][i]-all_frames_fatures[frame_i][j]))+"\n")
                    from_list.append(i)
                    to_list.append(j)

                    to_list.append(i)
                    from_list.append(j)

        edge_list = np.array([from_list,to_list]).astype(np.int64)
        all_edge_list.append(edge_list)
    print("creating Graphs")
    graphs = []
    for frame in tqdm(range(n_frames)):
        if structure_type == "crystal":
            g = data.Data(x=torch.tensor(all_frames_fatures[frame]).float(), edge_index=torch.tensor(all_edge_list[frame]).long(), y=torch.tensor([0]))
        else:
            g = data.Data(x=torch.tensor(all_frames_fatures[frame]).float(), edge_index=torch.tensor(all_edge_list[frame]).long(), y=torch.tensor([1]))
        graphs.append(g)
    return graphs

# %%
graphs_cry = createGraph(all_frames_cry,structure_type="crystal")
graphs_melt = createGraph(all_frames_melt,structure_type="melt")
# Out:
# Creating Feature matrix
# 100%|██████████| 51/51 [00:00<00:00, 70.88it/s]
# Creating Edge list
# 100%|██████████| 51/51 [00:55<00:00,  1.09s/it]
# creating Graphs
# 100%|██████████| 51/51 [00:00<00:00, 20206.83it/s]
# Creating Feature matrix
# 100%|██████████| 51/51 [00:00<00:00, 82.56it/s]
# Creating Edge list
# 100%|██████████| 51/51 [01:36<00:00,  1.89s/it]
# creating Graphs
# 100%|██████████| 51/51 [00:00<00:00, 12410.62it/s]

# %%
def convert_to_adj(edge_index, num_nodes=None):
    if num_nodes is None:
        num_nodes = edge_index.max() + 1
    adj = torch.zeros(num_nodes, num_nodes)
    adj[edge_index[0], edge_index[1]] = 1
    return adj

def convert_to_edge_index(adj):
    edge_index = adj.nonzero().t()
    return edge_index

# %%
# graphs = graphs_cry + graphs_melt
graphs = graphs_cry

# %%
# shuffle the graphs
np.random.shuffle(graphs)

# %%
graphs
# Out:
# [Data(x=[864, 3], edge_index=[2, 7374], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6992], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6990], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6964], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7088], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7306], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7048], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7036], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7056], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7218], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7086], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7116], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7274], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7094], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7028], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7132], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7146], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7076], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7074], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7006], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7116], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7052], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7092], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7008], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7012], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7034], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7060], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7078], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7054], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7052], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7128], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7006], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7108], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7026], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7092], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7090], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7060], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7044], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7020], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7064], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6934], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7294], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7080], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7024], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7096], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7192], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7048], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7122], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7240], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7100], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7078], y=[1])]

# %% [markdown]
# ## model

# %%
from typing import Optional, Tuple

import torch
from torch import Tensor
from torch.nn import Module

from torch_geometric.nn.inits import reset
from torch_geometric.utils import negative_sampling

EPS = 1e-15
MAX_LOGSTD = 10
edgeShape = None
featureShape = None


class InnerProductDecoder(torch.nn.Module):
    r"""The inner product decoder from the `"Variational Graph Auto-Encoders"
    <https://arxiv.org/abs/1611.07308>`_ paper

    .. math::
        \sigma(\mathbf{Z}\mathbf{Z}^{\top})

    where :math:`\mathbf{Z} \in \mathbb{R}^{N \times d}` denotes the latent
    space produced by the encoder."""

    def forward(self, z: Tensor, edge_index: Tensor,
                sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into edge probabilities for
        the given node-pairs :obj:`edge_index`.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        value = (z[edge_index[0]] * z[edge_index[1]]).sum(dim=1)
        return torch.sigmoid(value) if sigmoid else value

    def forward_all(self, z: Tensor, sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into a probabilistic dense
        adjacency matrix.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        adj = torch.matmul(z, z.t())
        return torch.sigmoid(adj) if sigmoid else adj


class GAE(torch.nn.Module):
    r"""The Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper based on user-defined encoder and decoder models.

    Args:
        encoder (torch.nn.Module): The encoder module.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__()
        self.encoder = encoder
        self.decoder = InnerProductDecoder() if decoder is None else decoder
        GAE.reset_parameters(self)

    def reset_parameters(self):
        r"""Resets all learnable parameters of the module."""
        reset(self.encoder)
        reset(self.decoder)

    def forward(self, *args, **kwargs) -> Tensor:  # pragma: no cover
        r"""Alias for :meth:`encode`."""
        return self.encoder(*args, **kwargs)

    def encode(self, *args, **kwargs) -> Tensor:
        r"""Runs the encoder and computes node-wise latent variables."""
        return self.encoder(*args, **kwargs)

    def decode(self, *args, **kwargs) -> Tensor:
        r"""Runs the decoder and computes edge probabilities."""
        return self.decoder(*args, **kwargs)

    def recon_loss(self, z: Tensor, pos_edge_index: Tensor,
                   neg_edge_index: Optional[Tensor] = None) -> Tensor:
        r"""Given latent variables :obj:`z`, computes the binary cross
        entropy loss for positive edges :obj:`pos_edge_index` and negative
        sampled edges.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to train against.
            neg_edge_index (torch.Tensor, optional): The negative edges to
                train against. If not given, uses negative sampling to
                calculate negative edges. (default: :obj:`None`)
        """
        pos_loss = -torch.log(
            self.decoder(z, pos_edge_index, sigmoid=True)[0] + EPS).mean()

        if neg_edge_index is None:
            neg_edge_index = negative_sampling(pos_edge_index, z.size(0))
        neg_loss = -torch.log(1 -
                              self.decoder(z, neg_edge_index.long(), sigmoid=True)[0] +
                              EPS).mean()

        return pos_loss + neg_loss

    def test(self, z: Tensor, pos_edge_index: Tensor,
             neg_edge_index: Tensor) -> Tuple[Tensor, Tensor]:
        r"""Given latent variables :obj:`z`, positive edges
        :obj:`pos_edge_index` and negative edges :obj:`neg_edge_index`,
        computes area under the ROC curve (AUC) and average precision (AP)
        
        scores.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to evaluate
                against.
            neg_edge_index (torch.Tensor): The negative edges to evaluate
                against.
        """
        from sklearn.metrics import average_precision_score, roc_auc_score

        pos_y = z.new_ones(pos_edge_index.size(1))
        neg_y = z.new_zeros(neg_edge_index.size(1))
        y = torch.cat([pos_y, neg_y], dim=0)

        pos_pred = self.decoder(z, pos_edge_index, sigmoid=True)
        neg_pred = self.decoder(z, neg_edge_index, sigmoid=True)
        pred = torch.cat([pos_pred, neg_pred], dim=0)

        y, pred = y.detach().cpu().numpy(), pred.detach().cpu().numpy()

        return roc_auc_score(y, pred), average_precision_score(y, pred)


class VGAE(GAE):
    r"""The Variational Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper.

    Args:
        encoder (torch.nn.Module): The encoder module to compute :math:`\mu`
            and :math:`\log\sigma^2`.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__(encoder, decoder)

    def reparametrize(self, mu: Tensor, logstd: Tensor) -> Tensor:
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def encode(self, *args, **kwargs) -> Tensor:
        """"""
        z, self.edge_index = self.encoder(
            *args, **kwargs)
        
        return z, self.edge_index

    def kl_loss(self, mu: Optional[Tensor] = None,
                logstd: Optional[Tensor] = None) -> Tensor:
        r"""Computes the KL loss, either for the passed arguments :obj:`mu`
        and :obj:`logstd`, or based on latent variables from last encoding.

        Args:
            mu (torch.Tensor, optional): The latent space for :math:`\mu`. If
                set to :obj:`None`, uses the last computation of :math:`\mu`.
                (default: :obj:`None`)
            logstd (torch.Tensor, optional): The latent space for
                :math:`\log\sigma`.  If set to :obj:`None`, uses the last
                computation of :math:`\log\sigma^2`. (default: :obj:`None`)
        """
        mu = self.__mu__ if mu is None else mu
        logstd = self.__logstd__ if logstd is None else logstd.clamp(
            max=MAX_LOGSTD)
        return -0.5 * torch.mean(
            torch.sum(1 + 2 * logstd - mu**2 - logstd.exp()**2, dim=1))

# %%
import torch.nn.functional as F



class VariationalGCNEncoder(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__() 
        # changes made such that guassian is 1 
        self.conv1 = GCNConv(in_channels, out_channels)
        self.conv2 = GCNConv( out_channels, 1 * out_channels)
        self.pool = SAGPooling(out_channels, 0.5)
        
        self.conv_mu = GCNConv(1 * out_channels, out_channels)
        self.conv_logstd = GCNConv(1 * out_channels, out_channels)
        self.conv_mu_crystal = GCNConv(1 * out_channels, out_channels)
        self.conv_logstd_crystal = GCNConv(1 * out_channels, out_channels)
        self.conv_mu_melt = GCNConv(1 * out_channels, out_channels)
        self.conv_logstd_melt = GCNConv(1 * out_channels, out_channels)
    
    def reparametrize(self, mu: Tensor, logstd: Tensor) -> Tensor:
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def forward(self, x, edge_index,class_label):
        # print("input:",x.shape, edge_index.shape)
        x = self.conv1(x, edge_index)
        x = F.silu(x)
        # print("conv1:",x.shape, edge_index.shape)
        x = self.conv2(x, edge_index)
        x = F.silu(x)
        # print("conv2:",x.shape, edge_index.shape)

        sample = self.reparametrize(self.conv_mu(x, edge_index), self.conv_logstd(x, edge_index))
        
        sample_crystal = self.reparametrize(self.conv_mu_crystal(sample, edge_index), self.conv_logstd_crystal(sample, edge_index))
        sample_melt = self.reparametrize(self.conv_mu_melt(sample, edge_index), self.conv_logstd_melt(sample, edge_index))

        self.conv_mu_crystal.train(True)
        self.conv_logstd_crystal.train(True)
        self.conv_mu_melt.train(True)
        self.conv_logstd_melt.train(True)


        if class_label == 0:
            self.conv_mu_melt.train(False)
            self.conv_logstd_melt.train(False)
            return sample_crystal, edge_index
        else:
            self.conv_mu_crystal.train(False)
            self.conv_logstd_crystal.train(False)
            return sample_melt, edge_index

# %%
class VariationalGCNDecoder(torch.nn.Module):
    def __init__(self,in_channels,out_channels):
        super().__init__()
        self.type_layer1 = Linear(1728,200)
        self.dropout = torch.nn.Dropout(0.5)
        self.type_layer2 = Linear(200,2)
        # changes made such that guassian is 1 
        self.conv1 = GCNConv(in_channels, out_channels)
        self.conv2 = GCNConv( out_channels, 1 * out_channels)
    def forward(self, x, edge_index, sigmoid=True):
        # print("input:",x.shape, edge_index.shape)
        flat = x.flatten()
        flat = self.type_layer1(flat).relu()
        flat = self.dropout(flat)
        str_type = F.softmax(self.type_layer2(flat).relu(),dim=0)
         
        x = self.conv1(x, edge_index)
        x = F.silu(x)
        # print("conv1:",x.shape, edge_index.shape)
        x = self.conv2(x, edge_index)
        x = F.silu(x)
        # print("conv2:",x.shape, edge_index.shape)
        return x, edge_index,str_type

# %%
import os
in_channels = graphs[0].num_features
out_channels = 2
lr = 1e-4
n_epochs = 200
batch_size=1
test_train_split = 0.8
model_name = "model2c.pt"
model_loaded = False
force_train = True  

if os.path.exists("./models/"+model_name) and not force_train:
    model = torch.load("./models/"+model_name)
    model_loaded = True
else:
    model = VGAE(VariationalGCNEncoder(in_channels, out_channels),
                VariationalGCNDecoder(out_channels, in_channels))

optimizer = torch.optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, step_size=300, gamma=0.5)

# %%
train_loader = DataLoader(graphs[:int(n_frames*test_train_split)], batch_size=batch_size, shuffle=True)
test_loader = DataLoader(graphs[int(n_frames*test_train_split):], batch_size=batch_size, shuffle=True)

# %%
lossFxn = torch.nn.MSELoss()
typeLossFxn = torch.nn.CrossEntropyLoss()

def train():
    model.train()
    model.zero_grad()
    model.float()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0
    type_loss_all = 0
    for data in train_loader:
        optimizer.zero_grad()
        z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
        decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)

     
        # TypeLoss = typeLossFxn(str_type.unsqueeze(0), data.y)
        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        loss = FeatureLoss + EdgeLoss 

        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        # type_loss_all += float(TypeLoss)

        loss.backward()
        optimizer.step()
        

    return loss_all / len(train_loader), feature_loss_all / len(train_loader), edge_loss_all / len(train_loader), kl_loss_all / len(train_loader), type_loss_all / len(train_loader)

# %%
lossFxn = torch.nn.MSELoss()
def test():
    model.eval()
    model.zero_grad()
    model.float()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0
    type_loss_all = 0

    for data in test_loader:
        optimizer.zero_grad()
        z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
        decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
        
        # TypeLoss = typeLossFxn(str_type.unsqueeze(0), data.y)
        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        loss = FeatureLoss + EdgeLoss 

        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        # type_loss_all += float(TypeLoss)
        
        
        

    return loss_all / len(test_loader), feature_loss_all / len(test_loader), edge_loss_all / len(test_loader), kl_loss_all / len(test_loader), type_loss_all / len(test_loader)

# %%
train_total_losses = []
train_feature_losses = []
train_edge_losses = []
train_kl_losses = []
train_type_losses = []

test_total_losses = []
test_feature_losses = []
test_edge_losses = []
test_kl_losses = []
test_type_losses = []

if model_loaded:        
    print("Pretrained Model Loaded, no training required")
else:
    for epoch in range(1, n_epochs + 1):
        
        train_total_loss, train_feature_loss, train_edge_loss, train_kl_loss,train_type_loss = train()
        test_total_loss, test_feature_loss, test_edge_loss, test_kl_loss, test_type_loss= test()
        
        print(f"Epoch: {epoch:03d}")
        print(f'\tTrain:\tTotal Loss: {train_total_loss:.4f}, Feature Loss: {train_feature_loss:.4f}, Type Loss: {train_type_loss:.4f} ,  LR: {scheduler.get_last_lr()[0]:.6f}')
        print(f'\tTest: \tTotal Loss: {test_total_loss:.4f}, Feature Loss: {test_feature_loss:.4f}, Type Loss: {test_type_loss:.4f} , LR: {scheduler.get_last_lr()[0]:.6f}')
        
        
        train_total_losses.append(train_total_loss)
        train_feature_losses.append(train_feature_loss)
        train_edge_losses.append(train_edge_loss)
        train_kl_losses.append(train_kl_loss)
        train_type_losses.append(train_type_loss)


        test_total_losses.append(test_total_loss)
        test_feature_losses.append(test_feature_loss)
        test_edge_losses.append(test_edge_loss)
        test_kl_losses.append(test_kl_loss)
        test_type_losses.append(test_type_loss)
        
        scheduler.step()
    torch.save(model,"./models/"+model_name)
# Out:
# Epoch: 001
# 	Train:	Total Loss: 11.6185, Feature Loss: 11.6185, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.1240, Feature Loss: 12.1240, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 002
# 	Train:	Total Loss: 11.5962, Feature Loss: 11.5962, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0999, Feature Loss: 12.0999, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 003
# 	Train:	Total Loss: 11.5817, Feature Loss: 11.5817, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0752, Feature Loss: 12.0752, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 004
# 	Train:	Total Loss: 11.5545, Feature Loss: 11.5545, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0495, Feature Loss: 12.0495, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 005
# 	Train:	Total Loss: 11.5277, Feature Loss: 11.5277, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0227, Feature Loss: 12.0227, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 006
# 	Train:	Total Loss: 11.4988, Feature Loss: 11.4988, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.9943, Feature Loss: 11.9943, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 007
# 	Train:	Total Loss: 11.4654, Feature Loss: 11.4654, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.9642, Feature Loss: 11.9642, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 008
# 	Train:	Total Loss: 11.4460, Feature Loss: 11.4460, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.9329, Feature Loss: 11.9329, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 009
# 	Train:	Total Loss: 11.4025, Feature Loss: 11.4025, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.8994, Feature Loss: 11.8994, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 010
# 	Train:	Total Loss: 11.3753, Feature Loss: 11.3753, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.8637, Feature Loss: 11.8637, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 011
# 	Train:	Total Loss: 11.3419, Feature Loss: 11.3419, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.8261, Feature Loss: 11.8261, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 012
# 	Train:	Total Loss: 11.2982, Feature Loss: 11.2982, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.7858, Feature Loss: 11.7858, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 013
# 	Train:	Total Loss: 11.2551, Feature Loss: 11.2551, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.7430, Feature Loss: 11.7430, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 014
# 	Train:	Total Loss: 11.2161, Feature Loss: 11.2161, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.6974, Feature Loss: 11.6974, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 015
# 	Train:	Total Loss: 11.1610, Feature Loss: 11.1610, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.6483, Feature Loss: 11.6483, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 016
# 	Train:	Total Loss: 11.1197, Feature Loss: 11.1197, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.5963, Feature Loss: 11.5963, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 017
# 	Train:	Total Loss: 11.0776, Feature Loss: 11.0776, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.5413, Feature Loss: 11.5413, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 018
# 	Train:	Total Loss: 11.0076, Feature Loss: 11.0076, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.4813, Feature Loss: 11.4813, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 019
# 	Train:	Total Loss: 10.9376, Feature Loss: 10.9376, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.4169, Feature Loss: 11.4169, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 020
# 	Train:	Total Loss: 10.8805, Feature Loss: 10.8805, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.3492, Feature Loss: 11.3492, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 021
# 	Train:	Total Loss: 10.8188, Feature Loss: 10.8188, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.2768, Feature Loss: 11.2768, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 022
# 	Train:	Total Loss: 10.7395, Feature Loss: 10.7395, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.1995, Feature Loss: 11.1995, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 023
# 	Train:	Total Loss: 10.6765, Feature Loss: 10.6765, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.1180, Feature Loss: 11.1180, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 024
# 	Train:	Total Loss: 10.5924, Feature Loss: 10.5924, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.0312, Feature Loss: 11.0312, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 025
# 	Train:	Total Loss: 10.5115, Feature Loss: 10.5115, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.9396, Feature Loss: 10.9396, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 026
# 	Train:	Total Loss: 10.3911, Feature Loss: 10.3911, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.8411, Feature Loss: 10.8411, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 027
# 	Train:	Total Loss: 10.2944, Feature Loss: 10.2944, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.7369, Feature Loss: 10.7369, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 028
# 	Train:	Total Loss: 10.1857, Feature Loss: 10.1857, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.6264, Feature Loss: 10.6264, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 029
# 	Train:	Total Loss: 10.0901, Feature Loss: 10.0901, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.5106, Feature Loss: 10.5106, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 030
# 	Train:	Total Loss: 9.9764, Feature Loss: 9.9764, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.3886, Feature Loss: 10.3886, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 031
# 	Train:	Total Loss: 9.8586, Feature Loss: 9.8586, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.2606, Feature Loss: 10.2606, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 032
# 	Train:	Total Loss: 9.7193, Feature Loss: 9.7193, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.1257, Feature Loss: 10.1257, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 033
# 	Train:	Total Loss: 9.6029, Feature Loss: 9.6029, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.9857, Feature Loss: 9.9857, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 034
# 	Train:	Total Loss: 9.4070, Feature Loss: 9.4070, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.8377, Feature Loss: 9.8377, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 035
# 	Train:	Total Loss: 9.2984, Feature Loss: 9.2984, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.6834, Feature Loss: 9.6834, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 036
# 	Train:	Total Loss: 9.0988, Feature Loss: 9.0988, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.5224, Feature Loss: 9.5224, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 037
# 	Train:	Total Loss: 8.9284, Feature Loss: 8.9284, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.3567, Feature Loss: 9.3567, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 038
# 	Train:	Total Loss: 8.8271, Feature Loss: 8.8271, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.1873, Feature Loss: 9.1873, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 039
# 	Train:	Total Loss: 8.6327, Feature Loss: 8.6327, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.0117, Feature Loss: 9.0117, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 040
# 	Train:	Total Loss: 8.4944, Feature Loss: 8.4944, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.8331, Feature Loss: 8.8331, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 041
# 	Train:	Total Loss: 8.3266, Feature Loss: 8.3266, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.6516, Feature Loss: 8.6516, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 042
# 	Train:	Total Loss: 8.1252, Feature Loss: 8.1252, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.4682, Feature Loss: 8.4682, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 043
# 	Train:	Total Loss: 7.9844, Feature Loss: 7.9844, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.2812, Feature Loss: 8.2812, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 044
# 	Train:	Total Loss: 7.8391, Feature Loss: 7.8391, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.0938, Feature Loss: 8.0938, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 045
# 	Train:	Total Loss: 7.6177, Feature Loss: 7.6177, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.9052, Feature Loss: 7.9052, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 046
# 	Train:	Total Loss: 7.3855, Feature Loss: 7.3855, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7
Type Loss: 0.0000 , LR: 0.000100
# Epoch: 160
# 	Train:	Total Loss: 3.5518, Feature Loss: 3.5518, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6564, Feature Loss: 3.6564, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 161
# 	Train:	Total Loss: 3.5444, Feature Loss: 3.5444, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6539, Feature Loss: 3.6539, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 162
# 	Train:	Total Loss: 3.5267, Feature Loss: 3.5267, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6510, Feature Loss: 3.6510, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 163
# 	Train:	Total Loss: 3.5447, Feature Loss: 3.5447, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6488, Feature Loss: 3.6488, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 164
# 	Train:	Total Loss: 3.5356, Feature Loss: 3.5356, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6458, Feature Loss: 3.6458, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 165
# 	Train:	Total Loss: 3.5308, Feature Loss: 3.5308, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6434, Feature Loss: 3.6434, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 166
# 	Train:	Total Loss: 3.5362, Feature Loss: 3.5362, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6407, Feature Loss: 3.6407, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 167
# 	Train:	Total Loss: 3.5192, Feature Loss: 3.5192, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6382, Feature Loss: 3.6382, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 168
# 	Train:	Total Loss: 3.5241, Feature Loss: 3.5241, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6355, Feature Loss: 3.6355, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 169
# 	Train:	Total Loss: 3.5321, Feature Loss: 3.5321, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6338, Feature Loss: 3.6338, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 170
# 	Train:	Total Loss: 3.5229, Feature Loss: 3.5229, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6322, Feature Loss: 3.6322, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 171
# 	Train:	Total Loss: 3.5096, Feature Loss: 3.5096, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6299, Feature Loss: 3.6299, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 172
# 	Train:	Total Loss: 3.4885, Feature Loss: 3.4885, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6273, Feature Loss: 3.6273, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 173
# 	Train:	Total Loss: 3.4877, Feature Loss: 3.4877, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6249, Feature Loss: 3.6249, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 174
# 	Train:	Total Loss: 3.4992, Feature Loss: 3.4992, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6231, Feature Loss: 3.6231, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 175
# 	Train:	Total Loss: 3.4986, Feature Loss: 3.4986, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6212, Feature Loss: 3.6212, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 176
# 	Train:	Total Loss: 3.4952, Feature Loss: 3.4952, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6187, Feature Loss: 3.6187, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 177
# 	Train:	Total Loss: 3.4853, Feature Loss: 3.4853, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6162, Feature Loss: 3.6162, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 178
# 	Train:	Total Loss: 3.5070, Feature Loss: 3.5070, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6144, Feature Loss: 3.6144, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 179
# 	Train:	Total Loss: 3.4859, Feature Loss: 3.4859, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6134, Feature Loss: 3.6134, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 180
# 	Train:	Total Loss: 3.4774, Feature Loss: 3.4774, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6115, Feature Loss: 3.6115, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 181
# 	Train:	Total Loss: 3.5049, Feature Loss: 3.5049, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6091, Feature Loss: 3.6091, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 182
# 	Train:	Total Loss: 3.4842, Feature Loss: 3.4842, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6071, Feature Loss: 3.6071, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 183
# 	Train:	Total Loss: 3.4837, Feature Loss: 3.4837, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6045, Feature Loss: 3.6045, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 184
# 	Train:	Total Loss: 3.4822, Feature Loss: 3.4822, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6032, Feature Loss: 3.6032, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 185
# 	Train:	Total Loss: 3.4563, Feature Loss: 3.4563, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6007, Feature Loss: 3.6007, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 186
# 	Train:	Total Loss: 3.4476, Feature Loss: 3.4476, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5988, Feature Loss: 3.5988, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 187
# 	Train:	Total Loss: 3.4571, Feature Loss: 3.4571, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5971, Feature Loss: 3.5971, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 188
# 	Train:	Total Loss: 3.4435, Feature Loss: 3.4435, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5954, Feature Loss: 3.5954, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 189
# 	Train:	Total Loss: 3.4943, Feature Loss: 3.4943, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5934, Feature Loss: 3.5934, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 190
# 	Train:	Total Loss: 3.4358, Feature Loss: 3.4358, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5917, Feature Loss: 3.5917, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 191
# 	Train:	Total Loss: 3.4511, Feature Loss: 3.4511, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5895, Feature Loss: 3.5895, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 192
# 	Train:	Total Loss: 3.4564, Feature Loss: 3.4564, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5872, Feature Loss: 3.5872, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 193
# 	Train:	Total Loss: 3.4415, Feature Loss: 3.4415, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5852, Feature Loss: 3.5852, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 194
# 	Train:	Total Loss: 3.4481, Feature Loss: 3.4481, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5835, Feature Loss: 3.5835, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 195
# 	Train:	Total Loss: 3.4371, Feature Loss: 3.4371, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5814, Feature Loss: 3.5814, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 196
# 	Train:	Total Loss: 3.4436, Feature Loss: 3.4436, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5804, Feature Loss: 3.5804, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 197
# 	Train:	Total Loss: 3.4416, Feature Loss: 3.4416, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5781, Feature Loss: 3.5781, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 198
# 	Train:	Total Loss: 3.4317, Feature Loss: 3.4317, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5767, Feature Loss: 3.5767, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 199
# 	Train:	Total Loss: 3.4129, Feature Loss: 3.4129, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5744, Feature Loss: 3.5744, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 200
# 	Train:	Total Loss: 3.4300, Feature Loss: 3.4300, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5720, Feature Loss: 3.5720, Type Loss: 0.0000 , LR: 0.000100

# %%
if not model_loaded:
    plt.figure(figsize=(14, 5))
    plt.plot(test_total_losses, label='Total Test Loss')
    plt.plot(train_total_losses, label='Total Train Loss')
    plt.legend()
    plt.title('Total Loss')
    plt.savefig("model2c_totalloss.png")
    plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
if not model_loaded:
    plt.figure(figsize=(14, 5))
    plt.plot(test_feature_losses, label='Test Feature Loss')
    plt.plot(train_feature_losses, label='Train Feature Loss')
    plt.legend()
    plt.title('Feature Loss')
    plt.savefig("model2c_featureloss.png")
    plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
test_loader_melt = DataLoader(graphs_melt, batch_size=1)
encoded_data_melt=[]
type_data_melt = []
for data in test_loader:
    model.eval()
    z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
    decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
    encoded_data_melt.append(z.detach().numpy())
    type_data_melt.append(str_type.detach().numpy())

encoded_data_melt = np.array(encoded_data_melt)
type_data_melt = np.array(type_data_melt)

# %%
test_loader_cry = DataLoader(graphs_cry, batch_size=1)
encoded_data_cry=[]
type_data_cry = []
for data in test_loader:
    model.eval()
    z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
    decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
    encoded_data_cry.append(z.detach().numpy())
    type_data_cry.append(str_type.detach().numpy())

encoded_data_cry = np.array(encoded_data_cry)
type_data_cry = np.array(type_data_cry)

# %%
# %matplotlib widget

frame = 10

fig = plt.figure(figsize=(15,4))
data_melt = encoded_data_melt[frame]

data_cry = encoded_data_cry[frame]
plt.scatter(data_melt[:,0],data_melt[:,1],c="r",label="melt")
plt.scatter(data_cry[:,0],data_cry[:,1],c="b",label="crystal")
plt.savefig("model2c_scatter.png")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
