# %%
import mdtraj as md
from ase import Atoms
import nglview as nv
import networkx as nx

import numpy as np
import matplotlib.pyplot as plt
import torch
from tqdm import tqdm

import torch_geometric.transforms as T
from torch_geometric.loader import DataLoader
from torch_geometric.nn import GCNConv, SAGPooling, InnerProductDecoder
import torch_geometric.data as data
from torch_geometric.utils.convert import to_networkx
import torch.optim.lr_scheduler as lr_scheduler
from torch.nn import Linear
import sys

# %%
all_frames_cry = md.load_xtc("../simulation/para_crystal.xtc", top="../simulation/para_crystal.gro")
all_frames_melt = md.load_xtc("../simulation/para_melt.xtc", top="../simulation/para_melt.gro")

# %%
all_frames_cry = all_frames_cry[::100]
all_frames_melt = all_frames_melt[::100]

# %%
n_frames = all_frames_cry.xyz.shape[0]
n_atoms = all_frames_cry.topology.residue(0).n_atoms
n_mols = all_frames_cry.topology.n_residues

# %%
def createGraph(all_frames,structure_type="crystal"):
    all_frames_fatures = []

    print("Creating Feature matrix")
    for i in tqdm(range(all_frames.xyz.shape[0])):
        mol_com_pos = []

        for res in all_frames.top.residues:
            pos = []
            for atom in res.atoms:
                pos.append(all_frames.xyz[i][atom.index])
            mol_com_pos.append(np.mean(pos,axis=0))
            
            # print()
        mol_com_pos = np.array(mol_com_pos).astype(np.float32)  
        all_frames_fatures.append(mol_com_pos)

    all_frames_fatures = np.array(all_frames_fatures).astype(np.float32)



    cutoff = 0.8

    print("Creating Edge list")
    all_edge_list = []
    # with open("edge_list.txt","w") as f:
    for frame_i in tqdm(range(n_frames)):
        from_list = []
        to_list = []

        for i in range(len(all_frames_fatures[frame_i])):
            for j in range(i+1,len(all_frames_fatures[frame_i])):
                if np.linalg.norm(all_frames_fatures[frame_i][i]-all_frames_fatures[frame_i][j]) < cutoff:
                    # f.write(str(i)+" "+str(j)+" "+str(np.linalg.norm(all_frames_fatures[frame_i][i]-all_frames_fatures[frame_i][j]))+"\n")
                    from_list.append(i)
                    to_list.append(j)

                    to_list.append(i)
                    from_list.append(j)

        edge_list = np.array([from_list,to_list]).astype(np.int64)
        all_edge_list.append(edge_list)
    print("creating Graphs")
    graphs = []
    for frame in tqdm(range(n_frames)):
        if structure_type == "crystal":
            g = data.Data(x=torch.tensor(all_frames_fatures[frame]).float(), edge_index=torch.tensor(all_edge_list[frame]).long(), y=torch.tensor([0]))
        else:
            g = data.Data(x=torch.tensor(all_frames_fatures[frame]).float(), edge_index=torch.tensor(all_edge_list[frame]).long(), y=torch.tensor([1]))
        graphs.append(g)
    return graphs

# %%
graphs_cry = createGraph(all_frames_cry,structure_type="crystal")
graphs_melt = createGraph(all_frames_melt,structure_type="melt")
# Out:
# Creating Feature matrix
# 100%|██████████| 51/51 [00:00<00:00, 90.27it/s]
# Creating Edge list
# 100%|██████████| 51/51 [01:15<00:00,  1.48s/it]
# creating Graphs
# 100%|██████████| 51/51 [00:00<00:00, 13509.51it/s]
# Creating Feature matrix
# 100%|██████████| 51/51 [00:01<00:00, 42.70it/s]
# Creating Edge list
# 100%|██████████| 51/51 [01:42<00:00,  2.00s/it]
# creating Graphs
# 100%|██████████| 51/51 [00:00<00:00, 18281.30it/s]

# %%
def convert_to_adj(edge_index, num_nodes=None):
    if num_nodes is None:
        num_nodes = edge_index.max() + 1
    adj = torch.zeros(num_nodes, num_nodes)
    adj[edge_index[0], edge_index[1]] = 1
    return adj

def convert_to_edge_index(adj):
    edge_index = adj.nonzero().t()
    return edge_index

# %%
# graphs = graphs_cry + graphs_melt
graphs = graphs_melt

# %%
# shuffle the graphs
np.random.shuffle(graphs)

# %%
graphs
# Out:
# [Data(x=[864, 3], edge_index=[2, 6488], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6066], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6630], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6172], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6464], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6582], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6554], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5822], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6288], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6056], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6070], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6546], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6532], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6584], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5962], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6608], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6560], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6602], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6524], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6552], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6400], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6544], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5982], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6592], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6626], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6586], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6512], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6508], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6476], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6560], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6548], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5880], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6596], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6578], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6564], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6558], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6548], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5862], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6452], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6018], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6508], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5910], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6012], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6570], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6546], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6580], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6542], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5892], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6214], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6566], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5876], y=[1])]

# %% [markdown]
# ## model

# %%
from typing import Optional, Tuple

import torch
from torch import Tensor
from torch.nn import Module

from torch_geometric.nn.inits import reset
from torch_geometric.utils import negative_sampling

EPS = 1e-15
MAX_LOGSTD = 10
edgeShape = None
featureShape = None


class InnerProductDecoder(torch.nn.Module):
    r"""The inner product decoder from the `"Variational Graph Auto-Encoders"
    <https://arxiv.org/abs/1611.07308>`_ paper

    .. math::
        \sigma(\mathbf{Z}\mathbf{Z}^{\top})

    where :math:`\mathbf{Z} \in \mathbb{R}^{N \times d}` denotes the latent
    space produced by the encoder."""

    def forward(self, z: Tensor, edge_index: Tensor,
                sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into edge probabilities for
        the given node-pairs :obj:`edge_index`.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        value = (z[edge_index[0]] * z[edge_index[1]]).sum(dim=1)
        return torch.sigmoid(value) if sigmoid else value

    def forward_all(self, z: Tensor, sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into a probabilistic dense
        adjacency matrix.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        adj = torch.matmul(z, z.t())
        return torch.sigmoid(adj) if sigmoid else adj


class GAE(torch.nn.Module):
    r"""The Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper based on user-defined encoder and decoder models.

    Args:
        encoder (torch.nn.Module): The encoder module.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__()
        self.encoder = encoder
        self.decoder = InnerProductDecoder() if decoder is None else decoder
        GAE.reset_parameters(self)

    def reset_parameters(self):
        r"""Resets all learnable parameters of the module."""
        reset(self.encoder)
        reset(self.decoder)

    def forward(self, *args, **kwargs) -> Tensor:  # pragma: no cover
        r"""Alias for :meth:`encode`."""
        return self.encoder(*args, **kwargs)

    def encode(self, *args, **kwargs) -> Tensor:
        r"""Runs the encoder and computes node-wise latent variables."""
        return self.encoder(*args, **kwargs)

    def decode(self, *args, **kwargs) -> Tensor:
        r"""Runs the decoder and computes edge probabilities."""
        return self.decoder(*args, **kwargs)

    def recon_loss(self, z: Tensor, pos_edge_index: Tensor,
                   neg_edge_index: Optional[Tensor] = None) -> Tensor:
        r"""Given latent variables :obj:`z`, computes the binary cross
        entropy loss for positive edges :obj:`pos_edge_index` and negative
        sampled edges.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to train against.
            neg_edge_index (torch.Tensor, optional): The negative edges to
                train against. If not given, uses negative sampling to
                calculate negative edges. (default: :obj:`None`)
        """
        pos_loss = -torch.log(
            self.decoder(z, pos_edge_index, sigmoid=True)[0] + EPS).mean()

        if neg_edge_index is None:
            neg_edge_index = negative_sampling(pos_edge_index, z.size(0))
        neg_loss = -torch.log(1 -
                              self.decoder(z, neg_edge_index.long(), sigmoid=True)[0] +
                              EPS).mean()

        return pos_loss + neg_loss

    def test(self, z: Tensor, pos_edge_index: Tensor,
             neg_edge_index: Tensor) -> Tuple[Tensor, Tensor]:
        r"""Given latent variables :obj:`z`, positive edges
        :obj:`pos_edge_index` and negative edges :obj:`neg_edge_index`,
        computes area under the ROC curve (AUC) and average precision (AP)
        
        scores.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to evaluate
                against.
            neg_edge_index (torch.Tensor): The negative edges to evaluate
                against.
        """
        from sklearn.metrics import average_precision_score, roc_auc_score

        pos_y = z.new_ones(pos_edge_index.size(1))
        neg_y = z.new_zeros(neg_edge_index.size(1))
        y = torch.cat([pos_y, neg_y], dim=0)

        pos_pred = self.decoder(z, pos_edge_index, sigmoid=True)
        neg_pred = self.decoder(z, neg_edge_index, sigmoid=True)
        pred = torch.cat([pos_pred, neg_pred], dim=0)

        y, pred = y.detach().cpu().numpy(), pred.detach().cpu().numpy()

        return roc_auc_score(y, pred), average_precision_score(y, pred)


class VGAE(GAE):
    r"""The Variational Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper.

    Args:
        encoder (torch.nn.Module): The encoder module to compute :math:`\mu`
            and :math:`\log\sigma^2`.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__(encoder, decoder)

    def reparametrize(self, mu: Tensor, logstd: Tensor) -> Tensor:
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def encode(self, *args, **kwargs) -> Tensor:
        """"""
        z, self.edge_index = self.encoder(
            *args, **kwargs)
        
        return z, self.edge_index

    def kl_loss(self, mu: Optional[Tensor] = None,
                logstd: Optional[Tensor] = None) -> Tensor:
        r"""Computes the KL loss, either for the passed arguments :obj:`mu`
        and :obj:`logstd`, or based on latent variables from last encoding.

        Args:
            mu (torch.Tensor, optional): The latent space for :math:`\mu`. If
                set to :obj:`None`, uses the last computation of :math:`\mu`.
                (default: :obj:`None`)
            logstd (torch.Tensor, optional): The latent space for
                :math:`\log\sigma`.  If set to :obj:`None`, uses the last
                computation of :math:`\log\sigma^2`. (default: :obj:`None`)
        """
        mu = self.__mu__ if mu is None else mu
        logstd = self.__logstd__ if logstd is None else logstd.clamp(
            max=MAX_LOGSTD)
        return -0.5 * torch.mean(
            torch.sum(1 + 2 * logstd - mu**2 - logstd.exp()**2, dim=1))

# %%
import torch.nn.functional as F



class VariationalGCNEncoder(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__() 
        # changes made such that guassian is 1 
        self.conv1 = GCNConv(in_channels, out_channels)
        self.conv2 = GCNConv( out_channels, 1 * out_channels)
        self.pool = SAGPooling(out_channels, 0.5)
        
        self.conv_mu = GCNConv(1 * out_channels, out_channels)
        self.conv_logstd = GCNConv(1 * out_channels, out_channels)
        self.conv_mu_crystal = GCNConv(1 * out_channels, out_channels)
        self.conv_logstd_crystal = GCNConv(1 * out_channels, out_channels)
        self.conv_mu_melt = GCNConv(1 * out_channels, out_channels)
        self.conv_logstd_melt = GCNConv(1 * out_channels, out_channels)
    
    def reparametrize(self, mu: Tensor, logstd: Tensor) -> Tensor:
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def forward(self, x, edge_index,class_label):
        # print("input:",x.shape, edge_index.shape)
        x = self.conv1(x, edge_index)
        x = F.silu(x)
        # print("conv1:",x.shape, edge_index.shape)
        x = self.conv2(x, edge_index)
        x = F.silu(x)
        # print("conv2:",x.shape, edge_index.shape)

        sample = self.reparametrize(self.conv_mu(x, edge_index), self.conv_logstd(x, edge_index))
        
        sample_crystal = self.reparametrize(self.conv_mu_crystal(sample, edge_index), self.conv_logstd_crystal(sample, edge_index))
        sample_melt = self.reparametrize(self.conv_mu_melt(sample, edge_index), self.conv_logstd_melt(sample, edge_index))

        self.conv_mu_crystal.train(True)
        self.conv_logstd_crystal.train(True)
        self.conv_mu_melt.train(True)
        self.conv_logstd_melt.train(True)


        if class_label == 0:
            self.conv_mu_melt.train(False)
            self.conv_logstd_melt.train(False)
            return sample_crystal, edge_index
        else:
            self.conv_mu_crystal.train(False)
            self.conv_logstd_crystal.train(False)
            return sample_melt, edge_index

# %%
class VariationalGCNDecoder(torch.nn.Module):
    def __init__(self,in_channels,out_channels):
        super().__init__()
        self.type_layer1 = Linear(1728,200)
        self.dropout = torch.nn.Dropout(0.5)
        self.type_layer2 = Linear(200,2)
         # changes made such that guassian is 1 
        self.conv1 = GCNConv(in_channels, out_channels)
        self.conv2 = GCNConv( out_channels, 1 * out_channels)
    def forward(self, x, edge_index, sigmoid=True):
        # print("input:",x.shape, edge_index.shape)
        flat = x.flatten()
        flat = self.type_layer1(flat).relu()
        flat = self.dropout(flat)
        str_type = F.softmax(self.type_layer2(flat).relu(),dim=0)
         
        x = self.conv1(x, edge_index)
        x = F.silu(x)
        # print("conv1:",x.shape, edge_index.shape)
        x = self.conv2(x, edge_index)
        x = F.silu(x)
        # print("conv2:",x.shape, edge_index.shape)
        return x, edge_index,str_type

# %%
import os
in_channels = graphs[0].num_features
out_channels = 2
lr = 1e-4
n_epochs = 200
batch_size=1
test_train_split = 0.8
model_name = "model3c.pt"
model_loaded = False
force_train = True  

if os.path.exists("./models/"+model_name) and not force_train:
    model = torch.load("./models/"+model_name)
    model_loaded = True
else:
    model = VGAE(VariationalGCNEncoder(in_channels, out_channels),
                VariationalGCNDecoder(out_channels, in_channels))

optimizer = torch.optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, step_size=300, gamma=0.5)

# %%
train_loader = DataLoader(graphs[:int(n_frames*test_train_split)], batch_size=batch_size, shuffle=True)
test_loader = DataLoader(graphs[int(n_frames*test_train_split):], batch_size=batch_size, shuffle=True)

# %%
lossFxn = torch.nn.MSELoss()
typeLossFxn = torch.nn.CrossEntropyLoss()

def train():
    model.train()
    model.zero_grad()
    model.float()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0
    type_loss_all = 0
    for data in train_loader:
        optimizer.zero_grad()
        z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
        decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)

     
        # TypeLoss = typeLossFxn(str_type.unsqueeze(0), data.y)
        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        loss = FeatureLoss + EdgeLoss 

        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        # type_loss_all += float(TypeLoss)

        loss.backward()
        optimizer.step()
        

    return loss_all / len(train_loader), feature_loss_all / len(train_loader), edge_loss_all / len(train_loader), kl_loss_all / len(train_loader), type_loss_all / len(train_loader)

# %%
lossFxn = torch.nn.MSELoss()
def test():
    model.eval()
    model.zero_grad()
    model.float()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0
    type_loss_all = 0

    for data in test_loader:
        optimizer.zero_grad()
        z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
        decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
        
        # TypeLoss = typeLossFxn(str_type.unsqueeze(0), data.y)
        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        loss = FeatureLoss + EdgeLoss 

        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        # type_loss_all += float(TypeLoss)
        
        
        

    return loss_all / len(test_loader), feature_loss_all / len(test_loader), edge_loss_all / len(test_loader), kl_loss_all / len(test_loader), type_loss_all / len(test_loader)

# %%
train_total_losses = []
train_feature_losses = []
train_edge_losses = []
train_kl_losses = []
train_type_losses = []

test_total_losses = []
test_feature_losses = []
test_edge_losses = []
test_kl_losses = []
test_type_losses = []

if model_loaded:        
    print("Pretrained Model Loaded, no training required")
else:
    for epoch in range(1, n_epochs + 1):
        
        train_total_loss, train_feature_loss, train_edge_loss, train_kl_loss,train_type_loss = train()
        test_total_loss, test_feature_loss, test_edge_loss, test_kl_loss, test_type_loss= test()
        
        print(f"Epoch: {epoch:03d}")
        print(f'\tTrain:\tTotal Loss: {train_total_loss:.4f}, Feature Loss: {train_feature_loss:.4f}, Type Loss: {train_type_loss:.4f} ,  LR: {scheduler.get_last_lr()[0]:.6f}')
        print(f'\tTest: \tTotal Loss: {test_total_loss:.4f}, Feature Loss: {test_feature_loss:.4f}, Type Loss: {test_type_loss:.4f} , LR: {scheduler.get_last_lr()[0]:.6f}')
        
        
        train_total_losses.append(train_total_loss)
        train_feature_losses.append(train_feature_loss)
        train_edge_losses.append(train_edge_loss)
        train_kl_losses.append(train_kl_loss)
        train_type_losses.append(train_type_loss)


        test_total_losses.append(test_total_loss)
        test_feature_losses.append(test_feature_loss)
        test_edge_losses.append(test_edge_loss)
        test_kl_losses.append(test_kl_loss)
        test_type_losses.append(test_type_loss)
        
        scheduler.step()
    torch.save(model,"./models/"+model_name)
# Out:
# Epoch: 001
# 	Train:	Total Loss: 81344834009328.5156, Feature Loss: 81344834009328.5156, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0386, Feature Loss: 12.0386, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 002
# 	Train:	Total Loss: 144650165752256.7188, Feature Loss: 144650165752256.7188, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0657, Feature Loss: 12.0657, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 003
# 	Train:	Total Loss: 33678875530462.8633, Feature Loss: 33678875530462.8633, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0894, Feature Loss: 12.0894, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 004
# 	Train:	Total Loss: 49132873510744.4844, Feature Loss: 49132873510744.4844, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.1098, Feature Loss: 12.1098, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 005
# 	Train:	Total Loss: 39180895491160.1406, Feature Loss: 39180895491160.1406, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.1284, Feature Loss: 12.1284, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 006
# 	Train:	Total Loss: 28173771868865.2617, Feature Loss: 28173771868865.2617, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.1532, Feature Loss: 12.1532, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 007
# 	Train:	Total Loss: 26849673071462.9141, Feature Loss: 26849673071462.9141, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.1794, Feature Loss: 12.1794, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 008
# 	Train:	Total Loss: 712662818594424.0000, Feature Loss: 712662818594424.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.2571, Feature Loss: 12.2571, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 009
# 	Train:	Total Loss: 18621723455670.1875, Feature Loss: 18621723455670.1875, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.2664, Feature Loss: 12.2664, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 010
# 	Train:	Total Loss: 615821998412537.1250, Feature Loss: 615821998412537.1250, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.2783, Feature Loss: 12.2783, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 011
# 	Train:	Total Loss: 34913027839045.8008, Feature Loss: 34913027839045.8008, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.2785, Feature Loss: 12.2785, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 012
# 	Train:	Total Loss: 429263702673814.4375, Feature Loss: 429263702673814.4375, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.3070, Feature Loss: 12.3070, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 013
# 	Train:	Total Loss: 21638489514517.3945, Feature Loss: 21638489514517.3945, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.3317, Feature Loss: 12.3317, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 014
# 	Train:	Total Loss: 140204929435516.4062, Feature Loss: 140204929435516.4062, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.3358, Feature Loss: 12.3358, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 015
# 	Train:	Total Loss: 8695061781206.4248, Feature Loss: 8695061781206.4248, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.3404, Feature Loss: 12.3404, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 016
# 	Train:	Total Loss: 13832876020518.9570, Feature Loss: 13832876020518.9570, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.3435, Feature Loss: 12.3435, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 017
# 	Train:	Total Loss: 14399479084608.0254, Feature Loss: 14399479084608.0254, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.3490, Feature Loss: 12.3490, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 018
# 	Train:	Total Loss: 152513187835768.6875, Feature Loss: 152513187835768.6875, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.3713, Feature Loss: 12.3713, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 019
# 	Train:	Total Loss: 35933924161972.7109, Feature Loss: 35933924161972.7109, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.3769, Feature Loss: 12.3769, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 020
# 	Train:	Total Loss: 16526842060076.6191, Feature Loss: 16526842060076.6191, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.3813, Feature Loss: 12.3813, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 021
# 	Train:	Total Loss: 30912752715697.6484, Feature Loss: 30912752715697.6484, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.3931, Feature Loss: 12.3931, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 022
# 	Train:	Total Loss: 55817499033654.3906, Feature Loss: 55817499033654.3906, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.3985, Feature Loss: 12.3985, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 023
# 	Train:	Total Loss: 2424957772529.8789, Feature Loss: 2424957772529.8789, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.4011, Feature Loss: 12.4011, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 024
# 	Train:	Total Loss: 3600195947770.4092, Feature Loss: 3600195947770.4092, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.4034, Feature Loss: 12.4034, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 025
# 	Train:	Total Loss: 2898953341485.9551, Feature Loss: 2898953341485.9551, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.4058, Feature Loss: 12.4058, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 026
# 	Train:	Total Loss: 3892293663425.1367, Feature Loss: 3892293663425.1367, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.4072, Feature Loss: 12.4072, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 027
# 	Train:	Total Loss: 11708336043173.3555, Feature Loss: 11708336043173.3555, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.4164, Feature Loss: 12.4164, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 028
# 	Train:	Total Loss: 435296337960.2979, Feature Loss: 435296337960.2979, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.4188, Feature Loss: 12.4188, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 029
# 	Train:	Total Loss: 21984081353140.0195, Feature Loss: 21984081353140.0195, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.4219, Feature Loss: 12.4219, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 030
# 	Train:	Total Loss: 33711583017502.4453, Feature Loss: 33711583017502.4453, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.4384, Feature Loss: 12.4384, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 031
# 	Train:	Total Loss: 7005195925145.0430, Feature Loss: 7005195925145.0430, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.4464, Feature Loss: 12.4464, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 032
# 	Train:	Total Loss: 61596261823518.5156, Feature Loss: 61596261823518.5156, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.4511, Feature Loss: 12.4511, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 033
# 	Train:	Total Loss: 5532855537533.2920, Feature Loss: 5532855537533.2920, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.4580, Feature Loss: 12.4580, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 034
# 	Train:	Total Loss: 26437002959041.5078, Feature Loss: 26437002959041.5078, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.4612, Feature Loss: 12.4612, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 035
# 	Train:	Total Loss: 173627115702866.9375, Feature Loss: 173627115702866.9375, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.4672, Feature Loss: 12.4672, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 036
# 	Train:	Total Loss: 4087924548554.5845, Feature Loss: 4087924548554.5845, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.4698, Feature Loss: 12.4698, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 037
# 	Train:	Total Loss: 21634963029806.1875, Feature Loss: 21634963029806.1875, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.4706, Feature Loss: 12.4706, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 038
# 	Train:	Total Loss: 5259667022726.7119, Feature Loss: 5259667022726.7119, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.4718, Feature Loss: 12.4718, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 039
# 	Train:	Total Loss: 6190489591184.7236, Feature Loss: 6190489591184.7236, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.4735, Feature Loss: 12.4735, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 040
# 	Train:	Total Loss: 103830506814899.4062, Feature Loss: 103830506814899.4062, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.5119, Feature Loss: 12.5119, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 041
# 	Train:	Total Loss: 6552390485894.3828, Feature Loss: 6552390485894.3828, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.5155, Feature Loss: 12.5155, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 042
# 	Train:	Total Loss: 5480158876036.8643, Feature Loss: 5480158876036.8643, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.5192, Feature Loss: 12.5192, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 043
# 	Train:	Total Loss: 14847013664413.3691, Feature Loss: 14847013664413.3691, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.5243, Feature Loss: 12.5243, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 044
# 	Train:	Total Loss: 8474777182471.1562, Feature Loss: 8474777182471.1562, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.5338, Feature Loss: 12.5338, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 045
# 	Train:	Total Loss: 10027839373047.8086, Feature Loss: 10027839373047.8086, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.5432, Feature Loss: 12.5432, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 046
# 	Train:	Total Loss: 24609312643273.5703, Feature Loss: 24609312643273.5703, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.5615, Feature Loss: 12.5615, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 047
# 	Train:	Total Loss: 2252014017806.7451, Feature Loss: 2252014017806.7451, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.5680, Feature Loss: 12.5680, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 048
# 	Train:	Total Loss: 38001993838968.6953, Feature Loss: 38001993838968.6953, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.5903, Feature Loss: 12.5903, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 049
# 	Train:	Total Loss: 22522852928965.9883, Feature Loss: 22522852928965.9883, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.5918, Feature Loss: 12.5918, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 050
# 	Train:	Total Loss: 25630739760680.5742, Feature Loss: 25630739760680.5742, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.5945, Feature Loss: 12.5945, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 051
# 	Train:	Total Loss: 4225758272603.1924, Feature Loss: 4225758272603.1924, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.6109, Feature Loss: 12.6109, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 052
# 	Train:	Total Loss: 3270043999856.7910, Feature Loss: 3270043999856.7910, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.6156, Feature Loss: 12.6156, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 053
# 	Train:	Total Loss: 3415401401789.9536, Feature Loss: 3415401401789.9536, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.6204, Feature Loss: 12.6204, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 054
# 	Train:	Total Loss: 14201978720775.9805, Feature Loss: 14201978720775.9805, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.6277, Feature Loss: 12.6277, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 055
# 	Train:	Total Loss: 10540497882070.5742, Feature Loss: 10540497882070.5742, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.6305, Feature Loss: 12.6305, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 056
# 	Train:	Total Loss: 17628283072342.8633, Feature Loss: 17628283072342.8633, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.6388, Feature Loss: 12.6388, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 057
# 	Train:	Total Loss: 30169501563033.7500, Feature Loss: 30169501563033.7500, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.6498, Feature Loss: 12.6498, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 058
# 	Train:	Total Loss: 6107748088041.9160, Feature Loss: 6107748088041.9160, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.6608, Feature Loss: 12.6608, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 059
# 	Train:	Total Loss: 50235047409858.3125, Feature Loss: 50235047409858.3125, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.6878, Feature Loss: 12.6878, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 060
# 	Train:	Total Loss: 5039591181178.9453, Feature Loss: 5039591181178.9453, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.6987, Feature Loss: 12.6987, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 061
# 	Train:	Total Loss: 865625185995.8849, Feature Loss: 865625185995.8849, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.6998, Feature Loss: 12.6998, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 062
# 	Train:	Total Loss: 3245814073402.6919, Feature Loss: 3245814073402.6919, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.7049, Feature Loss: 12.7049, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 063
# 	Train:	Total Loss: 25997244705111.6016, Feature Loss: 25997244705111.6016, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.7255, Feature Loss: 12.7255, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 064
# 	Train:	Total Loss: 63146197314790.6719, Feature Loss: 63146197314790.6719, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.7529, Feature Loss: 12.7529, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 065
# 	Train:	Total Loss: 1383648115573.8955, Feature Loss: 1383648115573.8955, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.7665, Feature Loss: 12.7665, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 066
# 	Train:	Total Loss: 7128124557899.3066, Feature Loss: 7128124557899.3066, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.7776, Feature Loss: 12.7776, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 067
# 	Train:	Total Loss: 9653720133067.1152, Feature Loss: 9653720133067.1152, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.7897, Feature Loss: 12.7897, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 068
# 	Train:	Total Loss: 14987054450143.0664, Feature Loss: 14987054450143.0664, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.8030, Feature Loss: 12.8030, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 069
# 	Train:	Total Loss: 7250930557784.9941, Feature Loss: 7250930557784.9941, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.8060, Feature Loss: 12.8060, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 070
# 	Train:	Total Loss: 60198683136956.6250, Feature Loss: 60198683136956.6250, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.8349, Feature Loss: 12.8349, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 071
# 	Train:	Total Loss: 2056371868374.3560, Feature Loss: 2056371868374.3560, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.8430, Feature Loss: 12.8430, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 072
# 	Train:	Total Loss: 19488954491696.7422, Feature Loss: 19488954491696.7422, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.8611, Feature Loss: 12.8611, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 073
# 	Train:	Total Loss: 8026606203767.1543, Feature Loss: 8026606203767.1543, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.8630, Feature Loss: 12.8630, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 074
# 	Train:	Total Loss: 1734967239312.1775, Feature Loss: 1734967239312.1775, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.8684, Feature Loss: 12.8684, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 075
# 	Train:	Total Loss: 24778449040434.7500, Feature Loss: 24778449040434.7500, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.8882, Feature Loss: 12.8882, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 076
# 	Train:	Total Loss: 18649988756286.4453, Feature Loss: 18649988756286.4453, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.9038, Feature Loss: 12.9038, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 077
# 	Train:	Total Loss: 2038404816825.7212, Feature Loss: 2038404816825.7212, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.9086, Feature Loss: 12.9086, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 078
# 	Train:	Total Loss: 1244011080666.0266, Feature Loss: 1244011080666.0266, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.9125, Feature Loss: 12.9125, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 079
# 	Train:	Total Loss: 555585825492.7905, Feature Loss: 555585825492.7905, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.9136, Feature Loss: 12.9136, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 080
# 	Train:	Total Loss: 1572607341072.4539, Feature Loss: 1572607341072.4539, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.9164, Feature Loss: 12.9164, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 081
# 	Train:	Total Loss: 10018519383244.0469, Feature Loss: 10018519383244.0469, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.9283, Feature Loss: 12.9283, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 082
# 	Train:	Total Loss: 2800056566577.3950, Feature Loss: 2800056566577.3950, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.9307, Feature Loss: 12.9307, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 083
# 	Train:	Total Loss: 16191370614711.0742, Feature Loss: 16191370614711.0742, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.9382, Feature Loss: 12.9382, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 084
# 	Train:	Total Loss: 949083952884.0059, Feature Loss: 949083952884.0059, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.9529, Feature Loss: 12.9529, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 085
# 	Train:	Total Loss: 1305897047826.6216, Feature Loss: 1305897047826.6216, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.9552, Feature Loss: 12.9552, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 086
# 	Train:	Total Loss: 2192108131042.4265, Feature Loss: 2192108131042.4265, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.9584, Feature Loss: 12.9584, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 087
# 	Train:	Total Loss: 4042390115933.1406, Feature Loss: 4042390115933.1406, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.9590, Feature Loss: 12.9590, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 088
# 	Train:	Total Loss: 14799135377548.0898, Feature Loss: 14799135377548.0898, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.9735, Feature Loss: 12.9735, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 089
# 	Train:	Total Loss: 5035701952683.8496, Feature Loss: 5035701952683.8496, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.9814, Feature Loss: 12.9814, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 090
# 	Train:	Total Loss: 1926464182159.9087, Feature Loss: 1926464182159.9087, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.9895, Feature Loss: 12.9895, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 091
# 	Train:	Total Loss: 1354986856816.3350, Feature Loss: 1354986856816.3350, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.9943, Feature Loss: 12.9943, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 092
# 	Train:	Total Loss: 76948391775.3799, Feature Loss: 76948391775.3799, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.9960, Feature Loss: 12.9960, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 093
# 	Train:	Total Loss: 1732382819763.9180, Feature Loss: 1732382819763.9180, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.0005, Feature Loss: 13.0005, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 094
# 	Train:	Total Loss: 9464276525956.1465, Feature Loss: 9464276525956.1465, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.0121, Feature Loss: 13.0121, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 095
# 	Train:	Total Loss: 634737605225.7472, Feature Loss: 634737605225.7472, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.0191, Feature Loss: 13.0191, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 096
# 	Train:	Total Loss: 260551080452.4098, Feature Loss: 260551080452.4098, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.0203, Feature Loss: 13.0203, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 097
# 	Train:	Total Loss: 2443493243233.6250, Feature Loss: 2443493243233.6250, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.0279, Feature Loss: 13.0279, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 098
# 	Train:	Total Loss: 2335738112488.9521, Feature Loss: 2335738112488.9521, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.0303, Feature Loss: 13.0303, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 099
# 	Train:	Total Loss: 1101398550829.4548, Feature Loss: 1101398550829.4548, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.0369, Feature Loss: 13.0369, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 100
# 	Train:	Total Loss: 5481627032564.6426, Feature Loss: 5481627032564.6426, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.0502, Feature Loss: 13.0502, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 101
# 	Train:	Total Loss: 11480291097444.3555, Feature Loss: 11480291097444.3555, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.0669, Feature Loss: 13.0669, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 102
# 	Train:	Total Loss: 1207775784998.5557, Feature Loss: 1207775784998.5557, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.0720, Feature Loss: 13.0720, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 103
# 	Train:	Total Loss: 1010799479510.9167, Feature Loss: 1010799479510.9167, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.0764, Feature Loss: 13.0764, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 104
# 	Train:	Total Loss: 3725153326238.4033, Feature Loss: 3725153326238.4033, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.0894, Feature Loss: 13.0894, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 105
# 	Train:	Total Loss: 2285064115444.8594, Feature Loss: 2285064115444.8594, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.0969, Feature Loss: 13.0969, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 106
# 	Train:	Total Loss: 4541411750115.6865, Feature Loss: 4541411750115.6865, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.0981, Feature Loss: 13.0981, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 107
# 	Train:	Total Loss: 15327221811821.6680, Feature Loss: 15327221811821.6680, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1150, Feature Loss: 13.1150, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 108
# 	Train:	Total Loss: 949836786392.9011, Feature Loss: 949836786392.9011, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1187, Feature Loss: 13.1187, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 109
# 	Train:	Total Loss: 21148525701345.2578, Feature Loss: 21148525701345.2578, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1426, Feature Loss: 13.1426, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 110
# 	Train:	Total Loss: 419680931561.2626, Feature Loss: 419680931561.2626, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1488, Feature Loss: 13.1488, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 111
# 	Train:	Total Loss: 781583725697.2809, Feature Loss: 781583725697.2809, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1515, Feature Loss: 13.1515, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 112
# 	Train:	Total Loss: 3020310546600.4390, Feature Loss: 3020310546600.4390, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1549, Feature Loss: 13.1549, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 113
# 	Train:	Total Loss: 8435504785402.6348, Feature Loss: 8435504785402.6348, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1705, Feature Loss: 13.1705, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 114
# 	Train:	Total Loss: 4095541705894.0518, Feature Loss: 4095541705894.0518, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1703, Feature Loss: 13.1703, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 115
# 	Train:	Total Loss: 1796262140540.3413, Feature Loss: 1796262140540.3413, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1702, Feature Loss: 13.1702, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 116
# 	Train:	Total Loss: 397164406372.8840, Feature Loss: 397164406372.8840, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1709, Feature Loss: 13.1709, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 117
# 	Train:	Total Loss: 4359062724857.8975, Feature Loss: 4359062724857.8975, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1718, Feature Loss: 13.1718, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 118
# 	Train:	Total Loss: 2167184625469.0923, Feature Loss: 2167184625469.0923, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1721, Feature Loss: 13.1721, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 119
# 	Train:	Total Loss: 354266152998.3942, Feature Loss: 354266152998.3942, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1740, Feature Loss: 13.1740, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 120
# 	Train:	Total Loss: 224041094213.2694, Feature Loss: 224041094213.2694, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1768, Feature Loss: 13.1768, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 121
# 	Train:	Total Loss: 1985904434486.2812, Feature Loss: 1985904434486.2812, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1815, Feature Loss: 13.1815, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 122
# 	Train:	Total Loss: 103748703713.8048, Feature Loss: 103748703713.8048, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1832, Feature Loss: 13.1832, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 123
# 	Train:	Total Loss: 1233108740151.0845, Feature Loss: 1233108740151.0845, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1836, Feature Loss: 13.1836, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 124
# 	Train:	Total Loss: 177344233012.4826, Feature Loss: 177344233012.4826, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1861, Feature Loss: 13.1861, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 125
# 	Train:	Total Loss: 116891910893.3915, Feature Loss: 116891910893.3915, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1876, Feature Loss: 13.1876, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 126
# 	Train:	Total Loss: 4178864701855.7686, Feature Loss: 4178864701855.7686, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1992, Feature Loss: 13.1992, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 127
# 	Train:	Total Loss: 103295635852.9092, Feature Loss: 103295635852.9092, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2004, Feature Loss: 13.2004, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 128
# 	Train:	Total Loss: 2072379342965.3926, Feature Loss: 2072379342965.3926, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2055, Feature Loss: 13.2055, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 129
# 	Train:	Total Loss: 178494385545.5891, Feature Loss: 178494385545.5891, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2087, Feature Loss: 13.2087, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 130
# 	Train:	Total Loss: 3466921185073.3481, Feature Loss: 3466921185073.3481, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2096, Feature Loss: 13.2096, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 131
# 	Train:	Total Loss: 1040721146688.1497, Feature Loss: 1040721146688.1497, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2098, Feature Loss: 13.2098, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 132
# 	Train:	Total Loss: 422722831486.6678, Feature Loss: 422722831486.6678, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2113, Feature Loss: 13.2113, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 133
# 	Train:	Total Loss: 8236598656584.6465, Feature Loss: 8236598656584.6465, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2339, Feature Loss: 13.2339, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 134
# 	Train:	Total Loss: 4013851514214.0498, Feature Loss: 4013851514214.0498, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2448, Feature Loss: 13.2448, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 135
# 	Train:	Total Loss: 162386548520.0109, Feature Loss: 162386548520.0109, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2485, Feature Loss: 13.2485, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 136
# 	Train:	Total Loss: 351329725946.3090, Feature Loss: 351329725946.3090, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2495, Feature Loss: 13.2495, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 137
# 	Train:	Total Loss: 400678517186.9348, Feature Loss: 400678517186.9348, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2498, Feature Loss: 13.2498, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 138
# 	Train:	Total Loss: 143912285739.5714, Feature Loss: 143912285739.5714, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2500, Feature Loss: 13.2500, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 139
# 	Train:	Total Loss: 2511148898751.9873, Feature Loss: 2511148898751.9873, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2601, Feature Loss: 13.2601, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 140
# 	Train:	Total Loss: 703088123095.6028, Feature Loss: 703088123095.6028, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2618, Feature Loss: 13.2618, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 141
# 	Train:	Total Loss: 1740030944530.8750, Feature Loss: 1740030944530.8750, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2704, Feature Loss: 13.2704, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 142
# 	Train:	Total Loss: 1616817597635.3982, Feature Loss: 1616817597635.3982, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2813, Feature Loss: 13.2813, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 143
# 	Train:	Total Loss: 1637925621477.1257, Feature Loss: 1637925621477.1257, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2840, Feature Loss: 13.2840, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 144
# 	Train:	Total Loss: 2339432371205.5586, Feature Loss: 2339432371205.5586, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2854, Feature Loss: 13.2854, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 145
# 	Train:	Total Loss: 5576661368724.0713, Feature Loss: 5576661368724.0713, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.3031, Feature Loss: 13.3031, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 146
# 	Train:	Total Loss: 1218049383358.7856, Feature Loss: 1218049383358.7856, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.3076, Feature Loss: 13.3076, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 147
# 	Train:	Total Loss: 223814831927.0919, Feature Loss: 223814831927.0919, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.3108, Feature Loss: 13.3108, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 148
# 	Train:	Total Loss: 2098055090363.4297, Feature Loss: 2098055090363.4297, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.3210, Feature Loss: 13.3210, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 149
# 	Train:	Total Loss: 737330056086.9677, Feature Loss: 737330056086.9677, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.3216, Feature Loss: 13.3216, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 150
# 	Train:	Total Loss: 4394018040082.7798, Feature Loss: 4394018040082.7798, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.3417, Feature Loss: 13.3417, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 151
# 	Train:	Total Loss: 236963833601.0150, Feature Loss: 236963833601.0150, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.3447, Feature Loss: 13.3447, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 152
# 	Train:	Total Loss: 3592782943122.9033, Feature Loss: 3592782943122.9033, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.3619, Feature Loss: 13.3619, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 153
# 	Train:	Total Loss: 188063557371.8000, Feature Loss: 188063557371.8000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.3647, Feature Loss: 13.3647, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 154
# 	Train:	Total Loss: 16377382592235.7617, Feature Loss: 16377382592235.7617, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.3950, Feature Loss: 13.3950, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 155
# 	Train:	Total Loss: 115855843334.9186, Feature Loss: 115855843334.9186, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.3962, Feature Loss: 13.3962, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 156
# 	Train:	Total Loss: 122188965507.6647, Feature Loss: 122188965507.6647, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.4001, Feature Loss: 13.4001, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 157
# 	Train:	Total Loss: 5606606674571.8359, Feature Loss: 5606606674571.8359, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.4183, Feature Loss: 13.4183, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 158
# 	Train:	Total Loss: 659151546794.3702, Feature Loss: 659151546794.3702, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.4223, Feature Loss: 13.4223, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 159
# 	Train:	Total Loss: 144282418855.6292, Feature Loss: 144282418855.6292, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.4232, Feature Loss: 13.4232, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 160
# 	Train:	Total Loss: 845833148536.1071, Feature Loss: 845833148536.1071, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.4300, Feature Loss: 13.4300, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 161
# 	Train:	Total Loss: 421688788370.8830, Feature Loss: 421688788370.8830, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.4316, Feature Loss: 13.4316, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 162
# 	Train:	Total Loss: 43358555736.0595, Feature Loss: 43358555736.0595, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.4317, Feature Loss: 13.4317, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 163
# 	Train:	Total Loss: 4926530323896.9883, Feature Loss: 4926530323896.9883, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.4465, Feature Loss: 13.4465, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 164
# 	Train:	Total Loss: 7925567676945.4902, Feature Loss: 7925567676945.4902, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.4599, Feature Loss: 13.4599, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 165
# 	Train:	Total Loss: 2325573314300.5571, Feature Loss: 2325573314300.5571, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.4864, Feature Loss: 13.4864, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 166
# 	Train:	Total Loss: 3204114562235.1260, Feature Loss: 3204114562235.1260, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.4982, Feature Loss: 13.4982, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 167
# 	Train:	Total Loss: 386453838077.4908, Feature Loss: 386453838077.4908, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.5021, Feature Loss: 13.5021, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 168
# 	Train:	Total Loss: 91803499234.2072, Feature Loss: 91803499234.2072, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.5035, Feature Loss: 13.5035, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 169
# 	Train:	Total Loss: 2492062202898.6890, Feature Loss: 2492062202898.6890, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.5150, Feature Loss: 13.5150, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 170
# 	Train:	Total Loss: 19493987406.4809, Feature Loss: 19493987406.4809, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.5177, Feature Loss: 13.5177, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 171
# 	Train:	Total Loss: 383231506062.1662, Feature Loss: 383231506062.1662, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.5179, Feature Loss: 13.5179, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 172
# 	Train:	Total Loss: 431538201454.3142, Feature Loss: 431538201454.3142, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.5209, Feature Loss: 13.5209, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 173
# 	Train:	Total Loss: 394348884709.5900, Feature Loss: 394348884709.5900, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.5231, Feature Loss: 13.5231, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 174
# 	Train:	Total Loss: 967461940158.3330, Feature Loss: 967461940158.3330, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.5289, Feature Loss: 13.5289, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 175
# 	Train:	Total Loss: 50861247759.4802, Feature Loss: 50861247759.4802, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.5311, Feature Loss: 13.5311, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 176
# 	Train:	Total Loss: 39472992987.6756, Feature Loss: 39472992987.6756, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.5321, Feature Loss: 13.5321, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 177
# 	Train:	Total Loss: 127764110791.8040, Feature Loss: 127764110791.8040, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.5345, Feature Loss: 13.5345, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 178
# 	Train:	Total Loss: 32304626892.3087, Feature Loss: 32304626892.3087, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.5351, Feature Loss: 13.5351, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 179
# 	Train:	Total Loss: 522757519565.3986, Feature Loss: 522757519565.3986, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.5387, Feature Loss: 13.5387, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 180
# 	Train:	Total Loss: 110309566495.2168, Feature Loss: 110309566495.2168, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.5433, Feature Loss: 13.5433, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 181
# 	Train:	Total Loss: 213253834140.8382, Feature Loss: 213253834140.8382, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.5465, Feature Loss: 13.5465, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 182
# 	Train:	Total Loss: 26117471851.4665, Feature Loss: 26117471851.4665, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.5477, Feature Loss: 13.5477, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 183
# 	Train:	Total Loss: 285272514445.4489, Feature Loss: 285272514445.4489, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.5480, Feature Loss: 13.5480, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 184
# 	Train:	Total Loss: 427398315428.4503, Feature Loss: 427398315428.4503, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.5506, Feature Loss: 13.5506, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 185
# 	Train:	Total Loss: 242485186488.4107, Feature Loss: 242485186488.4107, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.5550, Feature Loss: 13.5550, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 186
# 	Train:	Total Loss: 123207159674.8487, Feature Loss: 123207159674.8487, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.5581, Feature Loss: 13.5581, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 187
# 	Train:	Total Loss: 180664132664.2808, Feature Loss: 180664132664.2808, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.5614, Feature Loss: 13.5614, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 188
# 	Train:	Total Loss: 120961002548.9993, Feature Loss: 120961002548.9993, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.5624, Feature Loss: 13.5624, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 189
# 	Train:	Total Loss: 118528978060.4105, Feature Loss: 118528978060.4105, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.5654, Feature Loss: 13.5654, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 190
# 	Train:	Total Loss: 80821040772.4595, Feature Loss: 80821040772.4595, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.5706, Feature Loss: 13.5706, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 191
# 	Train:	Total Loss: 48365187859.8972, Feature Loss: 48365187859.8972, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.5722, Feature Loss: 13.5722, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 192
# 	Train:	Total Loss: 1369213917800.1633, Feature Loss: 1369213917800.1633, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.5883, Feature Loss: 13.5883, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 193
# 	Train:	Total Loss: 178522717313.2312, Feature Loss: 178522717313.2312, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.5891, Feature Loss: 13.5891, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 194
# 	Train:	Total Loss: 168030124056.0170, Feature Loss: 168030124056.0170, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.5928, Feature Loss: 13.5928, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 195
# 	Train:	Total Loss: 92365311474.2594, Feature Loss: 92365311474.2594, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.5932, Feature Loss: 13.5932, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 196
# 	Train:	Total Loss: 58345891375.1911, Feature Loss: 58345891375.1911, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.5936, Feature Loss: 13.5936, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 197
# 	Train:	Total Loss: 572555441161.7172, Feature Loss: 572555441161.7172, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.6033, Feature Loss: 13.6033, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 198
# 	Train:	Total Loss: 282466335777.0956, Feature Loss: 282466335777.0956, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.6126, Feature Loss: 13.6126, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 199
# 	Train:	Total Loss: 357843791589.3022, Feature Loss: 357843791589.3022, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.6132, Feature Loss: 13.6132, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 200
# 	Train:	Total Loss: 86552537490.5426, Feature Loss: 86552537490.5426, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.6134, Feature Loss: 13.6134, Type Loss: 0.0000 , LR: 0.000100

# %%
if not model_loaded:
    plt.figure(figsize=(14, 5))
    plt.plot(test_total_losses, label='Total Test Loss')
    plt.plot(train_total_losses, label='Total Train Loss')
    plt.legend()
    plt.title('Total Loss')
    plt.savefig("model3c_totalloss.png")
    plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
if not model_loaded:
    plt.figure(figsize=(14, 5))
    plt.plot(test_feature_losses, label='Test Feature Loss')
    plt.plot(train_feature_losses, label='Train Feature Loss')
    plt.legend()
    plt.title('Feature Loss')
    plt.savefig("model3c_feature_loss.png")
    plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
test_loader_melt = DataLoader(graphs_melt, batch_size=1)
encoded_data_melt=[]
type_data_melt = []
for data in test_loader:
    model.eval()
    z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
    decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
    encoded_data_melt.append(z.detach().numpy())
    type_data_melt.append(str_type.detach().numpy())

encoded_data_melt = np.array(encoded_data_melt)
type_data_melt = np.array(type_data_melt)

# %%
test_loader_cry = DataLoader(graphs_cry, batch_size=1)
encoded_data_cry=[]
type_data_cry = []
for data in test_loader:
    model.eval()
    z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
    decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
    encoded_data_cry.append(z.detach().numpy())
    type_data_cry.append(str_type.detach().numpy())

encoded_data_cry = np.array(encoded_data_cry)
type_data_cry = np.array(type_data_cry)

# %%
# %matplotlib widget

frame = 10

fig = plt.figure(figsize=(15,4))
data_melt = encoded_data_melt[frame]

data_cry = encoded_data_cry[frame]
plt.scatter(data_melt[:,0],data_melt[:,1],c="r",label="melt")
plt.scatter(data_cry[:,0],data_cry[:,1],c="b",label="crystal")
plt.savefig("model3c_scatterplot.png")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
