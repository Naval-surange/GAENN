# %%
import mdtraj as md
from ase import Atoms
import nglview as nv
import networkx as nx

import numpy as np
import matplotlib.pyplot as plt
import torch
from tqdm import tqdm

import torch_geometric.transforms as T
from torch_geometric.loader import DataLoader
from torch_geometric.nn import GCNConv, SAGPooling, InnerProductDecoder
import torch_geometric.data as data
from torch_geometric.utils.convert import to_networkx
import torch.optim.lr_scheduler as lr_scheduler
from torch.nn import Linear
import sys

# %%
all_frames_cry = md.load_xtc("../simulation/para_crystal.xtc", top="../simulation/para_crystal.gro")
all_frames_melt = md.load_xtc("../simulation/para_melt.xtc", top="../simulation/para_melt.gro")

# %%
all_frames_cry = all_frames_cry[::100]
all_frames_melt = all_frames_melt[::100]

# %%
n_frames = all_frames_cry.xyz.shape[0]
n_atoms = all_frames_cry.topology.residue(0).n_atoms
n_mols = all_frames_cry.topology.n_residues

# %%
def createGraph(all_frames,structure_type="crystal"):
    all_frames_fatures = []

    print("Creating Feature matrix")
    for i in tqdm(range(all_frames.xyz.shape[0])):
        mol_com_pos = []

        for res in all_frames.top.residues:
            pos = []
            for atom in res.atoms:
                pos.append(all_frames.xyz[i][atom.index])
            mol_com_pos.append(np.mean(pos,axis=0))
            
            # print()
        mol_com_pos = np.array(mol_com_pos).astype(np.float32)  
        all_frames_fatures.append(mol_com_pos)

    all_frames_fatures = np.array(all_frames_fatures).astype(np.float32)



    cutoff = 0.8

    print("Creating Edge list")
    all_edge_list = []
    # with open("edge_list.txt","w") as f:
    for frame_i in tqdm(range(n_frames)):
        from_list = []
        to_list = []

        for i in range(len(all_frames_fatures[frame_i])):
            for j in range(i+1,len(all_frames_fatures[frame_i])):
                if np.linalg.norm(all_frames_fatures[frame_i][i]-all_frames_fatures[frame_i][j]) < cutoff:
                    # f.write(str(i)+" "+str(j)+" "+str(np.linalg.norm(all_frames_fatures[frame_i][i]-all_frames_fatures[frame_i][j]))+"\n")
                    from_list.append(i)
                    to_list.append(j)

                    to_list.append(i)
                    from_list.append(j)

        edge_list = np.array([from_list,to_list]).astype(np.int64)
        all_edge_list.append(edge_list)
    print("creating Graphs")
    graphs = []
    for frame in tqdm(range(n_frames)):
        if structure_type == "crystal":
            g = data.Data(x=torch.tensor(all_frames_fatures[frame]).float(), edge_index=torch.tensor(all_edge_list[frame]).long(), y=torch.tensor([0]))
        else:
            g = data.Data(x=torch.tensor(all_frames_fatures[frame]).float(), edge_index=torch.tensor(all_edge_list[frame]).long(), y=torch.tensor([1]))
        graphs.append(g)
    return graphs

# %%
graphs_cry = createGraph(all_frames_cry,structure_type="crystal")
graphs_melt = createGraph(all_frames_melt,structure_type="melt")
# Out:
# Creating Feature matrix
# 100%|██████████| 51/51 [00:01<00:00, 40.65it/s]
# Creating Edge list
# 100%|██████████| 51/51 [00:59<00:00,  1.16s/it]
# creating Graphs
# 100%|██████████| 51/51 [00:00<00:00, 19483.51it/s]
# Creating Feature matrix
# 100%|██████████| 51/51 [00:00<00:00, 81.65it/s]
# Creating Edge list
# 100%|██████████| 51/51 [02:05<00:00,  2.45s/it]
# creating Graphs
# 100%|██████████| 51/51 [00:00<00:00, 16402.85it/s]

# %%
def convert_to_adj(edge_index, num_nodes=None):
    if num_nodes is None:
        num_nodes = edge_index.max() + 1
    adj = torch.zeros(num_nodes, num_nodes)
    adj[edge_index[0], edge_index[1]] = 1
    return adj

def convert_to_edge_index(adj):
    edge_index = adj.nonzero().t()
    return edge_index

# %%
graphs = graphs_cry + graphs_melt

# %%
# shuffle the graphs
np.random.shuffle(graphs)

# %%
graphs
# Out:
# [Data(x=[864, 3], edge_index=[2, 6172], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7056], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6524], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6934], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7116], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6592], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5962], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5880], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5982], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7012], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6552], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6566], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6512], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6488], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6070], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6630], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5910], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6288], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6578], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7080], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7078], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7064], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7006], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6400], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6560], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7076], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6548], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6584], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7122], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5822], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7086], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6602], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7294], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7146], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7052], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7048], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6532], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7092], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7218], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7306], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7092], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6546], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6508], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7088], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7028], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7100], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7048], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7090], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6018], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7006], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6586], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6464], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5862], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7044], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7094], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7020], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6560], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6964], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7240], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6564], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7034], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6596], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6544], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7054], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6580], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7116], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6570], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6558], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7128], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6990], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6546], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6056], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7052], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6012], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6214], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7024], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7074], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7132], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7274], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6542], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5876], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7108], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6582], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7096], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6992], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7060], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6608], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6066], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7036], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7374], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6548], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6554], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7060], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6508], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7008], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5892], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7026], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7078], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6626], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6452], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7192], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6476], y=[1])]

# %% [markdown]
# ## model

# %%
from typing import Optional, Tuple

import torch
from torch import Tensor
from torch.nn import Module

from torch_geometric.nn.inits import reset
from torch_geometric.utils import negative_sampling

EPS = 1e-15
MAX_LOGSTD = 10
edgeShape = None
featureShape = None


class InnerProductDecoder(torch.nn.Module):
    r"""The inner product decoder from the `"Variational Graph Auto-Encoders"
    <https://arxiv.org/abs/1611.07308>`_ paper

    .. math::
        \sigma(\mathbf{Z}\mathbf{Z}^{\top})

    where :math:`\mathbf{Z} \in \mathbb{R}^{N \times d}` denotes the latent
    space produced by the encoder."""

    def forward(self, z: Tensor, edge_index: Tensor,
                sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into edge probabilities for
        the given node-pairs :obj:`edge_index`.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        value = (z[edge_index[0]] * z[edge_index[1]]).sum(dim=1)
        return torch.sigmoid(value) if sigmoid else value

    def forward_all(self, z: Tensor, sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into a probabilistic dense
        adjacency matrix.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        adj = torch.matmul(z, z.t())
        return torch.sigmoid(adj) if sigmoid else adj


class GAE(torch.nn.Module):
    r"""The Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper based on user-defined encoder and decoder models.

    Args:
        encoder (torch.nn.Module): The encoder module.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__()
        self.encoder = encoder
        self.decoder = InnerProductDecoder() if decoder is None else decoder
        GAE.reset_parameters(self)

    def reset_parameters(self):
        r"""Resets all learnable parameters of the module."""
        reset(self.encoder)
        reset(self.decoder)

    def forward(self, *args, **kwargs) -> Tensor:  # pragma: no cover
        r"""Alias for :meth:`encode`."""
        return self.encoder(*args, **kwargs)

    def encode(self, *args, **kwargs) -> Tensor:
        r"""Runs the encoder and computes node-wise latent variables."""
        return self.encoder(*args, **kwargs)

    def decode(self, *args, **kwargs) -> Tensor:
        r"""Runs the decoder and computes edge probabilities."""
        return self.decoder(*args, **kwargs)

    def recon_loss(self, z: Tensor, pos_edge_index: Tensor,
                   neg_edge_index: Optional[Tensor] = None) -> Tensor:
        r"""Given latent variables :obj:`z`, computes the binary cross
        entropy loss for positive edges :obj:`pos_edge_index` and negative
        sampled edges.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to train against.
            neg_edge_index (torch.Tensor, optional): The negative edges to
                train against. If not given, uses negative sampling to
                calculate negative edges. (default: :obj:`None`)
        """
        pos_loss = -torch.log(
            self.decoder(z, pos_edge_index, sigmoid=True)[0] + EPS).mean()

        if neg_edge_index is None:
            neg_edge_index = negative_sampling(pos_edge_index, z.size(0))
        neg_loss = -torch.log(1 -
                              self.decoder(z, neg_edge_index.long(), sigmoid=True)[0] +
                              EPS).mean()

        return pos_loss + neg_loss

    def test(self, z: Tensor, pos_edge_index: Tensor,
             neg_edge_index: Tensor) -> Tuple[Tensor, Tensor]:
        r"""Given latent variables :obj:`z`, positive edges
        :obj:`pos_edge_index` and negative edges :obj:`neg_edge_index`,
        computes area under the ROC curve (AUC) and average precision (AP)
        
        scores.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to evaluate
                against.
            neg_edge_index (torch.Tensor): The negative edges to evaluate
                against.
        """
        from sklearn.metrics import average_precision_score, roc_auc_score

        pos_y = z.new_ones(pos_edge_index.size(1))
        neg_y = z.new_zeros(neg_edge_index.size(1))
        y = torch.cat([pos_y, neg_y], dim=0)

        pos_pred = self.decoder(z, pos_edge_index, sigmoid=True)
        neg_pred = self.decoder(z, neg_edge_index, sigmoid=True)
        pred = torch.cat([pos_pred, neg_pred], dim=0)

        y, pred = y.detach().cpu().numpy(), pred.detach().cpu().numpy()

        return roc_auc_score(y, pred), average_precision_score(y, pred)


class VGAE(GAE):
    r"""The Variational Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper.

    Args:
        encoder (torch.nn.Module): The encoder module to compute :math:`\mu`
            and :math:`\log\sigma^2`.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__(encoder, decoder)

    def reparametrize(self, mu: Tensor, logstd: Tensor) -> Tensor:
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def encode(self, *args, **kwargs) -> Tensor:
        """"""
        z, self.edge_index = self.encoder(
            *args, **kwargs)
        
        return z, self.edge_index

    def kl_loss(self, mu: Optional[Tensor] = None,
                logstd: Optional[Tensor] = None) -> Tensor:
        r"""Computes the KL loss, either for the passed arguments :obj:`mu`
        and :obj:`logstd`, or based on latent variables from last encoding.

        Args:
            mu (torch.Tensor, optional): The latent space for :math:`\mu`. If
                set to :obj:`None`, uses the last computation of :math:`\mu`.
                (default: :obj:`None`)
            logstd (torch.Tensor, optional): The latent space for
                :math:`\log\sigma`.  If set to :obj:`None`, uses the last
                computation of :math:`\log\sigma^2`. (default: :obj:`None`)
        """
        mu = self.__mu__ if mu is None else mu
        logstd = self.__logstd__ if logstd is None else logstd.clamp(
            max=MAX_LOGSTD)
        return -0.5 * torch.mean(
            torch.sum(1 + 2 * logstd - mu**2 - logstd.exp()**2, dim=1))

# %%
import torch.nn.functional as F



class VariationalGCNEncoder(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.conv1 = GCNConv(in_channels, 2 * out_channels)
        self.conv2 = GCNConv(2*out_channels, 1 * out_channels)
        self.pool = SAGPooling(out_channels, 0.5)
        
        self.conv_mu = GCNConv(1 * out_channels, out_channels)
        self.conv_logstd = GCNConv(1 * out_channels, out_channels)
        self.conv_mu_crystal = GCNConv(1 * out_channels, out_channels)
        self.conv_logstd_crystal = GCNConv(1 * out_channels, out_channels)
        self.conv_mu_melt = GCNConv(1 * out_channels, out_channels)
        self.conv_logstd_melt = GCNConv(1 * out_channels, out_channels)
    
    def reparametrize(self, mu: Tensor, logstd: Tensor) -> Tensor:
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def forward(self, x, edge_index,class_label):
        # print("input:",x.shape, edge_index.shape)
        x = self.conv1(x, edge_index)
        x = F.silu(x)
        # print("conv1:",x.shape, edge_index.shape)
        x = self.conv2(x, edge_index)
        x = F.silu(x)
        # print("conv2:",x.shape, edge_index.shape)

        sample = self.reparametrize(self.conv_mu(x, edge_index), self.conv_logstd(x, edge_index))
        
        sample_crystal = self.reparametrize(self.conv_mu_crystal(sample, edge_index), self.conv_logstd_crystal(sample, edge_index))
        sample_melt = self.reparametrize(self.conv_mu_melt(sample, edge_index), self.conv_logstd_melt(sample, edge_index))

        self.conv_mu_crystal.train(True)
        self.conv_logstd_crystal.train(True)
        self.conv_mu_melt.train(True)
        self.conv_logstd_melt.train(True)


        if class_label == 0:
            self.conv_mu_melt.train(False)
            self.conv_logstd_melt.train(False)
            return sample_crystal, edge_index
        else:
            self.conv_mu_crystal.train(False)
            self.conv_logstd_crystal.train(False)
            return sample_melt, edge_index

# %%
class VariationalGCNDecoder(torch.nn.Module):
    def __init__(self,in_channels,out_channels):
        super().__init__()
        self.type_layer1 = Linear(1728,200)
        self.dropout = torch.nn.Dropout(0.5)
        self.type_layer2 = Linear(200,2)

        self.conv1 = GCNConv(in_channels, 2 * out_channels)
        self.conv2 = GCNConv(2 * out_channels, 1 * out_channels)
    def forward(self, x, edge_index, sigmoid=True):
        # print("input:",x.shape, edge_index.shape)
        flat = x.flatten()
        flat = self.type_layer1(flat).relu()
        flat = self.dropout(flat)
        str_type = F.softmax(self.type_layer2(flat).relu(),dim=0)
         
        x = self.conv1(x, edge_index)
        x = F.silu(x)
        # print("conv1:",x.shape, edge_index.shape)
        x = self.conv2(x, edge_index)
        x = F.silu(x)
        # print("conv2:",x.shape, edge_index.shape)
        return x, edge_index,str_type

# %%
import os
in_channels = graphs[0].num_features
out_channels = 2
lr = 1e-4
n_epochs = 200
batch_size=1
test_train_split = 0.8
model_name = "Inference_gmm1.pt"
model_loaded = False
force_train = True  

if os.path.exists("./models/"+model_name) and not force_train:
    model = torch.load("./models/"+model_name)
    model_loaded = True
else:
    model = VGAE(VariationalGCNEncoder(in_channels, out_channels),
                VariationalGCNDecoder(out_channels, in_channels))

optimizer = torch.optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, step_size=300, gamma=0.5)

# %%
train_loader = DataLoader(graphs[:int(n_frames*test_train_split)], batch_size=batch_size, shuffle=True)
test_loader = DataLoader(graphs[int(n_frames*test_train_split):], batch_size=batch_size, shuffle=True)

# %%
lossFxn = torch.nn.MSELoss()
typeLossFxn = torch.nn.CrossEntropyLoss()

def train():
    model.train()
    model.zero_grad()
    model.float()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0
    type_loss_all = 0
    for data in train_loader:
        optimizer.zero_grad()
        z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
        decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)

     
        # TypeLoss = typeLossFxn(str_type.unsqueeze(0), data.y)
        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        loss = FeatureLoss + EdgeLoss 

        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        # type_loss_all += float(TypeLoss)

        loss.backward()
        optimizer.step()
        

    return loss_all / len(train_loader), feature_loss_all / len(train_loader), edge_loss_all / len(train_loader), kl_loss_all / len(train_loader), type_loss_all / len(train_loader)

# %%
lossFxn = torch.nn.MSELoss()
def test():
    model.eval()
    model.zero_grad()
    model.float()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0
    type_loss_all = 0

    for data in test_loader:
        optimizer.zero_grad()
        z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
        decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
        
        # TypeLoss = typeLossFxn(str_type.unsqueeze(0), data.y)
        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        loss = FeatureLoss + EdgeLoss 

        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        # type_loss_all += float(TypeLoss)
        
        
        

    return loss_all / len(test_loader), feature_loss_all / len(test_loader), edge_loss_all / len(test_loader), kl_loss_all / len(test_loader), type_loss_all / len(test_loader)

# %%
train_total_losses = []
train_feature_losses = []
train_edge_losses = []
train_kl_losses = []
train_type_losses = []

test_total_losses = []
test_feature_losses = []
test_edge_losses = []
test_kl_losses = []
test_type_losses = []

if model_loaded:        
    print("Pretrained Model Loaded, no training required")
else:
    for epoch in range(1, n_epochs + 1):
        
        train_total_loss, train_feature_loss, train_edge_loss, train_kl_loss,train_type_loss = train()
        test_total_loss, test_feature_loss, test_edge_loss, test_kl_loss, test_type_loss= test()
        
        print(f"Epoch: {epoch:03d}")
        print(f'\tTrain:\tTotal Loss: {train_total_loss:.4f}, Feature Loss: {train_feature_loss:.4f}, Type Loss: {train_type_loss:.4f} ,  LR: {scheduler.get_last_lr()[0]:.6f}')
        print(f'\tTest: \tTotal Loss: {test_total_loss:.4f}, Feature Loss: {test_feature_loss:.4f}, Type Loss: {test_type_loss:.4f} , LR: {scheduler.get_last_lr()[0]:.6f}')
        
        
        train_total_losses.append(train_total_loss)
        train_feature_losses.append(train_feature_loss)
        train_edge_losses.append(train_edge_loss)
        train_kl_losses.append(train_kl_loss)
        train_type_losses.append(train_type_loss)


        test_total_losses.append(test_total_loss)
        test_feature_losses.append(test_feature_loss)
        test_edge_losses.append(test_edge_loss)
        test_kl_losses.append(test_kl_loss)
        test_type_losses.append(test_type_loss)
        
        scheduler.step()
    torch.save(model,"./models/"+model_name)
# Out:
# Epoch: 001
# 	Train:	Total Loss: 13.2873, Feature Loss: 13.2873, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.5515, Feature Loss: 12.5515, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 002
# 	Train:	Total Loss: 13.2399, Feature Loss: 13.2399, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.5115, Feature Loss: 12.5115, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 003
# 	Train:	Total Loss: 13.2109, Feature Loss: 13.2109, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.4740, Feature Loss: 12.4740, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 004
# 	Train:	Total Loss: 13.1590, Feature Loss: 13.1590, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.4363, Feature Loss: 12.4363, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 005
# 	Train:	Total Loss: 13.1131, Feature Loss: 13.1131, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.3997, Feature Loss: 12.3997, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 006
# 	Train:	Total Loss: 13.0842, Feature Loss: 13.0842, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.3641, Feature Loss: 12.3641, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 007
# 	Train:	Total Loss: 13.0271, Feature Loss: 13.0271, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.3275, Feature Loss: 12.3275, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 008
# 	Train:	Total Loss: 13.0025, Feature Loss: 13.0025, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.2915, Feature Loss: 12.2915, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 009
# 	Train:	Total Loss: 12.9553, Feature Loss: 12.9553, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.2540, Feature Loss: 12.2540, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 010
# 	Train:	Total Loss: 12.9092, Feature Loss: 12.9092, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.2162, Feature Loss: 12.2162, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 011
# 	Train:	Total Loss: 12.8706, Feature Loss: 12.8706, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.1764, Feature Loss: 12.1764, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 012
# 	Train:	Total Loss: 12.8340, Feature Loss: 12.8340, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.1360, Feature Loss: 12.1360, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 013
# 	Train:	Total Loss: 12.7745, Feature Loss: 12.7745, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0927, Feature Loss: 12.0927, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 014
# 	Train:	Total Loss: 12.7348, Feature Loss: 12.7348, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0481, Feature Loss: 12.0481, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 015
# 	Train:	Total Loss: 12.6986, Feature Loss: 12.6986, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0013, Feature Loss: 12.0013, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 016
# 	Train:	Total Loss: 12.6212, Feature Loss: 12.6212, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.9510, Feature Loss: 11.9510, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 017
# 	Train:	Total Loss: 12.5734, Feature Loss: 12.5734, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.8978, Feature Loss: 11.8978, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 018
# 	Train:	Total Loss: 12.4967, Feature Loss: 12.4967, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.8413, Feature Loss: 11.8413, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 019
# 	Train:	Total Loss: 12.4312, Feature Loss: 12.4312, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.7796, Feature Loss: 11.7796, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 020
# 	Train:	Total Loss: 12.3735, Feature Loss: 12.3735, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.7155, Feature Loss: 11.7155, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 021
# 	Train:	Total Loss: 12.3203, Feature Loss: 12.3203, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.6472, Feature Loss: 11.6472, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 022
# 	Train:	Total Loss: 12.2406, Feature Loss: 12.2406, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.5757, Feature Loss: 11.5757, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 023
# 	Train:	Total Loss: 12.1593, Feature Loss: 12.1593, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.4994, Feature Loss: 11.4994, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 024
# 	Train:	Total Loss: 12.0303, Feature Loss: 12.0303, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.4169, Feature Loss: 11.4169, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 025
# 	Train:	Total Loss: 11.9555, Feature Loss: 11.9555, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.3300, Feature Loss: 11.3300, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 026
# 	Train:	Total Loss: 11.8774, Feature Loss: 11.8774, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.2367, Feature Loss: 11.2367, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 027
# 	Train:	Total Loss: 11.7856, Feature Loss: 11.7856, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.1403, Feature Loss: 11.1403, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 028
# 	Train:	Total Loss: 11.6640, Feature Loss: 11.6640, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.0376, Feature Loss: 11.0376, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 029
# 	Train:	Total Loss: 11.5771, Feature Loss: 11.5771, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.9292, Feature Loss: 10.9292, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 030
# 	Train:	Total Loss: 11.5798, Feature Loss: 11.5798, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.8203, Feature Loss: 10.8203, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 031
# 	Train:	Total Loss: 11.3765, Feature Loss: 11.3765, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.7049, Feature Loss: 10.7049, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 032
# 	Train:	Total Loss: 11.2131, Feature Loss: 11.2131, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.5820, Feature Loss: 10.5820, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 033
# 	Train:	Total Loss: 11.0989, Feature Loss: 11.0989, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.4525, Feature Loss: 10.4525, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 034
# 	Train:	Total Loss: 10.9356, Feature Loss: 10.9356, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.3167, Feature Loss: 10.3167, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 035
# 	Train:	Total Loss: 10.9066, Feature Loss: 10.9066, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.1796, Feature Loss: 10.1796, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 036
# 	Train:	Total Loss: 10.7299, Feature Loss: 10.7299, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.0379, Feature Loss: 10.0379, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 037
# 	Train:	Total Loss: 10.5995, Feature Loss: 10.5995, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.8926, Feature Loss: 9.8926, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 038
# 	Train:	Total Loss: 10.4839, Feature Loss: 10.4839, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.7454, Feature Loss: 9.7454, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 039
# 	Train:	Total Loss: 10.3387, Feature Loss: 10.3387, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.5961, Feature Loss: 9.5961, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 040
# 	Train:	Total Loss: 10.2256, Feature Loss: 10.2256, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.4464, Feature Loss: 9.4464, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 041
# 	Train:	Total Loss: 10.0068, Feature Loss: 10.0068, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.2918, Feature Loss: 9.2918, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 042
# 	Train:	Total Loss: 9.9196, Feature Loss: 9.9196, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.1378, Feature Loss: 9.1378, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 043
# 	Train:	Total Loss: 9.7553, Feature Loss: 9.7553, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.9863, Feature Loss: 8.9863, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 044
# 	Train:	Total Loss: 9.5681, Feature Loss: 9.5681, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.8327, Feature Loss: 8.8327, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 045
# 	Train:	Total Loss: 9.4665, Feature Loss: 9.4665, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.6862, Feature Loss: 8.6862, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 046
# 	Train:	Total Loss: 9.3892, Feature Loss: 9.3892, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.5321, Feature Loss: 8.5321, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 047
# 	Train:	Total Loss: 9.1926, Feature Loss: 9.1926, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.3877, Feature Loss: 8.3877, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 048
# 	Train:	Total Loss: 9.0483, Feature Loss: 9.0483, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.2439, Feature Loss: 8.2439, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 049
# 	Train:	Total Loss: 8.9824, Feature Loss: 8.9824, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.1073, Feature Loss: 8.1073, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 050
# 	Train:	Total Loss: 8.8223, Feature Loss: 8.8223, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.9731, Feature Loss: 7.9731, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 051
# 	Train:	Total Loss: 8.6532, Feature Loss: 8.6532, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.8433, Feature Loss: 7.8433, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 052
# 	Train:	Total Loss: 8.6070, Feature Loss: 8.6070, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.7206, Feature Loss: 7.7206, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 053
# 	Train:	Total Loss: 8.4733, Feature Loss: 8.4733, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.5970, Feature Loss: 7.5970, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 054
# 	Train:	Total Loss: 8.3163, Feature Loss: 8.3163, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.4744, Feature Loss: 7.4744, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 055
# 	Train:	Total Loss: 8.2415, Feature Loss: 8.2415, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.3642, Feature Loss: 7.3642, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 056
# 	Train:	Total Loss: 8.0505, Feature Loss: 8.0505, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.2580, Feature Loss: 7.2580, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 057
# 	Train:	Total Loss: 8.0152, Feature Loss: 8.0152, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.1465, Feature Loss: 7.1465, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 058
# 	Train:	Total Loss: 7.8878, Feature Loss: 7.8878, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.0456, Feature Loss: 7.0456, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 059
# 	Train:	Total Loss: 7.7377, Feature Loss: 7.7377, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.9432, Feature Loss: 6.9432, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 060
# 	Train:	Total Loss: 7.6879, Feature Loss: 7.6879, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.8505, Feature Loss: 6.8505, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 061
# 	Train:	Total Loss: 7.6328, Feature Loss: 7.6328, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.7593, Feature Loss: 6.7593, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 062
# 	Train:	Total Loss: 7.5510, Feature Loss: 7.5510, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.6670, Feature Loss: 6.6670, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 063
# 	Train:	Total Loss: 7.4349, Feature Loss: 7.4349, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.5807, Feature Loss: 6.5807, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 064
# 	Train:	Total Loss: 7.3889, Feature Loss: 7.3889, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.4962, Feature Loss: 6.4962, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 065
# 	Train:	Total Loss: 7.2679, Feature Loss: 7.2679, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.4150, Feature Loss: 6.4150, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 066
# 	Train:	Total Loss: 7.1684, Feature Loss: 7.1684, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.3334, Feature Loss: 6.3334, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 067
# 	Train:	Total Loss: 7.1021, Feature Loss: 7.1021, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.2582, Feature Loss: 6.2582, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 068
# 	Train:	Total Loss: 6.9742, Feature Loss: 6.9742, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.1818, Feature Loss: 6.1818, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 069
# 	Train:	Total Loss: 6.9178, Feature Loss: 6.9178, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.1080, Feature Loss: 6.1080, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 070
# 	Train:	Total Loss: 6.8400, Feature Loss: 6.8400, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.0352, Feature Loss: 6.0352, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 071
# 	Train:	Total Loss: 6.7932, Feature Loss: 6.7932, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.9661, Feature Loss: 5.9661, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 072
# 	Train:	Total Loss: 6.7019, Feature Loss: 6.7019, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.8963, Feature Loss: 5.8963, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 073
# 	Train:	Total Loss: 6.5630, Feature Loss: 6.5630, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.8261, Feature Loss: 5.8261, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 074
# 	Train:	Total Loss: 6.5687, Feature Loss: 6.5687, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.7586, Feature Loss: 5.7586, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 075
# 	Train:	Total Loss: 6.5013, Feature Loss: 6.5013, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.6905, Feature Loss: 5.6905, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 076
# 	Train:	Total Loss: 6.3988, Feature Loss: 6.3988, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.6241, Feature Loss: 5.6241, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 077
# 	Train:	Total Loss: 6.3268, Feature Loss: 6.3268, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.5596, Feature Loss: 5.5596, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 078
# 	Train:	Total Loss: 6.2721, Feature Loss: 6.2721, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.4931, Feature Loss: 5.4931, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 079
# 	Train:	Total Loss: 6.2191, Feature Loss: 6.2191, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.4292, Feature Loss: 5.4292, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 080
# 	Train:	Total Loss: 6.1303, Feature Loss: 6.1303, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.3661, Feature Loss: 5.3661, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 081
# 	Train:	Total Loss: 6.0410, Feature Loss: 6.0410, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.3046, Feature Loss: 5.3046, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 082
# 	Train:	Total Loss: 5.9103, Feature Loss: 5.9103, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.2430, Feature Loss: 5.2430, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 083
# 	Train:	Total Loss: 5.9383, Feature Loss: 5.9383, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.1837, Feature Loss: 5.1837, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 084
# 	Train:	Total Loss: 5.9121, Feature Loss: 5.9121, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.1246, Feature Loss: 5.1246, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 085
# 	Train:	Total Loss: 5.7481, Feature Loss: 5.7481, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.0661, Feature Loss: 5.0661, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 086
# 	Train:	Total Loss: 5.7057, Feature Loss: 5.7057, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.0072, Feature Loss: 5.0072, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 087
# 	Train:	Total Loss: 5.6772, Feature Loss: 5.6772, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.9486, Feature Loss: 4.9486, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 088
# 	Train:	Total Loss: 5.6265, Feature Loss: 5.6265, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.8947, Feature Loss: 4.8947, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 089
# 	Train:	Total Loss: 5.5846, Feature Loss: 5.5846, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.8377, Feature Loss: 4.8377, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 090
# 	Train:	Total Loss: 5.4773, Feature Loss: 5.4773, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.7804, Feature Loss: 4.7804, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 091
# 	Train:	Total Loss: 5.3687, Feature Loss: 5.3687, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.7274, Feature Loss: 4.7274, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 092
# 	Train:	Total Loss: 5.3394, Feature Loss: 5.3394, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.6741, Feature Loss: 4.6741, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 093
# 	Train:	Total Loss: 5.2797, Feature Loss: 5.2797, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.6187, Feature Loss: 4.6187, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 094
# 	Train:	Total Loss: 5.2494, Feature Loss: 5.2494, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.5707, Feature Loss: 4.5707, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 095
# 	Train:	Total Loss: 5.1440, Feature Loss: 5.1440, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.5188, Feature Loss: 4.5188, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 096
# 	Train:	Total Loss: 5.1613, Feature Loss: 5.1613, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.4689, Feature Loss: 4.4689, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 097
# 	Train:	Total Loss: 5.0807, Feature Loss: 5.0807, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.4179, Feature Loss: 4.4179, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 098
# 	Train:	Total Loss: 4.9775, Feature Loss: 4.9775, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.3718, Feature Loss: 4.3718, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 099
# 	Train:	Total Loss: 4.9209, Feature Loss: 4.9209, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.3237, Feature Loss: 4.3237, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 100
# 	Train:	Total Loss: 4.8946, Feature Loss: 4.8946, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.2807, Feature Loss: 4.2807, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 101
# 	Train:	Total Loss: 4.8176, Feature Loss: 4.8176, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.2321, Feature Loss: 4.2321, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 102
# 	Train:	Total Loss: 4.7992, Feature Loss: 4.7992, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.1873, Feature Loss: 4.1873, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 103
# 	Train:	Total Loss: 4.7474, Feature Loss: 4.7474, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.1434, Feature Loss: 4.1434, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 104
# 	Train:	Total Loss: 4.6838, Feature Loss: 4.6838, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.1022, Feature Loss: 4.1022, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 105
# 	Train:	Total Loss: 4.6349, Feature Loss: 4.6349, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.0594, Feature Loss: 4.0594, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 106
# 	Train:	Total Loss: 4.5877, Feature Loss: 4.5877, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.0187, Feature Loss: 4.0187, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 107
# 	Train:	Total Loss: 4.5408, Feature Loss: 4.5408, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.9788, Feature Loss: 3.9788, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 108
# 	Train:	Total Loss: 4.4970, Feature Loss: 4.4970, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.9387, Feature Loss: 3.9387, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 109
# 	Train:	Total Loss: 4.4393, Feature Loss: 4.4393, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.9017, Feature Loss: 3.9017, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 110
# 	Train:	Total Loss: 4.3874, Feature Loss: 4.3874, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8623, Feature Loss: 3.8623, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 111
# 	Train:	Total Loss: 4.3552, Feature Loss: 4.3552, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8274, Feature Loss: 3.8274, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 112
# 	Train:	Total Loss: 4.3057, Feature Loss: 4.3057, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7909, Feature Loss: 3.7909, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 113
# 	Train:	Total Loss: 4.2933, Feature Loss: 4.2933, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7561, Feature Loss: 3.7561, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 114
# 	Train:	Total Loss: 4.2395, Feature Loss: 4.2395, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7214, Feature Loss: 3.7214, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 115
# 	Train:	Total Loss: 4.2124, Feature Loss: 4.2124, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6898, Feature Loss: 3.6898, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 116
# 	Train:	Total Loss: 4.1808, Feature Loss: 4.1808, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6558, Feature Loss: 3.6558, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 117
# 	Train:	Total Loss: 4.1023, Feature Loss: 4.1023, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6264, Feature Loss: 3.6264, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 118
# 	Train:	Total Loss: 4.0895, Feature Loss: 4.0895, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5951, Feature Loss: 3.5951, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 119
# 	Train:	Total Loss: 4.0238, Feature Loss: 4.0238, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5656, Feature Loss: 3.5656, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 120
# 	Train:	Total Loss: 4.0464, Feature Loss: 4.0464, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5356, Feature Loss: 3.5356, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 121
# 	Train:	Total Loss: 3.9813, Feature Loss: 3.9813, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5069, Feature Loss: 3.5069, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 122
# 	Train:	Total Loss: 3.9156, Feature Loss: 3.9156, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.4800, Feature Loss: 3.4800, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 123
# 	Train:	Total Loss: 3.9377, Feature Loss: 3.9377, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.4539, Feature Loss: 3.4539, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 124
# 	Train:	Total Loss: 3.9213, Feature Loss: 3.9213, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.4283, Feature Loss: 3.4283, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 125
# 	Train:	Total Loss: 3.9033, Feature Loss: 3.9033, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.4020, Feature Loss: 3.4020, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 126
# 	Train:	Total Loss: 3.8449, Feature Loss: 3.8449, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.3780, Feature Loss: 3.3780, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 127
# 	Train:	Total Loss: 3.8135, Feature Loss: 3.8135, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.3538, Feature Loss: 3.3538, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 128
# 	Train:	Total Loss: 3.7899, Feature Loss: 3.7899, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.3316, Feature Loss: 3.3316, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 129
# 	Train:	Total Loss: 3.7435, Feature Loss: 3.7435, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.3092, Feature Loss: 3.3092, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 130
# 	Train:	Total Loss: 3.7367, Feature Loss: 3.7367, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2858, Feature Loss: 3.2858, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 131
# 	Train:	Total Loss: 3.7080, Feature Loss: 3.7080, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2655, Feature Loss: 3.2655, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 132
# 	Train:	Total Loss: 3.6869, Feature Loss: 3.6869, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2440, Feature Loss: 3.2440, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 133
# 	Train:	Total Loss: 3.6669, Feature Loss: 3.6669, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2247, Feature Loss: 3.2247, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 134
# 	Train:	Total Loss: 3.5975, Feature Loss: 3.5975, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2046, Feature Loss: 3.2046, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 135
# 	Train:	Total Loss: 3.6091, Feature Loss: 3.6091, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.1850, Feature Loss: 3.1850, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 136
# 	Train:	Total Loss: 3.5760, Feature Loss: 3.5760, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.1673, Feature Loss: 3.1673, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 137
# 	Train:	Total Loss: 3.5821, Feature Loss: 3.5821, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.1497, Feature Loss: 3.1497, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 138
# 	Train:	Total Loss: 3.5467, Feature Loss: 3.5467, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.1315, Feature Loss: 3.1315, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 139
# 	Train:	Total Loss: 3.5364, Feature Loss: 3.5364, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.1148, Feature Loss: 3.1148, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 140
# 	Train:	Total Loss: 3.4952, Feature Loss: 3.4952, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.0984, Feature Loss: 3.0984, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 141
# 	Train:	Total Loss: 3.4822, Feature Loss: 3.4822, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.0825, Feature Loss: 3.0825, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 142
# 	Train:	Total Loss: 3.4700, Feature Loss: 3.4700, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.0672, Feature Loss: 3.0672, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 143
# 	Train:	Total Loss: 3.4515, Feature Loss: 3.4515, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.0513, Feature Loss: 3.0513, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 144
# 	Train:	Total Loss: 3.4235, Feature Loss: 3.4235, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.0369, Feature Loss: 3.0369, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 145
# 	Train:	Total Loss: 3.4361, Feature Loss: 3.4361, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.0230, Feature Loss: 3.0230, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 146
# 	Train:	Total Loss: 3.4010, Feature Loss: 3.4010, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.0097, Feature Loss: 3.0097, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 147
# 	Train:	Total Loss: 3.4087, Feature Loss: 3.4087, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.9960, Feature Loss: 2.9960, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 148
# 	Train:	Total Loss: 3.3802, Feature Loss: 3.3802, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.9832, Feature Loss: 2.9832, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 149
# 	Train:	Total Loss: 3.3525, Feature Loss: 3.3525, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.9700, Feature Loss: 2.9700, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 150
# 	Train:	Total Loss: 3.3277, Feature Loss: 3.3277, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.9576, Feature Loss: 2.9576, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 151
# 	Train:	Total Loss: 3.3299, Feature Loss: 3.3299, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.9477, Feature Loss: 2.9477, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 152
# 	Train:	Total Loss: 3.2928, Feature Loss: 3.2928, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.9344, Feature Loss: 2.9344, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 153
# 	Train:	Total Loss: 3.2925, Feature Loss: 3.2925, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.9230, Feature Loss: 2.9230, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 154
# 	Train:	Total Loss: 3.2885, Feature Loss: 3.2885, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.9119, Feature Loss: 2.9119, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 155
# 	Train:	Total Loss: 3.2621, Feature Loss: 3.2621, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.9019, Feature Loss: 2.9019, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 156
# 	Train:	Total Loss: 3.2660, Feature Loss: 3.2660, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8909, Feature Loss: 2.8909, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 157
# 	Train:	Total Loss: 3.2407, Feature Loss: 3.2407, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8813, Feature Loss: 2.8813, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 158
# 	Train:	Total Loss: 3.2320, Feature Loss: 3.2320, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8705, Feature Loss: 2.8705, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 159
# 	Train:	Total Loss: 3.2279, Feature Loss: 3.2279, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8611, Feature Loss: 2.8611, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 160
# 	Train:	Total Loss: 3.1817, Feature Loss: 3.1817, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8515, Feature Loss: 2.8515, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 161
# 	Train:	Total Loss: 3.2277, Feature Loss: 3.2277, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8436, Feature Loss: 2.8436, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 162
# 	Train:	Total Loss: 3.2004, Feature Loss: 3.2004, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8336, Feature Loss: 2.8336, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 163
# 	Train:	Total Loss: 3.1950, Feature Loss: 3.1950, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8246, Feature Loss: 2.8246, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 164
# 	Train:	Total Loss: 3.1850, Feature Loss: 3.1850, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8163, Feature Loss: 2.8163, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 165
# 	Train:	Total Loss: 3.1683, Feature Loss: 3.1683, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8083, Feature Loss: 2.8083, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 166
# 	Train:	Total Loss: 3.1375, Feature Loss: 3.1375, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8001, Feature Loss: 2.8001, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 167
# 	Train:	Total Loss: 3.1330, Feature Loss: 3.1330, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7928, Feature Loss: 2.7928, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 168
# 	Train:	Total Loss: 3.1452, Feature Loss: 3.1452, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7857, Feature Loss: 2.7857, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 169
# 	Train:	Total Loss: 3.1289, Feature Loss: 3.1289, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7781, Feature Loss: 2.7781, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 170
# 	Train:	Total Loss: 3.1193, Feature Loss: 3.1193, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7709, Feature Loss: 2.7709, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 171
# 	Train:	Total Loss: 3.0916, Feature Loss: 3.0916, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7644, Feature Loss: 2.7644, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 172
# 	Train:	Total Loss: 3.0984, Feature Loss: 3.0984, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7571, Feature Loss: 2.7571, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 173
# 	Train:	Total Loss: 3.0744, Feature Loss: 3.0744, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7503, Feature Loss: 2.7503, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 174
# 	Train:	Total Loss: 3.0765, Feature Loss: 3.0765, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7438, Feature Loss: 2.7438, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 175
# 	Train:	Total Loss: 3.0554, Feature Loss: 3.0554, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7384, Feature Loss: 2.7384, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 176
# 	Train:	Total Loss: 3.0589, Feature Loss: 3.0589, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7312, Feature Loss: 2.7312, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 177
# 	Train:	Total Loss: 3.0489, Feature Loss: 3.0489, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7250, Feature Loss: 2.7250, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 178
# 	Train:	Total Loss: 3.0601, Feature Loss: 3.0601, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7188, Feature Loss: 2.7188, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 179
# 	Train:	Total Loss: 3.0433, Feature Loss: 3.0433, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7131, Feature Loss: 2.7131, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 180
# 	Train:	Total Loss: 3.0183, Feature Loss: 3.0183, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7081, Feature Loss: 2.7081, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 181
# 	Train:	Total Loss: 3.0188, Feature Loss: 3.0188, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7025, Feature Loss: 2.7025, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 182
# 	Train:	Total Loss: 3.0100, Feature Loss: 3.0100, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6971, Feature Loss: 2.6971, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 183
# 	Train:	Total Loss: 2.9934, Feature Loss: 2.9934, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6926, Feature Loss: 2.6926, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 184
# 	Train:	Total Loss: 3.0126, Feature Loss: 3.0126, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6873, Feature Loss: 2.6873, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 185
# 	Train:	Total Loss: 3.0018, Feature Loss: 3.0018, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6836, Feature Loss: 2.6836, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 186
# 	Train:	Total Loss: 2.9780, Feature Loss: 2.9780, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6782, Feature Loss: 2.6782, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 187
# 	Train:	Total Loss: 2.9889, Feature Loss: 2.9889, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6732, Feature Loss: 2.6732, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 188
# 	Train:	Total Loss: 2.9891, Feature Loss: 2.9891, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6692, Feature Loss: 2.6692, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 189
# 	Train:	Total Loss: 2.9676, Feature Loss: 2.9676, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6646, Feature Loss: 2.6646, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 190
# 	Train:	Total Loss: 2.9636, Feature Loss: 2.9636, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6609, Feature Loss: 2.6609, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 191
# 	Train:	Total Loss: 2.9709, Feature Loss: 2.9709, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6563, Feature Loss: 2.6563, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 192
# 	Train:	Total Loss: 2.9337, Feature Loss: 2.9337, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6525, Feature Loss: 2.6525, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 193
# 	Train:	Total Loss: 2.9625, Feature Loss: 2.9625, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6488, Feature Loss: 2.6488, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 194
# 	Train:	Total Loss: 2.9621, Feature Loss: 2.9621, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6447, Feature Loss: 2.6447, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 195
# 	Train:	Total Loss: 2.9372, Feature Loss: 2.9372, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6412, Feature Loss: 2.6412, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 196
# 	Train:	Total Loss: 2.9359, Feature Loss: 2.9359, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6380, Feature Loss: 2.6380, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 197
# 	Train:	Total Loss: 2.9283, Feature Loss: 2.9283, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6346, Feature Loss: 2.6346, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 198
# 	Train:	Total Loss: 2.9188, Feature Loss: 2.9188, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6311, Feature Loss: 2.6311, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 199
# 	Train:	Total Loss: 2.9116, Feature Loss: 2.9116, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6281, Feature Loss: 2.6281, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 200
# 	Train:	Total Loss: 2.9120, Feature Loss: 2.9120, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6250, Feature Loss: 2.6250, Type Loss: 0.0000 , LR: 0.000100

# %%
if not model_loaded:
    plt.figure(figsize=(14, 5))
    plt.plot(test_total_losses, label='Total Test Loss')
    plt.plot(train_total_losses, label='Total Train Loss')
    plt.legend()
    plt.title('Total Loss')
    plt.savefig("GMM1_totalloss.png")
    plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
if not model_loaded:
    plt.figure(figsize=(14, 5))
    plt.plot(test_feature_losses, label='Test Feature Loss')
    plt.plot(train_feature_losses, label='Train Feature Loss')
    plt.legend()
    plt.title('Feature Loss')
    plt.savefig("GMM1_feature_loss.png")
    plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
test_loader_melt = DataLoader(graphs_melt, batch_size=1)
encoded_data_melt=[]
type_data_melt = []
for data in test_loader:
    model.eval()
    z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
    decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
    encoded_data_melt.append(z.detach().numpy())
    type_data_melt.append(str_type.detach().numpy())

encoded_data_melt = np.array(encoded_data_melt)
type_data_melt = np.array(type_data_melt)

# %%
test_loader_cry = DataLoader(graphs_cry, batch_size=1)
encoded_data_cry=[]
type_data_cry = []
for data in test_loader:
    model.eval()
    z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
    decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
    encoded_data_cry.append(z.detach().numpy())
    type_data_cry.append(str_type.detach().numpy())

encoded_data_cry = np.array(encoded_data_cry)
type_data_cry = np.array(type_data_cry)

# %%
# %matplotlib widget

frame = 10

fig = plt.figure(figsize=(15,4))
data_melt = encoded_data_melt[frame]

data_cry = encoded_data_cry[frame]
plt.scatter(data_melt[:,0],data_melt[:,1],c="r",label="melt")
plt.scatter(data_cry[:,0],data_cry[:,1],c="b",label="crystal")
plt.savefig("GMM1_scatter.png")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
