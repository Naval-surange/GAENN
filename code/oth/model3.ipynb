# %%
import mdtraj as md
from ase import Atoms
import nglview as nv
import networkx as nx

import numpy as np
import matplotlib.pyplot as plt
import torch
from tqdm import tqdm

import torch_geometric.transforms as T
from torch_geometric.loader import DataLoader
from torch_geometric.nn import GCNConv, SAGPooling, InnerProductDecoder
import torch_geometric.data as data
from torch_geometric.utils.convert import to_networkx
import torch.optim.lr_scheduler as lr_scheduler
from torch.nn import Linear
import sys

# %%
all_frames_cry = md.load_xtc("../simulation/para_crystal.xtc", top="../simulation/para_crystal.gro")
all_frames_melt = md.load_xtc("../simulation/para_melt.xtc", top="../simulation/para_melt.gro")

# %%
all_frames_cry = all_frames_cry[::100]
all_frames_melt = all_frames_melt[::100]

# %%
n_frames = all_frames_cry.xyz.shape[0]
n_atoms = all_frames_cry.topology.residue(0).n_atoms
n_mols = all_frames_cry.topology.n_residues

# %%
def createGraph(all_frames,structure_type="crystal"):
    all_frames_fatures = []

    print("Creating Feature matrix")
    for i in tqdm(range(all_frames.xyz.shape[0])):
        mol_com_pos = []

        for res in all_frames.top.residues:
            pos = []
            for atom in res.atoms:
                pos.append(all_frames.xyz[i][atom.index])
            mol_com_pos.append(np.mean(pos,axis=0))
            
            # print()
        mol_com_pos = np.array(mol_com_pos).astype(np.float32)  
        all_frames_fatures.append(mol_com_pos)

    all_frames_fatures = np.array(all_frames_fatures).astype(np.float32)



    cutoff = 0.8

    print("Creating Edge list")
    all_edge_list = []
    # with open("edge_list.txt","w") as f:
    for frame_i in tqdm(range(n_frames)):
        from_list = []
        to_list = []

        for i in range(len(all_frames_fatures[frame_i])):
            for j in range(i+1,len(all_frames_fatures[frame_i])):
                if np.linalg.norm(all_frames_fatures[frame_i][i]-all_frames_fatures[frame_i][j]) < cutoff:
                    # f.write(str(i)+" "+str(j)+" "+str(np.linalg.norm(all_frames_fatures[frame_i][i]-all_frames_fatures[frame_i][j]))+"\n")
                    from_list.append(i)
                    to_list.append(j)

                    to_list.append(i)
                    from_list.append(j)

        edge_list = np.array([from_list,to_list]).astype(np.int64)
        all_edge_list.append(edge_list)
    print("creating Graphs")
    graphs = []
    for frame in tqdm(range(n_frames)):
        if structure_type == "crystal":
            g = data.Data(x=torch.tensor(all_frames_fatures[frame]).float(), edge_index=torch.tensor(all_edge_list[frame]).long(), y=torch.tensor([0]))
        else:
            g = data.Data(x=torch.tensor(all_frames_fatures[frame]).float(), edge_index=torch.tensor(all_edge_list[frame]).long(), y=torch.tensor([1]))
        graphs.append(g)
    return graphs

# %%
graphs_cry = createGraph(all_frames_cry,structure_type="crystal")
graphs_melt = createGraph(all_frames_melt,structure_type="melt")
# Out:
# Creating Feature matrix
# 100%|██████████| 51/51 [00:00<00:00, 87.03it/s]
# Creating Edge list
# 100%|██████████| 51/51 [00:58<00:00,  1.14s/it]
# creating Graphs
# 100%|██████████| 51/51 [00:00<00:00, 584.36it/s]
# Creating Feature matrix
# 100%|██████████| 51/51 [00:00<00:00, 93.30it/s]
# Creating Edge list
# 100%|██████████| 51/51 [00:50<00:00,  1.02it/s]
# creating Graphs
# 100%|██████████| 51/51 [00:00<00:00, 16292.90it/s]

# %%
def convert_to_adj(edge_index, num_nodes=None):
    if num_nodes is None:
        num_nodes = edge_index.max() + 1
    adj = torch.zeros(num_nodes, num_nodes)
    adj[edge_index[0], edge_index[1]] = 1
    return adj

def convert_to_edge_index(adj):
    edge_index = adj.nonzero().t()
    return edge_index

# %%
graphs = graphs_cry + graphs_melt
# graphs = graphs_melt

# %%
# shuffle the graphs
np.random.shuffle(graphs)

# %%
graphs
# Out:
# [Data(x=[864, 3], edge_index=[2, 7306], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6570], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7274], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7074], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6544], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6964], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7078], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6584], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7116], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6552], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6512], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6012], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5822], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7092], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6630], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6524], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5880], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6066], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6070], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7096], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6596], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7048], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7080], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6580], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6400], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6558], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6056], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6608], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6626], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6602], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5862], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6564], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7116], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6488], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7052], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7060], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6288], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6546], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6560], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7218], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7052], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7128], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5982], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7092], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7374], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6172], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7108], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7028], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7060], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6990], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5962], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7192], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7064], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6464], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7076], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7132], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7088], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7036], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6452], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7024], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5910], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7006], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6548], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7056], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7008], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6542], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6560], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7026], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6582], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7094], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6508], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5892], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5876], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6508], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7054], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7100], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6476], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6214], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7078], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6592], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7122], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6566], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6548], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7146], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6586], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7240], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7006], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6578], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7034], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6554], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7020], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6018], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7048], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6546], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7044], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6934], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7294], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6532], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7086], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7012], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6992], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7090], y=[1])]

# %% [markdown]
# ## model

# %%
from typing import Optional, Tuple

import torch
from torch import Tensor
from torch.nn import Module

from torch_geometric.nn.inits import reset
from torch_geometric.utils import negative_sampling

EPS = 1e-15
MAX_LOGSTD = 10
edgeShape = None
featureShape = None


class InnerProductDecoder(torch.nn.Module):
    r"""The inner product decoder from the `"Variational Graph Auto-Encoders"
    <https://arxiv.org/abs/1611.07308>`_ paper

    .. math::
        \sigma(\mathbf{Z}\mathbf{Z}^{\top})

    where :math:`\mathbf{Z} \in \mathbb{R}^{N \times d}` denotes the latent
    space produced by the encoder."""

    def forward(self, z: Tensor, edge_index: Tensor,
                sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into edge probabilities for
        the given node-pairs :obj:`edge_index`.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        value = (z[edge_index[0]] * z[edge_index[1]]).sum(dim=1)
        return torch.sigmoid(value) if sigmoid else value

    def forward_all(self, z: Tensor, sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into a probabilistic dense
        adjacency matrix.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        adj = torch.matmul(z, z.t())
        return torch.sigmoid(adj) if sigmoid else adj


class GAE(torch.nn.Module):
    r"""The Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper based on user-defined encoder and decoder models.

    Args:
        encoder (torch.nn.Module): The encoder module.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__()
        self.encoder = encoder
        self.decoder = InnerProductDecoder() if decoder is None else decoder
        GAE.reset_parameters(self)

    def reset_parameters(self):
        r"""Resets all learnable parameters of the module."""
        reset(self.encoder)
        reset(self.decoder)

    def forward(self, *args, **kwargs) -> Tensor:  # pragma: no cover
        r"""Alias for :meth:`encode`."""
        return self.encoder(*args, **kwargs)

    def encode(self, *args, **kwargs) -> Tensor:
        r"""Runs the encoder and computes node-wise latent variables."""
        return self.encoder(*args, **kwargs)

    def decode(self, *args, **kwargs) -> Tensor:
        r"""Runs the decoder and computes edge probabilities."""
        return self.decoder(*args, **kwargs)

    def recon_loss(self, z: Tensor, pos_edge_index: Tensor,
                   neg_edge_index: Optional[Tensor] = None) -> Tensor:
        r"""Given latent variables :obj:`z`, computes the binary cross
        entropy loss for positive edges :obj:`pos_edge_index` and negative
        sampled edges.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to train against.
            neg_edge_index (torch.Tensor, optional): The negative edges to
                train against. If not given, uses negative sampling to
                calculate negative edges. (default: :obj:`None`)
        """
        pos_loss = -torch.log(
            self.decoder(z, pos_edge_index, sigmoid=True)[0] + EPS).mean()

        if neg_edge_index is None:
            neg_edge_index = negative_sampling(pos_edge_index, z.size(0))
        neg_loss = -torch.log(1 -
                              self.decoder(z, neg_edge_index.long(), sigmoid=True)[0] +
                              EPS).mean()

        return pos_loss + neg_loss

    def test(self, z: Tensor, pos_edge_index: Tensor,
             neg_edge_index: Tensor) -> Tuple[Tensor, Tensor]:
        r"""Given latent variables :obj:`z`, positive edges
        :obj:`pos_edge_index` and negative edges :obj:`neg_edge_index`,
        computes area under the ROC curve (AUC) and average precision (AP)
        
        scores.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to evaluate
                against.
            neg_edge_index (torch.Tensor): The negative edges to evaluate
                against.
        """
        from sklearn.metrics import average_precision_score, roc_auc_score

        pos_y = z.new_ones(pos_edge_index.size(1))
        neg_y = z.new_zeros(neg_edge_index.size(1))
        y = torch.cat([pos_y, neg_y], dim=0)

        pos_pred = self.decoder(z, pos_edge_index, sigmoid=True)
        neg_pred = self.decoder(z, neg_edge_index, sigmoid=True)
        pred = torch.cat([pos_pred, neg_pred], dim=0)

        y, pred = y.detach().cpu().numpy(), pred.detach().cpu().numpy()

        return roc_auc_score(y, pred), average_precision_score(y, pred)


class VGAE(GAE):
    r"""The Variational Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper.

    Args:
        encoder (torch.nn.Module): The encoder module to compute :math:`\mu`
            and :math:`\log\sigma^2`.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__(encoder, decoder)

    def reparametrize(self, mu: Tensor, logstd: Tensor) -> Tensor:
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def encode(self, *args, **kwargs) -> Tensor:
        """"""
        z, self.edge_index = self.encoder(
            *args, **kwargs)
        
        return z, self.edge_index

    def kl_loss(self, mu: Optional[Tensor] = None,
                logstd: Optional[Tensor] = None) -> Tensor:
        r"""Computes the KL loss, either for the passed arguments :obj:`mu`
        and :obj:`logstd`, or based on latent variables from last encoding.

        Args:
            mu (torch.Tensor, optional): The latent space for :math:`\mu`. If
                set to :obj:`None`, uses the last computation of :math:`\mu`.
                (default: :obj:`None`)
            logstd (torch.Tensor, optional): The latent space for
                :math:`\log\sigma`.  If set to :obj:`None`, uses the last
                computation of :math:`\log\sigma^2`. (default: :obj:`None`)
        """
        mu = self.__mu__ if mu is None else mu
        logstd = self.__logstd__ if logstd is None else logstd.clamp(
            max=MAX_LOGSTD)
        return -0.5 * torch.mean(
            torch.sum(1 + 2 * logstd - mu**2 - logstd.exp()**2, dim=1))

# %%
import torch.nn.functional as F



class VariationalGCNEncoder(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__() # changes made such that guassian is 1 
        self.conv1 = GCNConv(in_channels, 2*out_channels)
        self.conv2 = GCNConv(2*out_channels, 1 * out_channels)
        self.pool = SAGPooling(out_channels, 0.5)
        
        self.conv_mu = GCNConv(1 * out_channels, out_channels)
        self.conv_logstd = GCNConv(1 * out_channels, out_channels)
    def reparametrize(self, mu: Tensor, logstd: Tensor) -> Tensor:
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def forward(self, x, edge_index,class_label):
        # print("input:",x.shape, edge_index.shape)
        x = self.conv1(x, edge_index)
        x = F.silu(x)
        # print("conv1:",x.shape, edge_index.shape)
        x = self.conv2(x, edge_index)
        x = F.silu(x)
        # print("conv2:",x.shape, edge_index.shape)

        sample = self.reparametrize(self.conv_mu(x, edge_index), self.conv_logstd(x, edge_index))
        sample = self.reparametrize(self.conv_mu(sample, edge_index), self.conv_logstd(sample, edge_index))
        # self.conv_mu_crystal.train(True)
        # self.conv_logstd_crystal.train(True)
        # self.conv_mu_melt.train(True)
        # self.conv_logstd_melt.train(True)
        self.conv_mu.train(True)
        self.conv_logstd.train(True)
        return sample, edge_index

# %%
class VariationalGCNDecoder(torch.nn.Module):
    def __init__(self,in_channels,out_channels):
        super().__init__()
        self.type_layer1 = Linear(1728,200)
        self.dropout = torch.nn.Dropout(0.5)
        self.type_layer2 = Linear(200,2)
        self.conv1 = GCNConv(in_channels,2*out_channels)
        self.conv2 = GCNConv(2*out_channels, 1 * out_channels)
    def forward(self, x, edge_index, sigmoid=True):
        # print("input:",x.shape, edge_index.shape)
        flat = x.flatten()
        flat = self.type_layer1(flat).relu()
        flat = self.dropout(flat)
        str_type = F.softmax(self.type_layer2(flat).relu(),dim=0)
         
        x = self.conv1(x, edge_index)
        x = F.silu(x)
        # print("conv1:",x.shape, edge_index.shape)
        x = self.conv2(x, edge_index)
        x = F.silu(x)
        # print("conv2:",x.shape, edge_index.shape)
        return x, edge_index,str_type

# %%
import os
in_channels = graphs[0].num_features
out_channels = 2
lr = 1e-4
n_epochs = 200
batch_size=1
test_train_split = 0.8
model_name = "model3.pt"
model_loaded = False
force_train = True  

if os.path.exists("./models/"+model_name) and not force_train:
    model = torch.load("./models/"+model_name)
    model_loaded = True
else:
    model = VGAE(VariationalGCNEncoder(in_channels, out_channels),
                VariationalGCNDecoder(out_channels, in_channels))

optimizer = torch.optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, step_size=300, gamma=0.5)

# %%
train_loader = DataLoader(graphs_melt[:int(n_frames*test_train_split)], batch_size=batch_size, shuffle=True)
test_loader = DataLoader(graphs[int(n_frames*test_train_split):], batch_size=batch_size, shuffle=True)

# %%
lossFxn = torch.nn.MSELoss()
typeLossFxn = torch.nn.CrossEntropyLoss()

def train():
    model.train()
    model.zero_grad()
    model.float()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0
    type_loss_all = 0
    for data in train_loader:
        optimizer.zero_grad()
        z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
        decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)

     
        # TypeLoss = typeLossFxn(str_type.unsqueeze(0), data.y)
        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        loss = FeatureLoss + EdgeLoss 

        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        # type_loss_all += float(TypeLoss)

        loss.backward()
        optimizer.step()
        

    return loss_all / len(train_loader), feature_loss_all / len(train_loader), edge_loss_all / len(train_loader), kl_loss_all / len(train_loader), type_loss_all / len(train_loader)

# %%
lossFxn = torch.nn.MSELoss()
def test():
    model.eval()
    model.zero_grad()
    model.float()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0
    type_loss_all = 0

    for data in test_loader:
        optimizer.zero_grad()
        z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
        decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
        
        # TypeLoss = typeLossFxn(str_type.unsqueeze(0), data.y)
        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        loss = FeatureLoss + EdgeLoss 

        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        # type_loss_all += float(TypeLoss)
        
        
        

    return loss_all / len(test_loader), feature_loss_all / len(test_loader), edge_loss_all / len(test_loader), kl_loss_all / len(test_loader), type_loss_all / len(test_loader)

# %%
train_total_losses = []
train_feature_losses = []
train_edge_losses = []
train_kl_losses = []
train_type_losses = []

test_total_losses = []
test_feature_losses = []
test_edge_losses = []
test_kl_losses = []
test_type_losses = []

if model_loaded:        
    print("Pretrained Model Loaded, no training required")
else:
    for epoch in range(1, n_epochs + 1):
        
        train_total_loss, train_feature_loss, train_edge_loss, train_kl_loss,train_type_loss = train()
        test_total_loss, test_feature_loss, test_edge_loss, test_kl_loss, test_type_loss= test()
        
        print(f"Epoch: {epoch:03d}")
        print(f'\tTrain:\tTotal Loss: {train_total_loss:.4f}, Feature Loss: {train_feature_loss:.4f}, Type Loss: {train_type_loss:.4f} ,  LR: {scheduler.get_last_lr()[0]:.6f}')
        print(f'\tTest: \tTotal Loss: {test_total_loss:.4f}, Feature Loss: {test_feature_loss:.4f}, Type Loss: {test_type_loss:.4f} , LR: {scheduler.get_last_lr()[0]:.6f}')
        
        
        train_total_losses.append(train_total_loss)
        train_feature_losses.append(train_feature_loss)
        train_edge_losses.append(train_edge_loss)
        train_kl_losses.append(train_kl_loss)
        train_type_losses.append(train_type_loss)


        test_total_losses.append(test_total_loss)
        test_feature_losses.append(test_feature_loss)
        test_edge_losses.append(test_edge_loss)
        test_kl_losses.append(test_kl_loss)
        test_type_losses.append(test_type_loss)
        
        scheduler.step()
    torch.save(model,"./models/"+model_name)
# Out:
# Epoch: 001
# 	Train:	Total Loss: 16550830629.4279, Feature Loss: 16550830629.4279, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2192, Feature Loss: 13.2192, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 002
# 	Train:	Total Loss: 521511855110490.6250, Feature Loss: 521511855110490.6250, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2138, Feature Loss: 13.2138, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 003
# 	Train:	Total Loss: 551484733268215488.0000, Feature Loss: 551484733268215488.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2110, Feature Loss: 13.2110, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 004
# 	Train:	Total Loss: 254854121916856.0938, Feature Loss: 254854121916856.0938, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2107, Feature Loss: 13.2107, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 005
# 	Train:	Total Loss: 1673879648473.9507, Feature Loss: 1673879648473.9507, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2098, Feature Loss: 13.2098, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 006
# 	Train:	Total Loss: 1879209011857337.2500, Feature Loss: 1879209011857337.2500, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2115, Feature Loss: 13.2115, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 007
# 	Train:	Total Loss: 4003760229.5821, Feature Loss: 4003760229.5821, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2105, Feature Loss: 13.2105, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 008
# 	Train:	Total Loss: 79596147912.9091, Feature Loss: 79596147912.9091, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2095, Feature Loss: 13.2095, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 009
# 	Train:	Total Loss: 379635133767189632.0000, Feature Loss: 379635133767189632.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2086, Feature Loss: 13.2086, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 010
# 	Train:	Total Loss: 629292273370037.5000, Feature Loss: 629292273370037.5000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2105, Feature Loss: 13.2105, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 011
# 	Train:	Total Loss: 892022585425.9446, Feature Loss: 892022585425.9446, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2094, Feature Loss: 13.2094, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 012
# 	Train:	Total Loss: 1668921500587527680.0000, Feature Loss: 1668921500587527680.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2060, Feature Loss: 13.2060, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 013
# 	Train:	Total Loss: 13222858927900823912448.0000, Feature Loss: 13222858927900823912448.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2116, Feature Loss: 13.2116, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 014
# 	Train:	Total Loss: 13486238619215588.0000, Feature Loss: 13486238619215588.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2107, Feature Loss: 13.2107, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 015
# 	Train:	Total Loss: 784889509439012736.0000, Feature Loss: 784889509439012736.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2096, Feature Loss: 13.2096, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 016
# 	Train:	Total Loss: 1464128601004487.5000, Feature Loss: 1464128601004487.5000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2083, Feature Loss: 13.2083, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 017
# 	Train:	Total Loss: 528965613586740.0000, Feature Loss: 528965613586740.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2071, Feature Loss: 13.2071, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 018
# 	Train:	Total Loss: 449422918466405952.0000, Feature Loss: 449422918466405952.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2058, Feature Loss: 13.2058, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 019
# 	Train:	Total Loss: 3247694256490521600.0000, Feature Loss: 3247694256490521600.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2047, Feature Loss: 13.2047, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 020
# 	Train:	Total Loss: 262278577475111.0000, Feature Loss: 262278577475111.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2034, Feature Loss: 13.2034, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 021
# 	Train:	Total Loss: 1718874354265747095552.0000, Feature Loss: 1718874354265747095552.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2040, Feature Loss: 13.2040, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 022
# 	Train:	Total Loss: 25634319323313768.0000, Feature Loss: 25634319323313768.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2027, Feature Loss: 13.2027, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 023
# 	Train:	Total Loss: 5641767079073.4307, Feature Loss: 5641767079073.4307, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.2013, Feature Loss: 13.2013, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 024
# 	Train:	Total Loss: 105467282196.1058, Feature Loss: 105467282196.1058, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1997, Feature Loss: 13.1997, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 025
# 	Train:	Total Loss: 629852485015.8011, Feature Loss: 629852485015.8011, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1982, Feature Loss: 13.1982, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 026
# 	Train:	Total Loss: 30614392100089088.0000, Feature Loss: 30614392100089088.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1966, Feature Loss: 13.1966, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 027
# 	Train:	Total Loss: 54552282663036141568.0000, Feature Loss: 54552282663036141568.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1958, Feature Loss: 13.1958, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 028
# 	Train:	Total Loss: 1660677356905134592.0000, Feature Loss: 1660677356905134592.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1943, Feature Loss: 13.1943, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 029
# 	Train:	Total Loss: 92500159526.1717, Feature Loss: 92500159526.1717, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1925, Feature Loss: 13.1925, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 030
# 	Train:	Total Loss: 10870721677126702.0000, Feature Loss: 10870721677126702.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1907, Feature Loss: 13.1907, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 031
# 	Train:	Total Loss: 10995803458235552.0000, Feature Loss: 10995803458235552.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1889, Feature Loss: 13.1889, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 032
# 	Train:	Total Loss: 22934730418503656.0000, Feature Loss: 22934730418503656.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1870, Feature Loss: 13.1870, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 033
# 	Train:	Total Loss: 1898163048794282660986880.0000, Feature Loss: 1898163048794282660986880.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1877, Feature Loss: 13.1877, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 034
# 	Train:	Total Loss: 5247480909057915904.0000, Feature Loss: 5247480909057915904.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1928, Feature Loss: 13.1928, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 035
# 	Train:	Total Loss: 9848064588854.6543, Feature Loss: 9848064588854.6543, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1908, Feature Loss: 13.1908, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 036
# 	Train:	Total Loss: 1566013884149825536.0000, Feature Loss: 1566013884149825536.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1886, Feature Loss: 13.1886, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 037
# 	Train:	Total Loss: 78182080188.9112, Feature Loss: 78182080188.9112, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1863, Feature Loss: 13.1863, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 038
# 	Train:	Total Loss: 1516239958658609.7500, Feature Loss: 1516239958658609.7500, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1840, Feature Loss: 13.1840, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 039
# 	Train:	Total Loss: 25255402845733673953656832.0000, Feature Loss: 25255402845733673953656832.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1855, Feature Loss: 13.1855, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 040
# 	Train:	Total Loss: 20072763136897388.0000, Feature Loss: 20072763136897388.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1887, Feature Loss: 13.1887, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 041
# 	Train:	Total Loss: 7706936917809.5371, Feature Loss: 7706936917809.5371, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1862, Feature Loss: 13.1862, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 042
# 	Train:	Total Loss: 19354755125099628593152.0000, Feature Loss: 19354755125099628593152.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1837, Feature Loss: 13.1837, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 043
# 	Train:	Total Loss: 1815281298901.8794, Feature Loss: 1815281298901.8794, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1809, Feature Loss: 13.1809, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 044
# 	Train:	Total Loss: 825433031998648704.0000, Feature Loss: 825433031998648704.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1780, Feature Loss: 13.1780, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 045
# 	Train:	Total Loss: 2757841747995.1836, Feature Loss: 2757841747995.1836, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1751, Feature Loss: 13.1751, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 046
# 	Train:	Total Loss: 515549964110113.6875, Feature Loss: 515549964110113.6875, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1719, Feature Loss: 13.1719, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 047
# 	Train:	Total Loss: 28110185313.6364, Feature Loss: 28110185313.6364, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1686, Feature Loss: 13.1686, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 048
# 	Train:	Total Loss: 214530217285.8589, Feature Loss: 214530217285.8589, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1652, Feature Loss: 13.1652, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 049
# 	Train:	Total Loss: 49696955245069.2344, Feature Loss: 49696955245069.2344, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1618, Feature Loss: 13.1618, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 050
# 	Train:	Total Loss: 16315377005403802.0000, Feature Loss: 16315377005403802.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1581, Feature Loss: 13.1581, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 051
# 	Train:	Total Loss: 1888811145.7288, Feature Loss: 1888811145.7288, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1544, Feature Loss: 13.1544, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 052
# 	Train:	Total Loss: 5704457048.8087, Feature Loss: 5704457048.8087, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1504, Feature Loss: 13.1504, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 053
# 	Train:	Total Loss: 2461479753605601.0000, Feature Loss: 2461479753605601.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1463, Feature Loss: 13.1463, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 054
# 	Train:	Total Loss: 3049316020862930.5000, Feature Loss: 3049316020862930.5000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1420, Feature Loss: 13.1420, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 055
# 	Train:	Total Loss: 5946038636905598287872.0000, Feature Loss: 5946038636905598287872.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1378, Feature Loss: 13.1378, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 056
# 	Train:	Total Loss: 6563109110420397359104.0000, Feature Loss: 6563109110420397359104.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1332, Feature Loss: 13.1332, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 057
# 	Train:	Total Loss: 360494113325681536.0000, Feature Loss: 360494113325681536.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1286, Feature Loss: 13.1286, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 058
# 	Train:	Total Loss: 959451415857332608.0000, Feature Loss: 959451415857332608.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1237, Feature Loss: 13.1237, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 059
# 	Train:	Total Loss: 7479434376533146110787584.0000, Feature Loss: 7479434376533146110787584.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1217, Feature Loss: 13.1217, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 060
# 	Train:	Total Loss: 803959030646889088.0000, Feature Loss: 803959030646889088.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1208, Feature Loss: 13.1208, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 061
# 	Train:	Total Loss: 4473639548421825.0000, Feature Loss: 4473639548421825.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1152, Feature Loss: 13.1152, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 062
# 	Train:	Total Loss: 4976279581809007.0000, Feature Loss: 4976279581809007.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1095, Feature Loss: 13.1095, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 063
# 	Train:	Total Loss: 467080632612938.8125, Feature Loss: 467080632612938.8125, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1035, Feature Loss: 13.1035, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 064
# 	Train:	Total Loss: 6685176288522.7119, Feature Loss: 6685176288522.7119, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.0973, Feature Loss: 13.0973, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 065
# 	Train:	Total Loss: 1044734031144677.7500, Feature Loss: 1044734031144677.7500, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.0906, Feature Loss: 13.0906, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 066
# 	Train:	Total Loss: 175309942914924.4375, Feature Loss: 175309942914924.4375, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.0837, Feature Loss: 13.0837, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 067
# 	Train:	Total Loss: 512193278239.7671, Feature Loss: 512193278239.7671, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.0766, Feature Loss: 13.0766, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 068
# 	Train:	Total Loss: 1822538804246676736.0000, Feature Loss: 1822538804246676736.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.0694, Feature Loss: 13.0694, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 069
# 	Train:	Total Loss: 424387298157614.2500, Feature Loss: 424387298157614.2500, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.0615, Feature Loss: 13.0615, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 070
# 	Train:	Total Loss: 7337299003711746100657389568.0000, Feature Loss: 7337299003711746100657389568.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.0598, Feature Loss: 13.0598, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 071
# 	Train:	Total Loss: 24924856479074940.0000, Feature Loss: 24924856479074940.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.0561, Feature Loss: 13.0561, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 072
# 	Train:	Total Loss: 214513120555377.2812, Feature Loss: 214513120555377.2812, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.0475, Feature Loss: 13.0475, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 073
# 	Train:	Total Loss: 346145155671745.3125, Feature Loss: 346145155671745.3125, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.0384, Feature Loss: 13.0384, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 074
# 	Train:	Total Loss: 73174936134241.4219, Feature Loss: 73174936134241.4219, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.0291, Feature Loss: 13.0291, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 075
# 	Train:	Total Loss: 1037483223046.9635, Feature Loss: 1037483223046.9635, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.0200, Feature Loss: 13.0200, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 076
# 	Train:	Total Loss: 5941635916868425.0000, Feature Loss: 5941635916868425.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.0097, Feature Loss: 13.0097, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 077
# 	Train:	Total Loss: 118265332980508.5469, Feature Loss: 118265332980508.5469, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.9990, Feature Loss: 12.9990, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 078
# 	Train:	Total Loss: 26126742555415032102912.0000, Feature Loss: 26126742555415032102912.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.9885, Feature Loss: 12.9885, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 079
# 	Train:	Total Loss: 1959099472657.8188, Feature Loss: 1959099472657.8188, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.9772, Feature Loss: 12.9772, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 080
# 	Train:	Total Loss: 21325387033972464.0000, Feature Loss: 21325387033972464.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.9652, Feature Loss: 12.9652, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 081
# 	Train:	Total Loss: 896030956081.0544, Feature Loss: 896030956081.0544, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.9527, Feature Loss: 12.9527, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 082
# 	Train:	Total Loss: 878001967606463987712.0000, Feature Loss: 878001967606463987712.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.9401, Feature Loss: 12.9401, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 083
# 	Train:	Total Loss: 141908392888.8704, Feature Loss: 141908392888.8704, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.9264, Feature Loss: 12.9264, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 084
# 	Train:	Total Loss: 1008680288501.9646, Feature Loss: 1008680288501.9646, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.9125, Feature Loss: 12.9125, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 085
# 	Train:	Total Loss: 4257967966942289.5000, Feature Loss: 4257967966942289.5000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.8976, Feature Loss: 12.8976, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 086
# 	Train:	Total Loss: 10726245818880344.0000, Feature Loss: 10726245818880344.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.8829, Feature Loss: 12.8829, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 087
# 	Train:	Total Loss: 885031527.9036, Feature Loss: 885031527.9036, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.8677, Feature Loss: 12.8677, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 088
# 	Train:	Total Loss: 21620644743019955690143744.0000, Feature Loss: 21620644743019955690143744.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.8529, Feature Loss: 12.8529, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 089
# 	Train:	Total Loss: 622075861049596224471040.0000, Feature Loss: 622075861049596224471040.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.8365, Feature Loss: 12.8365, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 090
# 	Train:	Total Loss: 48877007417470.4531, Feature Loss: 48877007417470.4531, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.8187, Feature Loss: 12.8187, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 091
# 	Train:	Total Loss: 272167837788792520704.0000, Feature Loss: 272167837788792520704.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.8007, Feature Loss: 12.8007, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 092
# 	Train:	Total Loss: 392962646385728.4375, Feature Loss: 392962646385728.4375, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.7822, Feature Loss: 12.7822, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 093
# 	Train:	Total Loss: 10891768807866128.0000, Feature Loss: 10891768807866128.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.7635, Feature Loss: 12.7635, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 094
# 	Train:	Total Loss: 59154906698430.0469, Feature Loss: 59154906698430.0469, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.7434, Feature Loss: 12.7434, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 095
# 	Train:	Total Loss: 2130240420521.9316, Feature Loss: 2130240420521.9316, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.7225, Feature Loss: 12.7225, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 096
# 	Train:	Total Loss: 97606270629930493542400.0000, Feature Loss: 97606270629930493542400.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.7010, Feature Loss: 12.7010, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 097
# 	Train:	Total Loss: 147985794075707113472.0000, Feature Loss: 147985794075707113472.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.6791, Feature Loss: 12.6791, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 098
# 	Train:	Total Loss: 84756820511.2672, Feature Loss: 84756820511.2672, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.6563, Feature Loss: 12.6563, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 099
# 	Train:	Total Loss: 3126516748016909566345216.0000, Feature Loss: 3126516748016909566345216.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.6328, Feature Loss: 12.6328, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 100
# 	Train:	Total Loss: 25590107567099348.0000, Feature Loss: 25590107567099348.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.6084, Feature Loss: 12.6084, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 101
# 	Train:	Total Loss: 2209446389302.2026, Feature Loss: 2209446389302.2026, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.5832, Feature Loss: 12.5832, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 102
# 	Train:	Total Loss: 68022124559581.7734, Feature Loss: 68022124559581.7734, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.5574, Feature Loss: 12.5574, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 103
# 	Train:	Total Loss: 379436903006588.0625, Feature Loss: 379436903006588.0625, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.5304, Feature Loss: 12.5304, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 104
# 	Train:	Total Loss: 801228606709348.1250, Feature Loss: 801228606709348.1250, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.5022, Feature Loss: 12.5022, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 105
# 	Train:	Total Loss: 1475868356608897536.0000, Feature Loss: 1475868356608897536.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.4726, Feature Loss: 12.4726, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 106
# 	Train:	Total Loss: 243083600724179.0000, Feature Loss: 243083600724179.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.4424, Feature Loss: 12.4424, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 107
# 	Train:	Total Loss: 78971944785156079616.0000, Feature Loss: 78971944785156079616.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.4144, Feature Loss: 12.4144, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 108
# 	Train:	Total Loss: 17637502383200524.0000, Feature Loss: 17637502383200524.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.3815, Feature Loss: 12.3815, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 109
# 	Train:	Total Loss: 2279517840255889946181632.0000, Feature Loss: 2279517840255889946181632.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.3486, Feature Loss: 12.3486, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 110
# 	Train:	Total Loss: 27655359238064132.0000, Feature Loss: 27655359238064132.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.3099, Feature Loss: 12.3099, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 111
# 	Train:	Total Loss: 17921921442576.7344, Feature Loss: 17921921442576.7344, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.2698, Feature Loss: 12.2698, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 112
# 	Train:	Total Loss: 291711629861487.3750, Feature Loss: 291711629861487.3750, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.2337, Feature Loss: 12.2337, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 113
# 	Train:	Total Loss: 8492231213647496.0000, Feature Loss: 8492231213647496.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.2311, Feature Loss: 12.2311, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 114
# 	Train:	Total Loss: 232408105260.8376, Feature Loss: 232408105260.8376, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.2235, Feature Loss: 12.2235, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 115
# 	Train:	Total Loss: 90796958904978400.0000, Feature Loss: 90796958904978400.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.2157, Feature Loss: 12.2157, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 116
# 	Train:	Total Loss: 1490069768586455.7500, Feature Loss: 1490069768586455.7500, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.2081, Feature Loss: 12.2081, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 117
# 	Train:	Total Loss: 7075170465354602250240.0000, Feature Loss: 7075170465354602250240.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.2003, Feature Loss: 12.2003, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 118
# 	Train:	Total Loss: 4260485411610984710144.0000, Feature Loss: 4260485411610984710144.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.1925, Feature Loss: 12.1925, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 119
# 	Train:	Total Loss: 25092079.1799, Feature Loss: 25092079.1799, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.1848, Feature Loss: 12.1848, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 120
# 	Train:	Total Loss: 278011024575671.6875, Feature Loss: 278011024575671.6875, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.1773, Feature Loss: 12.1773, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 121
# 	Train:	Total Loss: 8001093674443787264.0000, Feature Loss: 8001093674443787264.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.1696, Feature Loss: 12.1696, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 122
# 	Train:	Total Loss: 1120993652990130944.0000, Feature Loss: 1120993652990130944.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.1622, Feature Loss: 12.1622, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 123
# 	Train:	Total Loss: 64236259225084008.0000, Feature Loss: 64236259225084008.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.1547, Feature Loss: 12.1547, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 124
# 	Train:	Total Loss: 25285897867767641538560.0000, Feature Loss: 25285897867767641538560.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.1472, Feature Loss: 12.1472, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 125
# 	Train:	Total Loss: 6471138338426305.0000, Feature Loss: 6471138338426305.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.1396, Feature Loss: 12.1396, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 126
# 	Train:	Total Loss: 329657133340469100544.0000, Feature Loss: 329657133340469100544.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.1321, Feature Loss: 12.1321, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 127
# 	Train:	Total Loss: 9401120894379888.0000, Feature Loss: 9401120894379888.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.1245, Feature Loss: 12.1245, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 128
# 	Train:	Total Loss: 674315674049874688.0000, Feature Loss: 674315674049874688.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.1165, Feature Loss: 12.1165, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 129
# 	Train:	Total Loss: 186588929266122.4375, Feature Loss: 186588929266122.4375, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.1083, Feature Loss: 12.1083, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 130
# 	Train:	Total Loss: 764910787442688030408704.0000, Feature Loss: 764910787442688030408704.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.1084, Feature Loss: 12.1084, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 131
# 	Train:	Total Loss: 9714487627644636.0000, Feature Loss: 9714487627644636.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.1053, Feature Loss: 12.1053, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 132
# 	Train:	Total Loss: 1685723991897849088.0000, Feature Loss: 1685723991897849088.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0986, Feature Loss: 12.0986, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 133
# 	Train:	Total Loss: 2876292862.8210, Feature Loss: 2876292862.8210, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0918, Feature Loss: 12.0918, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 134
# 	Train:	Total Loss: 6497713081502901.0000, Feature Loss: 6497713081502901.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0848, Feature Loss: 12.0848, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 135
# 	Train:	Total Loss: 1487900763130.2300, Feature Loss: 1487900763130.2300, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0778, Feature Loss: 12.0778, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 136
# 	Train:	Total Loss: 15734355796454780.0000, Feature Loss: 15734355796454780.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0709, Feature Loss: 12.0709, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 137
# 	Train:	Total Loss: 357261356629906.8750, Feature Loss: 357261356629906.8750, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0640, Feature Loss: 12.0640, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 138
# 	Train:	Total Loss: 64448825101.6264, Feature Loss: 64448825101.6264, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0571, Feature Loss: 12.0571, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 139
# 	Train:	Total Loss: 23371952414.1057, Feature Loss: 23371952414.1057, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0504, Feature Loss: 12.0504, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 140
# 	Train:	Total Loss: 102679670001697.9688, Feature Loss: 102679670001697.9688, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0437, Feature Loss: 12.0437, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 141
# 	Train:	Total Loss: 9996899024375.8340, Feature Loss: 9996899024375.8340, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0370, Feature Loss: 12.0370, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 142
# 	Train:	Total Loss: 12456463764374.0000, Feature Loss: 12456463764374.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0302, Feature Loss: 12.0302, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 143
# 	Train:	Total Loss: 14338693475490.5410, Feature Loss: 14338693475490.5410, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0232, Feature Loss: 12.0232, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 144
# 	Train:	Total Loss: 18901854853024260096.0000, Feature Loss: 18901854853024260096.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0162, Feature Loss: 12.0162, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 145
# 	Train:	Total Loss: 7356790506248.2324, Feature Loss: 7356790506248.2324, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0094, Feature Loss: 12.0094, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 146
# 	Train:	Total Loss: 113359990113304018944.0000, Feature Loss: 113359990113304018944.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0025, Feature Loss: 12.0025, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 147
# 	Train:	Total Loss: 45049610684860.5469, Feature Loss: 45049610684860.5469, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.9960, Feature Loss: 11.9960, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 148
# 	Train:	Total Loss: 199531566492814976.0000, Feature Loss: 199531566492814976.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.9894, Feature Loss: 11.9894, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 149
# 	Train:	Total Loss: 110730650763588.9375, Feature Loss: 110730650763588.9375, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.9829, Feature Loss: 11.9829, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 150
# 	Train:	Total Loss: 1804935319897239191552.0000, Feature Loss: 1804935319897239191552.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.9762, Feature Loss: 11.9762, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 151
# 	Train:	Total Loss: 37435745228110160.0000, Feature Loss: 37435745228110160.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.9697, Feature Loss: 11.9697, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 152
# 	Train:	Total Loss: 1195937708285843472384.0000, Feature Loss: 1195937708285843472384.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.9633, Feature Loss: 11.9633, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 153
# 	Train:	Total Loss: 20996020306967376429056.0000, Feature Loss: 20996020306967376429056.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.9566, Feature Loss: 11.9566, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 154
# 	Train:	Total Loss: 14292074624315626.0000, Feature Loss: 14292074624315626.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.9503, Feature Loss: 11.9503, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 155
# 	Train:	Total Loss: 8502161528482551570628608.0000, Feature Loss: 8502161528482551570628608.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.9447, Feature Loss: 11.9447, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 156
# 	Train:	Total Loss: 3887611085702541.0000, Feature Loss: 3887611085702541.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.9387, Feature Loss: 11.9387, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 157
# 	Train:	Total Loss: 803016414224359.1250, Feature Loss: 803016414224359.1250, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.9321, Feature Loss: 11.9321, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 158
# 	Train:	Total Loss: 1774638054929482.0000, Feature Loss: 1774638054929482.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.9254, Feature Loss: 11.9254, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 159
# 	Train:	Total Loss: 766321376706.2870, Feature Loss: 766321376706.2870, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.9188, Feature Loss: 11.9188, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 160
# 	Train:	Total Loss: 1457465302542817.5000, Feature Loss: 1457465302542817.5000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.9124, Feature Loss: 11.9124, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 161
# 	Train:	Total Loss: 2048318886281587200.0000, Feature Loss: 2048318886281587200.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.9058, Feature Loss: 11.9058, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 162
# 	Train:	Total Loss: 16414720245.7043, Feature Loss: 16414720245.7043, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.8990, Feature Loss: 11.8990, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 163
# 	Train:	Total Loss: 413395935705.9337, Feature Loss: 413395935705.9337, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.8926, Feature Loss: 11.8926, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 164
# 	Train:	Total Loss: 30436511745480.0625, Feature Loss: 30436511745480.0625, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.8860, Feature Loss: 11.8860, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 165
# 	Train:	Total Loss: 1386318915703212544.0000, Feature Loss: 1386318915703212544.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.8794, Feature Loss: 11.8794, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 166
# 	Train:	Total Loss: 4671969628423.6260, Feature Loss: 4671969628423.6260, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.8728, Feature Loss: 11.8728, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 167
# 	Train:	Total Loss: 152969271601840.9688, Feature Loss: 152969271601840.9688, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.8663, Feature Loss: 11.8663, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 168
# 	Train:	Total Loss: 65354035406.2620, Feature Loss: 65354035406.2620, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.8596, Feature Loss: 11.8596, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 169
# 	Train:	Total Loss: 39217132727321.0469, Feature Loss: 39217132727321.0469, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.8530, Feature Loss: 11.8530, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 170
# 	Train:	Total Loss: 207811320017.8583, Feature Loss: 207811320017.8583, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.8465, Feature Loss: 11.8465, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 171
# 	Train:	Total Loss: 637631448530966784.0000, Feature Loss: 637631448530966784.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.8399, Feature Loss: 11.8399, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 172
# 	Train:	Total Loss: 726828409685529198592.0000, Feature Loss: 726828409685529198592.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.8332, Feature Loss: 11.8332, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 173
# 	Train:	Total Loss: 228771552062497024.0000, Feature Loss: 228771552062497024.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.8266, Feature Loss: 11.8266, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 174
# 	Train:	Total Loss: 258566588712389.0000, Feature Loss: 258566588712389.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.8201, Feature Loss: 11.8201, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 175
# 	Train:	Total Loss: 10831194968583.9629, Feature Loss: 10831194968583.9629, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.8135, Feature Loss: 11.8135, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 176
# 	Train:	Total Loss: 19817799214472.8789, Feature Loss: 19817799214472.8789, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.8072, Feature Loss: 11.8072, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 177
# 	Train:	Total Loss: 451022153344305.8750, Feature Loss: 451022153344305.8750, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.8008, Feature Loss: 11.8008, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 178
# 	Train:	Total Loss: 84332120311.1546, Feature Loss: 84332120311.1546, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.7942, Feature Loss: 11.7942, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 179
# 	Train:	Total Loss: 2423160593938.2739, Feature Loss: 2423160593938.2739, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.7878, Feature Loss: 11.7878, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 180
# 	Train:	Total Loss: 29371382883646.1016, Feature Loss: 29371382883646.1016, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.7813, Feature Loss: 11.7813, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 181
# 	Train:	Total Loss: 14406317939225438191616.0000, Feature Loss: 14406317939225438191616.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.7749, Feature Loss: 11.7749, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 182
# 	Train:	Total Loss: 6645651112171.2314, Feature Loss: 6645651112171.2314, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.7681, Feature Loss: 11.7681, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 183
# 	Train:	Total Loss: 77609330997521203200.0000, Feature Loss: 77609330997521203200.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.7613, Feature Loss: 11.7613, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 184
# 	Train:	Total Loss: 1475533209358058.5000, Feature Loss: 1475533209358058.5000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.7722, Feature Loss: 11.7722, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 185
# 	Train:	Total Loss: 44756675748900.1094, Feature Loss: 44756675748900.1094, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.7727, Feature Loss: 11.7727, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 186
# 	Train:	Total Loss: 63979673700572.6719, Feature Loss: 63979673700572.6719, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.7712, Feature Loss: 11.7712, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 187
# 	Train:	Total Loss: 35087005310157717504.0000, Feature Loss: 35087005310157717504.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.7697, Feature Loss: 11.7697, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 188
# 	Train:	Total Loss: 22379202462375.8008, Feature Loss: 22379202462375.8008, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.7684, Feature Loss: 11.7684, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 189
# 	Train:	Total Loss: 9912554779832.9141, Feature Loss: 9912554779832.9141, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.7671, Feature Loss: 11.7671, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 190
# 	Train:	Total Loss: 109912268116954080.0000, Feature Loss: 109912268116954080.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.7656, Feature Loss: 11.7656, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 191
# 	Train:	Total Loss: 11152915443917.3496, Feature Loss: 11152915443917.3496, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.7641, Feature Loss: 11.7641, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 192
# 	Train:	Total Loss: 2128687164451925524480.0000, Feature Loss: 2128687164451925524480.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.7628, Feature Loss: 11.7628, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 193
# 	Train:	Total Loss: 208776314138668256.0000, Feature Loss: 208776314138668256.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.7614, Feature Loss: 11.7614, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 194
# 	Train:	Total Loss: 1429945799.1643, Feature Loss: 1429945799.1643, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.7600, Feature Loss: 11.7600, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 195
# 	Train:	Total Loss: 5671693318558.5869, Feature Loss: 5671693318558.5869, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.7587, Feature Loss: 11.7587, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 196
# 	Train:	Total Loss: 52698271211779.9531, Feature Loss: 52698271211779.9531, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.7573, Feature Loss: 11.7573, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 197
# 	Train:	Total Loss: 3282144420197.4976, Feature Loss: 3282144420197.4976, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.7558, Feature Loss: 11.7558, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 198
# 	Train:	Total Loss: 2379766523992.6494, Feature Loss: 2379766523992.6494, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.7545, Feature Loss: 11.7545, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 199
# 	Train:	Total Loss: 114241094680.9437, Feature Loss: 114241094680.9437, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.7530, Feature Loss: 11.7530, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 200
# 	Train:	Total Loss: 4369811384999712.0000, Feature Loss: 4369811384999712.0000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.7515, Feature Loss: 11.7515, Type Loss: 0.0000 , LR: 0.000100

# %%
if not model_loaded:
    plt.figure(figsize=(14, 5))
    plt.plot(test_total_losses, label='Total Test Loss')
    plt.plot(train_total_losses, label='Total Train Loss')
    plt.legend()
    plt.title('Total Loss')
    plt.savefig("model2_totalloss.png")
    plt.show()

# %%
if not model_loaded:
    plt.figure(figsize=(14, 5))
    plt.plot(test_feature_losses, label='Test Feature Loss')
    plt.plot(train_feature_losses, label='Train Feature Loss')
    plt.legend()
    plt.title('Feature Loss')
    plt.savefig("model3_feature_loss.png")
    plt.show()

# %%
test_loader_melt = DataLoader(graphs_melt, batch_size=1)
encoded_data_melt=[]
type_data_melt = []
for data in test_loader:
    model.eval()
    z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
    decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
    encoded_data_melt.append(z.detach().numpy())
    type_data_melt.append(str_type.detach().numpy())

encoded_data_melt = np.array(encoded_data_melt)
type_data_melt = np.array(type_data_melt)

# %%
test_loader_cry = DataLoader(graphs_cry, batch_size=1)
encoded_data_cry=[]
type_data_cry = []
for data in test_loader:
    model.eval()
    z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
    decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
    encoded_data_cry.append(z.detach().numpy())
    type_data_cry.append(str_type.detach().numpy())

encoded_data_cry = np.array(encoded_data_cry)
type_data_cry = np.array(type_data_cry)

# %%
# %matplotlib widget

frame = 10

fig = plt.figure(figsize=(15,4))
data_melt = encoded_data_melt[frame]

data_cry = encoded_data_cry[frame]
plt.scatter(data_melt[:,0],data_melt[:,1],c="r",label="melt")
plt.scatter(data_cry[:,0],data_cry[:,1],c="b",label="crystal")
plt.savefig("model3_scatterplot.png")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
