# %%
import mdtraj as md
from ase import Atoms
import nglview as nv
import networkx as nx

import numpy as np
import matplotlib.pyplot as plt
import torch
from tqdm import tqdm

import torch_geometric.transforms as T
from torch_geometric.loader import DataLoader
from torch_geometric.nn import GCNConv, SAGPooling, InnerProductDecoder
import torch_geometric.data as data
from torch_geometric.utils.convert import to_networkx
import torch.optim.lr_scheduler as lr_scheduler
from torch.nn import Linear
import sys

# %%
all_frames_cry = md.load_xtc("../simulation/para_crystal.xtc", top="../simulation/para_crystal.gro")
all_frames_melt = md.load_xtc("../simulation/para_melt.xtc", top="../simulation/para_melt.gro")

# %%
all_frames_cry = all_frames_cry[::100]
all_frames_melt = all_frames_melt[::100]

# %%
n_frames = all_frames_cry.xyz.shape[0]
n_atoms = all_frames_cry.topology.residue(0).n_atoms
n_mols = all_frames_cry.topology.n_residues

# %%
def createGraph(all_frames,structure_type="crystal"):
    all_frames_fatures = []

    print("Creating Feature matrix")
    for i in tqdm(range(all_frames.xyz.shape[0])):
        mol_com_pos = []

        for res in all_frames.top.residues:
            pos = []
            for atom in res.atoms:
                pos.append(all_frames.xyz[i][atom.index])
            mol_com_pos.append(np.mean(pos,axis=0))
            
            # print()
        mol_com_pos = np.array(mol_com_pos).astype(np.float32)  
        all_frames_fatures.append(mol_com_pos)

    all_frames_fatures = np.array(all_frames_fatures).astype(np.float32)



    cutoff = 0.8

    print("Creating Edge list")
    all_edge_list = []
    # with open("edge_list.txt","w") as f:
    for frame_i in tqdm(range(n_frames)):
        from_list = []
        to_list = []

        for i in range(len(all_frames_fatures[frame_i])):
            for j in range(i+1,len(all_frames_fatures[frame_i])):
                if np.linalg.norm(all_frames_fatures[frame_i][i]-all_frames_fatures[frame_i][j]) < cutoff:
                    # f.write(str(i)+" "+str(j)+" "+str(np.linalg.norm(all_frames_fatures[frame_i][i]-all_frames_fatures[frame_i][j]))+"\n")
                    from_list.append(i)
                    to_list.append(j)

                    to_list.append(i)
                    from_list.append(j)

        edge_list = np.array([from_list,to_list]).astype(np.int64)
        all_edge_list.append(edge_list)
    print("creating Graphs")
    graphs = []
    for frame in tqdm(range(n_frames)):
        if structure_type == "crystal":
            g = data.Data(x=torch.tensor(all_frames_fatures[frame]).float(), edge_index=torch.tensor(all_edge_list[frame]).long(), y=torch.tensor([0]))
        else:
            g = data.Data(x=torch.tensor(all_frames_fatures[frame]).float(), edge_index=torch.tensor(all_edge_list[frame]).long(), y=torch.tensor([1]))
        graphs.append(g)
    return graphs

# %%
graphs_cry = createGraph(all_frames_cry,structure_type="crystal")
graphs_melt = createGraph(all_frames_melt,structure_type="melt")
# Out:
# Creating Feature matrix
# 100%|██████████| 51/51 [00:01<00:00, 48.91it/s]
# Creating Edge list
# 100%|██████████| 51/51 [02:22<00:00,  2.79s/it]
# creating Graphs
# 100%|██████████| 51/51 [00:00<00:00, 477.87it/s]
# Creating Feature matrix
# 100%|██████████| 51/51 [00:01<00:00, 45.37it/s]
# Creating Edge list
# 100%|██████████| 51/51 [01:06<00:00,  1.30s/it]
# creating Graphs
# 100%|██████████| 51/51 [00:00<00:00, 17647.84it/s]

# %%
def convert_to_adj(edge_index, num_nodes=None):
    if num_nodes is None:
        num_nodes = edge_index.max() + 1
    adj = torch.zeros(num_nodes, num_nodes)
    adj[edge_index[0], edge_index[1]] = 1
    return adj

def convert_to_edge_index(adj):
    edge_index = adj.nonzero().t()
    return edge_index

# %%
graphs = graphs_cry + graphs_melt
# graphs = graphs_cry

# %%
# shuffle the graphs
np.random.shuffle(graphs)

# %%
graphs
# Out:
# [Data(x=[864, 3], edge_index=[2, 6172], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6608], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7048], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7060], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7052], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7054], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7122], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7078], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6012], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6964], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7028], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7116], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7012], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7026], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6214], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5862], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7048], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6508], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6570], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6596], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7034], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6564], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7024], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7076], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6582], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7006], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6578], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5910], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7132], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7240], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7006], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7094], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6992], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7078], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6548], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6630], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6476], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7128], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6592], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7116], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7064], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6560], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6546], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7192], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6524], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7294], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6626], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6602], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5822], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6452], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5892], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7096], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7086], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6018], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7090], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7108], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7100], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7080], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7146], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6584], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7092], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6400], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6546], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7052], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5982], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6288], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6532], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7274], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7074], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6488], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6056], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6508], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6544], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7374], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6558], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7020], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6580], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6542], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5880], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7088], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5876], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6070], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6066], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7044], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6566], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7056], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5962], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7306], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6586], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6512], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7092], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6552], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6554], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6990], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6464], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7060], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6548], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6560], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6934], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7036], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7218], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7008], y=[1])]

# %% [markdown]
# ## model

# %%
from typing import Optional, Tuple

import torch
from torch import Tensor
from torch.nn import Module

from torch_geometric.nn.inits import reset
from torch_geometric.utils import negative_sampling

EPS = 1e-15
MAX_LOGSTD = 10
edgeShape = None
featureShape = None


class InnerProductDecoder(torch.nn.Module):
    r"""The inner product decoder from the `"Variational Graph Auto-Encoders"
    <https://arxiv.org/abs/1611.07308>`_ paper

    .. math::
        \sigma(\mathbf{Z}\mathbf{Z}^{\top})

    where :math:`\mathbf{Z} \in \mathbb{R}^{N \times d}` denotes the latent
    space produced by the encoder."""

    def forward(self, z: Tensor, edge_index: Tensor,
                sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into edge probabilities for
        the given node-pairs :obj:`edge_index`.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        value = (z[edge_index[0]] * z[edge_index[1]]).sum(dim=1)
        return torch.sigmoid(value) if sigmoid else value

    def forward_all(self, z: Tensor, sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into a probabilistic dense
        adjacency matrix.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        adj = torch.matmul(z, z.t())
        return torch.sigmoid(adj) if sigmoid else adj


class GAE(torch.nn.Module):
    r"""The Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper based on user-defined encoder and decoder models.

    Args:
        encoder (torch.nn.Module): The encoder module.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__()
        self.encoder = encoder
        self.decoder = InnerProductDecoder() if decoder is None else decoder
        GAE.reset_parameters(self)

    def reset_parameters(self):
        r"""Resets all learnable parameters of the module."""
        reset(self.encoder)
        reset(self.decoder)

    def forward(self, *args, **kwargs) -> Tensor:  # pragma: no cover
        r"""Alias for :meth:`encode`."""
        return self.encoder(*args, **kwargs)

    def encode(self, *args, **kwargs) -> Tensor:
        r"""Runs the encoder and computes node-wise latent variables."""
        return self.encoder(*args, **kwargs)

    def decode(self, *args, **kwargs) -> Tensor:
        r"""Runs the decoder and computes edge probabilities."""
        return self.decoder(*args, **kwargs)

    def recon_loss(self, z: Tensor, pos_edge_index: Tensor,
                   neg_edge_index: Optional[Tensor] = None) -> Tensor:
        r"""Given latent variables :obj:`z`, computes the binary cross
        entropy loss for positive edges :obj:`pos_edge_index` and negative
        sampled edges.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to train against.
            neg_edge_index (torch.Tensor, optional): The negative edges to
                train against. If not given, uses negative sampling to
                calculate negative edges. (default: :obj:`None`)
        """
        pos_loss = -torch.log(
            self.decoder(z, pos_edge_index, sigmoid=True)[0] + EPS).mean()

        if neg_edge_index is None:
            neg_edge_index = negative_sampling(pos_edge_index, z.size(0))
        neg_loss = -torch.log(1 -
                              self.decoder(z, neg_edge_index.long(), sigmoid=True)[0] +
                              EPS).mean()

        return pos_loss + neg_loss

    def test(self, z: Tensor, pos_edge_index: Tensor,
             neg_edge_index: Tensor) -> Tuple[Tensor, Tensor]:
        r"""Given latent variables :obj:`z`, positive edges
        :obj:`pos_edge_index` and negative edges :obj:`neg_edge_index`,
        computes area under the ROC curve (AUC) and average precision (AP)
        
        scores.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to evaluate
                against.
            neg_edge_index (torch.Tensor): The negative edges to evaluate
                against.
        """
        from sklearn.metrics import average_precision_score, roc_auc_score

        pos_y = z.new_ones(pos_edge_index.size(1))
        neg_y = z.new_zeros(neg_edge_index.size(1))
        y = torch.cat([pos_y, neg_y], dim=0)

        pos_pred = self.decoder(z, pos_edge_index, sigmoid=True)
        neg_pred = self.decoder(z, neg_edge_index, sigmoid=True)
        pred = torch.cat([pos_pred, neg_pred], dim=0)

        y, pred = y.detach().cpu().numpy(), pred.detach().cpu().numpy()

        return roc_auc_score(y, pred), average_precision_score(y, pred)


class VGAE(GAE):
    r"""The Variational Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper.

    Args:
        encoder (torch.nn.Module): The encoder module to compute :math:`\mu`
            and :math:`\log\sigma^2`.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__(encoder, decoder)

    def reparametrize(self, mu: Tensor, logstd: Tensor) -> Tensor:
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def encode(self, *args, **kwargs) -> Tensor:
        """"""
        z, self.edge_index = self.encoder(
            *args, **kwargs)
        
        return z, self.edge_index

    def kl_loss(self, mu: Optional[Tensor] = None,
                logstd: Optional[Tensor] = None) -> Tensor:
        r"""Computes the KL loss, either for the passed arguments :obj:`mu`
        and :obj:`logstd`, or based on latent variables from last encoding.

        Args:
            mu (torch.Tensor, optional): The latent space for :math:`\mu`. If
                set to :obj:`None`, uses the last computation of :math:`\mu`.
                (default: :obj:`None`)
            logstd (torch.Tensor, optional): The latent space for
                :math:`\log\sigma`.  If set to :obj:`None`, uses the last
                computation of :math:`\log\sigma^2`. (default: :obj:`None`)
        """
        mu = self.__mu__ if mu is None else mu
        logstd = self.__logstd__ if logstd is None else logstd.clamp(
            max=MAX_LOGSTD)
        return -0.5 * torch.mean(
            torch.sum(1 + 2 * logstd - mu**2 - logstd.exp()**2, dim=1))

# %%
import torch.nn.functional as F



class VariationalGCNEncoder(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__() # changes made such that guassian is 1 
        self.conv1 = GCNConv(in_channels, 2*out_channels)
        self.conv2 = GCNConv(2*out_channels, 1 * out_channels)
        self.pool = SAGPooling(out_channels, 0.5)
        
        self.conv_mu = GCNConv(1 * out_channels, out_channels)
        self.conv_logstd = GCNConv(1 * out_channels, out_channels)
    def reparametrize(self, mu: Tensor, logstd: Tensor) -> Tensor:
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def forward(self, x, edge_index,class_label):
        # print("input:",x.shape, edge_index.shape)
        x = self.conv1(x, edge_index)
        x = F.silu(x)
        # print("conv1:",x.shape, edge_index.shape)
        x = self.conv2(x, edge_index)
        x = F.silu(x)
        # print("conv2:",x.shape, edge_index.shape)

        sample = self.reparametrize(self.conv_mu(x, edge_index), self.conv_logstd(x, edge_index))
        sample = self.reparametrize(self.conv_mu(sample, edge_index), self.conv_logstd(sample, edge_index))
        # self.conv_mu_crystal.train(True)
        # self.conv_logstd_crystal.train(True)
        # self.conv_mu_melt.train(True)
        # self.conv_logstd_melt.train(True)
        self.conv_mu.train(True)
        self.conv_logstd.train(True)
        return sample, edge_index

# %%
class VariationalGCNDecoder(torch.nn.Module):
    def __init__(self,in_channels,out_channels):
        super().__init__()
        self.type_layer1 = Linear(1728,200)
        self.dropout = torch.nn.Dropout(0.5)
        self.type_layer2 = Linear(200,2)
        self.conv1 = GCNConv(in_channels,2*out_channels)
        self.conv2 = GCNConv(2*out_channels, 1 * out_channels)
    def forward(self, x, edge_index, sigmoid=True):
        # print("input:",x.shape, edge_index.shape)
        flat = x.flatten()
        flat = self.type_layer1(flat).relu()
        flat = self.dropout(flat)
        str_type = F.softmax(self.type_layer2(flat).relu(),dim=0)
         
        x = self.conv1(x, edge_index)
        x = F.silu(x)
        # print("conv1:",x.shape, edge_index.shape)
        x = self.conv2(x, edge_index)
        x = F.silu(x)
        # print("conv2:",x.shape, edge_index.shape)
        return x, edge_index,str_type

# %%
import os
in_channels = graphs[0].num_features
out_channels = 2
lr = 1e-4
n_epochs = 200
batch_size=1
test_train_split = 0.8
model_name = "model2.pt"
model_loaded = False
force_train = True  

if os.path.exists("./models/"+model_name) and not force_train:
    model = torch.load("./models/"+model_name)
    model_loaded = True
else:
    model = VGAE(VariationalGCNEncoder(in_channels, out_channels),
                VariationalGCNDecoder(out_channels, in_channels))

optimizer = torch.optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, step_size=300, gamma=0.5)

# %%
train_loader = DataLoader(graphs_cry[:int(n_frames*test_train_split)], batch_size=batch_size, shuffle=True)
test_loader = DataLoader(graphs_cry[int(n_frames*test_train_split):], batch_size=batch_size, shuffle=True)

# %%
lossFxn = torch.nn.MSELoss()
typeLossFxn = torch.nn.CrossEntropyLoss()

def train():
    model.train()
    model.zero_grad()
    model.float()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0
    type_loss_all = 0
    for data in train_loader:
        optimizer.zero_grad()
        z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
        decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)

     
        # TypeLoss = typeLossFxn(str_type.unsqueeze(0), data.y)
        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        loss = FeatureLoss + EdgeLoss 

        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        # type_loss_all += float(TypeLoss)

        loss.backward()
        optimizer.step()
        

    return loss_all / len(train_loader), feature_loss_all / len(train_loader), edge_loss_all / len(train_loader), kl_loss_all / len(train_loader), type_loss_all / len(train_loader)

# %%
lossFxn = torch.nn.MSELoss()
def test():
    model.eval()
    model.zero_grad()
    model.float()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0
    type_loss_all = 0

    for data in test_loader:
        optimizer.zero_grad()
        z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
        decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
        
        # TypeLoss = typeLossFxn(str_type.unsqueeze(0), data.y)
        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        loss = FeatureLoss + EdgeLoss 

        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        # type_loss_all += float(TypeLoss)
        
        
        

    return loss_all / len(test_loader), feature_loss_all / len(test_loader), edge_loss_all / len(test_loader), kl_loss_all / len(test_loader), type_loss_all / len(test_loader)

# %%
train_total_losses = []
train_feature_losses = []
train_edge_losses = []
train_kl_losses = []
train_type_losses = []

test_total_losses = []
test_feature_losses = []
test_edge_losses = []
test_kl_losses = []
test_type_losses = []

if model_loaded:        
    print("Pretrained Model Loaded, no training required")
else:
    for epoch in range(1, n_epochs + 1):
        
        train_total_loss, train_feature_loss, train_edge_loss, train_kl_loss,train_type_loss = train()
        test_total_loss, test_feature_loss, test_edge_loss, test_kl_loss, test_type_loss= test()
        
        print(f"Epoch: {epoch:03d}")
        print(f'\tTrain:\tTotal Loss: {train_total_loss:.4f}, Feature Loss: {train_feature_loss:.4f}, Type Loss: {train_type_loss:.4f} ,  LR: {scheduler.get_last_lr()[0]:.6f}')
        print(f'\tTest: \tTotal Loss: {test_total_loss:.4f}, Feature Loss: {test_feature_loss:.4f}, Type Loss: {test_type_loss:.4f} , LR: {scheduler.get_last_lr()[0]:.6f}')
        
        
        train_total_losses.append(train_total_loss)
        train_feature_losses.append(train_feature_loss)
        train_edge_losses.append(train_edge_loss)
        train_kl_losses.append(train_kl_loss)
        train_type_losses.append(train_type_loss)


        test_total_losses.append(test_total_loss)
        test_feature_losses.append(test_feature_loss)
        test_edge_losses.append(test_edge_loss)
        test_kl_losses.append(test_kl_loss)
        test_type_losses.append(test_type_loss)
        
        scheduler.step()
    torch.save(model,"./models/"+model_name)
# Out:
# Epoch: 001
# 	Train:	Total Loss: 11.5280, Feature Loss: 11.5280, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.8187, Feature Loss: 10.8187, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 002
# 	Train:	Total Loss: 11.4300, Feature Loss: 11.4300, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.7324, Feature Loss: 10.7324, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 003
# 	Train:	Total Loss: 11.3536, Feature Loss: 11.3536, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.6341, Feature Loss: 10.6341, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 004
# 	Train:	Total Loss: 11.2358, Feature Loss: 11.2358, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.5222, Feature Loss: 10.5222, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 005
# 	Train:	Total Loss: 11.1152, Feature Loss: 11.1152, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.3968, Feature Loss: 10.3968, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 006
# 	Train:	Total Loss: 10.9854, Feature Loss: 10.9854, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.2564, Feature Loss: 10.2564, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 007
# 	Train:	Total Loss: 10.8072, Feature Loss: 10.8072, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.1033, Feature Loss: 10.1033, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 008
# 	Train:	Total Loss: 10.6496, Feature Loss: 10.6496, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.9390, Feature Loss: 9.9390, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 009
# 	Train:	Total Loss: 10.5007, Feature Loss: 10.5007, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.7683, Feature Loss: 9.7683, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 010
# 	Train:	Total Loss: 10.2979, Feature Loss: 10.2979, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.5958, Feature Loss: 9.5958, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 011
# 	Train:	Total Loss: 10.1649, Feature Loss: 10.1649, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.4254, Feature Loss: 9.4254, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 012
# 	Train:	Total Loss: 9.9962, Feature Loss: 9.9962, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.2592, Feature Loss: 9.2592, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 013
# 	Train:	Total Loss: 9.8333, Feature Loss: 9.8333, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.0996, Feature Loss: 9.0996, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 014
# 	Train:	Total Loss: 9.6772, Feature Loss: 9.6772, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.9483, Feature Loss: 8.9483, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 015
# 	Train:	Total Loss: 9.5172, Feature Loss: 9.5172, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.8062, Feature Loss: 8.8062, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 016
# 	Train:	Total Loss: 9.3674, Feature Loss: 9.3674, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.6704, Feature Loss: 8.6704, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 017
# 	Train:	Total Loss: 9.2668, Feature Loss: 9.2668, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.5396, Feature Loss: 8.5396, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 018
# 	Train:	Total Loss: 9.1208, Feature Loss: 9.1208, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.4120, Feature Loss: 8.4120, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 019
# 	Train:	Total Loss: 8.9752, Feature Loss: 8.9752, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.2854, Feature Loss: 8.2854, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 020
# 	Train:	Total Loss: 8.8551, Feature Loss: 8.8551, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.1579, Feature Loss: 8.1579, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 021
# 	Train:	Total Loss: 8.7008, Feature Loss: 8.7008, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.0286, Feature Loss: 8.0286, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 022
# 	Train:	Total Loss: 8.5594, Feature Loss: 8.5594, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.8961, Feature Loss: 7.8961, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 023
# 	Train:	Total Loss: 8.4361, Feature Loss: 8.4361, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.7608, Feature Loss: 7.7608, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 024
# 	Train:	Total Loss: 8.2752, Feature Loss: 8.2752, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.6227, Feature Loss: 7.6227, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 025
# 	Train:	Total Loss: 8.1458, Feature Loss: 8.1458, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.4816, Feature Loss: 7.4816, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 026
# 	Train:	Total Loss: 7.9805, Feature Loss: 7.9805, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.3377, Feature Loss: 7.3377, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 027
# 	Train:	Total Loss: 7.8320, Feature Loss: 7.8320, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.1934, Feature Loss: 7.1934, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 028
# 	Train:	Total Loss: 7.6845, Feature Loss: 7.6845, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.0472, Feature Loss: 7.0472, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 029
# 	Train:	Total Loss: 7.5259, Feature Loss: 7.5259, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.9022, Feature Loss: 6.9022, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 030
# 	Train:	Total Loss: 7.3612, Feature Loss: 7.3612, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.7585, Feature Loss: 6.7585, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 031
# 	Train:	Total Loss: 7.2213, Feature Loss: 7.2213, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.6192, Feature Loss: 6.6192, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 032
# 	Train:	Total Loss: 7.0678, Feature Loss: 7.0678, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.4857, Feature Loss: 6.4857, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 033
# 	Train:	Total Loss: 6.9165, Feature Loss: 6.9165, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.3581, Feature Loss: 6.3581, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 034
# 	Train:	Total Loss: 6.7854, Feature Loss: 6.7854, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.2394, Feature Loss: 6.2394, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 035
# 	Train:	Total Loss: 6.6615, Feature Loss: 6.6615, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.1292, Feature Loss: 6.1292, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 036
# 	Train:	Total Loss: 6.5396, Feature Loss: 6.5396, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.0296, Feature Loss: 6.0296, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 037
# 	Train:	Total Loss: 6.4539, Feature Loss: 6.4539, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.9400, Feature Loss: 5.9400, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 038
# 	Train:	Total Loss: 6.3598, Feature Loss: 6.3598, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.8608, Feature Loss: 5.8608, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 039
# 	Train:	Total Loss: 6.2775, Feature Loss: 6.2775, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.7918, Feature Loss: 5.7918, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 040
# 	Train:	Total Loss: 6.2012, Feature Loss: 6.2012, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.7344, Feature Loss: 5.7344, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 041
# 	Train:	Total Loss: 6.1454, Feature Loss: 6.1454, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.6851, Feature Loss: 5.6851, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 042
# 	Train:	Total Loss: 6.0958, Feature Loss: 6.0958, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.6451, Feature Loss: 5.6451, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 043
# 	Train:	Total Loss: 6.0445, Feature Loss: 6.0445, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.6119, Feature Loss: 5.6119, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 044
# 	Train:	Total Loss: 6.0167, Feature Loss: 6.0167, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.5852, Feature Loss: 5.5852, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 045
# 	Train:	Total Loss: 5.9899, Feature Loss: 5.9899, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.5635, Feature Loss: 5.5635, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 046
# 	Train:	Total Loss: 5.9622, Feature Loss: 5.9622, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.5463, Feature Loss: 5.5463, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 047
# 	Train:	Total Loss: 5.9415, Feature Loss: 5.9415, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.5326, Feature Loss: 5.5326, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 048
# 	Train:	Total Loss: 5.9362, Feature Loss: 5.9362, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.5210, Feature Loss: 5.5210, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 049
# 	Train:	Total Loss: 5.9193, Feature Loss: 5.9193, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.5112, Feature Loss: 5.5112, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 050
# 	Train:	Total Loss: 5.9073, Feature Loss: 5.9073, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.5021, Feature Loss: 5.5021, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 051
# 	Train:	Total Loss: 5.8968, Feature Loss: 5.8968, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.4930, Feature Loss: 5.4930, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 052
# 	Train:	Total Loss: 5.8829, Feature Loss: 5.8829, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.4828, Feature Loss: 5.4828, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 053
# 	Train:	Total Loss: 5.8746, Feature Loss: 5.8746, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.4687, Feature Loss: 5.4687, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 054
# 	Train:	Total Loss: 5.8534, Feature Loss: 5.8534, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.4473, Feature Loss: 5.4473, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 055
# 	Train:	Total Loss: 5.8336, Feature Loss: 5.8336, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.4098, Feature Loss: 5.4098, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 056
# 	Train:	Total Loss: 5.7811, Feature Loss: 5.7811, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.3383, Feature Loss: 5.3383, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 057
# 	Train:	Total Loss: 5.6866, Feature Loss: 5.6866, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.2025, Feature Loss: 5.2025, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 058
# 	Train:	Total Loss: 5.4925, Feature Loss: 5.4925, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.9691, Feature Loss: 4.9691, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 059
# 	Train:	Total Loss: 5.2044, Feature Loss: 5.2044, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.6400, Feature Loss: 4.6400, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 060
# 	Train:	Total Loss: 4.8243, Feature Loss: 4.8243, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.2703, Feature Loss: 4.2703, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 061
# 	Train:	Total Loss: 4.4432, Feature Loss: 4.4432, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.9228, Feature Loss: 3.9228, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 062
# 	Train:	Total Loss: 4.1021, Feature Loss: 4.1021, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6351, Feature Loss: 3.6351, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 063
# 	Train:	Total Loss: 3.8243, Feature Loss: 3.8243, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.4055, Feature Loss: 3.4055, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 064
# 	Train:	Total Loss: 3.6111, Feature Loss: 3.6111, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2321, Feature Loss: 3.2321, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 065
# 	Train:	Total Loss: 3.4594, Feature Loss: 3.4594, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.1032, Feature Loss: 3.1032, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 066
# 	Train:	Total Loss: 3.3291, Feature Loss: 3.3291, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.0056, Feature Loss: 3.0056, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 067
# 	Train:	Total Loss: 3.2341, Feature Loss: 3.2341, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.9314, Feature Loss: 2.9314, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 068
# 	Train:	Total Loss: 3.1715, Feature Loss: 3.1715, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8755, Feature Loss: 2.8755, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 069
# 	Train:	Total Loss: 3.1140, Feature Loss: 3.1140, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8332, Feature Loss: 2.8332, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 070
# 	Train:	Total Loss: 3.0715, Feature Loss: 3.0715, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8001, Feature Loss: 2.8001, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 071
# 	Train:	Total Loss: 3.0343, Feature Loss: 3.0343, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7746, Feature Loss: 2.7746, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 072
# 	Train:	Total Loss: 3.0147, Feature Loss: 3.0147, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7539, Feature Loss: 2.7539, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 073
# 	Train:	Total Loss: 2.9963, Feature Loss: 2.9963, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7377, Feature Loss: 2.7377, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 074
# 	Train:	Total Loss: 2.9715, Feature Loss: 2.9715, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7247, Feature Loss: 2.7247, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 075
# 	Train:	Total Loss: 2.9601, Feature Loss: 2.9601, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7135, Feature Loss: 2.7135, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 076
# 	Train:	Total Loss: 2.9521, Feature Loss: 2.9521, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7044, Feature Loss: 2.7044, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 077
# 	Train:	Total Loss: 2.9367, Feature Loss: 2.9367, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6965, Feature Loss: 2.6965, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 078
# 	Train:	Total Loss: 2.9326, Feature Loss: 2.9326, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6896, Feature Loss: 2.6896, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 079
# 	Train:	Total Loss: 2.9253, Feature Loss: 2.9253, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6834, Feature Loss: 2.6834, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 080
# 	Train:	Total Loss: 2.9162, Feature Loss: 2.9162, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6779, Feature Loss: 2.6779, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 081
# 	Train:	Total Loss: 2.9036, Feature Loss: 2.9036, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6730, Feature Loss: 2.6730, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 082
# 	Train:	Total Loss: 2.9038, Feature Loss: 2.9038, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6683, Feature Loss: 2.6683, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 083
# 	Train:	Total Loss: 2.8908, Feature Loss: 2.8908, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6642, Feature Loss: 2.6642, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 084
# 	Train:	Total Loss: 2.8874, Feature Loss: 2.8874, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6601, Feature Loss: 2.6601, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 085
# 	Train:	Total Loss: 2.8884, Feature Loss: 2.8884, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6564, Feature Loss: 2.6564, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 086
# 	Train:	Total Loss: 2.8800, Feature Loss: 2.8800, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6529, Feature Loss: 2.6529, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 087
# 	Train:	Total Loss: 2.8784, Feature Loss: 2.8784, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6496, Feature Loss: 2.6496, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 088
# 	Train:	Total Loss: 2.8727, Feature Loss: 2.8727, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6464, Feature Loss: 2.6464, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 089
# 	Train:	Total Loss: 2.8720, Feature Loss: 2.8720, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6433, Feature Loss: 2.6433, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 090
# 	Train:	Total Loss: 2.8681, Feature Loss: 2.8681, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6404, Feature Loss: 2.6404, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 091
# 	Train:	Total Loss: 2.8663, Feature Loss: 2.8663, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6377, Feature Loss: 2.6377, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 092
# 	Train:	Total Loss: 2.8596, Feature Loss: 2.8596, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6350, Feature Loss: 2.6350, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 093
# 	Train:	Total Loss: 2.8550, Feature Loss: 2.8550, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6326, Feature Loss: 2.6326, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 094
# 	Train:	Total Loss: 2.8543, Feature Loss: 2.8543, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6301, Feature Loss: 2.6301, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 095
# 	Train:	Total Loss: 2.8463, Feature Loss: 2.8463, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6277, Feature Loss: 2.6277, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 096
# 	Train:	Total Loss: 2.8518, Feature Loss: 2.8518, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6254, Feature Loss: 2.6254, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 097
# 	Train:	Total Loss: 2.8443, Feature Loss: 2.8443, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6233, Feature Loss: 2.6233, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 098
# 	Train:	Total Loss: 2.8406, Feature Loss: 2.8406, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6212, Feature Loss: 2.6212, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 099
# 	Train:	Total Loss: 2.8419, Feature Loss: 2.8419, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6194, Feature Loss: 2.6194, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 100
# 	Train:	Total Loss: 2.8423, Feature Loss: 2.8423, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6173, Feature Loss: 2.6173, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 101
# 	Train:	Total Loss: 2.8344, Feature Loss: 2.8344, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6152, Feature Loss: 2.6152, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 102
# 	Train:	Total Loss: 2.8358, Feature Loss: 2.8358, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6136, Feature Loss: 2.6136, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 103
# 	Train:	Total Loss: 2.8317, Feature Loss: 2.8317, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6117, Feature Loss: 2.6117, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 104
# 	Train:	Total Loss: 2.8311, Feature Loss: 2.8311, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6100, Feature Loss: 2.6100, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 105
# 	Train:	Total Loss: 2.8255, Feature Loss: 2.8255, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6083, Feature Loss: 2.6083, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 106
# 	Train:	Total Loss: 2.8255, Feature Loss: 2.8255, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6067, Feature Loss: 2.6067, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 107
# 	Train:	Total Loss: 2.8290, Feature Loss: 2.8290, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6051, Feature Loss: 2.6051, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 108
# 	Train:	Total Loss: 2.8195, Feature Loss: 2.8195, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6035, Feature Loss: 2.6035, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 109
# 	Train:	Total Loss: 2.8186, Feature Loss: 2.8186, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6020, Feature Loss: 2.6020, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 110
# 	Train:	Total Loss: 2.8182, Feature Loss: 2.8182, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.6004, Feature Loss: 2.6004, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 111
# 	Train:	Total Loss: 2.8181, Feature Loss: 2.8181, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5990, Feature Loss: 2.5990, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 112
# 	Train:	Total Loss: 2.8146, Feature Loss: 2.8146, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5976, Feature Loss: 2.5976, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 113
# 	Train:	Total Loss: 2.8147, Feature Loss: 2.8147, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5961, Feature Loss: 2.5961, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 114
# 	Train:	Total Loss: 2.8098, Feature Loss: 2.8098, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5949, Feature Loss: 2.5949, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 115
# 	Train:	Total Loss: 2.8093, Feature Loss: 2.8093, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5935, Feature Loss: 2.5935, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 116
# 	Train:	Total Loss: 2.8098, Feature Loss: 2.8098, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5923, Feature Loss: 2.5923, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 117
# 	Train:	Total Loss: 2.8081, Feature Loss: 2.8081, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5911, Feature Loss: 2.5911, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 118
# 	Train:	Total Loss: 2.8059, Feature Loss: 2.8059, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5898, Feature Loss: 2.5898, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 119
# 	Train:	Total Loss: 2.8010, Feature Loss: 2.8010, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5887, Feature Loss: 2.5887, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 120
# 	Train:	Total Loss: 2.8016, Feature Loss: 2.8016, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5875, Feature Loss: 2.5875, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 121
# 	Train:	Total Loss: 2.8001, Feature Loss: 2.8001, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5864, Feature Loss: 2.5864, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 122
# 	Train:	Total Loss: 2.7995, Feature Loss: 2.7995, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5852, Feature Loss: 2.5852, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 123
# 	Train:	Total Loss: 2.7983, Feature Loss: 2.7983, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5841, Feature Loss: 2.5841, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 124
# 	Train:	Total Loss: 2.7964, Feature Loss: 2.7964, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5832, Feature Loss: 2.5832, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 125
# 	Train:	Total Loss: 2.7938, Feature Loss: 2.7938, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5820, Feature Loss: 2.5820, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 126
# 	Train:	Total Loss: 2.7913, Feature Loss: 2.7913, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5811, Feature Loss: 2.5811, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 127
# 	Train:	Total Loss: 2.7946, Feature Loss: 2.7946, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5802, Feature Loss: 2.5802, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 128
# 	Train:	Total Loss: 2.7929, Feature Loss: 2.7929, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5791, Feature Loss: 2.5791, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 129
# 	Train:	Total Loss: 2.7907, Feature Loss: 2.7907, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5782, Feature Loss: 2.5782, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 130
# 	Train:	Total Loss: 2.7848, Feature Loss: 2.7848, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5773, Feature Loss: 2.5773, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 131
# 	Train:	Total Loss: 2.7906, Feature Loss: 2.7906, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5765, Feature Loss: 2.5765, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 132
# 	Train:	Total Loss: 2.7868, Feature Loss: 2.7868, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5756, Feature Loss: 2.5756, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 133
# 	Train:	Total Loss: 2.7872, Feature Loss: 2.7872, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5746, Feature Loss: 2.5746, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 134
# 	Train:	Total Loss: 2.7851, Feature Loss: 2.7851, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5737, Feature Loss: 2.5737, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 135
# 	Train:	Total Loss: 2.7825, Feature Loss: 2.7825, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5729, Feature Loss: 2.5729, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 136
# 	Train:	Total Loss: 2.7816, Feature Loss: 2.7816, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5720, Feature Loss: 2.5720, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 137
# 	Train:	Total Loss: 2.7801, Feature Loss: 2.7801, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5711, Feature Loss: 2.5711, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 138
# 	Train:	Total Loss: 2.7816, Feature Loss: 2.7816, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5707, Feature Loss: 2.5707, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 139
# 	Train:	Total Loss: 2.7799, Feature Loss: 2.7799, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5698, Feature Loss: 2.5698, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 140
# 	Train:	Total Loss: 2.7777, Feature Loss: 2.7777, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5690, Feature Loss: 2.5690, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 141
# 	Train:	Total Loss: 2.7774, Feature Loss: 2.7774, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5682, Feature Loss: 2.5682, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 142
# 	Train:	Total Loss: 2.7778, Feature Loss: 2.7778, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5678, Feature Loss: 2.5678, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 143
# 	Train:	Total Loss: 2.7772, Feature Loss: 2.7772, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5670, Feature Loss: 2.5670, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 144
# 	Train:	Total Loss: 2.7779, Feature Loss: 2.7779, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5663, Feature Loss: 2.5663, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 145
# 	Train:	Total Loss: 2.7735, Feature Loss: 2.7735, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5656, Feature Loss: 2.5656, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 146
# 	Train:	Total Loss: 2.7755, Feature Loss: 2.7755, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5648, Feature Loss: 2.5648, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 147
# 	Train:	Total Loss: 2.7747, Feature Loss: 2.7747, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5642, Feature Loss: 2.5642, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 148
# 	Train:	Total Loss: 2.7732, Feature Loss: 2.7732, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5636, Feature Loss: 2.5636, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 149
# 	Train:	Total Loss: 2.7708, Feature Loss: 2.7708, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5630, Feature Loss: 2.5630, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 150
# 	Train:	Total Loss: 2.7709, Feature Loss: 2.7709, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5624, Feature Loss: 2.5624, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 151
# 	Train:	Total Loss: 2.7719, Feature Loss: 2.7719, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5618, Feature Loss: 2.5618, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 152
# 	Train:	Total Loss: 2.7714, Feature Loss: 2.7714, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5615, Feature Loss: 2.5615, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 153
# 	Train:	Total Loss: 2.7686, Feature Loss: 2.7686, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5605, Feature Loss: 2.5605, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 154
# 	Train:	Total Loss: 2.7695, Feature Loss: 2.7695, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5601, Feature Loss: 2.5601, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 155
# 	Train:	Total Loss: 2.7714, Feature Loss: 2.7714, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5597, Feature Loss: 2.5597, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 156
# 	Train:	Total Loss: 2.7697, Feature Loss: 2.7697, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5590, Feature Loss: 2.5590, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 157
# 	Train:	Total Loss: 2.7665, Feature Loss: 2.7665, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5587, Feature Loss: 2.5587, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 158
# 	Train:	Total Loss: 2.7682, Feature Loss: 2.7682, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5581, Feature Loss: 2.5581, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 159
# 	Train:	Total Loss: 2.7656, Feature Loss: 2.7656, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5576, Feature Loss: 2.5576, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 160
# 	Train:	Total Loss: 2.7642, Feature Loss: 2.7642, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5570, Feature Loss: 2.5570, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 161
# 	Train:	Total Loss: 2.7639, Feature Loss: 2.7639, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5566, Feature Loss: 2.5566, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 162
# 	Train:	Total Loss: 2.7624, Feature Loss: 2.7624, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5558, Feature Loss: 2.5558, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 163
# 	Train:	Total Loss: 2.7631, Feature Loss: 2.7631, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5556, Feature Loss: 2.5556, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 164
# 	Train:	Total Loss: 2.7633, Feature Loss: 2.7633, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5550, Feature Loss: 2.5550, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 165
# 	Train:	Total Loss: 2.7628, Feature Loss: 2.7628, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5545, Feature Loss: 2.5545, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 166
# 	Train:	Total Loss: 2.7622, Feature Loss: 2.7622, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5541, Feature Loss: 2.5541, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 167
# 	Train:	Total Loss: 2.7625, Feature Loss: 2.7625, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5538, Feature Loss: 2.5538, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 168
# 	Train:	Total Loss: 2.7613, Feature Loss: 2.7613, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5533, Feature Loss: 2.5533, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 169
# 	Train:	Total Loss: 2.7607, Feature Loss: 2.7607, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5525, Feature Loss: 2.5525, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 170
# 	Train:	Total Loss: 2.7594, Feature Loss: 2.7594, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5523, Feature Loss: 2.5523, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 171
# 	Train:	Total Loss: 2.7600, Feature Loss: 2.7600, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5518, Feature Loss: 2.5518, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 172
# 	Train:	Total Loss: 2.7630, Feature Loss: 2.7630, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5514, Feature Loss: 2.5514, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 173
# 	Train:	Total Loss: 2.7575, Feature Loss: 2.7575, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5508, Feature Loss: 2.5508, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 174
# 	Train:	Total Loss: 2.7585, Feature Loss: 2.7585, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5505, Feature Loss: 2.5505, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 175
# 	Train:	Total Loss: 2.7571, Feature Loss: 2.7571, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5498, Feature Loss: 2.5498, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 176
# 	Train:	Total Loss: 2.7565, Feature Loss: 2.7565, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5495, Feature Loss: 2.5495, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 177
# 	Train:	Total Loss: 2.7565, Feature Loss: 2.7565, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5489, Feature Loss: 2.5489, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 178
# 	Train:	Total Loss: 2.7571, Feature Loss: 2.7571, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5485, Feature Loss: 2.5485, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 179
# 	Train:	Total Loss: 2.7571, Feature Loss: 2.7571, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5481, Feature Loss: 2.5481, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 180
# 	Train:	Total Loss: 2.7554, Feature Loss: 2.7554, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5477, Feature Loss: 2.5477, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 181
# 	Train:	Total Loss: 2.7557, Feature Loss: 2.7557, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5469, Feature Loss: 2.5469, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 182
# 	Train:	Total Loss: 2.7561, Feature Loss: 2.7561, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5465, Feature Loss: 2.5465, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 183
# 	Train:	Total Loss: 2.7535, Feature Loss: 2.7535, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5459, Feature Loss: 2.5459, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 184
# 	Train:	Total Loss: 2.7544, Feature Loss: 2.7544, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5453, Feature Loss: 2.5453, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 185
# 	Train:	Total Loss: 2.7521, Feature Loss: 2.7521, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5447, Feature Loss: 2.5447, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 186
# 	Train:	Total Loss: 2.7518, Feature Loss: 2.7518, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5444, Feature Loss: 2.5444, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 187
# 	Train:	Total Loss: 2.7514, Feature Loss: 2.7514, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5438, Feature Loss: 2.5438, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 188
# 	Train:	Total Loss: 2.7523, Feature Loss: 2.7523, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5434, Feature Loss: 2.5434, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 189
# 	Train:	Total Loss: 2.7510, Feature Loss: 2.7510, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5427, Feature Loss: 2.5427, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 190
# 	Train:	Total Loss: 2.7494, Feature Loss: 2.7494, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5422, Feature Loss: 2.5422, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 191
# 	Train:	Total Loss: 2.7469, Feature Loss: 2.7469, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5416, Feature Loss: 2.5416, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 192
# 	Train:	Total Loss: 2.7478, Feature Loss: 2.7478, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5409, Feature Loss: 2.5409, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 193
# 	Train:	Total Loss: 2.7476, Feature Loss: 2.7476, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5406, Feature Loss: 2.5406, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 194
# 	Train:	Total Loss: 2.7481, Feature Loss: 2.7481, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5398, Feature Loss: 2.5398, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 195
# 	Train:	Total Loss: 2.7454, Feature Loss: 2.7454, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5392, Feature Loss: 2.5392, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 196
# 	Train:	Total Loss: 2.7464, Feature Loss: 2.7464, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5384, Feature Loss: 2.5384, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 197
# 	Train:	Total Loss: 2.7448, Feature Loss: 2.7448, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5380, Feature Loss: 2.5380, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 198
# 	Train:	Total Loss: 2.7439, Feature Loss: 2.7439, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5372, Feature Loss: 2.5372, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 199
# 	Train:	Total Loss: 2.7445, Feature Loss: 2.7445, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5367, Feature Loss: 2.5367, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 200
# 	Train:	Total Loss: 2.7434, Feature Loss: 2.7434, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.5356, Feature Loss: 2.5356, Type Loss: 0.0000 , LR: 0.000100

# %%
if not model_loaded:
    plt.figure(figsize=(14, 5))
    plt.plot(test_total_losses, label='Total Test Loss')
    plt.plot(train_total_losses, label='Total Train Loss')
    plt.legend()
    plt.title('Total Loss')
    plt.savefig("model2_totalloss.png")
    plt.show()

# %%
if not model_loaded:
    plt.figure(figsize=(14, 5))
    plt.plot(test_feature_losses, label='Test Feature Loss')
    plt.plot(train_feature_losses, label='Train Feature Loss')
    plt.legend()
    plt.title('Feature Loss')
    plt.savefig("model2_featureloss.png")
    plt.show()

# %%
test_loader_melt = DataLoader(graphs_melt, batch_size=1)
encoded_data_melt=[]
type_data_melt = []
for data in test_loader:
    model.eval()
    z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
    decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
    encoded_data_melt.append(z.detach().numpy())
    type_data_melt.append(str_type.detach().numpy())

encoded_data_melt = np.array(encoded_data_melt)
type_data_melt = np.array(type_data_melt)

# %%
test_loader_cry = DataLoader(graphs_cry, batch_size=1)
encoded_data_cry=[]
type_data_cry = []
for data in test_loader:
    model.eval()
    z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
    decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
    encoded_data_cry.append(z.detach().numpy())
    type_data_cry.append(str_type.detach().numpy())

encoded_data_cry = np.array(encoded_data_cry)
type_data_cry = np.array(type_data_cry)

# %%
# %matplotlib widget

frame = 10

fig = plt.figure(figsize=(15,4))
data_melt = encoded_data_melt[frame]

data_cry = encoded_data_cry[frame]
plt.scatter(data_melt[:,0],data_melt[:,1],c="r",label="melt")
plt.scatter(data_cry[:,0],data_cry[:,1],c="b",label="crystal")
plt.savefig("model2_scatter.png")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget

frame = 10

fig = plt.figure(figsize=(15,4))
data_melt = encoded_data_melt[frame]

data_cry = encoded_data_cry[frame]
# plt.scatter(data_melt[:,0],data_melt[:,1],c="r",label="melt")""
plt.scatter(data_cry[:,0],data_cry[:,1],c="b",label="crystal")
plt.savefig("model2_scatter.png")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
