# %%
import mdtraj as md
from ase import Atoms
import nglview as nv
import networkx as nx

import numpy as np
import matplotlib.pyplot as plt
import torch
from tqdm import tqdm

import torch_geometric.transforms as T
from torch_geometric.loader import DataLoader
from torch_geometric.nn import GCNConv, SAGPooling, InnerProductDecoder
import torch_geometric.data as data
from torch_geometric.utils.convert import to_networkx
import torch.optim.lr_scheduler as lr_scheduler
from torch.nn import Linear
import sys

# %%
all_frames_cry = md.load_xtc("../simulation/para_crystal.xtc", top="../simulation/para_crystal.gro")
all_frames_melt = md.load_xtc("../simulation/para_melt.xtc", top="../simulation/para_melt.gro")

# %%
all_frames_cry = all_frames_cry[::100]
all_frames_melt = all_frames_melt[::100]

# %%
n_frames = all_frames_cry.xyz.shape[0]
n_atoms = all_frames_cry.topology.residue(0).n_atoms
n_mols = all_frames_cry.topology.n_residues

# %%
def createGraph(all_frames,structure_type="crystal"):
    all_frames_fatures = []

    print("Creating Feature matrix")
    for i in tqdm(range(all_frames.xyz.shape[0])):
        mol_com_pos = []

        for res in all_frames.top.residues:
            pos = []
            for atom in res.atoms:
                pos.append(all_frames.xyz[i][atom.index])
            mol_com_pos.append(np.mean(pos,axis=0))
            
            # print()
        mol_com_pos = np.array(mol_com_pos).astype(np.float32)  
        all_frames_fatures.append(mol_com_pos)

    all_frames_fatures = np.array(all_frames_fatures).astype(np.float32)



    cutoff = 0.8

    print("Creating Edge list")
    all_edge_list = []
    # with open("edge_list.txt","w") as f:
    for frame_i in tqdm(range(n_frames)):
        from_list = []
        to_list = []

        for i in range(len(all_frames_fatures[frame_i])):
            for j in range(i+1,len(all_frames_fatures[frame_i])):
                if np.linalg.norm(all_frames_fatures[frame_i][i]-all_frames_fatures[frame_i][j]) < cutoff:
                    # f.write(str(i)+" "+str(j)+" "+str(np.linalg.norm(all_frames_fatures[frame_i][i]-all_frames_fatures[frame_i][j]))+"\n")
                    from_list.append(i)
                    to_list.append(j)

                    to_list.append(i)
                    from_list.append(j)

        edge_list = np.array([from_list,to_list]).astype(np.int64)
        all_edge_list.append(edge_list)
    print("creating Graphs")
    graphs = []
    for frame in tqdm(range(n_frames)):
        if structure_type == "crystal":
            g = data.Data(x=torch.tensor(all_frames_fatures[frame]).float(), edge_index=torch.tensor(all_edge_list[frame]).long(), y=torch.tensor([0]))
        else:
            g = data.Data(x=torch.tensor(all_frames_fatures[frame]).float(), edge_index=torch.tensor(all_edge_list[frame]).long(), y=torch.tensor([1]))
        graphs.append(g)
    return graphs

# %%
graphs_cry = createGraph(all_frames_cry,structure_type="crystal")
graphs_melt = createGraph(all_frames_melt,structure_type="melt")
# Out:
# Creating Feature matrix
# 100%|██████████| 51/51 [00:00<00:00, 87.55it/s]
# Creating Edge list
# 100%|██████████| 51/51 [01:09<00:00,  1.36s/it]
# creating Graphs
# 100%|██████████| 51/51 [00:00<00:00, 16454.58it/s]
# Creating Feature matrix
# 100%|██████████| 51/51 [00:00<00:00, 90.06it/s]
# Creating Edge list
# 100%|██████████| 51/51 [00:50<00:00,  1.02it/s]
# creating Graphs
# 100%|██████████| 51/51 [00:00<00:00, 16054.45it/s]

# %%
def convert_to_adj(edge_index, num_nodes=None):
    if num_nodes is None:
        num_nodes = edge_index.max() + 1
    adj = torch.zeros(num_nodes, num_nodes)
    adj[edge_index[0], edge_index[1]] = 1
    return adj

def convert_to_edge_index(adj):
    edge_index = adj.nonzero().t()
    return edge_index

# %%
graphs = graphs_cry + graphs_melt
# graphs = graphs_cry

# %%
# shuffle the graphs
np.random.shuffle(graphs)

# %%
graphs
# Out:
# [Data(x=[864, 3], edge_index=[2, 6512], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6452], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5822], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7294], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7146], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6608], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7060], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6578], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7306], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5892], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7080], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7060], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5876], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7024], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6542], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7048], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7100], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6488], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6546], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6508], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6056], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5880], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6018], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7088], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6532], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7034], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6214], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6626], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6544], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7064], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7374], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6560], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6464], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6586], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7094], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5862], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7086], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6546], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7128], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7092], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7108], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7240], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7132], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6564], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6554], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7116], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7052], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7078], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6400], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7274], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7012], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6570], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6630], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5982], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6934], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6592], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6580], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6012], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7096], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7026], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6566], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6508], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7028], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6172], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6582], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7218], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7078], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6602], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6558], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6584], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7090], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6524], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7056], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6066], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7048], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6990], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7074], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6992], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6548], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7054], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6964], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7008], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6548], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7020], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7006], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6596], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7192], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7116], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7036], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7092], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6560], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7052], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6552], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7006], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7044], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5962], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6070], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7076], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7122], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6476], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5910], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6288], y=[1])]

# %% [markdown]
# ## model

# %%
from typing import Optional, Tuple

import torch
from torch import Tensor
from torch.nn import Module

from torch_geometric.nn.inits import reset
from torch_geometric.utils import negative_sampling

EPS = 1e-15
MAX_LOGSTD = 10
edgeShape = None
featureShape = None


class InnerProductDecoder(torch.nn.Module):
    r"""The inner product decoder from the `"Variational Graph Auto-Encoders"
    <https://arxiv.org/abs/1611.07308>`_ paper

    .. math::
        \sigma(\mathbf{Z}\mathbf{Z}^{\top})

    where :math:`\mathbf{Z} \in \mathbb{R}^{N \times d}` denotes the latent
    space produced by the encoder."""

    def forward(self, z: Tensor, edge_index: Tensor,
                sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into edge probabilities for
        the given node-pairs :obj:`edge_index`.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        value = (z[edge_index[0]] * z[edge_index[1]]).sum(dim=1)
        return torch.sigmoid(value) if sigmoid else value

    def forward_all(self, z: Tensor, sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into a probabilistic dense
        adjacency matrix.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        adj = torch.matmul(z, z.t())
        return torch.sigmoid(adj) if sigmoid else adj


class GAE(torch.nn.Module):
    r"""The Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper based on user-defined encoder and decoder models.

    Args:
        encoder (torch.nn.Module): The encoder module.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__()
        self.encoder = encoder
        self.decoder = InnerProductDecoder() if decoder is None else decoder
        GAE.reset_parameters(self)

    def reset_parameters(self):
        r"""Resets all learnable parameters of the module."""
        reset(self.encoder)
        reset(self.decoder)

    def forward(self, *args, **kwargs) -> Tensor:  # pragma: no cover
        r"""Alias for :meth:`encode`."""
        return self.encoder(*args, **kwargs)

    def encode(self, *args, **kwargs) -> Tensor:
        r"""Runs the encoder and computes node-wise latent variables."""
        return self.encoder(*args, **kwargs)

    def decode(self, *args, **kwargs) -> Tensor:
        r"""Runs the decoder and computes edge probabilities."""
        return self.decoder(*args, **kwargs)

    def recon_loss(self, z: Tensor, pos_edge_index: Tensor,
                   neg_edge_index: Optional[Tensor] = None) -> Tensor:
        r"""Given latent variables :obj:`z`, computes the binary cross
        entropy loss for positive edges :obj:`pos_edge_index` and negative
        sampled edges.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to train against.
            neg_edge_index (torch.Tensor, optional): The negative edges to
                train against. If not given, uses negative sampling to
                calculate negative edges. (default: :obj:`None`)
        """
        pos_loss = -torch.log(
            self.decoder(z, pos_edge_index, sigmoid=True)[0] + EPS).mean()

        if neg_edge_index is None:
            neg_edge_index = negative_sampling(pos_edge_index, z.size(0))
        neg_loss = -torch.log(1 -
                              self.decoder(z, neg_edge_index.long(), sigmoid=True)[0] +
                              EPS).mean()

        return pos_loss + neg_loss

    def test(self, z: Tensor, pos_edge_index: Tensor,
             neg_edge_index: Tensor) -> Tuple[Tensor, Tensor]:
        r"""Given latent variables :obj:`z`, positive edges
        :obj:`pos_edge_index` and negative edges :obj:`neg_edge_index`,
        computes area under the ROC curve (AUC) and average precision (AP)
        
        scores.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to evaluate
                against.
            neg_edge_index (torch.Tensor): The negative edges to evaluate
                against.
        """
        from sklearn.metrics import average_precision_score, roc_auc_score

        pos_y = z.new_ones(pos_edge_index.size(1))
        neg_y = z.new_zeros(neg_edge_index.size(1))
        y = torch.cat([pos_y, neg_y], dim=0)

        pos_pred = self.decoder(z, pos_edge_index, sigmoid=True)
        neg_pred = self.decoder(z, neg_edge_index, sigmoid=True)
        pred = torch.cat([pos_pred, neg_pred], dim=0)

        y, pred = y.detach().cpu().numpy(), pred.detach().cpu().numpy()

        return roc_auc_score(y, pred), average_precision_score(y, pred)


class VGAE(GAE):
    r"""The Variational Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper.

    Args:
        encoder (torch.nn.Module): The encoder module to compute :math:`\mu`
            and :math:`\log\sigma^2`.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__(encoder, decoder)

    def reparametrize(self, mu: Tensor, logstd: Tensor) -> Tensor:
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def encode(self, *args, **kwargs) -> Tensor:
        """"""
        z, self.edge_index = self.encoder(
            *args, **kwargs)
        
        return z, self.edge_index

    def kl_loss(self, mu: Optional[Tensor] = None,
                logstd: Optional[Tensor] = None) -> Tensor:
        r"""Computes the KL loss, either for the passed arguments :obj:`mu`
        and :obj:`logstd`, or based on latent variables from last encoding.

        Args:
            mu (torch.Tensor, optional): The latent space for :math:`\mu`. If
                set to :obj:`None`, uses the last computation of :math:`\mu`.
                (default: :obj:`None`)
            logstd (torch.Tensor, optional): The latent space for
                :math:`\log\sigma`.  If set to :obj:`None`, uses the last
                computation of :math:`\log\sigma^2`. (default: :obj:`None`)
        """
        mu = self.__mu__ if mu is None else mu
        logstd = self.__logstd__ if logstd is None else logstd.clamp(
            max=MAX_LOGSTD)
        return -0.5 * torch.mean(
            torch.sum(1 + 2 * logstd - mu**2 - logstd.exp()**2, dim=1))

# %%
import torch.nn.functional as F



class VariationalGCNEncoder(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__() # changes made such that guassian is 1 
        self.conv1 = GCNConv(in_channels, 2*out_channels)
        self.conv2 = GCNConv(2*out_channels, 1 * out_channels)
        self.pool = SAGPooling(out_channels, 0.5)
        
        self.conv_mu = GCNConv(1 * out_channels, out_channels)
        self.conv_logstd = GCNConv(1 * out_channels, out_channels)
    def reparametrize(self, mu: Tensor, logstd: Tensor) -> Tensor:
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def forward(self, x, edge_index,class_label):
        # print("input:",x.shape, edge_index.shape)
        x = self.conv1(x, edge_index)
        x = F.silu(x)
        # print("conv1:",x.shape, edge_index.shape)
        x = self.conv2(x, edge_index)
        x = F.silu(x)
        # print("conv2:",x.shape, edge_index.shape)

        sample = self.reparametrize(self.conv_mu(x, edge_index), self.conv_logstd(x, edge_index))
        sample = self.reparametrize(self.conv_mu(sample, edge_index), self.conv_logstd(sample, edge_index))
        # self.conv_mu_crystal.train(True)
        # self.conv_logstd_crystal.train(True)
        # self.conv_mu_melt.train(True)
        # self.conv_logstd_melt.train(True)
        self.conv_mu.train(True)
        self.conv_logstd.train(True)
        return sample, edge_index

# %%
class VariationalGCNDecoder(torch.nn.Module):
    def __init__(self,in_channels,out_channels):
        super().__init__()
        self.type_layer1 = Linear(1728,200)
        self.dropout = torch.nn.Dropout(0.5)
        self.type_layer2 = Linear(200,2)
        self.conv1 = GCNConv(in_channels,2*out_channels)
        self.conv2 = GCNConv(2*out_channels, 1 * out_channels)
    def forward(self, x, edge_index, sigmoid=True):
        # print("input:",x.shape, edge_index.shape)
        flat = x.flatten()
        flat = self.type_layer1(flat).relu()
        flat = self.dropout(flat)
        str_type = F.softmax(self.type_layer2(flat).relu(),dim=0)
         
        x = self.conv1(x, edge_index)
        x = F.silu(x)
        # print("conv1:",x.shape, edge_index.shape)
        x = self.conv2(x, edge_index)
        x = F.silu(x)
        # print("conv2:",x.shape, edge_index.shape)
        return x, edge_index,str_type

# %%
import os
in_channels = graphs[0].num_features
out_channels = 2
lr = 1e-4
n_epochs = 200
batch_size=1
test_train_split = 0.8
model_name = "model2.pt"
model_loaded = False
force_train = True  

if os.path.exists("./models/"+model_name) and not force_train:
    model = torch.load("./models/"+model_name)
    model_loaded = True
else:
    model = VGAE(VariationalGCNEncoder(in_channels, out_channels),
                VariationalGCNDecoder(out_channels, in_channels))

optimizer = torch.optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, step_size=300, gamma=0.5)

# %%
train_loader = DataLoader(graphs_cry[:int(n_frames*test_train_split)], batch_size=batch_size, shuffle=True)
test_loader = DataLoader(graphs_cry[int(n_frames*test_train_split):], batch_size=batch_size, shuffle=True)

# %%
lossFxn = torch.nn.MSELoss()
typeLossFxn = torch.nn.CrossEntropyLoss()

def train():
    model.train()
    model.zero_grad()
    model.float()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0
    type_loss_all = 0
    for data in train_loader:
        optimizer.zero_grad()
        z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
        decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)

     
        # TypeLoss = typeLossFxn(str_type.unsqueeze(0), data.y)
        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        loss = FeatureLoss + EdgeLoss 

        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        # type_loss_all += float(TypeLoss)

        loss.backward()
        optimizer.step()
        

    return loss_all / len(train_loader), feature_loss_all / len(train_loader), edge_loss_all / len(train_loader), kl_loss_all / len(train_loader), type_loss_all / len(train_loader)

# %%
lossFxn = torch.nn.MSELoss()
def test():
    model.eval()
    model.zero_grad()
    model.float()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0
    type_loss_all = 0

    for data in test_loader:
        optimizer.zero_grad()
        z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
        decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
        
        # TypeLoss = typeLossFxn(str_type.unsqueeze(0), data.y)
        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        loss = FeatureLoss + EdgeLoss 

        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        # type_loss_all += float(TypeLoss)
        
        
        

    return loss_all / len(test_loader), feature_loss_all / len(test_loader), edge_loss_all / len(test_loader), kl_loss_all / len(test_loader), type_loss_all / len(test_loader)

# %%
train_total_losses = []
train_feature_losses = []
train_edge_losses = []
train_kl_losses = []
train_type_losses = []

test_total_losses = []
test_feature_losses = []
test_edge_losses = []
test_kl_losses = []
test_type_losses = []

if model_loaded:        
    print("Pretrained Model Loaded, no training required")
else:
    for epoch in range(1, n_epochs + 1):
        
        train_total_loss, train_feature_loss, train_edge_loss, train_kl_loss,train_type_loss = train()
        test_total_loss, test_feature_loss, test_edge_loss, test_kl_loss, test_type_loss= test()
        
        print(f"Epoch: {epoch:03d}")
        print(f'\tTrain:\tTotal Loss: {train_total_loss:.4f}, Feature Loss: {train_feature_loss:.4f}, Type Loss: {train_type_loss:.4f} ,  LR: {scheduler.get_last_lr()[0]:.6f}')
        print(f'\tTest: \tTotal Loss: {test_total_loss:.4f}, Feature Loss: {test_feature_loss:.4f}, Type Loss: {test_type_loss:.4f} , LR: {scheduler.get_last_lr()[0]:.6f}')
        
        
        train_total_losses.append(train_total_loss)
        train_feature_losses.append(train_feature_loss)
        train_edge_losses.append(train_edge_loss)
        train_kl_losses.append(train_kl_loss)
        train_type_losses.append(train_type_loss)


        test_total_losses.append(test_total_loss)
        test_feature_losses.append(test_feature_loss)
        test_edge_losses.append(test_edge_loss)
        test_kl_losses.append(test_kl_loss)
        test_type_losses.append(test_type_loss)
        
        scheduler.step()
    torch.save(model,"./models/"+model_name)
# Out:
# Epoch: 001
# 	Train:	Total Loss: 32.9407, Feature Loss: 32.9407, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.5019, Feature Loss: 10.5019, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 002
# 	Train:	Total Loss: 72.0721, Feature Loss: 72.0721, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.4774, Feature Loss: 10.4774, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 003
# 	Train:	Total Loss: 21.2349, Feature Loss: 21.2349, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.4427, Feature Loss: 10.4427, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 004
# 	Train:	Total Loss: 87.9704, Feature Loss: 87.9704, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.4210, Feature Loss: 10.4210, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 005
# 	Train:	Total Loss: 19.7249, Feature Loss: 19.7249, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.3867, Feature Loss: 10.3867, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 006
# 	Train:	Total Loss: 39.3853, Feature Loss: 39.3853, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.3501, Feature Loss: 10.3501, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 007
# 	Train:	Total Loss: 34.6088, Feature Loss: 34.6088, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.3168, Feature Loss: 10.3168, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 008
# 	Train:	Total Loss: 34.2288, Feature Loss: 34.2288, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.2885, Feature Loss: 10.2885, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 009
# 	Train:	Total Loss: 17.3423, Feature Loss: 17.3423, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.2434, Feature Loss: 10.2434, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 010
# 	Train:	Total Loss: 61.6502, Feature Loss: 61.6502, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.2221, Feature Loss: 10.2221, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 011
# 	Train:	Total Loss: 33.9907, Feature Loss: 33.9907, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.1794, Feature Loss: 10.1794, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 012
# 	Train:	Total Loss: 23.9711, Feature Loss: 23.9711, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.1350, Feature Loss: 10.1350, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 013
# 	Train:	Total Loss: 24.3946, Feature Loss: 24.3946, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.0926, Feature Loss: 10.0926, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 014
# 	Train:	Total Loss: 18.4465, Feature Loss: 18.4465, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.0489, Feature Loss: 10.0489, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 015
# 	Train:	Total Loss: 43.7794, Feature Loss: 43.7794, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.0108, Feature Loss: 10.0108, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 016
# 	Train:	Total Loss: 19.9624, Feature Loss: 19.9624, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.9688, Feature Loss: 9.9688, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 017
# 	Train:	Total Loss: 21.6070, Feature Loss: 21.6070, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.9246, Feature Loss: 9.9246, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 018
# 	Train:	Total Loss: 14.2069, Feature Loss: 14.2069, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.8778, Feature Loss: 9.8778, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 019
# 	Train:	Total Loss: 17.6621, Feature Loss: 17.6621, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.8320, Feature Loss: 9.8320, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 020
# 	Train:	Total Loss: 19.4084, Feature Loss: 19.4084, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.7986, Feature Loss: 9.7986, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 021
# 	Train:	Total Loss: 34.4833, Feature Loss: 34.4833, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.7673, Feature Loss: 9.7673, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 022
# 	Train:	Total Loss: 16.2363, Feature Loss: 16.2363, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.7355, Feature Loss: 9.7355, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 023
# 	Train:	Total Loss: 21.2725, Feature Loss: 21.2725, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.6977, Feature Loss: 9.6977, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 024
# 	Train:	Total Loss: 12.3014, Feature Loss: 12.3014, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.6552, Feature Loss: 9.6552, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 025
# 	Train:	Total Loss: 27.8482, Feature Loss: 27.8482, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.6393, Feature Loss: 9.6393, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 026
# 	Train:	Total Loss: 17.4523, Feature Loss: 17.4523, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.5997, Feature Loss: 9.5997, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 027
# 	Train:	Total Loss: 19.4948, Feature Loss: 19.4948, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.5643, Feature Loss: 9.5643, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 028
# 	Train:	Total Loss: 13.1926, Feature Loss: 13.1926, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.5233, Feature Loss: 9.5233, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 029
# 	Train:	Total Loss: 11.6061, Feature Loss: 11.6061, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.4793, Feature Loss: 9.4793, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 030
# 	Train:	Total Loss: 14.2520, Feature Loss: 14.2520, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.4422, Feature Loss: 9.4422, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 031
# 	Train:	Total Loss: 14.9757, Feature Loss: 14.9757, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.4052, Feature Loss: 9.4052, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 032
# 	Train:	Total Loss: 12.6678, Feature Loss: 12.6678, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.3649, Feature Loss: 9.3649, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 033
# 	Train:	Total Loss: 14.7130, Feature Loss: 14.7130, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.3255, Feature Loss: 9.3255, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 034
# 	Train:	Total Loss: 19.2696, Feature Loss: 19.2696, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.2853, Feature Loss: 9.2853, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 035
# 	Train:	Total Loss: 11.6708, Feature Loss: 11.6708, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.2499, Feature Loss: 9.2499, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 036
# 	Train:	Total Loss: 13.4933, Feature Loss: 13.4933, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.2099, Feature Loss: 9.2099, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 037
# 	Train:	Total Loss: 20.1074, Feature Loss: 20.1074, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.1803, Feature Loss: 9.1803, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 038
# 	Train:	Total Loss: 12.3089, Feature Loss: 12.3089, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.1399, Feature Loss: 9.1399, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 039
# 	Train:	Total Loss: 14.2334, Feature Loss: 14.2334, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.1049, Feature Loss: 9.1049, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 040
# 	Train:	Total Loss: 17.6487, Feature Loss: 17.6487, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.0901, Feature Loss: 9.0901, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 041
# 	Train:	Total Loss: 15.2460, Feature Loss: 15.2460, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.0569, Feature Loss: 9.0569, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 042
# 	Train:	Total Loss: 13.7719, Feature Loss: 13.7719, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.0267, Feature Loss: 9.0267, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 043
# 	Train:	Total Loss: 14.4784, Feature Loss: 14.4784, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.9948, Feature Loss: 8.9948, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 044
# 	Train:	Total Loss: 12.7500, Feature Loss: 12.7500, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.9555, Feature Loss: 8.9555, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 045
# 	Train:	Total Loss: 19.8299, Feature Loss: 19.8299, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.9287, Feature Loss: 8.9287, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 046
# 	Train:	Total Loss: 14.5274, Feature Loss: 14.5274, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.8927, Feature Loss: 8.8927, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 047
# 	Train:	Total Loss: 15.2597, Feature Loss: 15.2597, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.8586, Feature Loss: 8.8586, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 048
# 	Train:	Total Loss: 20.6229, Feature Loss: 20.6229, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.8387, Feature Loss: 8.8387, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 049
# 	Train:	Total Loss: 13.1038, Feature Loss: 13.1038, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.8044, Feature Loss: 8.8044, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 050
# 	Train:	Total Loss: 12.8077, Feature Loss: 12.8077, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.7671, Feature Loss: 8.7671, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 051
# 	Train:	Total Loss: 13.2966, Feature Loss: 13.2966, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.7349, Feature Loss: 8.7349, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 052
# 	Train:	Total Loss: 11.4319, Feature Loss: 11.4319, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.6957, Feature Loss: 8.6957, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 053
# 	Train:	Total Loss: 10.0964, Feature Loss: 10.0964, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.6524, Feature Loss: 8.6524, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 054
# 	Train:	Total Loss: 10.1193, Feature Loss: 10.1193, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.6102, Feature Loss: 8.6102, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 055
# 	Train:	Total Loss: 16.1310, Feature Loss: 16.1310, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.5843, Feature Loss: 8.5843, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 056
# 	Train:	Total Loss: 15.2942, Feature Loss: 15.2942, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.5576, Feature Loss: 8.5576, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 057
# 	Train:	Total Loss: 11.5229, Feature Loss: 11.5229, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.5215, Feature Loss: 8.5215, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 058
# 	Train:	Total Loss: 10.5700, Feature Loss: 10.5700, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.4825, Feature Loss: 8.4825, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 059
# 	Train:	Total Loss: 9.4225, Feature Loss: 9.4225, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.4392, Feature Loss: 8.4392, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 060
# 	Train:	Total Loss: 9.4049, Feature Loss: 9.4049, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.3943, Feature Loss: 8.3943, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 061
# 	Train:	Total Loss: 9.1905, Feature Loss: 9.1905, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.3499, Feature Loss: 8.3499, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 062
# 	Train:	Total Loss: 14.8288, Feature Loss: 14.8288, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.3175, Feature Loss: 8.3175, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 063
# 	Train:	Total Loss: 10.0571, Feature Loss: 10.0571, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.2805, Feature Loss: 8.2805, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 064
# 	Train:	Total Loss: 10.2915, Feature Loss: 10.2915, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.2407, Feature Loss: 8.2407, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 065
# 	Train:	Total Loss: 10.9222, Feature Loss: 10.9222, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.2027, Feature Loss: 8.2027, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 066
# 	Train:	Total Loss: 10.2005, Feature Loss: 10.2005, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.1602, Feature Loss: 8.1602, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 067
# 	Train:	Total Loss: 10.6427, Feature Loss: 10.6427, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.1220, Feature Loss: 8.1220, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 068
# 	Train:	Total Loss: 14.8347, Feature Loss: 14.8347, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.0943, Feature Loss: 8.0943, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 069
# 	Train:	Total Loss: 9.5784, Feature Loss: 9.5784, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.0522, Feature Loss: 8.0522, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 070
# 	Train:	Total Loss: 11.1337, Feature Loss: 11.1337, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.0133, Feature Loss: 8.0133, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 071
# 	Train:	Total Loss: 9.2781, Feature Loss: 9.2781, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.9713, Feature Loss: 7.9713, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 072
# 	Train:	Total Loss: 10.5482, Feature Loss: 10.5482, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.9399, Feature Loss: 7.9399, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 073
# 	Train:	Total Loss: 10.5860, Feature Loss: 10.5860, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.8998, Feature Loss: 7.8998, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 074
# 	Train:	Total Loss: 10.9625, Feature Loss: 10.9625, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.8681, Feature Loss: 7.8681, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 075
# 	Train:	Total Loss: 8.8170, Feature Loss: 8.8170, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.8247, Feature Loss: 7.8247, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 076
# 	Train:	Total Loss: 9.2029, Feature Loss: 9.2029, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.7809, Feature Loss: 7.7809, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 077
# 	Train:	Total Loss: 10.5467, Feature Loss: 10.5467, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.7467, Feature Loss: 7.7467, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 078
# 	Train:	Total Loss: 9.1288, Feature Loss: 9.1288, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.7069, Feature Loss: 7.7069, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 079
# 	Train:	Total Loss: 10.3416, Feature Loss: 10.3416, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.6739, Feature Loss: 7.6739, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 080
# 	Train:	Total Loss: 8.9950, Feature Loss: 8.9950, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.6300, Feature Loss: 7.6300, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 081
# 	Train:	Total Loss: 9.5235, Feature Loss: 9.5235, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.5941, Feature Loss: 7.5941, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 082
# 	Train:	Total Loss: 9.4248, Feature Loss: 9.4248, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.5552, Feature Loss: 7.5552, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 083
# 	Train:	Total Loss: 8.6211, Feature Loss: 8.6211, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.5121, Feature Loss: 7.5121, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 084
# 	Train:	Total Loss: 8.3712, Feature Loss: 8.3712, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.4667, Feature Loss: 7.4667, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 085
# 	Train:	Total Loss: 9.2084, Feature Loss: 9.2084, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.4203, Feature Loss: 7.4203, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 086
# 	Train:	Total Loss: 8.5220, Feature Loss: 8.5220, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.3788, Feature Loss: 7.3788, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 087
# 	Train:	Total Loss: 9.2763, Feature Loss: 9.2763, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.3427, Feature Loss: 7.3427, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 088
# 	Train:	Total Loss: 8.6942, Feature Loss: 8.6942, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.3005, Feature Loss: 7.3005, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 089
# 	Train:	Total Loss: 8.4543, Feature Loss: 8.4543, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.2594, Feature Loss: 7.2594, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 090
# 	Train:	Total Loss: 9.7549, Feature Loss: 9.7549, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.2195, Feature Loss: 7.2195, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 091
# 	Train:	Total Loss: 8.1781, Feature Loss: 8.1781, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.1747, Feature Loss: 7.1747, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 092
# 	Train:	Total Loss: 7.9799, Feature Loss: 7.9799, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.1279, Feature Loss: 7.1279, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 093
# 	Train:	Total Loss: 8.3500, Feature Loss: 8.3500, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.0851, Feature Loss: 7.0851, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 094
# 	Train:	Total Loss: 8.4712, Feature Loss: 8.4712, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.0409, Feature Loss: 7.0409, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 095
# 	Train:	Total Loss: 8.7748, Feature Loss: 8.7748, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.9998, Feature Loss: 6.9998, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 096
# 	Train:	Total Loss: 9.0400, Feature Loss: 9.0400, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.9628, Feature Loss: 6.9628, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 097
# 	Train:	Total Loss: 7.8662, Feature Loss: 7.8662, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.9169, Feature Loss: 6.9169, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 098
# 	Train:	Total Loss: 9.1585, Feature Loss: 9.1585, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.8809, Feature Loss: 6.8809, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 099
# 	Train:	Total Loss: 8.7056, Feature Loss: 8.7056, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.8396, Feature Loss: 6.8396, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 100
# 	Train:	Total Loss: 7.6408, Feature Loss: 7.6408, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.7930, Feature Loss: 6.7930, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 101
# 	Train:	Total Loss: 7.7353, Feature Loss: 7.7353, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.7463, Feature Loss: 6.7463, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 102
# 	Train:	Total Loss: 8.1908, Feature Loss: 8.1908, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.7028, Feature Loss: 6.7028, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 103
# 	Train:	Total Loss: 7.8064, Feature Loss: 7.8064, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.6588, Feature Loss: 6.6588, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 104
# 	Train:	Total Loss: 7.4311, Feature Loss: 7.4311, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.6135, Feature Loss: 6.6135, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 105
# 	Train:	Total Loss: 8.9940, Feature Loss: 8.9940, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.5797, Feature Loss: 6.5797, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 106
# 	Train:	Total Loss: 7.4196, Feature Loss: 7.4196, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.5369, Feature Loss: 6.5369, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 107
# 	Train:	Total Loss: 8.3035, Feature Loss: 8.3035, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.4965, Feature Loss: 6.4965, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 108
# 	Train:	Total Loss: 9.3348, Feature Loss: 9.3348, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.4610, Feature Loss: 6.4610, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 109
# 	Train:	Total Loss: 7.3964, Feature Loss: 7.3964, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.4310, Feature Loss: 6.4310, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 110
# 	Train:	Total Loss: 8.1529, Feature Loss: 8.1529, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.3916, Feature Loss: 6.3916, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 111
# 	Train:	Total Loss: 8.9019, Feature Loss: 8.9019, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.3561, Feature Loss: 6.3561, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 112
# 	Train:	Total Loss: 7.6034, Feature Loss: 7.6034, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.3161, Feature Loss: 6.3161, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 113
# 	Train:	Total Loss: 7.2045, Feature Loss: 7.2045, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.2710, Feature Loss: 6.2710, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 114
# 	Train:	Total Loss: 7.3818, Feature Loss: 7.3818, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.2276, Feature Loss: 6.2276, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 115
# 	Train:	Total Loss: 8.5241, Feature Loss: 8.5241, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.1932, Feature Loss: 6.1932, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 116
# 	Train:	Total Loss: 8.2183, Feature Loss: 8.2183, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.1552, Feature Loss: 6.1552, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 117
# 	Train:	Total Loss: 7.1346, Feature Loss: 7.1346, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.1100, Feature Loss: 6.1100, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 118
# 	Train:	Total Loss: 7.2454, Feature Loss: 7.2454, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.0655, Feature Loss: 6.0655, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 119
# 	Train:	Total Loss: 7.2316, Feature Loss: 7.2316, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.0204, Feature Loss: 6.0204, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 120
# 	Train:	Total Loss: 7.0624, Feature Loss: 7.0624, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.9743, Feature Loss: 5.9743, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 121
# 	Train:	Total Loss: 6.6940, Feature Loss: 6.6940, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.9272, Feature Loss: 5.9272, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 122
# 	Train:	Total Loss: 6.9006, Feature Loss: 6.9006, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.8813, Feature Loss: 5.8813, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 123
# 	Train:	Total Loss: 6.7345, Feature Loss: 6.7345, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.8356, Feature Loss: 5.8356, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 124
# 	Train:	Total Loss: 6.6966, Feature Loss: 6.6966, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.7897, Feature Loss: 5.7897, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 125
# 	Train:	Total Loss: 7.1792, Feature Loss: 7.1792, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.7508, Feature Loss: 5.7508, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 126
# 	Train:	Total Loss: 6.6891, Feature Loss: 6.6891, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.7065, Feature Loss: 5.7065, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 127
# 	Train:	Total Loss: 6.7488, Feature Loss: 6.7488, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.6622, Feature Loss: 5.6622, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 128
# 	Train:	Total Loss: 7.5196, Feature Loss: 7.5196, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.6258, Feature Loss: 5.6258, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 129
# 	Train:	Total Loss: 6.7190, Feature Loss: 6.7190, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.5832, Feature Loss: 5.5832, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 130
# 	Train:	Total Loss: 6.4508, Feature Loss: 6.4508, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.5375, Feature Loss: 5.5375, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 131
# 	Train:	Total Loss: 7.1501, Feature Loss: 7.1501, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.5003, Feature Loss: 5.5003, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 132
# 	Train:	Total Loss: 6.4892, Feature Loss: 6.4892, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.4546, Feature Loss: 5.4546, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 133
# 	Train:	Total Loss: 6.5332, Feature Loss: 6.5332, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.4095, Feature Loss: 5.4095, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 134
# 	Train:	Total Loss: 6.4310, Feature Loss: 6.4310, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.3651, Feature Loss: 5.3651, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 135
# 	Train:	Total Loss: 6.5539, Feature Loss: 6.5539, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.3221, Feature Loss: 5.3221, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 136
# 	Train:	Total Loss: 6.5337, Feature Loss: 6.5337, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.2849, Feature Loss: 5.2849, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 137
# 	Train:	Total Loss: 7.2174, Feature Loss: 7.2174, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.2539, Feature Loss: 5.2539, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 138
# 	Train:	Total Loss: 6.0765, Feature Loss: 6.0765, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.2105, Feature Loss: 5.2105, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 139
# 	Train:	Total Loss: 6.1214, Feature Loss: 6.1214, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.1645, Feature Loss: 5.1645, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 140
# 	Train:	Total Loss: 6.6261, Feature Loss: 6.6261, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.1232, Feature Loss: 5.1232, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 141
# 	Train:	Total Loss: 5.9627, Feature Loss: 5.9627, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.0810, Feature Loss: 5.0810, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 142
# 	Train:	Total Loss: 6.9007, Feature Loss: 6.9007, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.0512, Feature Loss: 5.0512, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 143
# 	Train:	Total Loss: 6.3122, Feature Loss: 6.3122, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.0115, Feature Loss: 5.0115, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 144
# 	Train:	Total Loss: 5.9640, Feature Loss: 5.9640, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.9729, Feature Loss: 4.9729, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 145
# 	Train:	Total Loss: 6.2476, Feature Loss: 6.2476, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.9332, Feature Loss: 4.9332, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 146
# 	Train:	Total Loss: 6.0719, Feature Loss: 6.0719, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.8945, Feature Loss: 4.8945, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 147
# 	Train:	Total Loss: 5.9641, Feature Loss: 5.9641, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.8547, Feature Loss: 4.8547, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 148
# 	Train:	Total Loss: 6.1258, Feature Loss: 6.1258, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.8134, Feature Loss: 4.8134, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 149
# 	Train:	Total Loss: 5.6748, Feature Loss: 5.6748, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.7728, Feature Loss: 4.7728, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 150
# 	Train:	Total Loss: 5.6487, Feature Loss: 5.6487, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.7292, Feature Loss: 4.7292, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 151
# 	Train:	Total Loss: 6.1017, Feature Loss: 6.1017, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.6925, Feature Loss: 4.6925, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 152
# 	Train:	Total Loss: 5.6657, Feature Loss: 5.6657, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.6499, Feature Loss: 4.6499, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 153
# 	Train:	Total Loss: 5.6895, Feature Loss: 5.6895, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.6096, Feature Loss: 4.6096, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 154
# 	Train:	Total Loss: 5.5561, Feature Loss: 5.5561, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.5670, Feature Loss: 4.5670, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 155
# 	Train:	Total Loss: 5.5240, Feature Loss: 5.5240, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.5277, Feature Loss: 4.5277, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 156
# 	Train:	Total Loss: 5.9868, Feature Loss: 5.9868, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.4980, Feature Loss: 4.4980, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 157
# 	Train:	Total Loss: 6.1782, Feature Loss: 6.1782, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.4719, Feature Loss: 4.4719, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 158
# 	Train:	Total Loss: 5.9290, Feature Loss: 5.9290, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.4419, Feature Loss: 4.4419, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 159
# 	Train:	Total Loss: 5.3721, Feature Loss: 5.3721, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.4042, Feature Loss: 4.4042, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 160
# 	Train:	Total Loss: 5.3821, Feature Loss: 5.3821, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.3648, Feature Loss: 4.3648, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 161
# 	Train:	Total Loss: 5.7519, Feature Loss: 5.7519, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.3307, Feature Loss: 4.3307, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 162
# 	Train:	Total Loss: 5.7112, Feature Loss: 5.7112, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.2996, Feature Loss: 4.2996, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 163
# 	Train:	Total Loss: 5.2147, Feature Loss: 5.2147, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.2627, Feature Loss: 4.2627, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 164
# 	Train:	Total Loss: 5.8026, Feature Loss: 5.8026, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.2377, Feature Loss: 4.2377, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 165
# 	Train:	Total Loss: 5.7902, Feature Loss: 5.7902, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.2100, Feature Loss: 4.2100, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 166
# 	Train:	Total Loss: 5.4556, Feature Loss: 5.4556, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.1751, Feature Loss: 4.1751, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 167
# 	Train:	Total Loss: 5.1074, Feature Loss: 5.1074, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.1378, Feature Loss: 4.1378, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 168
# 	Train:	Total Loss: 4.9826, Feature Loss: 4.9826, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.0989, Feature Loss: 4.0989, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 169
# 	Train:	Total Loss: 5.0315, Feature Loss: 5.0315, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.0623, Feature Loss: 4.0623, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 170
# 	Train:	Total Loss: 5.2470, Feature Loss: 5.2470, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.0304, Feature Loss: 4.0304, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 171
# 	Train:	Total Loss: 4.8436, Feature Loss: 4.8436, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.9941, Feature Loss: 3.9941, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 172
# 	Train:	Total Loss: 5.0421, Feature Loss: 5.0421, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.9616, Feature Loss: 3.9616, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 173
# 	Train:	Total Loss: 5.0270, Feature Loss: 5.0270, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.9284, Feature Loss: 3.9284, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 174
# 	Train:	Total Loss: 5.0349, Feature Loss: 5.0349, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8980, Feature Loss: 3.8980, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 175
# 	Train:	Total Loss: 4.7918, Feature Loss: 4.7918, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8633, Feature Loss: 3.8633, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 176
# 	Train:	Total Loss: 4.7808, Feature Loss: 4.7808, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8299, Feature Loss: 3.8299, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 177
# 	Train:	Total Loss: 5.2711, Feature Loss: 5.2711, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8094, Feature Loss: 3.8094, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 178
# 	Train:	Total Loss: 4.5845, Feature Loss: 4.5845, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7765, Feature Loss: 3.7765, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 179
# 	Train:	Total Loss: 5.2467, Feature Loss: 5.2467, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7533, Feature Loss: 3.7533, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 180
# 	Train:	Total Loss: 4.9730, Feature Loss: 4.9730, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7309, Feature Loss: 3.7309, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 181
# 	Train:	Total Loss: 5.2225, Feature Loss: 5.2225, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7135, Feature Loss: 3.7135, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 182
# 	Train:	Total Loss: 4.5513, Feature Loss: 4.5513, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6848, Feature Loss: 3.6848, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 183
# 	Train:	Total Loss: 4.5898, Feature Loss: 4.5898, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6550, Feature Loss: 3.6550, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 184
# 	Train:	Total Loss: 4.5699, Feature Loss: 4.5699, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6266, Feature Loss: 3.6266, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 185
# 	Train:	Total Loss: 4.4040, Feature Loss: 4.4040, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5951, Feature Loss: 3.5951, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 186
# 	Train:	Total Loss: 4.5101, Feature Loss: 4.5101, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5662, Feature Loss: 3.5662, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 187
# 	Train:	Total Loss: 4.4541, Feature Loss: 4.4541, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5380, Feature Loss: 3.5380, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 188
# 	Train:	Total Loss: 4.4114, Feature Loss: 4.4114, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5101, Feature Loss: 3.5101, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 189
# 	Train:	Total Loss: 4.7345, Feature Loss: 4.7345, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.4922, Feature Loss: 3.4922, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 190
# 	Train:	Total Loss: 4.2687, Feature Loss: 4.2687, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.4658, Feature Loss: 3.4658, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 191
# 	Train:	Total Loss: 4.2408, Feature Loss: 4.2408, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.4389, Feature Loss: 3.4389, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 192
# 	Train:	Total Loss: 4.2451, Feature Loss: 4.2451, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.4125, Feature Loss: 3.4125, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 193
# 	Train:	Total Loss: 4.3348, Feature Loss: 4.3348, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.3890, Feature Loss: 3.3890, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 194
# 	Train:	Total Loss: 4.4117, Feature Loss: 4.4117, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.3674, Feature Loss: 3.3674, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 195
# 	Train:	Total Loss: 4.2901, Feature Loss: 4.2901, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.3473, Feature Loss: 3.3473, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 196
# 	Train:	Total Loss: 4.2451, Feature Loss: 4.2451, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.3248, Feature Loss: 3.3248, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 197
# 	Train:	Total Loss: 4.1095, Feature Loss: 4.1095, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.3014, Feature Loss: 3.3014, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 198
# 	Train:	Total Loss: 4.0467, Feature Loss: 4.0467, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2784, Feature Loss: 3.2784, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 199
# 	Train:	Total Loss: 4.0529, Feature Loss: 4.0529, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2568, Feature Loss: 3.2568, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 200
# 	Train:	Total Loss: 4.2050, Feature Loss: 4.2050, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2376, Feature Loss: 3.2376, Type Loss: 0.0000 , LR: 0.000100

# %%
if not model_loaded:
    plt.figure(figsize=(14, 5))
    plt.plot(test_total_losses, label='Total Test Loss')
    plt.plot(train_total_losses, label='Total Train Loss')
    plt.legend()
    plt.title('Total Loss')
    plt.savefig("model2_totalloss.png")
    plt.show()

# %%
if not model_loaded:
    plt.figure(figsize=(14, 5))
    plt.plot(test_feature_losses, label='Test Feature Loss')
    plt.plot(train_feature_losses, label='Train Feature Loss')
    plt.legend()
    plt.title('Feature Loss')
    plt.savefig("model2_featureloss.png")
    plt.show()

# %%
test_loader_melt = DataLoader(graphs_melt, batch_size=1)
encoded_data_melt=[]
type_data_melt = []
for data in test_loader:
    model.eval()
    z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
    decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
    encoded_data_melt.append(z.detach().numpy())
    type_data_melt.append(str_type.detach().numpy())

encoded_data_melt = np.array(encoded_data_melt)
type_data_melt = np.array(type_data_melt)

# %%
test_loader_cry = DataLoader(graphs_cry, batch_size=1)
encoded_data_cry=[]
type_data_cry = []
for data in test_loader:
    model.eval()
    z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
    decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
    encoded_data_cry.append(z.detach().numpy())
    type_data_cry.append(str_type.detach().numpy())

encoded_data_cry = np.array(encoded_data_cry)
type_data_cry = np.array(type_data_cry)

# %%
# %matplotlib widget

frame = 10

fig = plt.figure(figsize=(15,4))
data_melt = encoded_data_melt[frame]

data_cry = encoded_data_cry[frame]
plt.scatter(data_melt[:,0],data_melt[:,1],c="r",label="melt")
plt.scatter(data_cry[:,0],data_cry[:,1],c="b",label="crystal")
plt.savefig("model2_scatter.png")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget

frame = 10

fig = plt.figure(figsize=(15,4))
data_melt = encoded_data_melt[frame]

data_cry = encoded_data_cry[frame]
# plt.scatter(data_melt[:,0],data_melt[:,1],c="r",label="melt")""
plt.scatter(data_cry[:,0],data_cry[:,1],c="b",label="crystal")
plt.savefig("model2_scatter.png")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
