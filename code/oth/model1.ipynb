# %%
import mdtraj as md
from ase import Atoms
import nglview as nv
import networkx as nx

import numpy as np
import matplotlib.pyplot as plt
import torch
from tqdm import tqdm

import torch_geometric.transforms as T
from torch_geometric.loader import DataLoader
from torch_geometric.nn import GCNConv, SAGPooling, InnerProductDecoder
import torch_geometric.data as data
from torch_geometric.utils.convert import to_networkx
import torch.optim.lr_scheduler as lr_scheduler
from torch.nn import Linear
import sys

# %%
all_frames_cry = md.load_xtc("../simulation/para_crystal.xtc", top="../simulation/para_crystal.gro")
all_frames_melt = md.load_xtc("../simulation/para_melt.xtc", top="../simulation/para_melt.gro")

# %%
all_frames_cry = all_frames_cry[::100]
all_frames_melt = all_frames_melt[::100]

# %%
n_frames = all_frames_cry.xyz.shape[0]
n_atoms = all_frames_cry.topology.residue(0).n_atoms
n_mols = all_frames_cry.topology.n_residues

# %%
def createGraph(all_frames,structure_type="crystal"):
    all_frames_fatures = []

    print("Creating Feature matrix")
    for i in tqdm(range(all_frames.xyz.shape[0])):
        mol_com_pos = []

        for res in all_frames.top.residues:
            pos = []
            for atom in res.atoms:
                pos.append(all_frames.xyz[i][atom.index])
            mol_com_pos.append(np.mean(pos,axis=0))
            
            # print()
        mol_com_pos = np.array(mol_com_pos).astype(np.float32)  
        all_frames_fatures.append(mol_com_pos)

    all_frames_fatures = np.array(all_frames_fatures).astype(np.float32)



    cutoff = 0.8

    print("Creating Edge list")
    all_edge_list = []
    # with open("edge_list.txt","w") as f:
    for frame_i in tqdm(range(n_frames)):
        from_list = []
        to_list = []

        for i in range(len(all_frames_fatures[frame_i])):
            for j in range(i+1,len(all_frames_fatures[frame_i])):
                if np.linalg.norm(all_frames_fatures[frame_i][i]-all_frames_fatures[frame_i][j]) < cutoff:
                    # f.write(str(i)+" "+str(j)+" "+str(np.linalg.norm(all_frames_fatures[frame_i][i]-all_frames_fatures[frame_i][j]))+"\n")
                    from_list.append(i)
                    to_list.append(j)

                    to_list.append(i)
                    from_list.append(j)

        edge_list = np.array([from_list,to_list]).astype(np.int64)
        all_edge_list.append(edge_list)
    print("creating Graphs")
    graphs = []
    for frame in tqdm(range(n_frames)):
        if structure_type == "crystal":
            g = data.Data(x=torch.tensor(all_frames_fatures[frame]).float(), edge_index=torch.tensor(all_edge_list[frame]).long(), y=torch.tensor([0]))
        else:
            g = data.Data(x=torch.tensor(all_frames_fatures[frame]).float(), edge_index=torch.tensor(all_edge_list[frame]).long(), y=torch.tensor([1]))
        graphs.append(g)
    return graphs

# %%
graphs_cry = createGraph(all_frames_cry,structure_type="crystal")
graphs_melt = createGraph(all_frames_melt,structure_type="melt")
# Out:
# Creating Feature matrix
# 100%|██████████| 51/51 [00:01<00:00, 43.31it/s]
# Creating Edge list
# 100%|██████████| 51/51 [00:53<00:00,  1.05s/it]
# creating Graphs
# 100%|██████████| 51/51 [00:00<00:00, 16478.66it/s]
# Creating Feature matrix
# 100%|██████████| 51/51 [00:00<00:00, 87.12it/s]
# Creating Edge list
# 100%|██████████| 51/51 [01:43<00:00,  2.03s/it]
# creating Graphs
# 100%|██████████| 51/51 [00:00<00:00, 8747.78it/s]

# %%
def convert_to_adj(edge_index, num_nodes=None):
    if num_nodes is None:
        num_nodes = edge_index.max() + 1
    adj = torch.zeros(num_nodes, num_nodes)
    adj[edge_index[0], edge_index[1]] = 1
    return adj

def convert_to_edge_index(adj):
    edge_index = adj.nonzero().t()
    return edge_index

# %%
graphs = graphs_cry + graphs_melt

# %%
# shuffle the graphs
np.random.shuffle(graphs)

# %%
graphs
# Out:
# [Data(x=[864, 3], edge_index=[2, 7080], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7008], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6400], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7056], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6582], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7218], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7192], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7092], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6542], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7240], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7034], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6544], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6512], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7006], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6560], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7122], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7088], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5982], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6476], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6964], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7086], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7020], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6012], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6990], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6548], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6586], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6630], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7078], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6566], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6564], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7116], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7128], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6934], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6546], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6992], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6488], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6584], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7306], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7090], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7012], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6532], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7006], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7048], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7100], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7274], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6570], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6508], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7096], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6452], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7078], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7028], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7036], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6288], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7064], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7076], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6592], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6464], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6070], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7052], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5892], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5962], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6596], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7294], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7048], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5876], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6580], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6056], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6578], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7132], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6524], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7374], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6608], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7146], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6066], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6552], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6560], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5822], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6548], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7054], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6508], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7060], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7024], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7116], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7074], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6554], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7094], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7044], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6558], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5862], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6626], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7060], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7092], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7108], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6546], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5880], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6602], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6214], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7052], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5910], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6018], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6172], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7026], y=[1])]

# %% [markdown]
# ## model

# %%
from typing import Optional, Tuple

import torch
from torch import Tensor
from torch.nn import Module

from torch_geometric.nn.inits import reset
from torch_geometric.utils import negative_sampling

EPS = 1e-15
MAX_LOGSTD = 10
edgeShape = None
featureShape = None


class InnerProductDecoder(torch.nn.Module):
    r"""The inner product decoder from the `"Variational Graph Auto-Encoders"
    <https://arxiv.org/abs/1611.07308>`_ paper

    .. math::
        \sigma(\mathbf{Z}\mathbf{Z}^{\top})

    where :math:`\mathbf{Z} \in \mathbb{R}^{N \times d}` denotes the latent
    space produced by the encoder."""

    def forward(self, z: Tensor, edge_index: Tensor,
                sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into edge probabilities for
        the given node-pairs :obj:`edge_index`.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        value = (z[edge_index[0]] * z[edge_index[1]]).sum(dim=1)
        return torch.sigmoid(value) if sigmoid else value

    def forward_all(self, z: Tensor, sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into a probabilistic dense
        adjacency matrix.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        adj = torch.matmul(z, z.t())
        return torch.sigmoid(adj) if sigmoid else adj


class GAE(torch.nn.Module):
    r"""The Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper based on user-defined encoder and decoder models.

    Args:
        encoder (torch.nn.Module): The encoder module.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__()
        self.encoder = encoder
        self.decoder = InnerProductDecoder() if decoder is None else decoder
        GAE.reset_parameters(self)

    def reset_parameters(self):
        r"""Resets all learnable parameters of the module."""
        reset(self.encoder)
        reset(self.decoder)

    def forward(self, *args, **kwargs) -> Tensor:  # pragma: no cover
        r"""Alias for :meth:`encode`."""
        return self.encoder(*args, **kwargs)

    def encode(self, *args, **kwargs) -> Tensor:
        r"""Runs the encoder and computes node-wise latent variables."""
        return self.encoder(*args, **kwargs)

    def decode(self, *args, **kwargs) -> Tensor:
        r"""Runs the decoder and computes edge probabilities."""
        return self.decoder(*args, **kwargs)

    def recon_loss(self, z: Tensor, pos_edge_index: Tensor,
                   neg_edge_index: Optional[Tensor] = None) -> Tensor:
        r"""Given latent variables :obj:`z`, computes the binary cross
        entropy loss for positive edges :obj:`pos_edge_index` and negative
        sampled edges.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to train against.
            neg_edge_index (torch.Tensor, optional): The negative edges to
                train against. If not given, uses negative sampling to
                calculate negative edges. (default: :obj:`None`)
        """
        pos_loss = -torch.log(
            self.decoder(z, pos_edge_index, sigmoid=True)[0] + EPS).mean()

        if neg_edge_index is None:
            neg_edge_index = negative_sampling(pos_edge_index, z.size(0))
        neg_loss = -torch.log(1 -
                              self.decoder(z, neg_edge_index.long(), sigmoid=True)[0] +
                              EPS).mean()

        return pos_loss + neg_loss

    def test(self, z: Tensor, pos_edge_index: Tensor,
             neg_edge_index: Tensor) -> Tuple[Tensor, Tensor]:
        r"""Given latent variables :obj:`z`, positive edges
        :obj:`pos_edge_index` and negative edges :obj:`neg_edge_index`,
        computes area under the ROC curve (AUC) and average precision (AP)
        
        scores.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to evaluate
                against.
            neg_edge_index (torch.Tensor): The negative edges to evaluate
                against.
        """
        from sklearn.metrics import average_precision_score, roc_auc_score

        pos_y = z.new_ones(pos_edge_index.size(1))
        neg_y = z.new_zeros(neg_edge_index.size(1))
        y = torch.cat([pos_y, neg_y], dim=0)

        pos_pred = self.decoder(z, pos_edge_index, sigmoid=True)
        neg_pred = self.decoder(z, neg_edge_index, sigmoid=True)
        pred = torch.cat([pos_pred, neg_pred], dim=0)

        y, pred = y.detach().cpu().numpy(), pred.detach().cpu().numpy()

        return roc_auc_score(y, pred), average_precision_score(y, pred)


class VGAE(GAE):
    r"""The Variational Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper.

    Args:
        encoder (torch.nn.Module): The encoder module to compute :math:`\mu`
            and :math:`\log\sigma^2`.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__(encoder, decoder)

    def reparametrize(self, mu: Tensor, logstd: Tensor) -> Tensor:
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def encode(self, *args, **kwargs) -> Tensor:
        """"""
        z, self.edge_index = self.encoder(
            *args, **kwargs)
        
        return z, self.edge_index

    def kl_loss(self, mu: Optional[Tensor] = None,
                logstd: Optional[Tensor] = None) -> Tensor:
        r"""Computes the KL loss, either for the passed arguments :obj:`mu`
        and :obj:`logstd`, or based on latent variables from last encoding.

        Args:
            mu (torch.Tensor, optional): The latent space for :math:`\mu`. If
                set to :obj:`None`, uses the last computation of :math:`\mu`.
                (default: :obj:`None`)
            logstd (torch.Tensor, optional): The latent space for
                :math:`\log\sigma`.  If set to :obj:`None`, uses the last
                computation of :math:`\log\sigma^2`. (default: :obj:`None`)
        """
        mu = self.__mu__ if mu is None else mu
        logstd = self.__logstd__ if logstd is None else logstd.clamp(
            max=MAX_LOGSTD)
        return -0.5 * torch.mean(
            torch.sum(1 + 2 * logstd - mu**2 - logstd.exp()**2, dim=1))

# %%
import torch.nn.functional as F



class VariationalGCNEncoder(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__() # changes made such that guassian is 1 
        self.conv1 = GCNConv(in_channels, 2*out_channels)
        self.conv2 = GCNConv(2*out_channels, 1 * out_channels)
        self.pool = SAGPooling(out_channels, 0.5)
        
        self.conv_mu = GCNConv(1 * out_channels, out_channels)
        self.conv_logstd = GCNConv(1 * out_channels, out_channels)
    def reparametrize(self, mu: Tensor, logstd: Tensor) -> Tensor:
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def forward(self, x, edge_index,class_label):
        # print("input:",x.shape, edge_index.shape)
        x = self.conv1(x, edge_index)
        x = F.silu(x)
        # print("conv1:",x.shape, edge_index.shape)
        x = self.conv2(x, edge_index)
        x = F.silu(x)
        # print("conv2:",x.shape, edge_index.shape)

        sample = self.reparametrize(self.conv_mu(x, edge_index), self.conv_logstd(x, edge_index))
        sample = self.reparametrize(self.conv_mu(sample, edge_index), self.conv_logstd(sample, edge_index))
        # self.conv_mu_crystal.train(True)
        # self.conv_logstd_crystal.train(True)
        # self.conv_mu_melt.train(True)
        # self.conv_logstd_melt.train(True)
        self.conv_mu.train(True)
        self.conv_logstd.train(True)
        return sample, edge_index

# %%
class VariationalGCNDecoder(torch.nn.Module):
    def __init__(self,in_channels,out_channels):
        super().__init__()
        self.type_layer1 = Linear(1728,200)
        self.dropout = torch.nn.Dropout(0.5)
        self.type_layer2 = Linear(200,2)
        self.conv1 = GCNConv(in_channels,2*out_channels)
        self.conv2 = GCNConv(2*out_channels, 1 * out_channels)
    def forward(self, x, edge_index, sigmoid=True):
        # print("input:",x.shape, edge_index.shape)
        flat = x.flatten()
        flat = self.type_layer1(flat).relu()
        flat = self.dropout(flat)
        str_type = F.softmax(self.type_layer2(flat).relu(),dim=0)
         
        x = self.conv1(x, edge_index)
        x = F.silu(x)
        # print("conv1:",x.shape, edge_index.shape)
        x = self.conv2(x, edge_index)
        x = F.silu(x)
        # print("conv2:",x.shape, edge_index.shape)
        return x, edge_index,str_type

# %%
import os
in_channels = graphs[0].num_features
out_channels = 2
lr = 1e-4
n_epochs = 200
batch_size=1
test_train_split = 0.8
model_name = "_model1_.pt"
model_loaded = False
force_train = True  

if os.path.exists("./models/"+model_name) and not force_train:
    model = torch.load("./models/"+model_name)
    model_loaded = True
else:
    model = VGAE(VariationalGCNEncoder(in_channels, out_channels),
                VariationalGCNDecoder(out_channels, in_channels))

optimizer = torch.optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, step_size=300, gamma=0.5)

# %%
train_loader = DataLoader(graphs[:int(n_frames*test_train_split)], batch_size=batch_size, shuffle=True)
test_loader = DataLoader(graphs[int(n_frames*test_train_split):], batch_size=batch_size, shuffle=True)

# %%
lossFxn = torch.nn.MSELoss()
typeLossFxn = torch.nn.CrossEntropyLoss()

def train():
    model.train()
    model.zero_grad()
    model.float()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0
    type_loss_all = 0
    for data in train_loader:
        optimizer.zero_grad()
        z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
        decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)

     
        # TypeLoss = typeLossFxn(str_type.unsqueeze(0), data.y)
        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        loss = FeatureLoss + EdgeLoss 

        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        # type_loss_all += float(TypeLoss)

        loss.backward()
        optimizer.step()
        

    return loss_all / len(train_loader), feature_loss_all / len(train_loader), edge_loss_all / len(train_loader), kl_loss_all / len(train_loader), type_loss_all / len(train_loader)

# %%
lossFxn = torch.nn.MSELoss()
def test():
    model.eval()
    model.zero_grad()
    model.float()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0
    type_loss_all = 0

    for data in test_loader:
        optimizer.zero_grad()
        z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
        decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
        
        # TypeLoss = typeLossFxn(str_type.unsqueeze(0), data.y)
        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        loss = FeatureLoss + EdgeLoss 

        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        # type_loss_all += float(TypeLoss)
        
        
        

    return loss_all / len(test_loader), feature_loss_all / len(test_loader), edge_loss_all / len(test_loader), kl_loss_all / len(test_loader), type_loss_all / len(test_loader)

# %%
train_total_losses = []
train_feature_losses = []
train_edge_losses = []
train_kl_losses = []
train_type_losses = []

test_total_losses = []
test_feature_losses = []
test_edge_losses = []
test_kl_losses = []
test_type_losses = []

if model_loaded:        
    print("Pretrained Model Loaded, no training required")
else:
    for epoch in range(1, n_epochs + 1):
        
        train_total_loss, train_feature_loss, train_edge_loss, train_kl_loss,train_type_loss = train()
        test_total_loss, test_feature_loss, test_edge_loss, test_kl_loss, test_type_loss= test()
        
        print(f"Epoch: {epoch:03d}")
        print(f'\tTrain:\tTotal Loss: {train_total_loss:.4f}, Feature Loss: {train_feature_loss:.4f}, Type Loss: {train_type_loss:.4f} ,  LR: {scheduler.get_last_lr()[0]:.6f}')
        print(f'\tTest: \tTotal Loss: {test_total_loss:.4f}, Feature Loss: {test_feature_loss:.4f}, Type Loss: {test_type_loss:.4f} , LR: {scheduler.get_last_lr()[0]:.6f}')
        
        
        train_total_losses.append(train_total_loss)
        train_feature_losses.append(train_feature_loss)
        train_edge_losses.append(train_edge_loss)
        train_kl_losses.append(train_kl_loss)
        train_type_losses.append(train_type_loss)


        test_total_losses.append(test_total_loss)
        test_feature_losses.append(test_feature_loss)
        test_edge_losses.append(test_edge_loss)
        test_kl_losses.append(test_kl_loss)
        test_type_losses.append(test_type_loss)
        
        scheduler.step()
    torch.save(model,"./models/"+model_name)
# Out:
# Epoch: 001
# 	Train:	Total Loss: 11.6359, Feature Loss: 11.6359, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1908, Feature Loss: 13.1908, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 002
# 	Train:	Total Loss: 11.5565, Feature Loss: 11.5565, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1469, Feature Loss: 13.1469, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 003
# 	Train:	Total Loss: 11.5391, Feature Loss: 11.5391, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.1002, Feature Loss: 13.1002, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 004
# 	Train:	Total Loss: 11.4694, Feature Loss: 11.4694, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 13.0496, Feature Loss: 13.0496, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 005
# 	Train:	Total Loss: 11.4072, Feature Loss: 11.4072, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.9951, Feature Loss: 12.9951, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 006
# 	Train:	Total Loss: 11.3550, Feature Loss: 11.3550, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.9365, Feature Loss: 12.9365, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 007
# 	Train:	Total Loss: 11.2923, Feature Loss: 11.2923, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.8737, Feature Loss: 12.8737, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 008
# 	Train:	Total Loss: 11.2255, Feature Loss: 11.2255, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.8045, Feature Loss: 12.8045, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 009
# 	Train:	Total Loss: 11.1276, Feature Loss: 11.1276, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.7307, Feature Loss: 12.7307, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 010
# 	Train:	Total Loss: 11.0609, Feature Loss: 11.0609, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.6507, Feature Loss: 12.6507, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 011
# 	Train:	Total Loss: 10.9870, Feature Loss: 10.9870, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.5665, Feature Loss: 12.5665, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 012
# 	Train:	Total Loss: 10.9740, Feature Loss: 10.9740, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.4822, Feature Loss: 12.4822, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 013
# 	Train:	Total Loss: 10.7999, Feature Loss: 10.7999, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.3911, Feature Loss: 12.3911, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 014
# 	Train:	Total Loss: 10.7319, Feature Loss: 10.7319, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.2929, Feature Loss: 12.2929, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 015
# 	Train:	Total Loss: 10.6388, Feature Loss: 10.6388, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.1899, Feature Loss: 12.1899, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 016
# 	Train:	Total Loss: 10.4579, Feature Loss: 10.4579, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0805, Feature Loss: 12.0805, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 017
# 	Train:	Total Loss: 10.4468, Feature Loss: 10.4468, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.9670, Feature Loss: 11.9670, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 018
# 	Train:	Total Loss: 10.2702, Feature Loss: 10.2702, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.8465, Feature Loss: 11.8465, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 019
# 	Train:	Total Loss: 10.1152, Feature Loss: 10.1152, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.7163, Feature Loss: 11.7163, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 020
# 	Train:	Total Loss: 10.0640, Feature Loss: 10.0640, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.5834, Feature Loss: 11.5834, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 021
# 	Train:	Total Loss: 9.8437, Feature Loss: 9.8437, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.4438, Feature Loss: 11.4438, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 022
# 	Train:	Total Loss: 9.7172, Feature Loss: 9.7172, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.2958, Feature Loss: 11.2958, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 023
# 	Train:	Total Loss: 9.5862, Feature Loss: 9.5862, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.1455, Feature Loss: 11.1455, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 024
# 	Train:	Total Loss: 9.4496, Feature Loss: 9.4496, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.9878, Feature Loss: 10.9878, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 025
# 	Train:	Total Loss: 9.3361, Feature Loss: 9.3361, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.8274, Feature Loss: 10.8274, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 026
# 	Train:	Total Loss: 9.1724, Feature Loss: 9.1724, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.6637, Feature Loss: 10.6637, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 027
# 	Train:	Total Loss: 8.9868, Feature Loss: 8.9868, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.4933, Feature Loss: 10.4933, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 028
# 	Train:	Total Loss: 9.0016, Feature Loss: 9.0016, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.3267, Feature Loss: 10.3267, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 029
# 	Train:	Total Loss: 8.6960, Feature Loss: 8.6960, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.1458, Feature Loss: 10.1458, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 030
# 	Train:	Total Loss: 8.6958, Feature Loss: 8.6958, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.9688, Feature Loss: 9.9688, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 031
# 	Train:	Total Loss: 8.5263, Feature Loss: 8.5263, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.7846, Feature Loss: 9.7846, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 032
# 	Train:	Total Loss: 8.4165, Feature Loss: 8.4165, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.6043, Feature Loss: 9.6043, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 033
# 	Train:	Total Loss: 8.2924, Feature Loss: 8.2924, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.4214, Feature Loss: 9.4214, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 034
# 	Train:	Total Loss: 8.1155, Feature Loss: 8.1155, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.2311, Feature Loss: 9.2311, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 035
# 	Train:	Total Loss: 7.9811, Feature Loss: 7.9811, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.0445, Feature Loss: 9.0445, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 036
# 	Train:	Total Loss: 7.8497, Feature Loss: 7.8497, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.8543, Feature Loss: 8.8543, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 037
# 	Train:	Total Loss: 10.0959, Feature Loss: 10.0959, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.7641, Feature Loss: 8.7641, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 038
# 	Train:	Total Loss: 7.6363, Feature Loss: 7.6363, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.6458, Feature Loss: 8.6458, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 039
# 	Train:	Total Loss: 7.9395, Feature Loss: 7.9395, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.5305, Feature Loss: 8.5305, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 040
# 	Train:	Total Loss: 7.4074, Feature Loss: 7.4074, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.4039, Feature Loss: 8.4039, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 041
# 	Train:	Total Loss: 7.2948, Feature Loss: 7.2948, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.2736, Feature Loss: 8.2736, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 042
# 	Train:	Total Loss: 7.2042, Feature Loss: 7.2042, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.1415, Feature Loss: 8.1415, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 043
# 	Train:	Total Loss: 7.1044, Feature Loss: 7.1044, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.0093, Feature Loss: 8.0093, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 044
# 	Train:	Total Loss: 6.9663, Feature Loss: 6.9663, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.8756, Feature Loss: 7.8756, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 045
# 	Train:	Total Loss: 6.8984, Feature Loss: 6.8984, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.7407, Feature Loss: 7.7407, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 046
# 	Train:	Total Loss: 6.6710, Feature Loss: 6.6710, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.6057, Feature Loss: 7.6057, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 047
# 	Train:	Total Loss: 6.5905, Feature Loss: 6.5905, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.4667, Feature Loss: 7.4667, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 048
# 	Train:	Total Loss: 6.5999, Feature Loss: 6.5999, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.3309, Feature Loss: 7.3309, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 049
# 	Train:	Total Loss: 6.3523, Feature Loss: 6.3523, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.1936, Feature Loss: 7.1936, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 050
# 	Train:	Total Loss: 6.5858, Feature Loss: 6.5858, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.0592, Feature Loss: 7.0592, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 051
# 	Train:	Total Loss: 6.3036, Feature Loss: 6.3036, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.9250, Feature Loss: 6.9250, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 052
# 	Train:	Total Loss: 6.3219, Feature Loss: 6.3219, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.7948, Feature Loss: 6.7948, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 053
# 	Train:	Total Loss: 6.1977, Feature Loss: 6.1977, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.6632, Feature Loss: 6.6632, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 054
# 	Train:	Total Loss: 6.0790, Feature Loss: 6.0790, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.5347, Feature Loss: 6.5347, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 055
# 	Train:	Total Loss: 5.8600, Feature Loss: 5.8600, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.4034, Feature Loss: 6.4034, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 056
# 	Train:	Total Loss: 5.8719, Feature Loss: 5.8719, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.2822, Feature Loss: 6.2822, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 057
# 	Train:	Total Loss: 5.7995, Feature Loss: 5.7995, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.1571, Feature Loss: 6.1571, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 058
# 	Train:	Total Loss: 5.6826, Feature Loss: 5.6826, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.0409, Feature Loss: 6.0409, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 059
# 	Train:	Total Loss: 5.6108, Feature Loss: 5.6108, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.9230, Feature Loss: 5.9230, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 060
# 	Train:	Total Loss: 5.4909, Feature Loss: 5.4909, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.8092, Feature Loss: 5.8092, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 061
# 	Train:	Total Loss: 5.4723, Feature Loss: 5.4723, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.7023, Feature Loss: 5.7023, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 062
# 	Train:	Total Loss: 5.4203, Feature Loss: 5.4203, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.6018, Feature Loss: 5.6018, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 063
# 	Train:	Total Loss: 5.4239, Feature Loss: 5.4239, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.5043, Feature Loss: 5.5043, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 064
# 	Train:	Total Loss: 5.3075, Feature Loss: 5.3075, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.4010, Feature Loss: 5.4010, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 065
# 	Train:	Total Loss: 5.2537, Feature Loss: 5.2537, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.3068, Feature Loss: 5.3068, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 066
# 	Train:	Total Loss: 5.1678, Feature Loss: 5.1678, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.2171, Feature Loss: 5.2171, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 067
# 	Train:	Total Loss: 5.0806, Feature Loss: 5.0806, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.1303, Feature Loss: 5.1303, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 068
# 	Train:	Total Loss: 5.0594, Feature Loss: 5.0594, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.0490, Feature Loss: 5.0490, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 069
# 	Train:	Total Loss: 5.0245, Feature Loss: 5.0245, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.9660, Feature Loss: 4.9660, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 070
# 	Train:	Total Loss: 9.3455, Feature Loss: 9.3455, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.9557, Feature Loss: 4.9557, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 071
# 	Train:	Total Loss: 4.9742, Feature Loss: 4.9742, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.9013, Feature Loss: 4.9013, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 072
# 	Train:	Total Loss: 4.9454, Feature Loss: 4.9454, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.8542, Feature Loss: 4.8542, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 073
# 	Train:	Total Loss: 4.7641, Feature Loss: 4.7641, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.8030, Feature Loss: 4.8030, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 074
# 	Train:	Total Loss: 4.8125, Feature Loss: 4.8125, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.7484, Feature Loss: 4.7484, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 075
# 	Train:	Total Loss: 4.9945, Feature Loss: 4.9945, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.7044, Feature Loss: 4.7044, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 076
# 	Train:	Total Loss: 4.7280, Feature Loss: 4.7280, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.6604, Feature Loss: 4.6604, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 077
# 	Train:	Total Loss: 4.7197, Feature Loss: 4.7197, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.6175, Feature Loss: 4.6175, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 078
# 	Train:	Total Loss: 4.7674, Feature Loss: 4.7674, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.5776, Feature Loss: 4.5776, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 079
# 	Train:	Total Loss: 4.7834, Feature Loss: 4.7834, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.5363, Feature Loss: 4.5363, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 080
# 	Train:	Total Loss: 4.6680, Feature Loss: 4.6680, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.4970, Feature Loss: 4.4970, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 081
# 	Train:	Total Loss: 4.7457, Feature Loss: 4.7457, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.4559, Feature Loss: 4.4559, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 082
# 	Train:	Total Loss: 4.5360, Feature Loss: 4.5360, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.4206, Feature Loss: 4.4206, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 083
# 	Train:	Total Loss: 4.7027, Feature Loss: 4.7027, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.3888, Feature Loss: 4.3888, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 084
# 	Train:	Total Loss: 4.6066, Feature Loss: 4.6066, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.3555, Feature Loss: 4.3555, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 085
# 	Train:	Total Loss: 4.7731, Feature Loss: 4.7731, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.3275, Feature Loss: 4.3275, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 086
# 	Train:	Total Loss: 4.5757, Feature Loss: 4.5757, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.2986, Feature Loss: 4.2986, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 087
# 	Train:	Total Loss: 4.5907, Feature Loss: 4.5907, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.2762, Feature Loss: 4.2762, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 088
# 	Train:	Total Loss: 4.5430, Feature Loss: 4.5430, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.2527, Feature Loss: 4.2527, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 089
# 	Train:	Total Loss: 4.7824, Feature Loss: 4.7824, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.2323, Feature Loss: 4.2323, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 090
# 	Train:	Total Loss: 4.5242, Feature Loss: 4.5242, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.2094, Feature Loss: 4.2094, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 091
# 	Train:	Total Loss: 4.5235, Feature Loss: 4.5235, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.1909, Feature Loss: 4.1909, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 092
# 	Train:	Total Loss: 4.5053, Feature Loss: 4.5053, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.1707, Feature Loss: 4.1707, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 093
# 	Train:	Total Loss: 4.3297, Feature Loss: 4.3297, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.1545, Feature Loss: 4.1545, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 094
# 	Train:	Total Loss: 4.5413, Feature Loss: 4.5413, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.1346, Feature Loss: 4.1346, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 095
# 	Train:	Total Loss: 4.5100, Feature Loss: 4.5100, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.1186, Feature Loss: 4.1186, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 096
# 	Train:	Total Loss: 4.3657, Feature Loss: 4.3657, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.0997, Feature Loss: 4.0997, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 097
# 	Train:	Total Loss: 4.5260, Feature Loss: 4.5260, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.0817, Feature Loss: 4.0817, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 098
# 	Train:	Total Loss: 4.4537, Feature Loss: 4.4537, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.0656, Feature Loss: 4.0656, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 099
# 	Train:	Total Loss: 4.7471, Feature Loss: 4.7471, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.0516, Feature Loss: 4.0516, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 100
# 	Train:	Total Loss: 4.3810, Feature Loss: 4.3810, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.0383, Feature Loss: 4.0383, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 101
# 	Train:	Total Loss: 4.4629, Feature Loss: 4.4629, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.0298, Feature Loss: 4.0298, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 102
# 	Train:	Total Loss: 4.3827, Feature Loss: 4.3827, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.0216, Feature Loss: 4.0216, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 103
# 	Train:	Total Loss: 4.3012, Feature Loss: 4.3012, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.0036, Feature Loss: 4.0036, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 104
# 	Train:	Total Loss: 4.6984, Feature Loss: 4.6984, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.9998, Feature Loss: 3.9998, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 105
# 	Train:	Total Loss: 4.3216, Feature Loss: 4.3216, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.9861, Feature Loss: 3.9861, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 106
# 	Train:	Total Loss: 4.3039, Feature Loss: 4.3039, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.9753, Feature Loss: 3.9753, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 107
# 	Train:	Total Loss: 4.3135, Feature Loss: 4.3135, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.9646, Feature Loss: 3.9646, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 108
# 	Train:	Total Loss: 4.2919, Feature Loss: 4.2919, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.9531, Feature Loss: 3.9531, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 109
# 	Train:	Total Loss: 4.3237, Feature Loss: 4.3237, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.9419, Feature Loss: 3.9419, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 110
# 	Train:	Total Loss: 4.4110, Feature Loss: 4.4110, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.9355, Feature Loss: 3.9355, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 111
# 	Train:	Total Loss: 4.2434, Feature Loss: 4.2434, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.9311, Feature Loss: 3.9311, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 112
# 	Train:	Total Loss: 4.3064, Feature Loss: 4.3064, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.9240, Feature Loss: 3.9240, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 113
# 	Train:	Total Loss: 4.2807, Feature Loss: 4.2807, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.9145, Feature Loss: 3.9145, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 114
# 	Train:	Total Loss: 4.1956, Feature Loss: 4.1956, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.9070, Feature Loss: 3.9070, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 115
# 	Train:	Total Loss: 4.3873, Feature Loss: 4.3873, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.9012, Feature Loss: 3.9012, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 116
# 	Train:	Total Loss: 4.4073, Feature Loss: 4.4073, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8944, Feature Loss: 3.8944, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 117
# 	Train:	Total Loss: 4.2389, Feature Loss: 4.2389, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8868, Feature Loss: 3.8868, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 118
# 	Train:	Total Loss: 4.1623, Feature Loss: 4.1623, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8876, Feature Loss: 3.8876, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 119
# 	Train:	Total Loss: 4.2968, Feature Loss: 4.2968, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8805, Feature Loss: 3.8805, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 120
# 	Train:	Total Loss: 4.2155, Feature Loss: 4.2155, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8703, Feature Loss: 3.8703, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 121
# 	Train:	Total Loss: 4.1385, Feature Loss: 4.1385, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8600, Feature Loss: 3.8600, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 122
# 	Train:	Total Loss: 4.2991, Feature Loss: 4.2991, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8587, Feature Loss: 3.8587, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 123
# 	Train:	Total Loss: 4.1585, Feature Loss: 4.1585, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8546, Feature Loss: 3.8546, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 124
# 	Train:	Total Loss: 4.1317, Feature Loss: 4.1317, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8459, Feature Loss: 3.8459, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 125
# 	Train:	Total Loss: 4.2778, Feature Loss: 4.2778, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8416, Feature Loss: 3.8416, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 126
# 	Train:	Total Loss: 4.3351, Feature Loss: 4.3351, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8476, Feature Loss: 3.8476, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 127
# 	Train:	Total Loss: 4.3991, Feature Loss: 4.3991, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8496, Feature Loss: 3.8496, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 128
# 	Train:	Total Loss: 4.1361, Feature Loss: 4.1361, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8445, Feature Loss: 3.8445, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 129
# 	Train:	Total Loss: 4.1663, Feature Loss: 4.1663, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8381, Feature Loss: 3.8381, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 130
# 	Train:	Total Loss: 4.2936, Feature Loss: 4.2936, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8301, Feature Loss: 3.8301, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 131
# 	Train:	Total Loss: 4.4808, Feature Loss: 4.4808, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8307, Feature Loss: 3.8307, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 132
# 	Train:	Total Loss: 4.1134, Feature Loss: 4.1134, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8237, Feature Loss: 3.8237, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 133
# 	Train:	Total Loss: 4.1167, Feature Loss: 4.1167, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8212, Feature Loss: 3.8212, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 134
# 	Train:	Total Loss: 4.1599, Feature Loss: 4.1599, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8103, Feature Loss: 3.8103, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 135
# 	Train:	Total Loss: 4.0689, Feature Loss: 4.0689, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8058, Feature Loss: 3.8058, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 136
# 	Train:	Total Loss: 4.0330, Feature Loss: 4.0330, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7956, Feature Loss: 3.7956, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 137
# 	Train:	Total Loss: 4.0905, Feature Loss: 4.0905, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7883, Feature Loss: 3.7883, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 138
# 	Train:	Total Loss: 4.0897, Feature Loss: 4.0897, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7838, Feature Loss: 3.7838, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 139
# 	Train:	Total Loss: 3.9840, Feature Loss: 3.9840, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7835, Feature Loss: 3.7835, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 140
# 	Train:	Total Loss: 4.0719, Feature Loss: 4.0719, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7814, Feature Loss: 3.7814, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 141
# 	Train:	Total Loss: 3.9810, Feature Loss: 3.9810, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7715, Feature Loss: 3.7715, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 142
# 	Train:	Total Loss: 3.9947, Feature Loss: 3.9947, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7681, Feature Loss: 3.7681, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 143
# 	Train:	Total Loss: 4.0862, Feature Loss: 4.0862, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7610, Feature Loss: 3.7610, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 144
# 	Train:	Total Loss: 3.9813, Feature Loss: 3.9813, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7541, Feature Loss: 3.7541, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 145
# 	Train:	Total Loss: 4.0665, Feature Loss: 4.0665, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7503, Feature Loss: 3.7503, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 146
# 	Train:	Total Loss: 4.0289, Feature Loss: 4.0289, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7476, Feature Loss: 3.7476, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 147
# 	Train:	Total Loss: 4.0395, Feature Loss: 4.0395, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7410, Feature Loss: 3.7410, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 148
# 	Train:	Total Loss: 3.9651, Feature Loss: 3.9651, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7387, Feature Loss: 3.7387, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 149
# 	Train:	Total Loss: 3.9196, Feature Loss: 3.9196, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7370, Feature Loss: 3.7370, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 150
# 	Train:	Total Loss: 3.9648, Feature Loss: 3.9648, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7337, Feature Loss: 3.7337, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 151
# 	Train:	Total Loss: 3.9652, Feature Loss: 3.9652, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7251, Feature Loss: 3.7251, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 152
# 	Train:	Total Loss: 3.9008, Feature Loss: 3.9008, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7244, Feature Loss: 3.7244, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 153
# 	Train:	Total Loss: 3.9330, Feature Loss: 3.9330, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7176, Feature Loss: 3.7176, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 154
# 	Train:	Total Loss: 3.8689, Feature Loss: 3.8689, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7030, Feature Loss: 3.7030, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 155
# 	Train:	Total Loss: 3.8841, Feature Loss: 3.8841, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7010, Feature Loss: 3.7010, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 156
# 	Train:	Total Loss: 3.9137, Feature Loss: 3.9137, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7016, Feature Loss: 3.7016, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 157
# 	Train:	Total Loss: 3.9387, Feature Loss: 3.9387, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6910, Feature Loss: 3.6910, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 158
# 	Train:	Total Loss: 3.9067, Feature Loss: 3.9067, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6836, Feature Loss: 3.6836, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 159
# 	Train:	Total Loss: 3.8455, Feature Loss: 3.8455, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6810, Feature Loss: 3.6810, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 160
# 	Train:	Total Loss: 3.9626, Feature Loss: 3.9626, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6772, Feature Loss: 3.6772, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 161
# 	Train:	Total Loss: 3.9787, Feature Loss: 3.9787, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6804, Feature Loss: 3.6804, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 162
# 	Train:	Total Loss: 3.8696, Feature Loss: 3.8696, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6734, Feature Loss: 3.6734, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 163
# 	Train:	Total Loss: 3.8435, Feature Loss: 3.8435, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6746, Feature Loss: 3.6746, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 164
# 	Train:	Total Loss: 4.0006, Feature Loss: 4.0006, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6728, Feature Loss: 3.6728, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 165
# 	Train:	Total Loss: 3.8381, Feature Loss: 3.8381, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6678, Feature Loss: 3.6678, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 166
# 	Train:	Total Loss: 3.7768, Feature Loss: 3.7768, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6600, Feature Loss: 3.6600, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 167
# 	Train:	Total Loss: 3.8362, Feature Loss: 3.8362, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6562, Feature Loss: 3.6562, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 168
# 	Train:	Total Loss: 3.8224, Feature Loss: 3.8224, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6546, Feature Loss: 3.6546, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 169
# 	Train:	Total Loss: 3.8216, Feature Loss: 3.8216, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6533, Feature Loss: 3.6533, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 170
# 	Train:	Total Loss: 3.7099, Feature Loss: 3.7099, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6444, Feature Loss: 3.6444, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 171
# 	Train:	Total Loss: 3.8362, Feature Loss: 3.8362, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6391, Feature Loss: 3.6391, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 172
# 	Train:	Total Loss: 3.7977, Feature Loss: 3.7977, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6347, Feature Loss: 3.6347, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 173
# 	Train:	Total Loss: 3.7092, Feature Loss: 3.7092, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6294, Feature Loss: 3.6294, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 174
# 	Train:	Total Loss: 3.7583, Feature Loss: 3.7583, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6238, Feature Loss: 3.6238, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 175
# 	Train:	Total Loss: 3.8359, Feature Loss: 3.8359, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6189, Feature Loss: 3.6189, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 176
# 	Train:	Total Loss: 3.7947, Feature Loss: 3.7947, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6149, Feature Loss: 3.6149, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 177
# 	Train:	Total Loss: 3.7218, Feature Loss: 3.7218, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6101, Feature Loss: 3.6101, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 178
# 	Train:	Total Loss: 3.7258, Feature Loss: 3.7258, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6084, Feature Loss: 3.6084, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 179
# 	Train:	Total Loss: 3.6414, Feature Loss: 3.6414, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6030, Feature Loss: 3.6030, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 180
# 	Train:	Total Loss: 3.6566, Feature Loss: 3.6566, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5914, Feature Loss: 3.5914, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 181
# 	Train:	Total Loss: 3.6815, Feature Loss: 3.6815, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5891, Feature Loss: 3.5891, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 182
# 	Train:	Total Loss: 3.6891, Feature Loss: 3.6891, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5868, Feature Loss: 3.5868, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 183
# 	Train:	Total Loss: 3.6446, Feature Loss: 3.6446, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5812, Feature Loss: 3.5812, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 184
# 	Train:	Total Loss: 3.7154, Feature Loss: 3.7154, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5682, Feature Loss: 3.5682, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 185
# 	Train:	Total Loss: 3.6578, Feature Loss: 3.6578, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5692, Feature Loss: 3.5692, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 186
# 	Train:	Total Loss: 3.6721, Feature Loss: 3.6721, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5680, Feature Loss: 3.5680, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 187
# 	Train:	Total Loss: 3.6017, Feature Loss: 3.6017, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5635, Feature Loss: 3.5635, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 188
# 	Train:	Total Loss: 3.8385, Feature Loss: 3.8385, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5680, Feature Loss: 3.5680, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 189
# 	Train:	Total Loss: 3.5689, Feature Loss: 3.5689, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5610, Feature Loss: 3.5610, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 190
# 	Train:	Total Loss: 3.5984, Feature Loss: 3.5984, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5516, Feature Loss: 3.5516, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 191
# 	Train:	Total Loss: 3.5417, Feature Loss: 3.5417, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5511, Feature Loss: 3.5511, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 192
# 	Train:	Total Loss: 3.5939, Feature Loss: 3.5939, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5475, Feature Loss: 3.5475, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 193
# 	Train:	Total Loss: 3.5896, Feature Loss: 3.5896, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5392, Feature Loss: 3.5392, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 194
# 	Train:	Total Loss: 3.5990, Feature Loss: 3.5990, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5252, Feature Loss: 3.5252, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 195
# 	Train:	Total Loss: 3.6021, Feature Loss: 3.6021, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5192, Feature Loss: 3.5192, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 196
# 	Train:	Total Loss: 3.6123, Feature Loss: 3.6123, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5131, Feature Loss: 3.5131, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 197
# 	Train:	Total Loss: 3.4863, Feature Loss: 3.4863, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5115, Feature Loss: 3.5115, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 198
# 	Train:	Total Loss: 3.5110, Feature Loss: 3.5110, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.4971, Feature Loss: 3.4971, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 199
# 	Train:	Total Loss: 3.5215, Feature Loss: 3.5215, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.4881, Feature Loss: 3.4881, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 200
# 	Train:	Total Loss: 3.6086, Feature Loss: 3.6086, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.4827, Feature Loss: 3.4827, Type Loss: 0.0000 , LR: 0.000100

# %%
if not model_loaded:
    plt.figure(figsize=(14, 5))
    plt.plot(test_total_losses, label='Total Test Loss')
    plt.plot(train_total_losses, label='Total Train Loss')
    plt.legend()
    plt.title('Total Loss')
    plt.savefig("_1_totalloss.png")
    plt.show()

# %%
if not model_loaded:
    plt.figure(figsize=(14, 5))
    plt.plot(test_feature_losses, label='Test Feature Loss')
    plt.plot(train_feature_losses, label='Train Feature Loss')
    plt.legend()
    plt.title('Feature Loss')
    plt.savefig("_1_feature_loss.png")
    plt.show()

# %%
test_loader_melt = DataLoader(graphs_melt, batch_size=1)
encoded_data_melt=[]
type_data_melt = []
for data in test_loader:
    model.eval()
    z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
    decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
    encoded_data_melt.append(z.detach().numpy())
    type_data_melt.append(str_type.detach().numpy())

encoded_data_melt = np.array(encoded_data_melt)
type_data_melt = np.array(type_data_melt)

# %%
test_loader_cry = DataLoader(graphs_cry, batch_size=1)
encoded_data_cry=[]
type_data_cry = []
for data in test_loader:
    model.eval()
    z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
    decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
    encoded_data_cry.append(z.detach().numpy())
    type_data_cry.append(str_type.detach().numpy())

encoded_data_cry = np.array(encoded_data_cry)
type_data_cry = np.array(type_data_cry)

# %%
# %matplotlib widget

frame = 10

fig = plt.figure(figsize=(15,4))
data_melt = encoded_data_melt[frame]

data_cry = encoded_data_cry[frame]
plt.scatter(data_melt[:,0],data_melt[:,1],c="r",label="melt")
plt.scatter(data_cry[:,0],data_cry[:,1],c="b",label="crystal")
plt.savefig("_1_scatter.png")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
