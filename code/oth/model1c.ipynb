# %%
import mdtraj as md
from ase import Atoms
import nglview as nv
import networkx as nx

import numpy as np
import matplotlib.pyplot as plt
import torch
from tqdm import tqdm

import torch_geometric.transforms as T
from torch_geometric.loader import DataLoader
from torch_geometric.nn import GCNConv, SAGPooling, InnerProductDecoder
import torch_geometric.data as data
from torch_geometric.utils.convert import to_networkx
import torch.optim.lr_scheduler as lr_scheduler
from torch.nn import Linear
import sys

# %%
all_frames_cry = md.load_xtc("../simulation/para_crystal.xtc", top="../simulation/para_crystal.gro")
all_frames_melt = md.load_xtc("../simulation/para_melt.xtc", top="../simulation/para_melt.gro")

# %%
all_frames_cry = all_frames_cry[::100]
all_frames_melt = all_frames_melt[::100]

# %%
n_frames = all_frames_cry.xyz.shape[0]
n_atoms = all_frames_cry.topology.residue(0).n_atoms
n_mols = all_frames_cry.topology.n_residues

# %%
def createGraph(all_frames,structure_type="crystal"):
    all_frames_fatures = []

    print("Creating Feature matrix")
    for i in tqdm(range(all_frames.xyz.shape[0])):
        mol_com_pos = []

        for res in all_frames.top.residues:
            pos = []
            for atom in res.atoms:
                pos.append(all_frames.xyz[i][atom.index])
            mol_com_pos.append(np.mean(pos,axis=0))
            
            # print()
        mol_com_pos = np.array(mol_com_pos).astype(np.float32)  
        all_frames_fatures.append(mol_com_pos)

    all_frames_fatures = np.array(all_frames_fatures).astype(np.float32)



    cutoff = 0.8

    print("Creating Edge list")
    all_edge_list = []
    # with open("edge_list.txt","w") as f:
    for frame_i in tqdm(range(n_frames)):
        from_list = []
        to_list = []

        for i in range(len(all_frames_fatures[frame_i])):
            for j in range(i+1,len(all_frames_fatures[frame_i])):
                if np.linalg.norm(all_frames_fatures[frame_i][i]-all_frames_fatures[frame_i][j]) < cutoff:
                    # f.write(str(i)+" "+str(j)+" "+str(np.linalg.norm(all_frames_fatures[frame_i][i]-all_frames_fatures[frame_i][j]))+"\n")
                    from_list.append(i)
                    to_list.append(j)

                    to_list.append(i)
                    from_list.append(j)

        edge_list = np.array([from_list,to_list]).astype(np.int64)
        all_edge_list.append(edge_list)
    print("creating Graphs")
    graphs = []
    for frame in tqdm(range(n_frames)):
        if structure_type == "crystal":
            g = data.Data(x=torch.tensor(all_frames_fatures[frame]).float(), edge_index=torch.tensor(all_edge_list[frame]).long(), y=torch.tensor([0]))
        else:
            g = data.Data(x=torch.tensor(all_frames_fatures[frame]).float(), edge_index=torch.tensor(all_edge_list[frame]).long(), y=torch.tensor([1]))
        graphs.append(g)
    return graphs

# %%
graphs_cry = createGraph(all_frames_cry,structure_type="crystal")
graphs_melt = createGraph(all_frames_melt,structure_type="melt")
# Out:
# Creating Feature matrix
# 100%|██████████| 51/51 [00:00<00:00, 75.44it/s]
# Creating Edge list
# 100%|██████████| 51/51 [02:18<00:00,  2.72s/it]
# creating Graphs
# 100%|██████████| 51/51 [00:00<00:00, 13128.92it/s]
# Creating Feature matrix
# 100%|██████████| 51/51 [00:01<00:00, 47.94it/s]
# Creating Edge list
# 100%|██████████| 51/51 [02:03<00:00,  2.43s/it]
# creating Graphs
# 100%|██████████| 51/51 [00:00<00:00, 15423.57it/s]

# %%
def convert_to_adj(edge_index, num_nodes=None):
    if num_nodes is None:
        num_nodes = edge_index.max() + 1
    adj = torch.zeros(num_nodes, num_nodes)
    adj[edge_index[0], edge_index[1]] = 1
    return adj

def convert_to_edge_index(adj):
    edge_index = adj.nonzero().t()
    return edge_index

# %%
graphs = graphs_cry + graphs_melt

# %%
# shuffle the graphs
np.random.shuffle(graphs)

# %%
graphs
# Out:
# [Data(x=[864, 3], edge_index=[2, 7094], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6012], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6580], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6592], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6476], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6626], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6560], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6554], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7090], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7116], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6508], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7192], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6964], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7088], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6558], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6560], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7306], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6214], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7146], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6564], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6544], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5982], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6548], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5910], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7096], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7028], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6630], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7034], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5822], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6070], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7274], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6056], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7108], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6596], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7020], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7060], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7044], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7026], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7218], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7006], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6452], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7128], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6552], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6992], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6542], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7012], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6934], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7076], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6524], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6288], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6608], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6512], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5862], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7048], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7374], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7122], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5876], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7078], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5880], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6018], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6172], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6582], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7052], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6546], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6488], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7052], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6400], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7240], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7064], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7074], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6570], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7036], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6546], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6464], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6066], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6578], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7056], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7092], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5962], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5892], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7116], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6602], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7054], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7092], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7024], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7080], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7048], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7078], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7006], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7008], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6586], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6566], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6532], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7060], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7132], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7294], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6548], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6990], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6508], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7100], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7086], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6584], y=[1])]

# %% [markdown]
# ## model

# %%
from typing import Optional, Tuple

import torch
from torch import Tensor
from torch.nn import Module

from torch_geometric.nn.inits import reset
from torch_geometric.utils import negative_sampling

EPS = 1e-15
MAX_LOGSTD = 10
edgeShape = None
featureShape = None


class InnerProductDecoder(torch.nn.Module):
    r"""The inner product decoder from the `"Variational Graph Auto-Encoders"
    <https://arxiv.org/abs/1611.07308>`_ paper

    .. math::
        \sigma(\mathbf{Z}\mathbf{Z}^{\top})

    where :math:`\mathbf{Z} \in \mathbb{R}^{N \times d}` denotes the latent
    space produced by the encoder."""

    def forward(self, z: Tensor, edge_index: Tensor,
                sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into edge probabilities for
        the given node-pairs :obj:`edge_index`.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        value = (z[edge_index[0]] * z[edge_index[1]]).sum(dim=1)
        return torch.sigmoid(value) if sigmoid else value

    def forward_all(self, z: Tensor, sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into a probabilistic dense
        adjacency matrix.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        adj = torch.matmul(z, z.t())
        return torch.sigmoid(adj) if sigmoid else adj


class GAE(torch.nn.Module):
    r"""The Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper based on user-defined encoder and decoder models.

    Args:
        encoder (torch.nn.Module): The encoder module.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__()
        self.encoder = encoder
        self.decoder = InnerProductDecoder() if decoder is None else decoder
        GAE.reset_parameters(self)

    def reset_parameters(self):
        r"""Resets all learnable parameters of the module."""
        reset(self.encoder)
        reset(self.decoder)

    def forward(self, *args, **kwargs) -> Tensor:  # pragma: no cover
        r"""Alias for :meth:`encode`."""
        return self.encoder(*args, **kwargs)

    def encode(self, *args, **kwargs) -> Tensor:
        r"""Runs the encoder and computes node-wise latent variables."""
        return self.encoder(*args, **kwargs)

    def decode(self, *args, **kwargs) -> Tensor:
        r"""Runs the decoder and computes edge probabilities."""
        return self.decoder(*args, **kwargs)

    def recon_loss(self, z: Tensor, pos_edge_index: Tensor,
                   neg_edge_index: Optional[Tensor] = None) -> Tensor:
        r"""Given latent variables :obj:`z`, computes the binary cross
        entropy loss for positive edges :obj:`pos_edge_index` and negative
        sampled edges.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to train against.
            neg_edge_index (torch.Tensor, optional): The negative edges to
                train against. If not given, uses negative sampling to
                calculate negative edges. (default: :obj:`None`)
        """
        pos_loss = -torch.log(
            self.decoder(z, pos_edge_index, sigmoid=True)[0] + EPS).mean()

        if neg_edge_index is None:
            neg_edge_index = negative_sampling(pos_edge_index, z.size(0))
        neg_loss = -torch.log(1 -
                              self.decoder(z, neg_edge_index.long(), sigmoid=True)[0] +
                              EPS).mean()

        return pos_loss + neg_loss

    def test(self, z: Tensor, pos_edge_index: Tensor,
             neg_edge_index: Tensor) -> Tuple[Tensor, Tensor]:
        r"""Given latent variables :obj:`z`, positive edges
        :obj:`pos_edge_index` and negative edges :obj:`neg_edge_index`,
        computes area under the ROC curve (AUC) and average precision (AP)
        
        scores.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to evaluate
                against.
            neg_edge_index (torch.Tensor): The negative edges to evaluate
                against.
        """
        from sklearn.metrics import average_precision_score, roc_auc_score

        pos_y = z.new_ones(pos_edge_index.size(1))
        neg_y = z.new_zeros(neg_edge_index.size(1))
        y = torch.cat([pos_y, neg_y], dim=0)

        pos_pred = self.decoder(z, pos_edge_index, sigmoid=True)
        neg_pred = self.decoder(z, neg_edge_index, sigmoid=True)
        pred = torch.cat([pos_pred, neg_pred], dim=0)

        y, pred = y.detach().cpu().numpy(), pred.detach().cpu().numpy()

        return roc_auc_score(y, pred), average_precision_score(y, pred)


class VGAE(GAE):
    r"""The Variational Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper.

    Args:
        encoder (torch.nn.Module): The encoder module to compute :math:`\mu`
            and :math:`\log\sigma^2`.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__(encoder, decoder)

    def reparametrize(self, mu: Tensor, logstd: Tensor) -> Tensor:
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def encode(self, *args, **kwargs) -> Tensor:
        """"""
        z, self.edge_index = self.encoder(
            *args, **kwargs)
        
        return z, self.edge_index

    def kl_loss(self, mu: Optional[Tensor] = None,
                logstd: Optional[Tensor] = None) -> Tensor:
        r"""Computes the KL loss, either for the passed arguments :obj:`mu`
        and :obj:`logstd`, or based on latent variables from last encoding.

        Args:
            mu (torch.Tensor, optional): The latent space for :math:`\mu`. If
                set to :obj:`None`, uses the last computation of :math:`\mu`.
                (default: :obj:`None`)
            logstd (torch.Tensor, optional): The latent space for
                :math:`\log\sigma`.  If set to :obj:`None`, uses the last
                computation of :math:`\log\sigma^2`. (default: :obj:`None`)
        """
        mu = self.__mu__ if mu is None else mu
        logstd = self.__logstd__ if logstd is None else logstd.clamp(
            max=MAX_LOGSTD)
        return -0.5 * torch.mean(
            torch.sum(1 + 2 * logstd - mu**2 - logstd.exp()**2, dim=1))

# %%
import torch.nn.functional as F



class VariationalGCNEncoder(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__() # changes made such that guassian is 1 
        self.conv1 = GCNConv(in_channels, 2*out_channels)
        self.conv2 = GCNConv(2*out_channels, 1 * out_channels)
        self.pool = SAGPooling(out_channels, 0.5)
        
        self.conv_mu = GCNConv(1 * out_channels, out_channels)
        self.conv_logstd = GCNConv(1 * out_channels, out_channels)
    def reparametrize(self, mu: Tensor, logstd: Tensor) -> Tensor:
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def forward(self, x, edge_index,class_label):
        # print("input:",x.shape, edge_index.shape)
        x = self.conv1(x, edge_index)
        x = F.silu(x)
        # print("conv1:",x.shape, edge_index.shape)
        x = self.conv2(x, edge_index)
        x = F.silu(x)
        # print("conv2:",x.shape, edge_index.shape)

        sample = self.reparametrize(self.conv_mu(x, edge_index), self.conv_logstd(x, edge_index))
        sample = self.reparametrize(self.conv_mu(sample, edge_index), self.conv_logstd(sample, edge_index))
        # self.conv_mu_crystal.train(True)
        # self.conv_logstd_crystal.train(True)
        # self.conv_mu_melt.train(True)
        # self.conv_logstd_melt.train(True)
        self.conv_mu.train(True)
        self.conv_logstd.train(True)
        return sample, edge_index

# %%
class VariationalGCNDecoder(torch.nn.Module):
    def __init__(self,in_channels,out_channels):
        super().__init__()
        self.type_layer1 = Linear(1728,200)
        self.dropout = torch.nn.Dropout(0.5)
        self.type_layer2 = Linear(200,2)
        self.conv1 = GCNConv(in_channels,2*out_channels)
        self.conv2 = GCNConv(2*out_channels, 1 * out_channels)
    def forward(self, x, edge_index, sigmoid=True):
        # print("input:",x.shape, edge_index.shape)
        flat = x.flatten()
        flat = self.type_layer1(flat).relu()
        flat = self.dropout(flat)
        str_type = F.softmax(self.type_layer2(flat).relu(),dim=0)
         
        x = self.conv1(x, edge_index)
        x = F.silu(x)
        # print("conv1:",x.shape, edge_index.shape)
        x = self.conv2(x, edge_index)
        x = F.silu(x)
        # print("conv2:",x.shape, edge_index.shape)
        return x, edge_index,str_type

# %%
import os
in_channels = graphs[0].num_features
out_channels = 2
lr = 1e-4
n_epochs = 200
batch_size=1
test_train_split = 0.8
model_name = "_model1c_.pt"
model_loaded = False
force_train = True  

if os.path.exists("./models/"+model_name) and not force_train:
    model = torch.load("./models/"+model_name)
    model_loaded = True
else:
    model = VGAE(VariationalGCNEncoder(in_channels, out_channels),
                VariationalGCNDecoder(out_channels, in_channels))

optimizer = torch.optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, step_size=300, gamma=0.5)

# %%
train_loader = DataLoader(graphs[:int(n_frames*test_train_split)], batch_size=batch_size, shuffle=True)
test_loader = DataLoader(graphs[int(n_frames*test_train_split):], batch_size=batch_size, shuffle=True)

# %%
lossFxn = torch.nn.MSELoss()
typeLossFxn = torch.nn.CrossEntropyLoss()

def train():
    model.train()
    model.zero_grad()
    model.float()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0
    type_loss_all = 0
    for data in train_loader:
        optimizer.zero_grad()
        z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
        decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)

     
        # TypeLoss = typeLossFxn(str_type.unsqueeze(0), data.y)
        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        loss = FeatureLoss + EdgeLoss 

        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        # type_loss_all += float(TypeLoss)

        loss.backward()
        optimizer.step()
        

    return loss_all / len(train_loader), feature_loss_all / len(train_loader), edge_loss_all / len(train_loader), kl_loss_all / len(train_loader), type_loss_all / len(train_loader)

# %%
lossFxn = torch.nn.MSELoss()
def test():
    model.eval()
    model.zero_grad()
    model.float()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0
    type_loss_all = 0

    for data in test_loader:
        optimizer.zero_grad()
        z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
        decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
        
        # TypeLoss = typeLossFxn(str_type.unsqueeze(0), data.y)
        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        loss = FeatureLoss + EdgeLoss 

        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        # type_loss_all += float(TypeLoss)
        
        
        

    return loss_all / len(test_loader), feature_loss_all / len(test_loader), edge_loss_all / len(test_loader), kl_loss_all / len(test_loader), type_loss_all / len(test_loader)

# %%
train_total_losses = []
train_feature_losses = []
train_edge_losses = []
train_kl_losses = []
train_type_losses = []

test_total_losses = []
test_feature_losses = []
test_edge_losses = []
test_kl_losses = []
test_type_losses = []

if model_loaded:        
    print("Pretrained Model Loaded, no training required")
else:
    for epoch in range(1, n_epochs + 1):
        
        train_total_loss, train_feature_loss, train_edge_loss, train_kl_loss,train_type_loss = train()
        test_total_loss, test_feature_loss, test_edge_loss, test_kl_loss, test_type_loss= test()
        
        print(f"Epoch: {epoch:03d}")
        print(f'\tTrain:\tTotal Loss: {train_total_loss:.4f}, Feature Loss: {train_feature_loss:.4f}, Type Loss: {train_type_loss:.4f} ,  LR: {scheduler.get_last_lr()[0]:.6f}')
        print(f'\tTest: \tTotal Loss: {test_total_loss:.4f}, Feature Loss: {test_feature_loss:.4f}, Type Loss: {test_type_loss:.4f} , LR: {scheduler.get_last_lr()[0]:.6f}')
        
        
        train_total_losses.append(train_total_loss)
        train_feature_losses.append(train_feature_loss)
        train_edge_losses.append(train_edge_loss)
        train_kl_losses.append(train_kl_loss)
        train_type_losses.append(train_type_loss)


        test_total_losses.append(test_total_loss)
        test_feature_losses.append(test_feature_loss)
        test_edge_losses.append(test_edge_loss)
        test_kl_losses.append(test_kl_loss)
        test_type_losses.append(test_type_loss)
        
        scheduler.step()
    torch.save(model,"./models/"+model_name)
# Out:
# Epoch: 001
# 	Train:	Total Loss: 12.9432, Feature Loss: 12.9432, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.6334, Feature Loss: 12.6334, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 002
# 	Train:	Total Loss: 12.9074, Feature Loss: 12.9074, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.6092, Feature Loss: 12.6092, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 003
# 	Train:	Total Loss: 12.8784, Feature Loss: 12.8784, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.5846, Feature Loss: 12.5846, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 004
# 	Train:	Total Loss: 12.8431, Feature Loss: 12.8431, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.5597, Feature Loss: 12.5597, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 005
# 	Train:	Total Loss: 12.8158, Feature Loss: 12.8158, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.5348, Feature Loss: 12.5348, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 006
# 	Train:	Total Loss: 12.7786, Feature Loss: 12.7786, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.5091, Feature Loss: 12.5091, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 007
# 	Train:	Total Loss: 12.7575, Feature Loss: 12.7575, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.4832, Feature Loss: 12.4832, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 008
# 	Train:	Total Loss: 12.7184, Feature Loss: 12.7184, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.4568, Feature Loss: 12.4568, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 009
# 	Train:	Total Loss: 12.7795, Feature Loss: 12.7795, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.4307, Feature Loss: 12.4307, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 010
# 	Train:	Total Loss: 12.6672, Feature Loss: 12.6672, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.4042, Feature Loss: 12.4042, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 011
# 	Train:	Total Loss: 12.6144, Feature Loss: 12.6144, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.3769, Feature Loss: 12.3769, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 012
# 	Train:	Total Loss: 12.6023, Feature Loss: 12.6023, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.3485, Feature Loss: 12.3485, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 013
# 	Train:	Total Loss: 12.5521, Feature Loss: 12.5521, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.3195, Feature Loss: 12.3195, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 014
# 	Train:	Total Loss: 12.5358, Feature Loss: 12.5358, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.2903, Feature Loss: 12.2903, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 015
# 	Train:	Total Loss: 12.4878, Feature Loss: 12.4878, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.2592, Feature Loss: 12.2592, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 016
# 	Train:	Total Loss: 12.4549, Feature Loss: 12.4549, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.2277, Feature Loss: 12.2277, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 017
# 	Train:	Total Loss: 12.4187, Feature Loss: 12.4187, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.1954, Feature Loss: 12.1954, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 018
# 	Train:	Total Loss: 12.3686, Feature Loss: 12.3686, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.1618, Feature Loss: 12.1618, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 019
# 	Train:	Total Loss: 12.3224, Feature Loss: 12.3224, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.1263, Feature Loss: 12.1263, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 020
# 	Train:	Total Loss: 12.2857, Feature Loss: 12.2857, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0905, Feature Loss: 12.0905, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 021
# 	Train:	Total Loss: 12.2417, Feature Loss: 12.2417, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0524, Feature Loss: 12.0524, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 022
# 	Train:	Total Loss: 12.2136, Feature Loss: 12.2136, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0142, Feature Loss: 12.0142, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 023
# 	Train:	Total Loss: 12.1731, Feature Loss: 12.1731, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.9738, Feature Loss: 11.9738, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 024
# 	Train:	Total Loss: 12.1130, Feature Loss: 12.1130, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.9323, Feature Loss: 11.9323, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 025
# 	Train:	Total Loss: 12.0444, Feature Loss: 12.0444, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.8888, Feature Loss: 11.8888, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 026
# 	Train:	Total Loss: 12.0246, Feature Loss: 12.0246, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.8433, Feature Loss: 11.8433, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 027
# 	Train:	Total Loss: 11.9215, Feature Loss: 11.9215, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.7961, Feature Loss: 11.7961, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 028
# 	Train:	Total Loss: 11.9030, Feature Loss: 11.9030, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.7460, Feature Loss: 11.7460, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 029
# 	Train:	Total Loss: 11.8572, Feature Loss: 11.8572, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.6953, Feature Loss: 11.6953, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 030
# 	Train:	Total Loss: 11.7772, Feature Loss: 11.7772, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.6418, Feature Loss: 11.6418, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 031
# 	Train:	Total Loss: 11.7010, Feature Loss: 11.7010, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.5852, Feature Loss: 11.5852, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 032
# 	Train:	Total Loss: 11.6274, Feature Loss: 11.6274, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.5262, Feature Loss: 11.5262, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 033
# 	Train:	Total Loss: 11.5459, Feature Loss: 11.5459, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.4632, Feature Loss: 11.4632, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 034
# 	Train:	Total Loss: 11.4562, Feature Loss: 11.4562, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.3967, Feature Loss: 11.3967, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 035
# 	Train:	Total Loss: 11.6012, Feature Loss: 11.6012, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.3326, Feature Loss: 11.3326, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 036
# 	Train:	Total Loss: 11.3410, Feature Loss: 11.3410, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.2663, Feature Loss: 11.2663, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 037
# 	Train:	Total Loss: 11.2954, Feature Loss: 11.2954, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.1985, Feature Loss: 11.1985, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 038
# 	Train:	Total Loss: 11.1685, Feature Loss: 11.1685, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.1250, Feature Loss: 11.1250, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 039
# 	Train:	Total Loss: 11.0704, Feature Loss: 11.0704, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.0462, Feature Loss: 11.0462, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 040
# 	Train:	Total Loss: 10.9931, Feature Loss: 10.9931, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.9654, Feature Loss: 10.9654, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 041
# 	Train:	Total Loss: 10.9614, Feature Loss: 10.9614, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.8796, Feature Loss: 10.8796, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 042
# 	Train:	Total Loss: 10.8199, Feature Loss: 10.8199, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.7915, Feature Loss: 10.7915, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 043
# 	Train:	Total Loss: 10.6926, Feature Loss: 10.6926, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.6970, Feature Loss: 10.6970, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 044
# 	Train:	Total Loss: 10.6259, Feature Loss: 10.6259, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.5974, Feature Loss: 10.5974, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 045
# 	Train:	Total Loss: 10.5267, Feature Loss: 10.5267, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.4945, Feature Loss: 10.4945, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 046
# 	Train:	Total Loss: 10.4415, Feature Loss: 10.4415, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.3873, Feature Loss: 10.3873, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 047
# 	Train:	Total Loss: 10.3153, Feature Loss: 10.3153, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.2762, Feature Loss: 10.2762, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 048
# 	Train:	Total Loss: 10.1516, Feature Loss: 10.1516, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.1610, Feature Loss: 10.1610, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 049
# 	Train:	Total Loss: 10.1345, Feature Loss: 10.1345, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.0424, Feature Loss: 10.0424, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 050
# 	Train:	Total Loss: 11.1593, Feature Loss: 11.1593, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.9572, Feature Loss: 9.9572, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 051
# 	Train:	Total Loss: 9.8701, Feature Loss: 9.8701, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.8619, Feature Loss: 9.8619, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 052
# 	Train:	Total Loss: 9.8139, Feature Loss: 9.8139, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.7641, Feature Loss: 9.7641, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 053
# 	Train:	Total Loss: 9.6507, Feature Loss: 9.6507, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.6622, Feature Loss: 9.6622, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 054
# 	Train:	Total Loss: 9.6003, Feature Loss: 9.6003, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.5586, Feature Loss: 9.5586, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 055
# 	Train:	Total Loss: 9.5869, Feature Loss: 9.5869, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.4580, Feature Loss: 9.4580, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 056
# 	Train:	Total Loss: 9.4395, Feature Loss: 9.4395, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.3521, Feature Loss: 9.3521, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 057
# 	Train:	Total Loss: 9.5720, Feature Loss: 9.5720, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.2489, Feature Loss: 9.2489, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 058
# 	Train:	Total Loss: 9.2699, Feature Loss: 9.2699, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.1487, Feature Loss: 9.1487, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 059
# 	Train:	Total Loss: 10.7586, Feature Loss: 10.7586, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.0505, Feature Loss: 9.0505, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 060
# 	Train:	Total Loss: 9.1132, Feature Loss: 9.1132, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.9769, Feature Loss: 8.9769, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 061
# 	Train:	Total Loss: 8.9773, Feature Loss: 8.9773, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.8888, Feature Loss: 8.8888, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 062
# 	Train:	Total Loss: 9.0188, Feature Loss: 9.0188, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.8005, Feature Loss: 8.8005, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 063
# 	Train:	Total Loss: 8.8379, Feature Loss: 8.8379, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.7111, Feature Loss: 8.7111, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 064
# 	Train:	Total Loss: 8.7947, Feature Loss: 8.7947, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.6201, Feature Loss: 8.6201, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 065
# 	Train:	Total Loss: 8.6622, Feature Loss: 8.6622, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.5301, Feature Loss: 8.5301, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 066
# 	Train:	Total Loss: 8.6527, Feature Loss: 8.6527, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.4382, Feature Loss: 8.4382, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 067
# 	Train:	Total Loss: 8.5727, Feature Loss: 8.5727, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.3470, Feature Loss: 8.3470, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 068
# 	Train:	Total Loss: 8.5678, Feature Loss: 8.5678, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.2573, Feature Loss: 8.2573, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 069
# 	Train:	Total Loss: 8.2891, Feature Loss: 8.2891, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.1630, Feature Loss: 8.1630, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 070
# 	Train:	Total Loss: 8.2655, Feature Loss: 8.2655, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.0693, Feature Loss: 8.0693, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 071
# 	Train:	Total Loss: 8.2521, Feature Loss: 8.2521, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.9778, Feature Loss: 7.9778, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 072
# 	Train:	Total Loss: 8.0450, Feature Loss: 8.0450, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.8833, Feature Loss: 7.8833, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 073
# 	Train:	Total Loss: 8.0613, Feature Loss: 8.0613, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.7881, Feature Loss: 7.7881, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 074
# 	Train:	Total Loss: 7.9459, Feature Loss: 7.9459, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.6959, Feature Loss: 7.6959, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 075
# 	Train:	Total Loss: 7.8579, Feature Loss: 7.8579, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.6011, Feature Loss: 7.6011, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 076
# 	Train:	Total Loss: 7.7732, Feature Loss: 7.7732, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.5063, Feature Loss: 7.5063, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 077
# 	Train:	Total Loss: 7.7832, Feature Loss: 7.7832, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.4129, Feature Loss: 7.4129, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 078
# 	Train:	Total Loss: 7.6151, Feature Loss: 7.6151, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.3215, Feature Loss: 7.3215, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 079
# 	Train:	Total Loss: 7.6063, Feature Loss: 7.6063, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.2282, Feature Loss: 7.2282, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 080
# 	Train:	Total Loss: 7.4915, Feature Loss: 7.4915, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.1345, Feature Loss: 7.1345, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 081
# 	Train:	Total Loss: 7.5050, Feature Loss: 7.5050, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.0438, Feature Loss: 7.0438, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 082
# 	Train:	Total Loss: 7.2902, Feature Loss: 7.2902, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.9530, Feature Loss: 6.9530, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 083
# 	Train:	Total Loss: 7.2335, Feature Loss: 7.2335, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.8599, Feature Loss: 6.8599, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 084
# 	Train:	Total Loss: 7.2139, Feature Loss: 7.2139, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.7759, Feature Loss: 6.7759, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 085
# 	Train:	Total Loss: 7.0981, Feature Loss: 7.0981, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.6874, Feature Loss: 6.6874, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 086
# 	Train:	Total Loss: 7.0047, Feature Loss: 7.0047, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.6010, Feature Loss: 6.6010, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 087
# 	Train:	Total Loss: 6.9994, Feature Loss: 6.9994, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.5128, Feature Loss: 6.5128, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 088
# 	Train:	Total Loss: 6.7605, Feature Loss: 6.7605, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.4251, Feature Loss: 6.4251, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 089
# 	Train:	Total Loss: 6.7982, Feature Loss: 6.7982, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.3430, Feature Loss: 6.3430, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 090
# 	Train:	Total Loss: 6.7951, Feature Loss: 6.7951, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.2622, Feature Loss: 6.2622, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 091
# 	Train:	Total Loss: 6.6563, Feature Loss: 6.6563, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.1832, Feature Loss: 6.1832, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 092
# 	Train:	Total Loss: 6.5609, Feature Loss: 6.5609, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.0990, Feature Loss: 6.0990, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 093
# 	Train:	Total Loss: 6.4935, Feature Loss: 6.4935, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.0165, Feature Loss: 6.0165, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 094
# 	Train:	Total Loss: 6.5565, Feature Loss: 6.5565, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.9402, Feature Loss: 5.9402, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 095
# 	Train:	Total Loss: 6.4264, Feature Loss: 6.4264, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.8640, Feature Loss: 5.8640, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 096
# 	Train:	Total Loss: 6.3617, Feature Loss: 6.3617, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.7900, Feature Loss: 5.7900, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 097
# 	Train:	Total Loss: 6.2811, Feature Loss: 6.2811, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.7215, Feature Loss: 5.7215, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 098
# 	Train:	Total Loss: 6.2295, Feature Loss: 6.2295, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.6470, Feature Loss: 5.6470, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 099
# 	Train:	Total Loss: 6.1669, Feature Loss: 6.1669, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.5794, Feature Loss: 5.5794, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 100
# 	Train:	Total Loss: 6.0693, Feature Loss: 6.0693, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.5121, Feature Loss: 5.5121, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 101
# 	Train:	Total Loss: 6.0321, Feature Loss: 6.0321, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.4458, Feature Loss: 5.4458, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 102
# 	Train:	Total Loss: 5.9962, Feature Loss: 5.9962, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.3839, Feature Loss: 5.3839, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 103
# 	Train:	Total Loss: 5.9737, Feature Loss: 5.9737, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.3230, Feature Loss: 5.3230, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 104
# 	Train:	Total Loss: 6.0015, Feature Loss: 6.0015, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.2641, Feature Loss: 5.2641, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 105
# 	Train:	Total Loss: 5.7514, Feature Loss: 5.7514, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.2051, Feature Loss: 5.2051, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 106
# 	Train:	Total Loss: 5.7756, Feature Loss: 5.7756, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.1445, Feature Loss: 5.1445, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 107
# 	Train:	Total Loss: 5.8099, Feature Loss: 5.8099, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.0946, Feature Loss: 5.0946, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 108
# 	Train:	Total Loss: 5.5582, Feature Loss: 5.5582, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.0390, Feature Loss: 5.0390, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 109
# 	Train:	Total Loss: 5.6378, Feature Loss: 5.6378, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.9884, Feature Loss: 4.9884, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 110
# 	Train:	Total Loss: 5.5942, Feature Loss: 5.5942, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.9392, Feature Loss: 4.9392, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 111
# 	Train:	Total Loss: 5.4820, Feature Loss: 5.4820, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.8894, Feature Loss: 4.8894, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 112
# 	Train:	Total Loss: 5.6612, Feature Loss: 5.6612, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.8399, Feature Loss: 4.8399, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 113
# 	Train:	Total Loss: 5.4097, Feature Loss: 5.4097, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.7967, Feature Loss: 4.7967, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 114
# 	Train:	Total Loss: 5.3705, Feature Loss: 5.3705, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.7494, Feature Loss: 4.7494, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 115
# 	Train:	Total Loss: 5.2905, Feature Loss: 5.2905, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.7066, Feature Loss: 4.7066, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 116
# 	Train:	Total Loss: 5.3045, Feature Loss: 5.3045, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.6626, Feature Loss: 4.6626, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 117
# 	Train:	Total Loss: 5.3019, Feature Loss: 5.3019, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.6245, Feature Loss: 4.6245, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 118
# 	Train:	Total Loss: 5.2047, Feature Loss: 5.2047, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.5835, Feature Loss: 4.5835, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 119
# 	Train:	Total Loss: 5.1738, Feature Loss: 5.1738, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.5432, Feature Loss: 4.5432, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 120
# 	Train:	Total Loss: 5.1312, Feature Loss: 5.1312, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.5096, Feature Loss: 4.5096, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 121
# 	Train:	Total Loss: 5.1635, Feature Loss: 5.1635, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.4758, Feature Loss: 4.4758, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 122
# 	Train:	Total Loss: 5.1034, Feature Loss: 5.1034, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.4366, Feature Loss: 4.4366, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 123
# 	Train:	Total Loss: 5.0811, Feature Loss: 5.0811, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.4043, Feature Loss: 4.4043, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 124
# 	Train:	Total Loss: 5.0520, Feature Loss: 5.0520, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.3745, Feature Loss: 4.3745, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 125
# 	Train:	Total Loss: 4.9824, Feature Loss: 4.9824, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.3431, Feature Loss: 4.3431, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 126
# 	Train:	Total Loss: 4.9001, Feature Loss: 4.9001, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.3143, Feature Loss: 4.3143, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 127
# 	Train:	Total Loss: 4.9467, Feature Loss: 4.9467, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.2851, Feature Loss: 4.2851, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 128
# 	Train:	Total Loss: 4.8329, Feature Loss: 4.8329, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.2599, Feature Loss: 4.2599, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 129
# 	Train:	Total Loss: 4.8537, Feature Loss: 4.8537, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.2290, Feature Loss: 4.2290, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 130
# 	Train:	Total Loss: 4.8627, Feature Loss: 4.8627, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.2049, Feature Loss: 4.2049, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 131
# 	Train:	Total Loss: 4.8893, Feature Loss: 4.8893, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.1808, Feature Loss: 4.1808, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 132
# 	Train:	Total Loss: 4.7670, Feature Loss: 4.7670, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.1559, Feature Loss: 4.1559, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 133
# 	Train:	Total Loss: 4.7446, Feature Loss: 4.7446, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.1334, Feature Loss: 4.1334, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 134
# 	Train:	Total Loss: 4.7014, Feature Loss: 4.7014, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.1065, Feature Loss: 4.1065, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 135
# 	Train:	Total Loss: 4.6601, Feature Loss: 4.6601, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.0859, Feature Loss: 4.0859, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 136
# 	Train:	Total Loss: 4.7405, Feature Loss: 4.7405, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.0654, Feature Loss: 4.0654, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 137
# 	Train:	Total Loss: 4.8078, Feature Loss: 4.8078, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.0455, Feature Loss: 4.0455, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 138
# 	Train:	Total Loss: 4.8363, Feature Loss: 4.8363, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.0299, Feature Loss: 4.0299, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 139
# 	Train:	Total Loss: 4.5714, Feature Loss: 4.5714, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.0101, Feature Loss: 4.0101, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 140
# 	Train:	Total Loss: 4.5388, Feature Loss: 4.5388, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.9917, Feature Loss: 3.9917, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 141
# 	Train:	Total Loss: 4.5910, Feature Loss: 4.5910, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.9747, Feature Loss: 3.9747, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 142
# 	Train:	Total Loss: 4.5271, Feature Loss: 4.5271, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.9584, Feature Loss: 3.9584, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 143
# 	Train:	Total Loss: 4.4630, Feature Loss: 4.4630, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.9437, Feature Loss: 3.9437, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 144
# 	Train:	Total Loss: 4.5768, Feature Loss: 4.5768, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.9265, Feature Loss: 3.9265, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 145
# 	Train:	Total Loss: 4.5184, Feature Loss: 4.5184, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.9128, Feature Loss: 3.9128, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 146
# 	Train:	Total Loss: 4.4367, Feature Loss: 4.4367, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8969, Feature Loss: 3.8969, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 147
# 	Train:	Total Loss: 4.5634, Feature Loss: 4.5634, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8841, Feature Loss: 3.8841, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 148
# 	Train:	Total Loss: 4.4810, Feature Loss: 4.4810, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8726, Feature Loss: 3.8726, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 149
# 	Train:	Total Loss: 4.3455, Feature Loss: 4.3455, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8575, Feature Loss: 3.8575, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 150
# 	Train:	Total Loss: 4.3676, Feature Loss: 4.3676, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8434, Feature Loss: 3.8434, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 151
# 	Train:	Total Loss: 4.3849, Feature Loss: 4.3849, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8306, Feature Loss: 3.8306, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 152
# 	Train:	Total Loss: 4.2734, Feature Loss: 4.2734, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8177, Feature Loss: 3.8177, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 153
# 	Train:	Total Loss: 4.3897, Feature Loss: 4.3897, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8087, Feature Loss: 3.8087, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 154
# 	Train:	Total Loss: 4.3372, Feature Loss: 4.3372, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7984, Feature Loss: 3.7984, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 155
# 	Train:	Total Loss: 4.7159, Feature Loss: 4.7159, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7937, Feature Loss: 3.7937, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 156
# 	Train:	Total Loss: 4.3666, Feature Loss: 4.3666, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7838, Feature Loss: 3.7838, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 157
# 	Train:	Total Loss: 4.2493, Feature Loss: 4.2493, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7769, Feature Loss: 3.7769, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 158
# 	Train:	Total Loss: 4.2950, Feature Loss: 4.2950, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7666, Feature Loss: 3.7666, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 159
# 	Train:	Total Loss: 4.2377, Feature Loss: 4.2377, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7567, Feature Loss: 3.7567, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 160
# 	Train:	Total Loss: 4.3159, Feature Loss: 4.3159, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7498, Feature Loss: 3.7498, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 161
# 	Train:	Total Loss: 4.3226, Feature Loss: 4.3226, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7431, Feature Loss: 3.7431, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 162
# 	Train:	Total Loss: 4.3529, Feature Loss: 4.3529, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7360, Feature Loss: 3.7360, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 163
# 	Train:	Total Loss: 4.1402, Feature Loss: 4.1402, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7289, Feature Loss: 3.7289, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 164
# 	Train:	Total Loss: 4.2081, Feature Loss: 4.2081, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7223, Feature Loss: 3.7223, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 165
# 	Train:	Total Loss: 4.1627, Feature Loss: 4.1627, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7141, Feature Loss: 3.7141, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 166
# 	Train:	Total Loss: 4.1769, Feature Loss: 4.1769, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7050, Feature Loss: 3.7050, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 167
# 	Train:	Total Loss: 4.1716, Feature Loss: 4.1716, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6998, Feature Loss: 3.6998, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 168
# 	Train:	Total Loss: 4.1444, Feature Loss: 4.1444, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6955, Feature Loss: 3.6955, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 169
# 	Train:	Total Loss: 4.0977, Feature Loss: 4.0977, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6875, Feature Loss: 3.6875, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 170
# 	Train:	Total Loss: 4.1513, Feature Loss: 4.1513, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6837, Feature Loss: 3.6837, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 171
# 	Train:	Total Loss: 4.1257, Feature Loss: 4.1257, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6803, Feature Loss: 3.6803, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 172
# 	Train:	Total Loss: 4.1289, Feature Loss: 4.1289, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6785, Feature Loss: 3.6785, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 173
# 	Train:	Total Loss: 4.4866, Feature Loss: 4.4866, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6761, Feature Loss: 3.6761, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 174
# 	Train:	Total Loss: 4.0874, Feature Loss: 4.0874, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6735, Feature Loss: 3.6735, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 175
# 	Train:	Total Loss: 4.0969, Feature Loss: 4.0969, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6692, Feature Loss: 3.6692, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 176
# 	Train:	Total Loss: 4.0887, Feature Loss: 4.0887, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6658, Feature Loss: 3.6658, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 177
# 	Train:	Total Loss: 4.1112, Feature Loss: 4.1112, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6599, Feature Loss: 3.6599, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 178
# 	Train:	Total Loss: 4.0062, Feature Loss: 4.0062, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6565, Feature Loss: 3.6565, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 179
# 	Train:	Total Loss: 4.0896, Feature Loss: 4.0896, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6533, Feature Loss: 3.6533, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 180
# 	Train:	Total Loss: 4.0999, Feature Loss: 4.0999, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6520, Feature Loss: 3.6520, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 181
# 	Train:	Total Loss: 4.1769, Feature Loss: 4.1769, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6511, Feature Loss: 3.6511, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 182
# 	Train:	Total Loss: 4.0846, Feature Loss: 4.0846, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6485, Feature Loss: 3.6485, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 183
# 	Train:	Total Loss: 4.0471, Feature Loss: 4.0471, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6457, Feature Loss: 3.6457, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 184
# 	Train:	Total Loss: 3.9545, Feature Loss: 3.9545, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6418, Feature Loss: 3.6418, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 185
# 	Train:	Total Loss: 4.0667, Feature Loss: 4.0667, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6387, Feature Loss: 3.6387, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 186
# 	Train:	Total Loss: 4.1101, Feature Loss: 4.1101, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6367, Feature Loss: 3.6367, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 187
# 	Train:	Total Loss: 4.0093, Feature Loss: 4.0093, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6357, Feature Loss: 3.6357, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 188
# 	Train:	Total Loss: 4.0265, Feature Loss: 4.0265, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6329, Feature Loss: 3.6329, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 189
# 	Train:	Total Loss: 4.0125, Feature Loss: 4.0125, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6296, Feature Loss: 3.6296, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 190
# 	Train:	Total Loss: 4.0722, Feature Loss: 4.0722, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6296, Feature Loss: 3.6296, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 191
# 	Train:	Total Loss: 4.0253, Feature Loss: 4.0253, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6272, Feature Loss: 3.6272, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 192
# 	Train:	Total Loss: 4.0404, Feature Loss: 4.0404, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6276, Feature Loss: 3.6276, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 193
# 	Train:	Total Loss: 3.9648, Feature Loss: 3.9648, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6244, Feature Loss: 3.6244, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 194
# 	Train:	Total Loss: 4.1228, Feature Loss: 4.1228, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6244, Feature Loss: 3.6244, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 195
# 	Train:	Total Loss: 4.0847, Feature Loss: 4.0847, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6235, Feature Loss: 3.6235, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 196
# 	Train:	Total Loss: 3.9758, Feature Loss: 3.9758, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6214, Feature Loss: 3.6214, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 197
# 	Train:	Total Loss: 3.9798, Feature Loss: 3.9798, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6207, Feature Loss: 3.6207, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 198
# 	Train:	Total Loss: 3.9212, Feature Loss: 3.9212, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6185, Feature Loss: 3.6185, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 199
# 	Train:	Total Loss: 3.9291, Feature Loss: 3.9291, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6164, Feature Loss: 3.6164, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 200
# 	Train:	Total Loss: 3.9759, Feature Loss: 3.9759, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6154, Feature Loss: 3.6154, Type Loss: 0.0000 , LR: 0.000100

# %%
if not model_loaded:
    plt.figure(figsize=(14, 5))
    plt.plot(test_total_losses, label='Total Test Loss')
    plt.plot(train_total_losses, label='Total Train Loss')
    plt.legend()
    plt.title('Total Loss')
    plt.savefig("_1c_totalloss.png")
    plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
if not model_loaded:
    plt.figure(figsize=(14, 5))
    plt.plot(test_feature_losses, label='Test Feature Loss')
    plt.plot(train_feature_losses, label='Train Feature Loss')
    plt.legend()
    plt.title('Feature Loss')
    plt.savefig("_1c_feature_loss.png")
    plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
test_loader_melt = DataLoader(graphs_melt, batch_size=1)
encoded_data_melt=[]
type_data_melt = []
for data in test_loader:
    model.eval()
    z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
    decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
    encoded_data_melt.append(z.detach().numpy())
    type_data_melt.append(str_type.detach().numpy())

encoded_data_melt = np.array(encoded_data_melt)
type_data_melt = np.array(type_data_melt)

# %%
test_loader_cry = DataLoader(graphs_cry, batch_size=1)
encoded_data_cry=[]
type_data_cry = []
for data in test_loader:
    model.eval()
    z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
    decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
    encoded_data_cry.append(z.detach().numpy())
    type_data_cry.append(str_type.detach().numpy())

encoded_data_cry = np.array(encoded_data_cry)
type_data_cry = np.array(type_data_cry)

# %%
# %matplotlib widget

frame = 20

fig = plt.figure(figsize=(15,4))
data_melt = encoded_data_melt[frame]

data_cry = encoded_data_cry[frame]
plt.scatter(data_melt[:,0],data_melt[:,1],c="r",label="melt")
plt.scatter(data_cry[:,0],data_cry[:,1],c="b",label="crystal")
plt.savefig("_1c_scatter.png")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
