# %%
import mdtraj as md
from ase import Atoms
import nglview as nv
import networkx as nx

import numpy as np
import matplotlib.pyplot as plt
import torch
from tqdm import tqdm

import torch_geometric.transforms as T
from torch_geometric.loader import DataLoader
from torch_geometric.nn import GCNConv, SAGPooling, InnerProductDecoder
import torch_geometric.data as data
from torch_geometric.utils.convert import to_networkx
import torch.optim.lr_scheduler as lr_scheduler
from torch.nn import Linear
import sys

# %%
all_frames_cry = md.load_xtc("../simulation/para_crystal.xtc", top="../simulation/para_crystal.gro")
all_frames_melt = md.load_xtc("../simulation/para_melt.xtc", top="../simulation/para_melt.gro")

# %%
all_frames_cry = all_frames_cry[::100]
all_frames_melt = all_frames_melt[::100]

# %%
n_frames = all_frames_cry.xyz.shape[0]
n_atoms = all_frames_cry.topology.residue(0).n_atoms
n_mols = all_frames_cry.topology.n_residues

# %%
def createGraph(all_frames,structure_type="crystal"):
    all_frames_fatures = []

    print("Creating Feature matrix")
    for i in tqdm(range(all_frames.xyz.shape[0])):
        mol_com_pos = []

        for res in all_frames.top.residues:
            pos = []
            for atom in res.atoms:
                pos.append(all_frames.xyz[i][atom.index])
            mol_com_pos.append(np.mean(pos,axis=0))
            
            # print()
        mol_com_pos = np.array(mol_com_pos).astype(np.float32)  
        all_frames_fatures.append(mol_com_pos)

    all_frames_fatures = np.array(all_frames_fatures).astype(np.float32)



    cutoff = 0.8

    print("Creating Edge list")
    all_edge_list = []
    # with open("edge_list.txt","w") as f:
    for frame_i in tqdm(range(n_frames)):
        from_list = []
        to_list = []

        for i in range(len(all_frames_fatures[frame_i])):
            for j in range(i+1,len(all_frames_fatures[frame_i])):
                if np.linalg.norm(all_frames_fatures[frame_i][i]-all_frames_fatures[frame_i][j]) < cutoff:
                    # f.write(str(i)+" "+str(j)+" "+str(np.linalg.norm(all_frames_fatures[frame_i][i]-all_frames_fatures[frame_i][j]))+"\n")
                    from_list.append(i)
                    to_list.append(j)

                    to_list.append(i)
                    from_list.append(j)

        edge_list = np.array([from_list,to_list]).astype(np.int64)
        all_edge_list.append(edge_list)
    print("creating Graphs")
    graphs = []
    for frame in tqdm(range(n_frames)):
        if structure_type == "crystal":
            g = data.Data(x=torch.tensor(all_frames_fatures[frame]).float(), edge_index=torch.tensor(all_edge_list[frame]).long(), y=torch.tensor([0]))
        else:
            g = data.Data(x=torch.tensor(all_frames_fatures[frame]).float(), edge_index=torch.tensor(all_edge_list[frame]).long(), y=torch.tensor([1]))
        graphs.append(g)
    return graphs

# %%
graphs_cry = createGraph(all_frames_cry,structure_type="crystal")
graphs_melt = createGraph(all_frames_melt,structure_type="melt")
# Out:
# Creating Feature matrix
# 100%|██████████| 51/51 [00:01<00:00, 42.56it/s]
# Creating Edge list
# 100%|██████████| 51/51 [02:05<00:00,  2.46s/it]
# creating Graphs
# 100%|██████████| 51/51 [00:00<00:00, 594.46it/s]
# Creating Feature matrix
# 100%|██████████| 51/51 [00:00<00:00, 72.94it/s]
# Creating Edge list
# 100%|██████████| 51/51 [01:27<00:00,  1.71s/it]
# creating Graphs
# 100%|██████████| 51/51 [00:00<00:00, 16072.55it/s]

# %%
def convert_to_adj(edge_index, num_nodes=None):
    if num_nodes is None:
        num_nodes = edge_index.max() + 1
    adj = torch.zeros(num_nodes, num_nodes)
    adj[edge_index[0], edge_index[1]] = 1
    return adj

def convert_to_edge_index(adj):
    edge_index = adj.nonzero().t()
    return edge_index

# %%
graphs = graphs_cry + graphs_melt
# graphs = graphs_cry

# %%
# shuffle the graphs
np.random.shuffle(graphs)

# %%
graphs
# Out:
# [Data(x=[864, 3], edge_index=[2, 6546], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6578], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7294], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6464], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7036], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7092], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7090], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6508], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6934], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6524], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6172], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6558], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7006], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5822], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6630], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6066], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7306], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6992], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7064], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6056], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7240], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6990], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6554], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7274], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6596], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7116], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7034], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5962], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6546], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6964], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6564], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6508], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6012], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7128], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7132], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5880], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7080], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7048], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7086], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5876], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7116], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7024], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7108], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6592], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7056], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7218], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7374], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6584], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6452], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6602], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5982], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6488], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6566], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6532], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6570], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6580], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7100], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7076], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6542], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5910], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6400], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6214], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6608], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6548], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7028], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7008], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7012], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7146], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6560], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6586], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7044], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7074], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7078], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7052], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7060], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6560], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5892], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7078], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7026], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6476], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6288], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6582], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5862], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7088], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7020], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7096], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6070], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6018], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7060], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7092], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6552], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7048], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7094], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6548], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7192], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6512], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7054], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7006], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6544], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7122], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6626], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7052], y=[1])]

# %% [markdown]
# ## model

# %%
from typing import Optional, Tuple

import torch
from torch import Tensor
from torch.nn import Module

from torch_geometric.nn.inits import reset
from torch_geometric.utils import negative_sampling

EPS = 1e-15
MAX_LOGSTD = 10
edgeShape = None
featureShape = None


class InnerProductDecoder(torch.nn.Module):
    r"""The inner product decoder from the `"Variational Graph Auto-Encoders"
    <https://arxiv.org/abs/1611.07308>`_ paper

    .. math::
        \sigma(\mathbf{Z}\mathbf{Z}^{\top})

    where :math:`\mathbf{Z} \in \mathbb{R}^{N \times d}` denotes the latent
    space produced by the encoder."""

    def forward(self, z: Tensor, edge_index: Tensor,
                sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into edge probabilities for
        the given node-pairs :obj:`edge_index`.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        value = (z[edge_index[0]] * z[edge_index[1]]).sum(dim=1)
        return torch.sigmoid(value) if sigmoid else value

    def forward_all(self, z: Tensor, sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into a probabilistic dense
        adjacency matrix.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        adj = torch.matmul(z, z.t())
        return torch.sigmoid(adj) if sigmoid else adj


class GAE(torch.nn.Module):
    r"""The Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper based on user-defined encoder and decoder models.

    Args:
        encoder (torch.nn.Module): The encoder module.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__()
        self.encoder = encoder
        self.decoder = InnerProductDecoder() if decoder is None else decoder
        GAE.reset_parameters(self)

    def reset_parameters(self):
        r"""Resets all learnable parameters of the module."""
        reset(self.encoder)
        reset(self.decoder)

    def forward(self, *args, **kwargs) -> Tensor:  # pragma: no cover
        r"""Alias for :meth:`encode`."""
        return self.encoder(*args, **kwargs)

    def encode(self, *args, **kwargs) -> Tensor:
        r"""Runs the encoder and computes node-wise latent variables."""
        return self.encoder(*args, **kwargs)

    def decode(self, *args, **kwargs) -> Tensor:
        r"""Runs the decoder and computes edge probabilities."""
        return self.decoder(*args, **kwargs)

    def recon_loss(self, z: Tensor, pos_edge_index: Tensor,
                   neg_edge_index: Optional[Tensor] = None) -> Tensor:
        r"""Given latent variables :obj:`z`, computes the binary cross
        entropy loss for positive edges :obj:`pos_edge_index` and negative
        sampled edges.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to train against.
            neg_edge_index (torch.Tensor, optional): The negative edges to
                train against. If not given, uses negative sampling to
                calculate negative edges. (default: :obj:`None`)
        """
        pos_loss = -torch.log(
            self.decoder(z, pos_edge_index, sigmoid=True)[0] + EPS).mean()

        if neg_edge_index is None:
            neg_edge_index = negative_sampling(pos_edge_index, z.size(0))
        neg_loss = -torch.log(1 -
                              self.decoder(z, neg_edge_index.long(), sigmoid=True)[0] +
                              EPS).mean()

        return pos_loss + neg_loss

    def test(self, z: Tensor, pos_edge_index: Tensor,
             neg_edge_index: Tensor) -> Tuple[Tensor, Tensor]:
        r"""Given latent variables :obj:`z`, positive edges
        :obj:`pos_edge_index` and negative edges :obj:`neg_edge_index`,
        computes area under the ROC curve (AUC) and average precision (AP)
        
        scores.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to evaluate
                against.
            neg_edge_index (torch.Tensor): The negative edges to evaluate
                against.
        """
        from sklearn.metrics import average_precision_score, roc_auc_score

        pos_y = z.new_ones(pos_edge_index.size(1))
        neg_y = z.new_zeros(neg_edge_index.size(1))
        y = torch.cat([pos_y, neg_y], dim=0)

        pos_pred = self.decoder(z, pos_edge_index, sigmoid=True)
        neg_pred = self.decoder(z, neg_edge_index, sigmoid=True)
        pred = torch.cat([pos_pred, neg_pred], dim=0)

        y, pred = y.detach().cpu().numpy(), pred.detach().cpu().numpy()

        return roc_auc_score(y, pred), average_precision_score(y, pred)


class VGAE(GAE):
    r"""The Variational Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper.

    Args:
        encoder (torch.nn.Module): The encoder module to compute :math:`\mu`
            and :math:`\log\sigma^2`.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__(encoder, decoder)

    def reparametrize(self, mu: Tensor, logstd: Tensor) -> Tensor:
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def encode(self, *args, **kwargs) -> Tensor:
        """"""
        z, self.edge_index = self.encoder(
            *args, **kwargs)
        
        return z, self.edge_index

    def kl_loss(self, mu: Optional[Tensor] = None,
                logstd: Optional[Tensor] = None) -> Tensor:
        r"""Computes the KL loss, either for the passed arguments :obj:`mu`
        and :obj:`logstd`, or based on latent variables from last encoding.

        Args:
            mu (torch.Tensor, optional): The latent space for :math:`\mu`. If
                set to :obj:`None`, uses the last computation of :math:`\mu`.
                (default: :obj:`None`)
            logstd (torch.Tensor, optional): The latent space for
                :math:`\log\sigma`.  If set to :obj:`None`, uses the last
                computation of :math:`\log\sigma^2`. (default: :obj:`None`)
        """
        mu = self.__mu__ if mu is None else mu
        logstd = self.__logstd__ if logstd is None else logstd.clamp(
            max=MAX_LOGSTD)
        return -0.5 * torch.mean(
            torch.sum(1 + 2 * logstd - mu**2 - logstd.exp()**2, dim=1))

# %%
import torch.nn.functional as F



class VariationalGCNEncoder(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__() # changes made such that guassian is 1 
        self.conv1 = GCNConv(in_channels, 2*out_channels)
        self.conv2 = GCNConv(2*out_channels, 1 * out_channels)
        self.pool = SAGPooling(out_channels, 0.5)
        
        self.conv_mu = GCNConv(1 * out_channels, out_channels)
        self.conv_logstd = GCNConv(1 * out_channels, out_channels)
    def reparametrize(self, mu: Tensor, logstd: Tensor) -> Tensor:
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def forward(self, x, edge_index,class_label):
        # print("input:",x.shape, edge_index.shape)
        x = self.conv1(x, edge_index)
        x = F.silu(x)
        # print("conv1:",x.shape, edge_index.shape)
        x = self.conv2(x, edge_index)
        x = F.silu(x)
        # print("conv2:",x.shape, edge_index.shape)

        sample = self.reparametrize(self.conv_mu(x, edge_index), self.conv_logstd(x, edge_index))
        sample = self.reparametrize(self.conv_mu(sample, edge_index), self.conv_logstd(sample, edge_index))
        # self.conv_mu_crystal.train(True)
        # self.conv_logstd_crystal.train(True)
        # self.conv_mu_melt.train(True)
        # self.conv_logstd_melt.train(True)
        self.conv_mu.train(True)
        self.conv_logstd.train(True)
        return sample, edge_index

# %%
class VariationalGCNDecoder(torch.nn.Module):
    def __init__(self,in_channels,out_channels):
        super().__init__()
        self.type_layer1 = Linear(1728,200)
        self.dropout = torch.nn.Dropout(0.5)
        self.type_layer2 = Linear(200,2)
        self.conv1 = GCNConv(in_channels,2*out_channels)
        self.conv2 = GCNConv(2*out_channels, 1 * out_channels)
    def forward(self, x, edge_index, sigmoid=True):
        # print("input:",x.shape, edge_index.shape)
        flat = x.flatten()
        flat = self.type_layer1(flat).relu()
        flat = self.dropout(flat)
        str_type = F.softmax(self.type_layer2(flat).relu(),dim=0)
         
        x = self.conv1(x, edge_index)
        x = F.silu(x)
        # print("conv1:",x.shape, edge_index.shape)
        x = self.conv2(x, edge_index)
        x = F.silu(x)
        # print("conv2:",x.shape, edge_index.shape)
        return x, edge_index,str_type

# %%
import os
in_channels = graphs[0].num_features
out_channels = 2
lr = 1e-4
n_epochs = 200
batch_size=1
test_train_split = 0.8
model_name = "model2.pt"
model_loaded = False
force_train = True  

if os.path.exists("./models/"+model_name) and not force_train:
    model = torch.load("./models/"+model_name)
    model_loaded = True
else:
    model = VGAE(VariationalGCNEncoder(in_channels, out_channels),
                VariationalGCNDecoder(out_channels, in_channels))

optimizer = torch.optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, step_size=300, gamma=0.5)

# %%
train_loader = DataLoader(graphs_cry[:int(n_frames*test_train_split)], batch_size=batch_size, shuffle=True)
test_loader = DataLoader(graphs[int(n_frames*test_train_split):], batch_size=batch_size, shuffle=True)

# %%
lossFxn = torch.nn.MSELoss()
typeLossFxn = torch.nn.CrossEntropyLoss()

def train():
    model.train()
    model.zero_grad()
    model.float()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0
    type_loss_all = 0
    for data in train_loader:
        optimizer.zero_grad()
        z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
        decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)

     
        # TypeLoss = typeLossFxn(str_type.unsqueeze(0), data.y)
        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        loss = FeatureLoss + EdgeLoss 

        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        # type_loss_all += float(TypeLoss)

        loss.backward()
        optimizer.step()
        

    return loss_all / len(train_loader), feature_loss_all / len(train_loader), edge_loss_all / len(train_loader), kl_loss_all / len(train_loader), type_loss_all / len(train_loader)

# %%
lossFxn = torch.nn.MSELoss()
def test():
    model.eval()
    model.zero_grad()
    model.float()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0
    type_loss_all = 0

    for data in test_loader:
        optimizer.zero_grad()
        z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
        decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
        
        # TypeLoss = typeLossFxn(str_type.unsqueeze(0), data.y)
        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        loss = FeatureLoss + EdgeLoss 

        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        # type_loss_all += float(TypeLoss)
        
        
        

    return loss_all / len(test_loader), feature_loss_all / len(test_loader), edge_loss_all / len(test_loader), kl_loss_all / len(test_loader), type_loss_all / len(test_loader)

# %%
train_total_losses = []
train_feature_losses = []
train_edge_losses = []
train_kl_losses = []
train_type_losses = []

test_total_losses = []
test_feature_losses = []
test_edge_losses = []
test_kl_losses = []
test_type_losses = []

if model_loaded:        
    print("Pretrained Model Loaded, no training required")
else:
    for epoch in range(1, n_epochs + 1):
        
        train_total_loss, train_feature_loss, train_edge_loss, train_kl_loss,train_type_loss = train()
        test_total_loss, test_feature_loss, test_edge_loss, test_kl_loss, test_type_loss= test()
        
        print(f"Epoch: {epoch:03d}")
        print(f'\tTrain:\tTotal Loss: {train_total_loss:.4f}, Feature Loss: {train_feature_loss:.4f}, Type Loss: {train_type_loss:.4f} ,  LR: {scheduler.get_last_lr()[0]:.6f}')
        print(f'\tTest: \tTotal Loss: {test_total_loss:.4f}, Feature Loss: {test_feature_loss:.4f}, Type Loss: {test_type_loss:.4f} , LR: {scheduler.get_last_lr()[0]:.6f}')
        
        
        train_total_losses.append(train_total_loss)
        train_feature_losses.append(train_feature_loss)
        train_edge_losses.append(train_edge_loss)
        train_kl_losses.append(train_kl_loss)
        train_type_losses.append(train_type_loss)


        test_total_losses.append(test_total_loss)
        test_feature_losses.append(test_feature_loss)
        test_edge_losses.append(test_edge_loss)
        test_kl_losses.append(test_kl_loss)
        test_type_losses.append(test_type_loss)
        
        scheduler.step()
    torch.save(model,"./models/"+model_name)
# Out:
# Epoch: 001
# 	Train:	Total Loss: 12.0687, Feature Loss: 12.0687, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.5647, Feature Loss: 12.5647, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 002
# 	Train:	Total Loss: 12.0288, Feature Loss: 12.0288, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.5212, Feature Loss: 12.5212, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 003
# 	Train:	Total Loss: 11.9881, Feature Loss: 11.9881, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.4811, Feature Loss: 12.4811, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 004
# 	Train:	Total Loss: 11.9491, Feature Loss: 11.9491, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.4439, Feature Loss: 12.4439, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 005
# 	Train:	Total Loss: 11.9140, Feature Loss: 11.9140, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.4094, Feature Loss: 12.4094, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 006
# 	Train:	Total Loss: 11.8894, Feature Loss: 11.8894, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.3766, Feature Loss: 12.3766, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 007
# 	Train:	Total Loss: 11.8531, Feature Loss: 11.8531, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.3459, Feature Loss: 12.3459, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 008
# 	Train:	Total Loss: 11.8177, Feature Loss: 11.8177, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.3158, Feature Loss: 12.3158, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 009
# 	Train:	Total Loss: 11.7932, Feature Loss: 11.7932, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.2869, Feature Loss: 12.2869, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 010
# 	Train:	Total Loss: 11.7637, Feature Loss: 11.7637, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.2583, Feature Loss: 12.2583, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 011
# 	Train:	Total Loss: 11.7294, Feature Loss: 11.7294, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.2303, Feature Loss: 12.2303, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 012
# 	Train:	Total Loss: 11.7058, Feature Loss: 11.7058, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.2019, Feature Loss: 12.2019, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 013
# 	Train:	Total Loss: 11.6782, Feature Loss: 11.6782, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.1730, Feature Loss: 12.1730, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 014
# 	Train:	Total Loss: 11.6442, Feature Loss: 11.6442, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.1434, Feature Loss: 12.1434, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 015
# 	Train:	Total Loss: 11.6146, Feature Loss: 11.6146, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.1132, Feature Loss: 12.1132, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 016
# 	Train:	Total Loss: 11.5862, Feature Loss: 11.5862, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0821, Feature Loss: 12.0821, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 017
# 	Train:	Total Loss: 11.5528, Feature Loss: 11.5528, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0498, Feature Loss: 12.0498, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 018
# 	Train:	Total Loss: 11.5164, Feature Loss: 11.5164, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0157, Feature Loss: 12.0157, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 019
# 	Train:	Total Loss: 11.4833, Feature Loss: 11.4833, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.9798, Feature Loss: 11.9798, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 020
# 	Train:	Total Loss: 11.4520, Feature Loss: 11.4520, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.9424, Feature Loss: 11.9424, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 021
# 	Train:	Total Loss: 11.4138, Feature Loss: 11.4138, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.9031, Feature Loss: 11.9031, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 022
# 	Train:	Total Loss: 11.3760, Feature Loss: 11.3760, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.8616, Feature Loss: 11.8616, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 023
# 	Train:	Total Loss: 11.3258, Feature Loss: 11.3258, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.8177, Feature Loss: 11.8177, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 024
# 	Train:	Total Loss: 11.2794, Feature Loss: 11.2794, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.7711, Feature Loss: 11.7711, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 025
# 	Train:	Total Loss: 11.2440, Feature Loss: 11.2440, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.7220, Feature Loss: 11.7220, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 026
# 	Train:	Total Loss: 11.1854, Feature Loss: 11.1854, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.6692, Feature Loss: 11.6692, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 027
# 	Train:	Total Loss: 11.1310, Feature Loss: 11.1310, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.6131, Feature Loss: 11.6131, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 028
# 	Train:	Total Loss: 11.0780, Feature Loss: 11.0780, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.5540, Feature Loss: 11.5540, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 029
# 	Train:	Total Loss: 11.0010, Feature Loss: 11.0010, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.4899, Feature Loss: 11.4899, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 030
# 	Train:	Total Loss: 10.9441, Feature Loss: 10.9441, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.4227, Feature Loss: 11.4227, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 031
# 	Train:	Total Loss: 10.8630, Feature Loss: 10.8630, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.3497, Feature Loss: 11.3497, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 032
# 	Train:	Total Loss: 10.7955, Feature Loss: 10.7955, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.2728, Feature Loss: 11.2728, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 033
# 	Train:	Total Loss: 10.7090, Feature Loss: 10.7090, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.1902, Feature Loss: 11.1902, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 034
# 	Train:	Total Loss: 10.6348, Feature Loss: 10.6348, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.1036, Feature Loss: 11.1036, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 035
# 	Train:	Total Loss: 10.5271, Feature Loss: 10.5271, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.0115, Feature Loss: 11.0115, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 036
# 	Train:	Total Loss: 10.4551, Feature Loss: 10.4551, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.9148, Feature Loss: 10.9148, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 037
# 	Train:	Total Loss: 10.3647, Feature Loss: 10.3647, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.8148, Feature Loss: 10.8148, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 038
# 	Train:	Total Loss: 10.2315, Feature Loss: 10.2315, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.7084, Feature Loss: 10.7084, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 039
# 	Train:	Total Loss: 10.1302, Feature Loss: 10.1302, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.5999, Feature Loss: 10.5999, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 040
# 	Train:	Total Loss: 10.0050, Feature Loss: 10.0050, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.4855, Feature Loss: 10.4855, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 041
# 	Train:	Total Loss: 9.8899, Feature Loss: 9.8899, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.3687, Feature Loss: 10.3687, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 042
# 	Train:	Total Loss: 9.7807, Feature Loss: 9.7807, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.2485, Feature Loss: 10.2485, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 043
# 	Train:	Total Loss: 9.6440, Feature Loss: 9.6440, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.1240, Feature Loss: 10.1240, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 044
# 	Train:	Total Loss: 9.5044, Feature Loss: 9.5044, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.9954, Feature Loss: 9.9954, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 045
# 	Train:	Total Loss: 9.3703, Feature Loss: 9.3703, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.8627, Feature Loss: 9.8627, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 046
# 	Train:	Total Loss: 9.2540, Feature Loss: 9.2540, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.7272, Feature Loss: 9.7272, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 047
# 	Train:	Total Loss: 9.0903, Feature Loss: 9.0903, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.5885, Feature Loss: 9.5885, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 048
# 	Train:	Total Loss: 8.9686, Feature Loss: 8.9686, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.4471, Feature Loss: 9.4471, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 049
# 	Train:	Total Loss: 8.8083, Feature Loss: 8.8083, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.3025, Feature Loss: 9.3025, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 050
# 	Train:	Total Loss: 8.6644, Feature Loss: 8.6644, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.1538, Feature Loss: 9.1538, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 051
# 	Train:	Total Loss: 8.5738, Feature Loss: 8.5738, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.0050, Feature Loss: 9.0050, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 052
# 	Train:	Total Loss: 8.4274, Feature Loss: 8.4274, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.8550, Feature Loss: 8.8550, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 053
# 	Train:	Total Loss: 8.2670, Feature Loss: 8.2670, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.7029, Feature Loss: 8.7029, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 054
# 	Train:	Total Loss: 8.0776, Feature Loss: 8.0776, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.5443, Feature Loss: 8.5443, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 055
# 	Train:	Total Loss: 7.9362, Feature Loss: 7.9362, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.3827, Feature Loss: 8.3827, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 056
# 	Train:	Total Loss: 7.7418, Feature Loss: 7.7418, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.2178, Feature Loss: 8.2178, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 057
# 	Train:	Total Loss: 7.5945, Feature Loss: 7.5945, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.0525, Feature Loss: 8.0525, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 058
# 	Train:	Total Loss: 7.3986, Feature Loss: 7.3986, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.8841, Feature Loss: 7.8841, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 059
# 	Train:	Total Loss: 7.2414, Feature Loss: 7.2414, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.7139, Feature Loss: 7.7139, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 060
# 	Train:	Total Loss: 7.1228, Feature Loss: 7.1228, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.5432, Feature Loss: 7.5432, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 061
# 	Train:	Total Loss: 6.9420, Feature Loss: 6.9420, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.3698, Feature Loss: 7.3698, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 062
# 	Train:	Total Loss: 6.7412, Feature Loss: 6.7412, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.1965, Feature Loss: 7.1965, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 063
# 	Train:	Total Loss: 6.6156, Feature Loss: 6.6156, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.0225, Feature Loss: 7.0225, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 064
# 	Train:	Total Loss: 6.5084, Feature Loss: 6.5084, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.8495, Feature Loss: 6.8495, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 065
# 	Train:	Total Loss: 6.4067, Feature Loss: 6.4067, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.6786, Feature Loss: 6.6786, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 066
# 	Train:	Total Loss: 6.2098, Feature Loss: 6.2098, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.5089, Feature Loss: 6.5089, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 067
# 	Train:	Total Loss: 6.2669, Feature Loss: 6.2669, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.3470, Feature Loss: 6.3470, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 068
# 	Train:	Total Loss: 5.9939, Feature Loss: 5.9939, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.2120, Feature Loss: 6.2120, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 069
# 	Train:	Total Loss: 5.8256, Feature Loss: 5.8256, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.0657, Feature Loss: 6.0657, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 070
# 	Train:	Total Loss: 5.7676, Feature Loss: 5.7676, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.9234, Feature Loss: 5.9234, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 071
# 	Train:	Total Loss: 5.5783, Feature Loss: 5.5783, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.7849, Feature Loss: 5.7849, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 072
# 	Train:	Total Loss: 5.4958, Feature Loss: 5.4958, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.6505, Feature Loss: 5.6505, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 073
# 	Train:	Total Loss: 5.3919, Feature Loss: 5.3919, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.5210, Feature Loss: 5.5210, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 074
# 	Train:	Total Loss: 5.2470, Feature Loss: 5.2470, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.3942, Feature Loss: 5.3942, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 075
# 	Train:	Total Loss: 5.2464, Feature Loss: 5.2464, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.2757, Feature Loss: 5.2757, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 076
# 	Train:	Total Loss: 5.0981, Feature Loss: 5.0981, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.1584, Feature Loss: 5.1584, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 077
# 	Train:	Total Loss: 4.9990, Feature Loss: 4.9990, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.0463, Feature Loss: 5.0463, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 078
# 	Train:	Total Loss: 4.8739, Feature Loss: 4.8739, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.9391, Feature Loss: 4.9391, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 079
# 	Train:	Total Loss: 4.9476, Feature Loss: 4.9476, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.8393, Feature Loss: 4.8393, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 080
# 	Train:	Total Loss: 4.8428, Feature Loss: 4.8428, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.7410, Feature Loss: 4.7410, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 081
# 	Train:	Total Loss: 4.7940, Feature Loss: 4.7940, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.6494, Feature Loss: 4.6494, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 082
# 	Train:	Total Loss: 4.6509, Feature Loss: 4.6509, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.5608, Feature Loss: 4.5608, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 083
# 	Train:	Total Loss: 4.5626, Feature Loss: 4.5626, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.4761, Feature Loss: 4.4761, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 084
# 	Train:	Total Loss: 4.7939, Feature Loss: 4.7939, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.4022, Feature Loss: 4.4022, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 085
# 	Train:	Total Loss: 4.5842, Feature Loss: 4.5842, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.3296, Feature Loss: 4.3296, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 086
# 	Train:	Total Loss: 4.5804, Feature Loss: 4.5804, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.2604, Feature Loss: 4.2604, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 087
# 	Train:	Total Loss: 4.4882, Feature Loss: 4.4882, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.1961, Feature Loss: 4.1961, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 088
# 	Train:	Total Loss: 4.4059, Feature Loss: 4.4059, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.1393, Feature Loss: 4.1393, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 089
# 	Train:	Total Loss: 4.3952, Feature Loss: 4.3952, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.0855, Feature Loss: 4.0855, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 090
# 	Train:	Total Loss: 4.6795, Feature Loss: 4.6795, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.0466, Feature Loss: 4.0466, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 091
# 	Train:	Total Loss: 4.2151, Feature Loss: 4.2151, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.9949, Feature Loss: 3.9949, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 092
# 	Train:	Total Loss: 4.2671, Feature Loss: 4.2671, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.9489, Feature Loss: 3.9489, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 093
# 	Train:	Total Loss: 4.3303, Feature Loss: 4.3303, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.9081, Feature Loss: 3.9081, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 094
# 	Train:	Total Loss: 4.2454, Feature Loss: 4.2454, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8689, Feature Loss: 3.8689, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 095
# 	Train:	Total Loss: 4.2007, Feature Loss: 4.2007, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8317, Feature Loss: 3.8317, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 096
# 	Train:	Total Loss: 4.2597, Feature Loss: 4.2597, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7979, Feature Loss: 3.7979, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 097
# 	Train:	Total Loss: 4.1353, Feature Loss: 4.1353, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7640, Feature Loss: 3.7640, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 098
# 	Train:	Total Loss: 4.1177, Feature Loss: 4.1177, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7329, Feature Loss: 3.7329, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 099
# 	Train:	Total Loss: 4.0596, Feature Loss: 4.0596, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7040, Feature Loss: 3.7040, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 100
# 	Train:	Total Loss: 4.0897, Feature Loss: 4.0897, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6779, Feature Loss: 3.6779, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 101
# 	Train:	Total Loss: 4.1201, Feature Loss: 4.1201, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6521, Feature Loss: 3.6521, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 102
# 	Train:	Total Loss: 4.0950, Feature Loss: 4.0950, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6259, Feature Loss: 3.6259, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 103
# 	Train:	Total Loss: 4.1127, Feature Loss: 4.1127, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6020, Feature Loss: 3.6020, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 104
# 	Train:	Total Loss: 4.0005, Feature Loss: 4.0005, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5843, Feature Loss: 3.5843, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 105
# 	Train:	Total Loss: 3.9589, Feature Loss: 3.9589, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5612, Feature Loss: 3.5612, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 106
# 	Train:	Total Loss: 4.0423, Feature Loss: 4.0423, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5402, Feature Loss: 3.5402, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 107
# 	Train:	Total Loss: 4.0758, Feature Loss: 4.0758, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5229, Feature Loss: 3.5229, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 108
# 	Train:	Total Loss: 3.9701, Feature Loss: 3.9701, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5054, Feature Loss: 3.5054, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 109
# 	Train:	Total Loss: 3.9309, Feature Loss: 3.9309, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.4861, Feature Loss: 3.4861, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 110
# 	Train:	Total Loss: 3.9635, Feature Loss: 3.9635, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.4679, Feature Loss: 3.4679, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 111
# 	Train:	Total Loss: 3.9428, Feature Loss: 3.9428, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.4497, Feature Loss: 3.4497, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 112
# 	Train:	Total Loss: 4.0236, Feature Loss: 4.0236, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.4339, Feature Loss: 3.4339, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 113
# 	Train:	Total Loss: 3.8645, Feature Loss: 3.8645, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.4199, Feature Loss: 3.4199, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 114
# 	Train:	Total Loss: 3.9084, Feature Loss: 3.9084, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.4052, Feature Loss: 3.4052, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 115
# 	Train:	Total Loss: 3.8572, Feature Loss: 3.8572, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.3901, Feature Loss: 3.3901, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 116
# 	Train:	Total Loss: 3.9479, Feature Loss: 3.9479, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.3764, Feature Loss: 3.3764, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 117
# 	Train:	Total Loss: 3.8514, Feature Loss: 3.8514, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.3664, Feature Loss: 3.3664, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 118
# 	Train:	Total Loss: 3.8755, Feature Loss: 3.8755, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.3531, Feature Loss: 3.3531, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 119
# 	Train:	Total Loss: 3.8861, Feature Loss: 3.8861, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.3370, Feature Loss: 3.3370, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 120
# 	Train:	Total Loss: 3.8339, Feature Loss: 3.8339, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.3224, Feature Loss: 3.3224, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 121
# 	Train:	Total Loss: 3.8228, Feature Loss: 3.8228, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.3097, Feature Loss: 3.3097, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 122
# 	Train:	Total Loss: 3.7837, Feature Loss: 3.7837, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.3021, Feature Loss: 3.3021, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 123
# 	Train:	Total Loss: 3.7783, Feature Loss: 3.7783, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2870, Feature Loss: 3.2870, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 124
# 	Train:	Total Loss: 3.8211, Feature Loss: 3.8211, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2740, Feature Loss: 3.2740, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 125
# 	Train:	Total Loss: 3.8431, Feature Loss: 3.8431, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2655, Feature Loss: 3.2655, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 126
# 	Train:	Total Loss: 3.7796, Feature Loss: 3.7796, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2533, Feature Loss: 3.2533, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 127
# 	Train:	Total Loss: 3.7926, Feature Loss: 3.7926, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2418, Feature Loss: 3.2418, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 128
# 	Train:	Total Loss: 3.7795, Feature Loss: 3.7795, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2326, Feature Loss: 3.2326, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 129
# 	Train:	Total Loss: 3.7298, Feature Loss: 3.7298, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2259, Feature Loss: 3.2259, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 130
# 	Train:	Total Loss: 3.7680, Feature Loss: 3.7680, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2150, Feature Loss: 3.2150, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 131
# 	Train:	Total Loss: 3.7161, Feature Loss: 3.7161, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2021, Feature Loss: 3.2021, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 132
# 	Train:	Total Loss: 3.7732, Feature Loss: 3.7732, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.1911, Feature Loss: 3.1911, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 133
# 	Train:	Total Loss: 3.6933, Feature Loss: 3.6933, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.1797, Feature Loss: 3.1797, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 134
# 	Train:	Total Loss: 3.6639, Feature Loss: 3.6639, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.1653, Feature Loss: 3.1653, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 135
# 	Train:	Total Loss: 3.6890, Feature Loss: 3.6890, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.1576, Feature Loss: 3.1576, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 136
# 	Train:	Total Loss: 3.6200, Feature Loss: 3.6200, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.1526, Feature Loss: 3.1526, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 137
# 	Train:	Total Loss: 3.6724, Feature Loss: 3.6724, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.1378, Feature Loss: 3.1378, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 138
# 	Train:	Total Loss: 3.6693, Feature Loss: 3.6693, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.1249, Feature Loss: 3.1249, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 139
# 	Train:	Total Loss: 3.6794, Feature Loss: 3.6794, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.1158, Feature Loss: 3.1158, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 140
# 	Train:	Total Loss: 3.6553, Feature Loss: 3.6553, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.1063, Feature Loss: 3.1063, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 141
# 	Train:	Total Loss: 3.6343, Feature Loss: 3.6343, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.0963, Feature Loss: 3.0963, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 142
# 	Train:	Total Loss: 3.5812, Feature Loss: 3.5812, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.0870, Feature Loss: 3.0870, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 143
# 	Train:	Total Loss: 3.6331, Feature Loss: 3.6331, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.0758, Feature Loss: 3.0758, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 144
# 	Train:	Total Loss: 3.6343, Feature Loss: 3.6343, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.0753, Feature Loss: 3.0753, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 145
# 	Train:	Total Loss: 3.5637, Feature Loss: 3.5637, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.0590, Feature Loss: 3.0590, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 146
# 	Train:	Total Loss: 3.5860, Feature Loss: 3.5860, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.0531, Feature Loss: 3.0531, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 147
# 	Train:	Total Loss: 3.5190, Feature Loss: 3.5190, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.0421, Feature Loss: 3.0421, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 148
# 	Train:	Total Loss: 3.5812, Feature Loss: 3.5812, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.0392, Feature Loss: 3.0392, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 149
# 	Train:	Total Loss: 3.5194, Feature Loss: 3.5194, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.0261, Feature Loss: 3.0261, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 150
# 	Train:	Total Loss: 3.5270, Feature Loss: 3.5270, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.0172, Feature Loss: 3.0172, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 151
# 	Train:	Total Loss: 3.5005, Feature Loss: 3.5005, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.0111, Feature Loss: 3.0111, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 152
# 	Train:	Total Loss: 3.5063, Feature Loss: 3.5063, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.9978, Feature Loss: 2.9978, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 153
# 	Train:	Total Loss: 3.5133, Feature Loss: 3.5133, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.9865, Feature Loss: 2.9865, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 154
# 	Train:	Total Loss: 3.5055, Feature Loss: 3.5055, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.9764, Feature Loss: 2.9764, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 155
# 	Train:	Total Loss: 3.4710, Feature Loss: 3.4710, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.9697, Feature Loss: 2.9697, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 156
# 	Train:	Total Loss: 3.4572, Feature Loss: 3.4572, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.9647, Feature Loss: 2.9647, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 157
# 	Train:	Total Loss: 3.4280, Feature Loss: 3.4280, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.9575, Feature Loss: 2.9575, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 158
# 	Train:	Total Loss: 3.4880, Feature Loss: 3.4880, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.9496, Feature Loss: 2.9496, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 159
# 	Train:	Total Loss: 3.4462, Feature Loss: 3.4462, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.9384, Feature Loss: 2.9384, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 160
# 	Train:	Total Loss: 3.4200, Feature Loss: 3.4200, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.9334, Feature Loss: 2.9334, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 161
# 	Train:	Total Loss: 3.3924, Feature Loss: 3.3924, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.9241, Feature Loss: 2.9241, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 162
# 	Train:	Total Loss: 3.4828, Feature Loss: 3.4828, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.9164, Feature Loss: 2.9164, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 163
# 	Train:	Total Loss: 3.3773, Feature Loss: 3.3773, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.9174, Feature Loss: 2.9174, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 164
# 	Train:	Total Loss: 3.4387, Feature Loss: 3.4387, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.9034, Feature Loss: 2.9034, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 165
# 	Train:	Total Loss: 3.3932, Feature Loss: 3.3932, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8961, Feature Loss: 2.8961, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 166
# 	Train:	Total Loss: 3.3761, Feature Loss: 3.3761, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8843, Feature Loss: 2.8843, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 167
# 	Train:	Total Loss: 3.3606, Feature Loss: 3.3606, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8788, Feature Loss: 2.8788, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 168
# 	Train:	Total Loss: 3.3647, Feature Loss: 3.3647, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8778, Feature Loss: 2.8778, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 169
# 	Train:	Total Loss: 3.3705, Feature Loss: 3.3705, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8673, Feature Loss: 2.8673, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 170
# 	Train:	Total Loss: 3.3473, Feature Loss: 3.3473, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8630, Feature Loss: 2.8630, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 171
# 	Train:	Total Loss: 3.3575, Feature Loss: 3.3575, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8590, Feature Loss: 2.8590, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 172
# 	Train:	Total Loss: 3.3357, Feature Loss: 3.3357, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8496, Feature Loss: 2.8496, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 173
# 	Train:	Total Loss: 3.4804, Feature Loss: 3.4804, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8583, Feature Loss: 2.8583, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 174
# 	Train:	Total Loss: 3.3278, Feature Loss: 3.3278, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8386, Feature Loss: 2.8386, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 175
# 	Train:	Total Loss: 3.3250, Feature Loss: 3.3250, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8350, Feature Loss: 2.8350, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 176
# 	Train:	Total Loss: 3.3031, Feature Loss: 3.3031, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8314, Feature Loss: 2.8314, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 177
# 	Train:	Total Loss: 3.2895, Feature Loss: 3.2895, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8241, Feature Loss: 2.8241, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 178
# 	Train:	Total Loss: 3.2730, Feature Loss: 3.2730, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8124, Feature Loss: 2.8124, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 179
# 	Train:	Total Loss: 3.2945, Feature Loss: 3.2945, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8073, Feature Loss: 2.8073, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 180
# 	Train:	Total Loss: 3.2882, Feature Loss: 3.2882, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7997, Feature Loss: 2.7997, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 181
# 	Train:	Total Loss: 3.2811, Feature Loss: 3.2811, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7974, Feature Loss: 2.7974, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 182
# 	Train:	Total Loss: 3.2767, Feature Loss: 3.2767, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7921, Feature Loss: 2.7921, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 183
# 	Train:	Total Loss: 3.2927, Feature Loss: 3.2927, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7892, Feature Loss: 2.7892, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 184
# 	Train:	Total Loss: 3.2744, Feature Loss: 3.2744, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7841, Feature Loss: 2.7841, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 185
# 	Train:	Total Loss: 3.2465, Feature Loss: 3.2465, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7790, Feature Loss: 2.7790, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 186
# 	Train:	Total Loss: 3.2288, Feature Loss: 3.2288, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7758, Feature Loss: 2.7758, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 187
# 	Train:	Total Loss: 3.2791, Feature Loss: 3.2791, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7707, Feature Loss: 2.7707, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 188
# 	Train:	Total Loss: 3.2342, Feature Loss: 3.2342, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7686, Feature Loss: 2.7686, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 189
# 	Train:	Total Loss: 3.2370, Feature Loss: 3.2370, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7570, Feature Loss: 2.7570, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 190
# 	Train:	Total Loss: 3.2178, Feature Loss: 3.2178, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7564, Feature Loss: 2.7564, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 191
# 	Train:	Total Loss: 3.2021, Feature Loss: 3.2021, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7545, Feature Loss: 2.7545, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 192
# 	Train:	Total Loss: 3.2194, Feature Loss: 3.2194, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7497, Feature Loss: 2.7497, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 193
# 	Train:	Total Loss: 3.2216, Feature Loss: 3.2216, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7458, Feature Loss: 2.7458, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 194
# 	Train:	Total Loss: 3.2207, Feature Loss: 3.2207, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7377, Feature Loss: 2.7377, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 195
# 	Train:	Total Loss: 3.1813, Feature Loss: 3.1813, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7305, Feature Loss: 2.7305, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 196
# 	Train:	Total Loss: 3.1839, Feature Loss: 3.1839, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7380, Feature Loss: 2.7380, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 197
# 	Train:	Total Loss: 3.1903, Feature Loss: 3.1903, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7231, Feature Loss: 2.7231, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 198
# 	Train:	Total Loss: 3.1960, Feature Loss: 3.1960, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7255, Feature Loss: 2.7255, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 199
# 	Train:	Total Loss: 3.1502, Feature Loss: 3.1502, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7201, Feature Loss: 2.7201, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 200
# 	Train:	Total Loss: 3.1731, Feature Loss: 3.1731, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.7177, Feature Loss: 2.7177, Type Loss: 0.0000 , LR: 0.000100

# %%
if not model_loaded:
    plt.figure(figsize=(14, 5))
    plt.plot(test_total_losses, label='Total Test Loss')
    plt.plot(train_total_losses, label='Total Train Loss')
    plt.legend()
    plt.title('Total Loss')
    plt.savefig("model2_totalloss.png")
    plt.show()

# %%
if not model_loaded:
    plt.figure(figsize=(14, 5))
    plt.plot(test_feature_losses, label='Test Feature Loss')
    plt.plot(train_feature_losses, label='Train Feature Loss')
    plt.legend()
    plt.title('Feature Loss')
    plt.savefig("model2_featureloss.png")
    plt.show()

# %%
test_loader_melt = DataLoader(graphs_melt, batch_size=1)
encoded_data_melt=[]
type_data_melt = []
for data in test_loader:
    model.eval()
    z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
    decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
    encoded_data_melt.append(z.detach().numpy())
    type_data_melt.append(str_type.detach().numpy())

encoded_data_melt = np.array(encoded_data_melt)
type_data_melt = np.array(type_data_melt)

# %%
test_loader_cry = DataLoader(graphs_cry, batch_size=1)
encoded_data_cry=[]
type_data_cry = []
for data in test_loader:
    model.eval()
    z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
    decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
    encoded_data_cry.append(z.detach().numpy())
    type_data_cry.append(str_type.detach().numpy())

encoded_data_cry = np.array(encoded_data_cry)
type_data_cry = np.array(type_data_cry)

# %%
# %matplotlib widget

frame = 10

fig = plt.figure(figsize=(15,4))
data_melt = encoded_data_melt[frame]

data_cry = encoded_data_cry[frame]
plt.scatter(data_melt[:,0],data_melt[:,1],c="r",label="melt")
plt.scatter(data_cry[:,0],data_cry[:,1],c="b",label="crystal")
plt.savefig("model2_scatter.png")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
