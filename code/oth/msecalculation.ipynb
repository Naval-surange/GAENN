# %%
import mdtraj as md
from ase import Atoms
import nglview as nv
import networkx as nx

import numpy as np
import matplotlib.pyplot as plt
import torch
from tqdm import tqdm

import torch_geometric.transforms as T
from torch_geometric.loader import DataLoader
from torch_geometric.nn import GCNConv, SAGPooling, InnerProductDecoder
import torch_geometric.data as data
from torch_geometric.utils.convert import to_networkx
import torch.optim.lr_scheduler as lr_scheduler
from torch.nn import Linear
import sys

# %%
all_frames_cry = md.load_xtc("../simulation/para_crystal.xtc", top="../simulation/para_crystal.gro")
all_frames_melt = md.load_xtc("../simulation/para_melt.xtc", top="../simulation/para_melt.gro")

# %%
all_frames_cry = all_frames_cry[::100]
all_frames_melt = all_frames_melt[::100]

# %%
n_frames = all_frames_cry.xyz.shape[0]
n_atoms = all_frames_cry.topology.residue(0).n_atoms
n_mols = all_frames_cry.topology.n_residues

# %%
mol_com=[]
positions=[]

def createGraph(all_frames,structure_type="crystal"):
    all_frames_fatures = []

    print("Creating Feature matrix")
    for i in tqdm(range(all_frames.xyz.shape[0])):
        mol_com_pos = []

        for res in all_frames.top.residues:
            pos = []
            for atom in res.atoms:
                pos.append(all_frames.xyz[i][atom.index])
            mol_com_pos.append(np.mean(pos,axis=0))
            positions=pos
            
            # print()
        mol_com_pos = np.array(mol_com_pos).astype(np.float32)  
        all_frames_fatures.append(mol_com_pos)

    all_frames_fatures = np.array(all_frames_fatures).astype(np.float32)

    mol_com=mol_com_pos

    cutoff = 0.8

    print("Creating Edge list")
    all_edge_list = []
    # with open("edge_list.txt","w") as f:
    for frame_i in tqdm(range(n_frames)):
        from_list = []
        to_list = []

        for i in range(len(all_frames_fatures[frame_i])):
            for j in range(i+1,len(all_frames_fatures[frame_i])):
                if np.linalg.norm(all_frames_fatures[frame_i][i]-all_frames_fatures[frame_i][j]) < cutoff:
                    # f.write(str(i)+" "+str(j)+" "+str(np.linalg.norm(all_frames_fatures[frame_i][i]-all_frames_fatures[frame_i][j]))+"\n")
                    from_list.append(i)
                    to_list.append(j)

                    to_list.append(i)
                    from_list.append(j)

        edge_list = np.array([from_list,to_list]).astype(np.int64)
        all_edge_list.append(edge_list)
    print("creating Graphs")
    graphs = []
    for frame in tqdm(range(n_frames)):
        if structure_type == "crystal":
            g = data.Data(x=torch.tensor(all_frames_fatures[frame]).float(), edge_index=torch.tensor(all_edge_list[frame]).long(), y=torch.tensor([0]))
        else:
            g = data.Data(x=torch.tensor(all_frames_fatures[frame]).float(), edge_index=torch.tensor(all_edge_list[frame]).long(), y=torch.tensor([1]))
        graphs.append(g)
    return graphs

# %%
graphs_cry = createGraph(all_frames_cry,structure_type="crystal")
graphs_melt = createGraph(all_frames_melt,structure_type="melt")
# Out:
# Creating Feature matrix
# 100%|██████████| 51/51 [00:00<00:00, 94.16it/s]
# Creating Edge list
# 100%|██████████| 51/51 [00:49<00:00,  1.03it/s]
# creating Graphs
# 100%|██████████| 51/51 [00:00<00:00, 23304.23it/s]
# Creating Feature matrix
# 100%|██████████| 51/51 [00:00<00:00, 88.01it/s]
# Creating Edge list
# 100%|██████████| 51/51 [00:50<00:00,  1.01it/s]
# creating Graphs
# 100%|██████████| 51/51 [00:00<00:00, 18673.90it/s]

# %%
all_frame_positions = []
for i in range(n_frames):
    all_frame_positions.append(all_frames_cry.xyz[i])
all_frame_positions = np.array(all_frame_positions).astype(np.float32)
print(all_frame_positions)
# Out:
# [[[ 1.5200001   4.181       4.893     ]
#   [ 1.4070001   4.214       4.977     ]
#   [ 1.276       4.171       4.9360003 ]
#   ...
#   [ 5.9600005   0.284       8.767     ]
#   [ 6.0790005   0.41400003  8.779     ]
#   [ 5.6400003   0.76400006  8.121     ]]
#
#  [[ 1.243       4.421       4.637     ]
#   [ 1.12        4.4810004   4.6800003 ]
#   [ 1.006       4.465       4.5940003 ]
#   ...
#   [ 6.1740003   0.20300001  8.841001  ]
#   [ 6.2520003   0.34        8.786     ]
#   [ 5.848       0.60200006  8.101001  ]]
#
#  [[ 1.005       4.477       4.144     ]
#   [ 0.878       4.5400004   4.1730003 ]
#   [ 0.758       4.485       4.123     ]
#   ...
#   [ 6.175      -0.029       8.819     ]
#   [ 6.314      -0.012       8.704     ]
#   [ 5.952       0.323       8.021     ]]
#
#  ...
#
#  [[ 6.176       3.5700002   3.2170002 ]
#   [ 6.1330004   3.604       3.348     ]
#   [ 6.0220003   3.5390003   3.407     ]
#   ...
#   [ 5.7070003   0.67200005  6.26      ]
#   [ 5.5610003   0.58100003  6.3310003 ]
#   [ 5.6730003   0.054       5.662     ]]
#
#  [[ 6.13        3.5590003   3.206     ]
#   [ 6.1000004   3.5890002   3.341     ]
#   [ 5.986       3.5470002   3.4110003 ]
#   ...
#   [ 5.596       0.54700005  6.3450003 ]
#   [ 5.7400002   0.507       6.432     ]
#   [ 5.531      -0.078       5.762     ]]
#
#  [[ 6.2200003   3.571       3.226     ]
#   [ 6.1920004   3.5850003   3.3630002 ]
#   [ 6.0810003   3.522       3.4190001 ]
#   ...
#   [ 5.7770004   0.744       6.313     ]
#   [ 5.781       0.80500007  6.1480002 ]
#   [ 5.669       0.066       5.716     ]]]

# %%
def convert_to_adj(edge_index, num_nodes=None):
    if num_nodes is None:
        num_nodes = edge_index.max() + 1
    adj = torch.zeros(num_nodes, num_nodes)
    adj[edge_index[0], edge_index[1]] = 1
    return adj

def convert_to_edge_index(adj):
    edge_index = adj.nonzero().t()
    return edge_index

# %%
graphs = graphs_cry + graphs_melt

# %%
# shuffle the graphs
np.random.shuffle(graphs)

# %%
graphs
# Out:
# [Data(x=[864, 3], edge_index=[2, 5962], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6464], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6602], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5876], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7294], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7132], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6570], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6630], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5822], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7080], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7108], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6560], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6476], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6070], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7092], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6596], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6580], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7078], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5982], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6546], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7006], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7274], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7094], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6066], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7012], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6018], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7020], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7028], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7026], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6288], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7034], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7090], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6560], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7374], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7054], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7088], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6626], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7078], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6990], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7116], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7240], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6488], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6578], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6592], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6548], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6992], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7036], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6012], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7092], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7074], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7048], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7060], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7096], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7008], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7306], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7044], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6214], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6584], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6582], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6532], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6452], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6172], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6400], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7218], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7064], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7116], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6542], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6934], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6056], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6508], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6524], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6554], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6608], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7006], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7128], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6558], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7100], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7052], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6544], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5862], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7146], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6508], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7024], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5892], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6552], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6512], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5910], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6546], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7076], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6564], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7048], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7192], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6548], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5880], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7056], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6964], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7052], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7122], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6566], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7060], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7086], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6586], y=[1])]

# %% [markdown]
# ## model

# %%
from typing import Optional, Tuple

import torch
from torch import Tensor
from torch.nn import Module

from torch_geometric.nn.inits import reset
from torch_geometric.utils import negative_sampling

EPS = 1e-15
MAX_LOGSTD = 10
edgeShape = None
featureShape = None


class InnerProductDecoder(torch.nn.Module):
    r"""The inner product decoder from the `"Variational Graph Auto-Encoders"
    <https://arxiv.org/abs/1611.07308>`_ paper

    .. math::
        \sigma(\mathbf{Z}\mathbf{Z}^{\top})

    where :math:`\mathbf{Z} \in \mathbb{R}^{N \times d}` denotes the latent
    space produced by the encoder."""

    def forward(self, z: Tensor, edge_index: Tensor,
                sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into edge probabilities for
        the given node-pairs :obj:`edge_index`.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        value = (z[edge_index[0]] * z[edge_index[1]]).sum(dim=1)
        return torch.sigmoid(value) if sigmoid else value

    def forward_all(self, z: Tensor, sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into a probabilistic dense
        adjacency matrix.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        adj = torch.matmul(z, z.t())
        return torch.sigmoid(adj) if sigmoid else adj


class GAE(torch.nn.Module):
    r"""The Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper based on user-defined encoder and decoder models.

    Args:
        encoder (torch.nn.Module): The encoder module.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__()
        self.encoder = encoder
        self.decoder = InnerProductDecoder() if decoder is None else decoder
        GAE.reset_parameters(self)

    def reset_parameters(self):
        r"""Resets all learnable parameters of the module."""
        reset(self.encoder)
        reset(self.decoder)

    def forward(self, *args, **kwargs) -> Tensor:  # pragma: no cover
        r"""Alias for :meth:`encode`."""
        return self.encoder(*args, **kwargs)

    def encode(self, *args, **kwargs) -> Tensor:
        r"""Runs the encoder and computes node-wise latent variables."""
        return self.encoder(*args, **kwargs)

    def decode(self, *args, **kwargs) -> Tensor:
        r"""Runs the decoder and computes edge probabilities."""
        return self.decoder(*args, **kwargs)

    def recon_loss(self, z: Tensor, pos_edge_index: Tensor,
                   neg_edge_index: Optional[Tensor] = None) -> Tensor:
        r"""Given latent variables :obj:`z`, computes the binary cross
        entropy loss for positive edges :obj:`pos_edge_index` and negative
        sampled edges.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to train against.
            neg_edge_index (torch.Tensor, optional): The negative edges to
                train against. If not given, uses negative sampling to
                calculate negative edges. (default: :obj:`None`)
        """
        pos_loss = -torch.log(
            self.decoder(z, pos_edge_index, sigmoid=True)[0] + EPS).mean()

        if neg_edge_index is None:
            neg_edge_index = negative_sampling(pos_edge_index, z.size(0))
        neg_loss = -torch.log(1 -
                              self.decoder(z, neg_edge_index.long(), sigmoid=True)[0] +
                              EPS).mean()

        return pos_loss + neg_loss

    def test(self, z: Tensor, pos_edge_index: Tensor,
             neg_edge_index: Tensor) -> Tuple[Tensor, Tensor]:
        r"""Given latent variables :obj:`z`, positive edges
        :obj:`pos_edge_index` and negative edges :obj:`neg_edge_index`,
        computes area under the ROC curve (AUC) and average precision (AP)
        
        scores.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to evaluate
                against.
            neg_edge_index (torch.Tensor): The negative edges to evaluate
                against.
        """
        from sklearn.metrics import average_precision_score, roc_auc_score

        pos_y = z.new_ones(pos_edge_index.size(1))
        neg_y = z.new_zeros(neg_edge_index.size(1))
        y = torch.cat([pos_y, neg_y], dim=0)

        pos_pred = self.decoder(z, pos_edge_index, sigmoid=True)
        neg_pred = self.decoder(z, neg_edge_index, sigmoid=True)
        pred = torch.cat([pos_pred, neg_pred], dim=0)

        y, pred = y.detach().cpu().numpy(), pred.detach().cpu().numpy()

        return roc_auc_score(y, pred), average_precision_score(y, pred)


class VGAE(GAE):
    r"""The Variational Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper.

    Args:
        encoder (torch.nn.Module): The encoder module to compute :math:`\mu`
            and :math:`\log\sigma^2`.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__(encoder, decoder)

    def reparametrize(self, mu: Tensor, logstd: Tensor) -> Tensor:
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def encode(self, *args, **kwargs) -> Tensor:
        """"""
        z, self.edge_index = self.encoder(
            *args, **kwargs)
        
        return z, self.edge_index

    def kl_loss(self, mu: Optional[Tensor] = None,
                logstd: Optional[Tensor] = None) -> Tensor:
        r"""Computes the KL loss, either for the passed arguments :obj:`mu`
        and :obj:`logstd`, or based on latent variables from last encoding.

        Args:
            mu (torch.Tensor, optional): The latent space for :math:`\mu`. If
                set to :obj:`None`, uses the last computation of :math:`\mu`.
                (default: :obj:`None`)
            logstd (torch.Tensor, optional): The latent space for
                :math:`\log\sigma`.  If set to :obj:`None`, uses the last
                computation of :math:`\log\sigma^2`. (default: :obj:`None`)
        """
        mu = self.__mu__ if mu is None else mu
        logstd = self.__logstd__ if logstd is None else logstd.clamp(
            max=MAX_LOGSTD)
        return -0.5 * torch.mean(
            torch.sum(1 + 2 * logstd - mu**2 - logstd.exp()**2, dim=1))

# %%
import torch.nn.functional as F



class VariationalGCNEncoder(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.conv1 = GCNConv(in_channels, 2 * out_channels)
        self.conv2 = GCNConv(2*out_channels, 1 * out_channels)
        self.pool = SAGPooling(out_channels, 0.5)
        
        self.conv_mu = GCNConv(1 * out_channels, out_channels)
        self.conv_logstd = GCNConv(1 * out_channels, out_channels)
        self.conv_mu_crystal = GCNConv(1 * out_channels, out_channels)
        self.conv_logstd_crystal = GCNConv(1 * out_channels, out_channels)
        self.conv_mu_melt = GCNConv(1 * out_channels, out_channels)
        self.conv_logstd_melt = GCNConv(1 * out_channels, out_channels)
    
    def reparametrize(self, mu: Tensor, logstd: Tensor) -> Tensor:
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def forward(self, x, edge_index,class_label):
        # print("input:",x.shape, edge_index.shape)
        x = self.conv1(x, edge_index)
        x = F.silu(x)
        # print("conv1:",x.shape, edge_index.shape)
        x = self.conv2(x, edge_index)
        x = F.silu(x)
        # print("conv2:",x.shape, edge_index.shape)

        sample = self.reparametrize(self.conv_mu(x, edge_index), self.conv_logstd(x, edge_index))
        
        sample_crystal = self.reparametrize(self.conv_mu_crystal(sample, edge_index), self.conv_logstd_crystal(sample, edge_index))
        sample_melt = self.reparametrize(self.conv_mu_melt(sample, edge_index), self.conv_logstd_melt(sample, edge_index))

        self.conv_mu_crystal.train(True)
        self.conv_logstd_crystal.train(True)
        self.conv_mu_melt.train(True)
        self.conv_logstd_melt.train(True)


        if class_label == 0:
            self.conv_mu_melt.train(False)
            self.conv_logstd_melt.train(False)
            return sample_crystal, edge_index
        else:
            self.conv_mu_crystal.train(False)
            self.conv_logstd_crystal.train(False)
            return sample_melt, edge_index

# %%
class VariationalGCNDecoder(torch.nn.Module):
    def __init__(self,in_channels,out_channels):
        super().__init__()
        self.type_layer1 = Linear(1728,200)
        self.dropout = torch.nn.Dropout(0.5)
        self.type_layer2 = Linear(200,2)

        self.conv1 = GCNConv(in_channels, 2 * out_channels)
        self.conv2 = GCNConv(2 * out_channels, 1 * out_channels)
    def forward(self, x, edge_index, sigmoid=True):
        # print("input:",x.shape, edge_index.shape)
        flat = x.flatten()
        flat = self.type_layer1(flat).relu()
        flat = self.dropout(flat)
        str_type = F.softmax(self.type_layer2(flat).relu(),dim=0)
         
        x = self.conv1(x, edge_index)
        x = F.silu(x)
        # print("conv1:",x.shape, edge_index.shape)
        x = self.conv2(x, edge_index)
        x = F.silu(x)
        # print("conv2:",x.shape, edge_index.shape)
        return x, edge_index,str_type

# %%
import os
in_channels = graphs[0].num_features
out_channels = 2
lr = 1e-4
n_epochs = 200
batch_size=1
test_train_split = 0.8
model_name = "InterGVAE_para_combined_GMM.pt"
model_loaded = False
force_train = True

if os.path.exists("./models/"+model_name) and not force_train:
    model = torch.load("./models/"+model_name)
    model_loaded = True
else:
    model = VGAE(VariationalGCNEncoder(in_channels, out_channels),
                VariationalGCNDecoder(out_channels, in_channels))

optimizer = torch.optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, step_size=300, gamma=0.5)

# %%
train_loader = DataLoader(graphs[:int(n_frames*test_train_split)], batch_size=batch_size, shuffle=True)
test_loader = DataLoader(graphs[int(n_frames*test_train_split):], batch_size=batch_size, shuffle=True)

# %%
lossFxn = torch.nn.MSELoss()
typeLossFxn = torch.nn.CrossEntropyLoss()
mseloss_position=[]
def train():
    model.train()
    model.zero_grad()
    model.float()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0
    type_loss_all = 0
    mseloss_position_0=0
    for data in train_loader:
        optimizer.zero_grad()
        z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
        decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)

     
        # TypeLoss = typeLossFxn(str_type.unsqueeze(0), data.y)
        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        loss = FeatureLoss + EdgeLoss 
        mseloss_position_0 = lossFxn(decoded_x,data.x)
        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        # type_loss_all += float(TypeLoss)

        loss.backward()
        optimizer.step()
        mseloss_position.append(mseloss_position_0)
        

    return loss_all / len(train_loader), feature_loss_all / len(train_loader), edge_loss_all / len(train_loader), kl_loss_all / len(train_loader), type_loss_all / len(train_loader)

# %%
z
# Out:
# tensor([[ 0.2124, -2.2773],
#         [ 0.1015, -1.9469],
#         [-0.0301, -1.5198],
#         ...,
#         [ 0.1578, -2.1648],
#         [ 0.1642, -2.3212],
#         [-0.2779, -1.0083]], grad_fn=<AddBackward0>)

# %%
print(mseloss_position)
# Out:
# []

# %%
lossFxn = torch.nn.MSELoss()
def test():
    model.eval()
    model.zero_grad()
    model.float()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0
    type_loss_all = 0

    for data in test_loader:
        optimizer.zero_grad()
        z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
        decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
        
        # TypeLoss = typeLossFxn(str_type.unsqueeze(0), data.y)
        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        loss = FeatureLoss + EdgeLoss 

        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        # type_loss_all += float(TypeLoss)
        
        
        

    return loss_all / len(test_loader), feature_loss_all / len(test_loader), edge_loss_all / len(test_loader), kl_loss_all / len(test_loader), type_loss_all / len(test_loader)

# %%
train_total_losses = []
train_feature_losses = []
train_edge_losses = []
train_kl_losses = []
train_type_losses = []

test_total_losses = []
test_feature_losses = []
test_edge_losses = []
test_kl_losses = []
test_type_losses = []

if model_loaded:        
    print("Pretrained Model Loaded, no training required")
else:
    for epoch in range(1, n_epochs + 1):
        
        train_total_loss, train_feature_loss, train_edge_loss, train_kl_loss,train_type_loss = train()
        test_total_loss, test_feature_loss, test_edge_loss, test_kl_loss, test_type_loss= test()
        
        print(f"Epoch: {epoch:03d}")
        print(f'\tTrain:\tTotal Loss: {train_total_loss:.4f}, Feature Loss: {train_feature_loss:.4f}, Type Loss: {train_type_loss:.4f} ,  LR: {scheduler.get_last_lr()[0]:.6f}')
        print(f'\tTest: \tTotal Loss: {test_total_loss:.4f}, Feature Loss: {test_feature_loss:.4f}, Type Loss: {test_type_loss:.4f} , LR: {scheduler.get_last_lr()[0]:.6f}')
        
        
        train_total_losses.append(train_total_loss)
        train_feature_losses.append(train_feature_loss)
        train_edge_losses.append(train_edge_loss)
        train_kl_losses.append(train_kl_loss)
        train_type_losses.append(train_type_loss)


        test_total_losses.append(test_total_loss)
        test_feature_losses.append(test_feature_loss)
        test_edge_losses.append(test_edge_loss)
        test_kl_losses.append(test_kl_loss)
        test_type_losses.append(test_type_loss)
        
        scheduler.step()
    torch.save(model,"./models/"+model_name)
# Out:
# Epoch: 001
# 	Train:	Total Loss: 13.0615, Feature Loss: 13.0615, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.5553, Feature Loss: 12.5553, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 002
# 	Train:	Total Loss: 13.0338, Feature Loss: 13.0338, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.5302, Feature Loss: 12.5302, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 003
# 	Train:	Total Loss: 13.0088, Feature Loss: 13.0088, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.5047, Feature Loss: 12.5047, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 004
# 	Train:	Total Loss: 12.9824, Feature Loss: 12.9824, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.4785, Feature Loss: 12.4785, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 005
# 	Train:	Total Loss: 12.9462, Feature Loss: 12.9462, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.4519, Feature Loss: 12.4519, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 006
# 	Train:	Total Loss: 12.9131, Feature Loss: 12.9131, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.4244, Feature Loss: 12.4244, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 007
# 	Train:	Total Loss: 12.8872, Feature Loss: 12.8872, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.3964, Feature Loss: 12.3964, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 008
# 	Train:	Total Loss: 12.8462, Feature Loss: 12.8462, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.3675, Feature Loss: 12.3675, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 009
# 	Train:	Total Loss: 12.8213, Feature Loss: 12.8213, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.3378, Feature Loss: 12.3378, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 010
# 	Train:	Total Loss: 12.7893, Feature Loss: 12.7893, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.3070, Feature Loss: 12.3070, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 011
# 	Train:	Total Loss: 12.7507, Feature Loss: 12.7507, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.2751, Feature Loss: 12.2751, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 012
# 	Train:	Total Loss: 12.7242, Feature Loss: 12.7242, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.2418, Feature Loss: 12.2418, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 013
# 	Train:	Total Loss: 12.6833, Feature Loss: 12.6833, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.2070, Feature Loss: 12.2070, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 014
# 	Train:	Total Loss: 12.6230, Feature Loss: 12.6230, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.1706, Feature Loss: 12.1706, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 015
# 	Train:	Total Loss: 12.5922, Feature Loss: 12.5922, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.1327, Feature Loss: 12.1327, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 016
# 	Train:	Total Loss: 12.5602, Feature Loss: 12.5602, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0931, Feature Loss: 12.0931, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 017
# 	Train:	Total Loss: 12.5065, Feature Loss: 12.5065, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0508, Feature Loss: 12.0508, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 018
# 	Train:	Total Loss: 12.4624, Feature Loss: 12.4624, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 12.0069, Feature Loss: 12.0069, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 019
# 	Train:	Total Loss: 12.4052, Feature Loss: 12.4052, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.9612, Feature Loss: 11.9612, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 020
# 	Train:	Total Loss: 12.3364, Feature Loss: 12.3364, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11
Type Loss: 0.0000 , LR: 0.000100
# Epoch: 077
# 	Train:	Total Loss: 6.5840, Feature Loss: 6.5840, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.0058, Feature Loss: 6.0058, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 078
# 	Train:	Total Loss: 6.5172, Feature Loss: 6.5172, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.9312, Feature Loss: 5.9312, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 079
# 	Train:	Total Loss: 6.4637, Feature Loss: 6.4637, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.8588, Feature Loss: 5.8588, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 080
# 	Train:	Total Loss: 6.3666, Feature Loss: 6.3666, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.7881, Feature Loss: 5.7881, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 081
# 	Train:	Total Loss: 6.3638, Feature Loss: 6.3638, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.7176, Feature Loss: 5.7176, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 082
# 	Train:	Total Loss: 6.3052, Feature Loss: 6.3052, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.6489, Feature Loss: 5.6489, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 083
# 	Train:	Total Loss: 6.1767, Feature Loss: 6.1767, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.5816, Feature Loss: 5.5816, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 084
# 	Train:	Total Loss: 6.1892, Feature Loss: 6.1892, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.5140, Feature Loss: 5.5140, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 085
# 	Train:	Total Loss: 6.0839, Feature Loss: 6.0839, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.4507, Feature Loss: 5.4507, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 086
# 	Train:	Total Loss: 6.0654, Feature Loss: 6.0654, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.3856, Feature Loss: 5.3856, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 087
# 	Train:	Total Loss: 5.9694, Feature Loss: 5.9694, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.3225, Feature Loss: 5.3225, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 088
# 	Train:	Total Loss: 5.8932, Feature Loss: 5.8932, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.2634, Feature Loss: 5.2634, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 089
# 	Train:	Total Loss: 5.8660, Feature Loss: 5.8660, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.2022, Feature Loss: 5.2022, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 090
# 	Train:	Total Loss: 5.9491, Feature Loss: 5.9491, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.1468, Feature Loss: 5.1468, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 091
# 	Train:	Total Loss: 5.7798, Feature Loss: 5.7798, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.0927, Feature Loss: 5.0927, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 092
# 	Train:	Total Loss: 5.7007, Feature Loss: 5.7007, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.0405, Feature Loss: 5.0405, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 093
# 	Train:	Total Loss: 5.6216, Feature Loss: 5.6216, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.9879, Feature Loss: 4.9879, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 094
# 	Train:	Total Loss: 5.5950, Feature Loss: 5.5950, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.9356, Feature Loss: 4.9356, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 095
# 	Train:	Total Loss: 5.5720, Feature Loss: 5.5720, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.8858, Feature Loss: 4.8858, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 096
# 	Train:	Total Loss: 5.5138, Feature Loss: 5.5138, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.8374, Feature Loss: 4.8374, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 097
# 	Train:	Total Loss: 5.3479, Feature Loss: 5.3479, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.7893, Feature Loss: 4.7893, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 098
# 	Train:	Total Loss: 5.4833, Feature Loss: 5.4833, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.7453, Feature Loss: 4.7453, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 099
# 	Train:	Total Loss: 5.3150, Feature Loss: 5.3150, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.7030, Feature Loss: 4.7030, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 100
# 	Train:	Total Loss: 5.3058, Feature Loss: 5.3058, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.6602, Feature Loss: 4.6602, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 101
# 	Train:	Total Loss: 5.2653, Feature Loss: 5.2653, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.6178, Feature Loss: 4.6178, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 102
# 	Train:	Total Loss: 5.1985, Feature Loss: 5.1985, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.5778, Feature Loss: 4.5778, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 103
# 	Train:	Total Loss: 5.1594, Feature Loss: 5.1594, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.5369, Feature Loss: 4.5369, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 104
# 	Train:	Total Loss: 5.0348, Feature Loss: 5.0348, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.4982, Feature Loss: 4.4982, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 105
# 	Train:	Total Loss: 5.0159, Feature Loss: 5.0159, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4
Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.4648, Feature Loss: 3.4648, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 163
# 	Train:	Total Loss: 3.9896, Feature Loss: 3.9896, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.4553, Feature Loss: 3.4553, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 164
# 	Train:	Total Loss: 3.9578, Feature Loss: 3.9578, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.4463, Feature Loss: 3.4463, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 165
# 	Train:	Total Loss: 3.9771, Feature Loss: 3.9771, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.4371, Feature Loss: 3.4371, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 166
# 	Train:	Total Loss: 4.0342, Feature Loss: 4.0342, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.4277, Feature Loss: 3.4277, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 167
# 	Train:	Total Loss: 3.9430, Feature Loss: 3.9430, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.4190, Feature Loss: 3.4190, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 168
# 	Train:	Total Loss: 3.9061, Feature Loss: 3.9061, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.4098, Feature Loss: 3.4098, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 169
# 	Train:	Total Loss: 3.9673, Feature Loss: 3.9673, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.4009, Feature Loss: 3.4009, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 170
# 	Train:	Total Loss: 3.9744, Feature Loss: 3.9744, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.3928, Feature Loss: 3.3928, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 171
# 	Train:	Total Loss: 3.9121, Feature Loss: 3.9121, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.3835, Feature Loss: 3.3835, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 172
# 	Train:	Total Loss: 3.8469, Feature Loss: 3.8469, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.3746, Feature Loss: 3.3746, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 173
# 	Train:	Total Loss: 3.8430, Feature Loss: 3.8430, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.3670, Feature Loss: 3.3670, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 174
# 	Train:	Total Loss: 3.9561, Feature Loss: 3.9561, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.3587, Feature Loss: 3.3587, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 175
# 	Train:	Total Loss: 3.8821, Feature Loss: 3.8821, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.3500, Feature Loss: 3.3500, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 176
# 	Train:	Total Loss: 3.8723, Feature Loss: 3.8723, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.3419, Feature Loss: 3.3419, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 177
# 	Train:	Total Loss: 3.9005, Feature Loss: 3.9005, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.3338, Feature Loss: 3.3338, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 178
# 	Train:	Total Loss: 3.8367, Feature Loss: 3.8367, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.3256, Feature Loss: 3.3256, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 179
# 	Train:	Total Loss: 3.8250, Feature Loss: 3.8250, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.3173, Feature Loss: 3.3173, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 180
# 	Train:	Total Loss: 3.8537, Feature Loss: 3.8537, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.3089, Feature Loss: 3.3089, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 181
# 	Train:	Total Loss: 3.7824, Feature Loss: 3.7824, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.3009, Feature Loss: 3.3009, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 182
# 	Train:	Total Loss: 3.7667, Feature Loss: 3.7667, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2919, Feature Loss: 3.2919, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 183
# 	Train:	Total Loss: 3.8159, Feature Loss: 3.8159, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2838, Feature Loss: 3.2838, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 184
# 	Train:	Total Loss: 3.7212, Feature Loss: 3.7212, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2766, Feature Loss: 3.2766, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 185
# 	Train:	Total Loss: 3.8207, Feature Loss: 3.8207, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2684, Feature Loss: 3.2684, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 186
# 	Train:	Total Loss: 3.7600, Feature Loss: 3.7600, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2604, Feature Loss: 3.2604, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 187
# 	Train:	Total Loss: 3.7746, Feature Loss: 3.7746, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2528, Feature Loss: 3.2528, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 188
# 	Train:	Total Loss: 3.7576, Feature Loss: 3.7576, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2449, Feature Loss: 3.2449, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 189
# 	Train:	Total Loss: 3.7787, Feature Loss: 3.7787, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2376, Feature Loss: 3.2376, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 190
# 	Train:	Total Loss: 3.7529, Feature Loss: 3.7529, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2305, Feature Loss: 3.2305, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 191
# 	Train:	Total Loss: 3.7205, Feature Loss: 3.7205, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2228, Feature Loss: 3.2228, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 192
# 	Train:	Total Loss: 3.8194, Feature Loss: 3.8194, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2153, Feature Loss: 3.2153, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 193
# 	Train:	Total Loss: 3.6900, Feature Loss: 3.6900, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2081, Feature Loss: 3.2081, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 194
# 	Train:	Total Loss: 3.7314, Feature Loss: 3.7314, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2005, Feature Loss: 3.2005, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 195
# 	Train:	Total Loss: 3.6947, Feature Loss: 3.6947, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.1924, Feature Loss: 3.1924, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 196
# 	Train:	Total Loss: 3.6863, Feature Loss: 3.6863, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.1856, Feature Loss: 3.1856, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 197
# 	Train:	Total Loss: 3.6721, Feature Loss: 3.6721, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.1781, Feature Loss: 3.1781, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 198
# 	Train:	Total Loss: 3.6665, Feature Loss: 3.6665, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.1710, Feature Loss: 3.1710, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 199
# 	Train:	Total Loss: 3.6330, Feature Loss: 3.6330, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.1652, Feature Loss: 3.1652, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 200
# 	Train:	Total Loss: 3.6520, Feature Loss: 3.6520, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.1582, Feature Loss: 3.1582, Type Loss: 0.0000 , LR: 0.000100

# %%
if not model_loaded:
    plt.figure(figsize=(14, 5))
    plt.plot(test_total_losses, label='Total Test Loss')
    plt.plot(train_total_losses, label='Total Train Loss')
    plt.legend()
    plt.title('Total Loss')
    plt.savefig("Inference_para_combined_GMM_totalloss.png")
    plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
if not model_loaded:
    plt.figure(figsize=(14, 5))
    plt.plot(test_feature_losses, label='Test Feature Loss')
    plt.plot(train_feature_losses, label='Train Feature Loss')
    plt.legend()
    plt.title('Feature Loss')
    plt.savefig("Inference_para_combined_GMM_feature_loss.png")
    plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
test_loader_melt = DataLoader(graphs_melt, batch_size=1)
encoded_data_melt=[]
type_data_melt = []
for data in test_loader:
    model.eval()
    z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
    decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
    encoded_data_melt.append(z.detach().numpy())
    type_data_melt.append(str_type.detach().numpy())

encoded_data_melt = np.array(encoded_data_melt)
type_data_melt = np.array(type_data_melt)

# %%
test_loader_cry = DataLoader(graphs_cry, batch_size=1)
encoded_data_cry=[]
type_data_cry = []
for data in test_loader:
    model.eval()
    z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
    decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
    encoded_data_cry.append(z.detach().numpy())
    type_data_cry.append(str_type.detach().numpy())

encoded_data_cry = np.array(encoded_data_cry)
type_data_cry = np.array(type_data_cry)

# %%
# %matplotlib widget

frame = 10

fig = plt.figure(figsize=(15,4))
data_melt = encoded_data_melt[frame]

data_cry = encoded_data_cry[frame]
plt.scatter(data_melt[:,0],data_melt[:,1],c="r",label="melt")
plt.scatter(data_cry[:,0],data_cry[:,1],c="b",label="crystal")
plt.savefig("Inference_para_combined_GMM_scatter.png")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
