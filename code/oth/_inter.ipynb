# %%
import mdtraj as md
from ase import Atoms
import nglview as nv
import networkx as nx

import torch
import torch_geometric.transforms as T
from torch_geometric.loader import DataLoader
from torch_geometric.nn import GCNConv, SAGPooling, InnerProductDecoder
import torch_geometric.data as data
from torch_geometric.utils.convert import to_networkx

import numpy as np
import matplotlib.pyplot as plt

# %%
all_frames = md.load_xtc("../simulation/npt.xtc", top="../simulation/box.gro")

# %%
all_frames_fatures = []

for i in range(all_frames.xyz.shape[0]):
    mol_com_pos = []

    for res in all_frames.top.residues:
        # print(res.index,end=" ")
        pos = []
        for atom in res.atoms:
            # print(atom.index,"-->" , frame.xyz[0][atom.index],end=" ")
            pos.append(all_frames.xyz[i][atom.index])
        mol_com_pos.append(np.mean(pos,axis=0))
        
        # print()
    mol_com_pos = np.array(mol_com_pos).astype(np.float32)  
    all_frames_fatures.append(mol_com_pos)

all_frames_fatures = np.array(all_frames_fatures).astype(np.float32)
print(all_frames_fatures.shape)
# Out:
# (51, 101, 3)

# %%
print(dir(all_frames.topology.residue(0)))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_atoms', 'atom', 'atoms', 'atoms_by_name', 'chain', 'code', 'index', 'is_nucleic', 'is_protein', 'is_water', 'n_atoms', 'name', 'resSeq', 'segment_id']

# %%
n_frames = all_frames.xyz.shape[0]
n_atoms = all_frames.topology.residue(0).n_atoms
n_mols = all_frames.topology.n_residues

# %%
print("number of molecules",n_mols)
print("number of atoms in molecule",n_atoms)
print("number of frames",n_frames)
# Out:
# number of molecules 101
# number of atoms in molecule 4
# number of frames 51

# %%
# %matplotlib widget

frame = 10

fig = plt.figure(figsize=(15,4))
ax1 = fig.add_subplot(projection='3d')
ax1.scatter(all_frames_fatures[frame][:,0],all_frames_fatures[frame][:,1],all_frames_fatures[frame][:,2])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def convert_to_adj(edge_index, num_nodes=None):
    if num_nodes is None:
        num_nodes = edge_index.max() + 1
    adj = torch.zeros(num_nodes, num_nodes)
    adj[edge_index[0], edge_index[1]] = 1
    return adj

def convert_to_edge_index(adj):
    edge_index = adj.nonzero().t()
    return edge_index

# %%
cutoff = 0.5

all_edge_list = []
for frame_i in range(n_frames):
    from_list = []
    to_list = []

    for i in range(len(all_frames_fatures[frame_i])):
        for j in range(i+1,len(all_frames_fatures[frame_i])):
            if np.linalg.norm(all_frames_fatures[frame_i][i]-all_frames_fatures[frame_i][j]) < cutoff:
                # print(i,j,np.linalg.norm(mol_com_pos[i]-mol_com_pos[j]))
                from_list.append(i)
                to_list.append(j)

                to_list.append(i)
                from_list.append(j)

    edge_list = np.array([from_list,to_list]).astype(np.int64)
    all_edge_list.append(edge_list)

print(len(all_edge_list))
# Out:
# 51

# %%
# %matplotlib widget

frame = 10

plt.figure(figsize=(15,10))
adj_binary = convert_to_adj(all_edge_list[frame], num_nodes=101)
indices = torch.where(adj_binary)
G = nx.Graph()
edges = [(i, j) for i, j in zip(indices[0].tolist(), indices[1].tolist()) if i != j]
G.add_edges_from(edges)
nx.draw_networkx(G)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Converting to pytorch graph object

# %%
graphs = []
for frame in range(n_frames):
    g = data.Data(x=torch.tensor(all_frames_fatures[frame]).float(), edge_index=torch.tensor(all_edge_list[frame]).long(), y=torch.tensor([0]))
    graphs.append(g)

print(graphs[0])
# Out:
# Data(x=[101, 3], edge_index=[2, 1158], y=[1])

# %% [markdown]
# ## Model

# %%
from typing import Optional, Tuple

import torch
from torch import Tensor
from torch.nn import Module

from torch_geometric.nn.inits import reset
from torch_geometric.utils import negative_sampling

EPS = 1e-15
MAX_LOGSTD = 10
edgeShape = None
featureShape = None


class InnerProductDecoder(torch.nn.Module):
    r"""The inner product decoder from the `"Variational Graph Auto-Encoders"
    <https://arxiv.org/abs/1611.07308>`_ paper

    .. math::
        \sigma(\mathbf{Z}\mathbf{Z}^{\top})

    where :math:`\mathbf{Z} \in \mathbb{R}^{N \times d}` denotes the latent
    space produced by the encoder."""

    def forward(self, z: Tensor, edge_index: Tensor,
                sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into edge probabilities for
        the given node-pairs :obj:`edge_index`.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        value = (z[edge_index[0]] * z[edge_index[1]]).sum(dim=1)
        return torch.sigmoid(value) if sigmoid else value

    def forward_all(self, z: Tensor, sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into a probabilistic dense
        adjacency matrix.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        adj = torch.matmul(z, z.t())
        return torch.sigmoid(adj) if sigmoid else adj


class GAE(torch.nn.Module):
    r"""The Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper based on user-defined encoder and decoder models.

    Args:
        encoder (torch.nn.Module): The encoder module.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__()
        self.encoder = encoder
        self.decoder = InnerProductDecoder() if decoder is None else decoder
        GAE.reset_parameters(self)

    def reset_parameters(self):
        r"""Resets all learnable parameters of the module."""
        reset(self.encoder)
        reset(self.decoder)

    def forward(self, *args, **kwargs) -> Tensor:  # pragma: no cover
        r"""Alias for :meth:`encode`."""
        return self.encoder(*args, **kwargs)

    def encode(self, *args, **kwargs) -> Tensor:
        r"""Runs the encoder and computes node-wise latent variables."""
        return self.encoder(*args, **kwargs)

    def decode(self, *args, **kwargs) -> Tensor:
        r"""Runs the decoder and computes edge probabilities."""
        return self.decoder(*args, **kwargs)

    def recon_loss(self, z: Tensor, pos_edge_index: Tensor,
                   neg_edge_index: Optional[Tensor] = None) -> Tensor:
        r"""Given latent variables :obj:`z`, computes the binary cross
        entropy loss for positive edges :obj:`pos_edge_index` and negative
        sampled edges.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to train against.
            neg_edge_index (torch.Tensor, optional): The negative edges to
                train against. If not given, uses negative sampling to
                calculate negative edges. (default: :obj:`None`)
        """
        pos_loss = -torch.log(
            self.decoder(z, pos_edge_index, sigmoid=True)[0] + EPS).mean()

        if neg_edge_index is None:
            neg_edge_index = negative_sampling(pos_edge_index, z.size(0))
        neg_loss = -torch.log(1 -
                              self.decoder(z, neg_edge_index.long(), sigmoid=True)[0] +
                              EPS).mean()

        return pos_loss + neg_loss

    def test(self, z: Tensor, pos_edge_index: Tensor,
             neg_edge_index: Tensor) -> Tuple[Tensor, Tensor]:
        r"""Given latent variables :obj:`z`, positive edges
        :obj:`pos_edge_index` and negative edges :obj:`neg_edge_index`,
        computes area under the ROC curve (AUC) and average precision (AP)
        
        scores.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to evaluate
                against.
            neg_edge_index (torch.Tensor): The negative edges to evaluate
                against.
        """
        from sklearn.metrics import average_precision_score, roc_auc_score

        pos_y = z.new_ones(pos_edge_index.size(1))
        neg_y = z.new_zeros(neg_edge_index.size(1))
        y = torch.cat([pos_y, neg_y], dim=0)

        pos_pred = self.decoder(z, pos_edge_index, sigmoid=True)
        neg_pred = self.decoder(z, neg_edge_index, sigmoid=True)
        pred = torch.cat([pos_pred, neg_pred], dim=0)

        y, pred = y.detach().cpu().numpy(), pred.detach().cpu().numpy()

        return roc_auc_score(y, pred), average_precision_score(y, pred)


class VGAE(GAE):
    r"""The Variational Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper.

    Args:
        encoder (torch.nn.Module): The encoder module to compute :math:`\mu`
            and :math:`\log\sigma^2`.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__(encoder, decoder)

    def reparametrize(self, mu: Tensor, logstd: Tensor) -> Tensor:
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def encode(self, *args, **kwargs) -> Tensor:
        """"""
        self.__mu__, self.__logstd__, self.edge_index = self.encoder(
            *args, **kwargs)
        self.__logstd__ = self.__logstd__.clamp(max=MAX_LOGSTD)
        z = self.reparametrize(self.__mu__, self.__logstd__)
        return z, self.edge_index

    def kl_loss(self, mu: Optional[Tensor] = None,
                logstd: Optional[Tensor] = None) -> Tensor:
        r"""Computes the KL loss, either for the passed arguments :obj:`mu`
        and :obj:`logstd`, or based on latent variables from last encoding.

        Args:
            mu (torch.Tensor, optional): The latent space for :math:`\mu`. If
                set to :obj:`None`, uses the last computation of :math:`\mu`.
                (default: :obj:`None`)
            logstd (torch.Tensor, optional): The latent space for
                :math:`\log\sigma`.  If set to :obj:`None`, uses the last
                computation of :math:`\log\sigma^2`. (default: :obj:`None`)
        """
        mu = self.__mu__ if mu is None else mu
        logstd = self.__logstd__ if logstd is None else logstd.clamp(
            max=MAX_LOGSTD)
        return -0.5 * torch.mean(
            torch.sum(1 + 2 * logstd - mu**2 - logstd.exp()**2, dim=1))

# %%
def norm_g(g):
    degrees = torch.sum(g, 1)
    g = g / degrees
    return g


def top_k_graph(scores, g, h, k):
    num_nodes = g.shape[0]
    values, idx = torch.topk(scores, max(2, int(k*num_nodes)))
    new_h = h[idx, :]
    values = torch.unsqueeze(values, -1)
    new_h = torch.mul(new_h, values)
    un_g = g.bool().float()
    un_g = torch.matmul(un_g, un_g).bool().float()
    un_g = un_g[idx, :]
    un_g = un_g[:, idx]
    g = norm_g(un_g)
    return g, new_h, idx

class Pool(torch.nn.Module):

    def __init__(self, k, in_dim, p):
        super(Pool, self).__init__()
        self.k = k
        self.sigmoid = torch.nn.Sigmoid()
        self.proj = torch.nn.Linear(in_dim, 1)
        self.drop = torch.nn.Dropout(p=p) if p > 0 else torch.nn.Identity()

    def forward(self, g, h):
        Z = self.drop(h)
        weights = self.proj(Z).squeeze()
        scores = self.sigmoid(weights)
        return top_k_graph(scores, g, h, self.k)


class Unpool(torch.nn.Module):

    def __init__(self, *args):
        super(Unpool, self).__init__()

    def forward(self, h, edge_indices,factor=1):
        # add zeros to h factor times
        global featureShape
        h = torch.cat([h, torch.zeros(max(featureShape[0]- h.shape[0],0), h.shape[1]).to(h.device)], dim=0)
        return h

class Unpool2(torch.nn.Module):
    def __init__(self, *args):
        super(Unpool2, self).__init__()

    def forward(self, batch, unpool_ratio):
        num_nodes = batch[-1].item() + 1
        expanded_batch = batch.unsqueeze(1).repeat(1, unpool_ratio)  # Repeat batch indices
        expanded_batch = expanded_batch.view(-1)  # Flatten the batch indices
        return  expanded_batch

# %%
import torch.nn.functional as F



class VariationalGCNEncoder(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.conv1 = GCNConv(in_channels, 2 * out_channels)
        self.conv2 = GCNConv(2*out_channels, 1 * out_channels)
        self.conv_mu = GCNConv(1 * out_channels, out_channels)
        self.conv_logstd = GCNConv(1 * out_channels, out_channels)

    def forward(self, x, edge_index):
        global edgeShape, featureShape
        # print("input:",x.shape, edge_index.shape)
        x = self.conv1(x, edge_index)
        x = F.silu(x)
        # print("conv1:",x.shape, edge_index.shape)
        x = self.conv2(x, edge_index)
        x = F.silu(x)
        # print("conv2:",x.shape, edge_index.shape)
        
        return self.conv_mu(x, edge_index), self.conv_logstd(x, edge_index), edge_index

# %%
class VariationalGCNDecoder(torch.nn.Module):
    def __init__(self,in_channels,out_channels):
        super().__init__()
        self.conv1 = GCNConv(in_channels, 2 * out_channels)
        self.conv2 = GCNConv(2 * out_channels, 1 * out_channels)
    def forward(self, x, edge_index, sigmoid=True):
        global edgeShape, featureShape
        # print("input:",x.shape, edge_index.shape)
        x = self.conv1(x, edge_index)
        x = F.silu(x)
        # print("conv1:",x.shape, edge_index.shape)
        x = self.conv2(x, edge_index)
        x = F.silu(x)
        # print("conv2:",x.shape, edge_index.shape)
        return x, edge_index

# %%
import os
in_channels = graphs[0].num_features
out_channels = 2
lr = 1e-4
n_epochs = 500
batch_size=2
model_name = 'InterGVAE_large20.pt'
model_loaded=False
force_train=True
if os.path.exists("./models/"+model_name) and not force_train:
    model = torch.load("./models/"+model_name)
    model_loaded=True
else:
    model = VGAE(VariationalGCNEncoder(in_channels, out_channels),
                 VariationalGCNDecoder(out_channels, in_channels))
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %%
train_loader = DataLoader(graphs, batch_size=batch_size)

# %%
lossFxn = torch.nn.MSELoss()
def train():
    model.train()
    model.zero_grad()
    model.float()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0

    for data in train_loader:
        optimizer.zero_grad()
        z,encoded_edge_index = model.encode(data.x, data.edge_index)
        decoded_x, decoded_edge_index = model.decode(z, encoded_edge_index)

        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        loss = FeatureLoss + EdgeLoss
        loss = loss 

        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        kl_loss_all += float(model.kl_loss()/data.num_nodes)

        loss.backward()
        optimizer.step()

        

    return loss_all / len(train_loader.dataset), feature_loss_all / len(train_loader.dataset), edge_loss_all / len(train_loader.dataset), kl_loss_all / len(train_loader.dataset)

# %%
total_losses = []
feature_losses = []
edge_losses = []
kl_losses = []

for epoch in range(1, n_epochs + 1):
    total_loss, feature_loss, edge_loss, kl_loss = train()
    print(f'Epoch: {epoch:03d}, Total Loss: {total_loss:.4f}, Feature Loss: {feature_loss:.4f}, Edge Loss: {edge_loss:.4f}')
    total_losses.append(total_loss)
    feature_losses.append(feature_loss)
    edge_losses.append(edge_loss)
    kl_losses.append(kl_loss)
    
    

torch.save(model,"./models/"+model_name)
# Out:
# Epoch: 001, Total Loss: 2.4960, Feature Loss: 2.4960, Edge Loss: 0.0000
# Epoch: 002, Total Loss: 2.4904, Feature Loss: 2.4904, Edge Loss: 0.0000
# Epoch: 003, Total Loss: 2.4868, Feature Loss: 2.4868, Edge Loss: 0.0000
# Epoch: 004, Total Loss: 2.4920, Feature Loss: 2.4920, Edge Loss: 0.0000
# Epoch: 005, Total Loss: 2.4855, Feature Loss: 2.4855, Edge Loss: 0.0000
# Epoch: 006, Total Loss: 2.4767, Feature Loss: 2.4767, Edge Loss: 0.0000
# Epoch: 007, Total Loss: 2.4860, Feature Loss: 2.4860, Edge Loss: 0.0000
# Epoch: 008, Total Loss: 2.4781, Feature Loss: 2.4781, Edge Loss: 0.0000
# Epoch: 009, Total Loss: 2.4752, Feature Loss: 2.4752, Edge Loss: 0.0000
# Epoch: 010, Total Loss: 2.4695, Feature Loss: 2.4695, Edge Loss: 0.0000
# Epoch: 011, Total Loss: 2.4685, Feature Loss: 2.4685, Edge Loss: 0.0000
# Epoch: 012, Total Loss: 2.4615, Feature Loss: 2.4615, Edge Loss: 0.0000
# Epoch: 013, Total Loss: 2.4553, Feature Loss: 2.4553, Edge Loss: 0.0000
# Epoch: 014, Total Loss: 2.4552, Feature Loss: 2.4552, Edge Loss: 0.0000
# Epoch: 015, Total Loss: 2.4621, Feature Loss: 2.4621, Edge Loss: 0.0000
# Epoch: 016, Total Loss: 2.4599, Feature Loss: 2.4599, Edge Loss: 0.0000
# Epoch: 017, Total Loss: 2.4508, Feature Loss: 2.4508, Edge Loss: 0.0000
# Epoch: 018, Total Loss: 2.4484, Feature Loss: 2.4484, Edge Loss: 0.0000
# Epoch: 019, Total Loss: 2.4418, Feature Loss: 2.4418, Edge Loss: 0.0000
# Epoch: 020, Total Loss: 2.4356, Feature Loss: 2.4356, Edge Loss: 0.0000
# Epoch: 021, Total Loss: 2.4382, Feature Loss: 2.4382, Edge Loss: 0.0000
# Epoch: 022, Total Loss: 2.4373, Feature Loss: 2.4373, Edge Loss: 0.0000
# Epoch: 023, Total Loss: 2.4336, Feature Loss: 2.4336, Edge Loss: 0.0000
# Epoch: 024, Total Loss: 2.4333, Feature Loss: 2.4333, Edge Loss: 0.0000
# Epoch: 025, Total Loss: 2.4287, Feature Loss: 2.4287, Edge Loss: 0.0000
# Epoch: 026, Total Loss: 2.4227, Feature Loss: 2.4227, Edge Loss: 0.0000
# Epoch: 027, Total Loss: 2.4184, Feature Loss: 2.4184, Edge Loss: 0.0000
# Epoch: 028, Total Loss: 2.4190, Feature Loss: 2.4190, Edge Loss: 0.0000
# Epoch: 029, Total Loss: 2.4128, Feature Loss: 2.4128, Edge Loss: 0.0000
# Epoch: 030, Total Loss: 2.4138, Feature Loss: 2.4138, Edge Loss: 0.0000
# Epoch: 031, Total Loss: 2.4052, Feature Loss: 2.4052, Edge Loss: 0.0000
# Epoch: 032, Total Loss: 2.4045, Feature Loss: 2.4045, Edge Loss: 0.0000
# Epoch: 033, Total Loss: 2.4129, Feature Loss: 2.4129, Edge Loss: 0.0000
# Epoch: 034, Total Loss: 2.4028, Feature Loss: 2.4028, Edge Loss: 0.0000
# Epoch: 035, Total Loss: 2.3990, Feature Loss: 2.3990, Edge Loss: 0.0000
# Epoch: 036, Total Loss: 2.4000, Feature Loss: 2.4000, Edge Loss: 0.0000
# Epoch: 037, Total Loss: 2.3930, Feature Loss: 2.3930, Edge Loss: 0.0000
# Epoch: 038, Total Loss: 2.3979, Feature Loss: 2.3979, Edge Loss: 0.0000
# Epoch: 039, Total Loss: 2.3867, Feature Loss: 2.3867, Edge Loss: 0.0000
# Epoch: 040, Total Loss: 2.3840, Feature Loss: 2.3840, Edge Loss: 0.0000
# Epoch: 041, Total Loss: 2.3790, Feature Loss: 2.3790, Edge Loss: 0.0000
# Epoch: 042, Total Loss: 2.3770, Feature Loss: 2.3770, Edge Loss: 0.0000
# Epoch: 043, Total Loss: 2.3715, Feature Loss: 2.3715, Edge Loss: 0.0000
# Epoch: 044, Total Loss: 2.3671, Feature Loss: 2.3671, Edge Loss: 0.0000
# Epoch: 045, Total Loss: 2.3689, Feature Loss: 2.3689, Edge Loss: 0.0000
# Epoch: 046, Total Loss: 2.3710, Feature Loss: 2.3710, Edge Loss: 0.0000
# Epoch: 047, Total Loss: 2.3497, Feature Loss: 2.3497, Edge Loss: 0.0000
# Epoch: 048, Total Loss: 2.3543, Feature Loss: 2.3543, Edge Loss: 0.0000
# Epoch: 049, Total Loss: 2.3616, Feature Loss: 2.3616, Edge Loss: 0.0000
# Epoch: 050, Total Loss: 2.3461, Feature Loss: 2.3461, Edge Loss: 0.0000
# Epoch: 051, Total Loss: 2.3535, Feature Loss: 2.3535, Edge Loss: 0.0000
# Epoch: 052, Total Loss: 2.3504, Feature Loss: 2.3504, Edge Loss: 0.0000
# Epoch: 053, Total Loss: 2.3415, Feature Loss: 2.3415, Edge Loss: 0.0000
# Epoch: 054, Total Loss: 2.3440, Feature Loss: 2.3440, Edge Loss: 0.0000
# Epoch: 055, Total Loss: 2.3346, Feature Loss: 2.3346, Edge Loss: 0.0000
# Epoch: 056, Total Loss: 2.3370, Feature Loss: 2.3370, Edge Loss: 0.0000
# Epoch: 057, Total Loss: 2.3288, Feature Loss: 2.3288, Edge Loss: 0.0000
# Epoch: 058, Total Loss: 2.3175, Feature Loss: 2.3175, Edge Loss: 0.0000
# Epoch: 059, Total Loss: 2.3085, Feature Loss: 2.3085, Edge Loss: 0.0000
# Epoch: 060, Total Loss: 2.3088, Feature Loss: 2.3088, Edge Loss: 0.0000
# Epoch: 061, Total Loss: 2.3245, Feature Loss: 2.3245, Edge Loss: 0.0000
# Epoch: 062, Total Loss: 2.2966, Feature Loss: 2.2966, Edge Loss: 0.0000
# Epoch: 063, Total Loss: 2.2846, Feature Loss: 2.2846, Edge Loss: 0.0000
# Epoch: 064, Total Loss: 2.3001, Feature Loss: 2.3001, Edge Loss: 0.0000
# Epoch: 065, Total Loss: 2.3001, Feature Loss: 2.3001, Edge Loss: 0.0000
# Epoch: 066, Total Loss: 2.2925, Feature Loss: 2.2925, Edge Loss: 0.0000
# Epoch: 067, Total Loss: 2.2855, Feature Loss: 2.2855, Edge Loss: 0.0000
# Epoch: 068, Total Loss: 2.2739, Feature Loss: 2.2739, Edge Loss: 0.0000
# Epoch: 069, Total Loss: 2.2678, Feature Loss: 2.2678, Edge Loss: 0.0000
# Epoch: 070, Total Loss: 2.2648, Feature Loss: 2.2648, Edge Loss: 0.0000
# Epoch: 071, Total Loss: 2.2682, Feature Loss: 2.2682, Edge Loss: 0.0000
# Epoch: 072, Total Loss: 2.2715, Feature Loss: 2.2715, Edge Loss: 0.0000
# Epoch: 073, Total Loss: 2.2626, Feature Loss: 2.2626, Edge Loss: 0.0000
# Epoch: 074, Total Loss: 2.2537, Feature Loss: 2.2537, Edge Loss: 0.0000
# Epoch: 075, Total Loss: 2.2507, Feature Loss: 2.2507, Edge Loss: 0.0000
# Epoch: 076, Total Loss: 2.2588, Feature Loss: 2.2588, Edge Loss: 0.0000
# Epoch: 077, Total Loss: 2.2472, Feature Loss: 2.2472, Edge Loss: 0.0000
# Epoch: 078, Total Loss: 2.2271, Feature Loss: 2.2271, Edge Loss: 0.0000
# Epoch: 079, Total Loss: 2.2335, Feature Loss: 2.2335, Edge Loss: 0.0000
# Epoch: 080, Total Loss: 2.2234, Feature Loss: 2.2234, Edge Loss: 0.0000
# Epoch: 081, Total Loss: 2.2193, Feature Loss: 2.2193, Edge Loss: 0.0000
# Epoch: 082, Total Loss: 2.2248, Feature Loss: 2.2248, Edge Loss: 0.0000
# Epoch: 083, Total Loss: 2.2134, Feature Loss: 2.2134, Edge Loss: 0.0000
# Epoch: 084, Total Loss: 2.2109, Feature Loss: 2.2109, Edge Loss: 0.0000
# Epoch: 085, Total Loss: 2.2085, Feature Loss: 2.2085, Edge Loss: 0.0000
# Epoch: 086, Total Loss: 2.1964, Feature Loss: 2.1964, Edge Loss: 0.0000
# Epoch: 087, Total Loss: 2.1795, Feature Loss: 2.1795, Edge Loss: 0.0000
# Epoch: 088, Total Loss: 2.1903, Feature Loss: 2.1903, Edge Loss: 0.0000
# Epoch: 089, Total Loss: 2.1797, Feature Loss: 2.1797, Edge Loss: 0.0000
# Epoch: 090, Total Loss: 2.1890, Feature Loss: 2.1890, Edge Loss: 0.0000
# Epoch: 091, Total Loss: 2.1605, Feature Loss: 2.1605, Edge Loss: 0.0000
# Epoch: 092, Total Loss: 2.1764, Feature Loss: 2.1764, Edge Loss: 0.0000
# Epoch: 093, Total Loss: 2.1507, Feature Loss: 2.1507, Edge Loss: 0.0000
# Epoch: 094, Total Loss: 2.1492, Feature Loss: 2.1492, Edge Loss: 0.0000
# Epoch: 095, Total Loss: 2.1552, Feature Loss: 2.1552, Edge Loss: 0.0000
# Epoch: 096, Total Loss: 2.1424, Feature Loss: 2.1424, Edge Loss: 0.0000
# Epoch: 097, Total Loss: 2.1460, Feature Loss: 2.1460, Edge Loss: 0.0000
# Epoch: 098, Total Loss: 2.1624, Feature Loss: 2.1624, Edge Loss: 0.0000
# Epoch: 099, Total Loss: 2.1308, Feature Loss: 2.1308, Edge Loss: 0.0000
# Epoch: 100, Total Loss: 2.1515, Feature Loss: 2.1515, Edge Loss: 0.0000
# Epoch: 101, Total Loss: 2.1201, Feature Loss: 2.1201, Edge Loss: 0.0000
# Epoch: 102, Total Loss: 2.0973, Feature Loss: 2.0973, Edge Loss: 0.0000
# Epoch: 103, Total Loss: 2.1369, Feature Loss: 2.1369, Edge Loss: 0.0000
# Epoch: 104, Total Loss: 2.1062, Feature Loss: 2.1062, Edge Loss: 0.0000
# Epoch: 105, Total Loss: 2.0946, Feature Loss: 2.0946, Edge Loss: 0.0000
# Epoch: 106, Total Loss: 2.1082, Feature Loss: 2.1082, Edge Loss: 0.0000
# Epoch: 107, Total Loss: 2.1032, Feature Loss: 2.1032, Edge Loss: 0.0000
# Epoch: 108, Total Loss: 2.0831, Feature Loss: 2.0831, Edge Loss: 0.0000
# Epoch: 109, Total Loss: 2.1088, Feature Loss: 2.1088, Edge Loss: 0.0000
# Epoch: 110, Total Loss: 2.0757, Feature Loss: 2.0757, Edge Loss: 0.0000
# Epoch: 111, Total Loss: 2.0785, Feature Loss: 2.0785, Edge Loss: 0.0000
# Epoch: 112, Total Loss: 2.0737, Feature Loss: 2.0737, Edge Loss: 0.0000
# Epoch: 113, Total Loss: 2.0694, Feature Loss: 2.0694, Edge Loss: 0.0000
# Epoch: 114, Total Loss: 2.0372, Feature Loss: 2.0372, Edge Loss: 0.0000
# Epoch: 115, Total Loss: 2.0546, Feature Loss: 2.0546, Edge Loss: 0.0000
# Epoch: 116, Total Loss: 2.0640, Feature Loss: 2.0640, Edge Loss: 0.0000
# Epoch: 117, Total Loss: 2.0607, Feature Loss: 2.0607, Edge Loss: 0.0000
# Epoch: 118, Total Loss: 2.0656, Feature Loss: 2.0656, Edge Loss: 0.0000
# Epoch: 119, Total Loss: 2.0239, Feature Loss: 2.0239, Edge Loss: 0.0000
# Epoch: 120, Total Loss: 2.0343, Feature Loss: 2.0343, Edge Loss: 0.0000
# Epoch: 121, Total Loss: 2.0094, Feature Loss: 2.0094, Edge Loss: 0.0000
# Epoch: 122, Total Loss: 2.0241, Feature Loss: 2.0241, Edge Loss: 0.0000
# Epoch: 123, Total Loss: 1.9981, Feature Loss: 1.9981, Edge Loss: 0.0000
# Epoch: 124, Total Loss: 1.9992, Feature Loss: 1.9992, Edge Loss: 0.0000
# Epoch: 125, Total Loss: 1.9971, Feature Loss: 1.9971, Edge Loss: 0.0000
# Epoch: 126, Total Loss: 2.0096, Feature Loss: 2.0096, Edge Loss: 0.0000
# Epoch: 127, Total Loss: 1.9825, Feature Loss: 1.9825, Edge Loss: 0.0000
# Epoch: 128, Total Loss: 1.9959, Feature Loss: 1.9959, Edge Loss: 0.0000
# Epoch: 129, Total Loss: 1.9855, Feature Loss: 1.9855, Edge Loss: 0.0000
# Epoch: 130, Total Loss: 1.9725, Feature Loss: 1.9725, Edge Loss: 0.0000
# Epoch: 131, Total Loss: 1.9820, Feature Loss: 1.9820, Edge Loss: 0.0000
# Epoch: 132, Total Loss: 1.9766, Feature Loss: 1.9766, Edge Loss: 0.0000
# Epoch: 133, Total Loss: 1.9677, Feature Loss: 1.9677, Edge Loss: 0.0000
# Epoch: 134, Total Loss: 1.9559, Feature Loss: 1.9559, Edge Loss: 0.0000
# Epoch: 135, Total Loss: 1.9723, Feature Loss: 1.9723, Edge Loss: 0.0000
# Epoch: 136, Total Loss: 1.9585, Feature Loss: 1.9585, Edge Loss: 0.0000
# Epoch: 137, Total Loss: 1.9629, Feature Loss: 1.9629, Edge Loss: 0.0000
# Epoch: 138, Total Loss: 1.9373, Feature Loss: 1.9373, Edge Loss: 0.0000
# Epoch: 139, Total Loss: 1.9443, Feature Loss: 1.9443, Edge Loss: 0.0000
# Epoch: 140, Total Loss: 1.9549, Feature Loss: 1.9549, Edge Loss: 0.0000
# Epoch: 141, Total Loss: 1.9356, Feature Loss: 1.9356, Edge Loss: 0.0000
# Epoch: 142, Total Loss: 1.9452, Feature Loss: 1.9452, Edge Loss: 0.0000
# Epoch: 143, Total Loss: 1.9421, Feature Loss: 1.9421, Edge Loss: 0.0000
# Epoch: 144, Total Loss: 1.9307, Feature Loss: 1.9307, Edge Loss: 0.0000
# Epoch: 145, Total Loss: 1.9195, Feature Loss: 1.9195, Edge Loss: 0.0000
# Epoch: 146, Total Loss: 1.9372, Feature Loss: 1.9372, Edge Loss: 0.0000
# Epoch: 147, Total Loss: 1.8783, Feature Loss: 1.8783, Edge Loss: 0.0000
# Epoch: 148, Total Loss: 1.9111, Feature Loss: 1.9111, Edge Loss: 0.0000
# Epoch: 149, Total Loss: 1.8885, Feature Loss: 1.8885, Edge Loss: 0.0000
# Epoch: 150, Total Loss: 1.8759, Feature Loss: 1.8759, Edge Loss: 0.0000
# Epoch: 151, Total Loss: 1.8744, Feature Loss: 1.8744, Edge Loss: 0.0000
# Epoch: 152, Total Loss: 1.9072, Feature Loss: 1.9072, Edge Loss: 0.0000
# Epoch: 153, Total Loss: 1.8879, Feature Loss: 1.8879, Edge Loss: 0.0000
# Epoch: 154, Total Loss: 1.8784, Feature Loss: 1.8784, Edge Loss: 0.0000
# Epoch: 155, Total Loss: 1.8817, Feature Loss: 1.8817, Edge Loss: 0.0000
# Epoch: 156, Total Loss: 1.8491, Feature Loss: 1.8491, Edge Loss: 0.0000
# Epoch: 157, Total Loss: 1.8777, Feature Loss: 1.8777, Edge Loss: 0.0000
# Epoch: 158, Total Loss: 1.8580, Feature Loss: 1.8580, Edge Loss: 0.0000
# Epoch: 159, Total Loss: 1.8711, Feature Loss: 1.8711, Edge Loss: 0.0000
# Epoch: 160, Total Loss: 1.8162, Feature Loss: 1.8162, Edge Loss: 0.0000
# Epoch: 161, Total Loss: 1.8380, Feature Loss: 1.8380, Edge Loss: 0.0000
# Epoch: 162, Total Loss: 1.8502, Feature Loss: 1.8502, Edge Loss: 0.0000
# Epoch: 163, Total Loss: 1.8324, Feature Loss: 1.8324, Edge Loss: 0.0000
# Epoch: 164, Total Loss: 1.8598, Feature Loss: 1.8598, Edge Loss: 0.0000
# Epoch: 165, Total Loss: 1.8385, Feature Loss: 1.8385, Edge Loss: 0.0000
# Epoch: 166, Total Loss: 1.8119, Feature Loss: 1.8119, Edge Loss: 0.0000
# Epoch: 167, Total Loss: 1.8321, Feature Loss: 1.8321, Edge Loss: 0.0000
# Epoch: 168, Total Loss: 1.8205, Feature Loss: 1.8205, Edge Loss: 0.0000
# Epoch: 169, Total Loss: 1.8277, Feature Loss: 1.8277, Edge Loss: 0.0000
# Epoch: 170, Total Loss: 1.7931, Feature Loss: 1.7931, Edge Loss: 0.0000
# Epoch: 171, Total Loss: 1.8250, Feature Loss: 1.8250, Edge Loss: 0.0000
# Epoch: 172, Total Loss: 1.8065, Feature Loss: 1.8065, Edge Loss: 0.0000
# Epoch: 173, Total Loss: 1.8019, Feature Loss: 1.8019, Edge Loss: 0.0000
# Epoch: 174, Total Loss: 1.8410, Feature Loss: 1.8410, Edge Loss: 0.0000
# Epoch: 175, Total Loss: 1.7982, Feature Loss: 1.7982, Edge Loss: 0.0000
# Epoch: 176, Total Loss: 1.7786, Feature Loss: 1.7786, Edge Loss: 0.0000
# Epoch: 177, Total Loss: 1.8072, Feature Loss: 1.8072, Edge Loss: 0.0000
# Epoch: 178, Total Loss: 1.7788, Feature Loss: 1.7788, Edge Loss: 0.0000
# Epoch: 179, Total Loss: 1.7889, Feature Loss: 1.7889, Edge Loss: 0.0000
# Epoch: 180, Total Loss: 1.7643, Feature Loss: 1.7643, Edge Loss: 0.0000
# Epoch: 181, Total Loss: 1.8092, Feature Loss: 1.8092, Edge Loss: 0.0000
# Epoch: 182, Total Loss: 1.7725, Feature Loss: 1.7725, Edge Loss: 0.0000
# Epoch: 183, Total Loss: 1.7650, Feature Loss: 1.7650, Edge Loss: 0.0000
# Epoch: 184, Total Loss: 1.7999, Feature Loss: 1.7999, Edge Loss: 0.0000
# Epoch: 185, Total Loss: 1.7701, Feature Loss: 1.7701, Edge Loss: 0.0000
# Epoch: 186, Total Loss: 1.7700, Feature Loss: 1.7700, Edge Loss: 0.0000
# Epoch: 187, Total Loss: 1.8063, Feature Loss: 1.8063, Edge Loss: 0.0000
# Epoch: 188, Total Loss: 1.7266, Feature Loss: 1.7266, Edge Loss: 0.0000
# Epoch: 189, Total Loss: 1.7609, Feature Loss: 1.7609, Edge Loss: 0.0000
# Epoch: 190, Total Loss: 1.7396, Feature Loss: 1.7396, Edge Loss: 0.0000
# Epoch: 191, Total Loss: 1.7343, Feature Loss: 1.7343, Edge Loss: 0.0000
# Epoch: 192, Total Loss: 1.7581, Feature Loss: 1.7581, Edge Loss: 0.0000
# Epoch: 193, Total Loss: 1.7963, Feature Loss: 1.7963, Edge Loss: 0.0000
# Epoch: 194, Total Loss: 1.7541, Feature Loss: 1.7541, Edge Loss: 0.0000
# Epoch: 195, Total Loss: 1.7165, Feature Loss: 1.7165, Edge Loss: 0.0000
# Epoch: 196, Total Loss: 1.7356, Feature Loss: 1.7356, Edge Loss: 0.0000
# Epoch: 197, Total Loss: 1.7497, Feature Loss: 1.7497, Edge Loss: 0.0000
# Epoch: 198, Total Loss: 1.7423, Feature Loss: 1.7423, Edge Loss: 0.0000
# Epoch: 199, Total Loss: 1.7166, Feature Loss: 1.7166, Edge Loss: 0.0000
# Epoch: 200, Total Loss: 1.7221, Feature Loss: 1.7221, Edge Loss: 0.0000
# Epoch: 201, Total Loss: 1.7547, Feature Loss: 1.7547, Edge Loss: 0.0000
# Epoch: 202, Total Loss: 1.6958, Feature Loss: 1.6958, Edge Loss: 0.0000
# Epoch: 203, Total Loss: 1.7284, Feature Loss: 1.7284, Edge Loss: 0.0000
# Epoch: 204, Total Loss: 1.7091, Feature Loss: 1.7091, Edge Loss: 0.0000
# Epoch: 205, Total Loss: 1.7497, Feature Loss: 1.7497, Edge Loss: 0.0000
# Epoch: 206, Total Loss: 1.7114, Feature Loss: 1.7114, Edge Loss: 0.0000
# Epoch: 207, Total Loss: 1.7234, Feature Loss: 1.7234, Edge Loss: 0.0000
# Epoch: 208, Total Loss: 1.7166, Feature Loss: 1.7166, Edge Loss: 0.0000
# Epoch: 209, Total Loss: 1.6986, Feature Loss: 1.6986, Edge Loss: 0.0000
# Epoch: 210, Total Loss: 1.7225, Feature Loss: 1.7225, Edge Loss: 0.0000
# Epoch: 211, Total Loss: 1.7160, Feature Loss: 1.7160, Edge Loss: 0.0000
# Epoch: 212, Total Loss: 1.7137, Feature Loss: 1.7137, Edge Loss: 0.0000
# Epoch: 213, Total Loss: 1.6599, Feature Loss: 1.6599, Edge Loss: 0.0000
# Epoch: 214, Total Loss: 1.7042, Feature Loss: 1.7042, Edge Loss: 0.0000
# Epoch: 215, Total Loss: 1.6853, Feature Loss: 1.6853, Edge Loss: 0.0000
# Epoch: 216, Total Loss: 1.6714, Feature Loss: 1.6714, Edge Loss: 0.0000
# Epoch: 217, Total Loss: 1.6664, Feature Loss: 1.6664, Edge Loss: 0.0000
# Epoch: 218, Total Loss: 1.6888, Feature Loss: 1.6888, Edge Loss: 0.0000
# Epoch: 219, Total Loss: 1.6831, Feature Loss: 1.6831, Edge Loss: 0.0000
# Epoch: 220, Total Loss: 1.6264, Feature Loss: 1.6264, Edge Loss: 0.0000
# Epoch: 221, Total Loss: 1.6575, Feature Loss: 1.6575, Edge Loss: 0.0000
# Epoch: 222, Total Loss: 1.6598, Feature Loss: 1.6598, Edge Loss: 0.0000
# Epoch: 223, Total Loss: 1.6675, Feature Loss: 1.6675, Edge Loss: 0.0000
# Epoch: 224, Total Loss: 1.6692, Feature Loss: 1.6692, Edge Loss: 0.0000
# Epoch: 225, Total Loss: 1.6509, Feature Loss: 1.6509, Edge Loss: 0.0000
# Epoch: 226, Total Loss: 1.6672, Feature Loss: 1.6672, Edge Loss: 0.0000
# Epoch: 227, Total Loss: 1.6280, Feature Loss: 1.6280, Edge Loss: 0.0000
# Epoch: 228, Total Loss: 1.6372, Feature Loss: 1.6372, Edge Loss: 0.0000
# Epoch: 229, Total Loss: 1.6937, Feature Loss: 1.6937, Edge Loss: 0.0000
# Epoch: 230, Total Loss: 1.6044, Feature Loss: 1.6044, Edge Loss: 0.0000
# Epoch: 231, Total Loss: 1.6859, Feature Loss: 1.6859, Edge Loss: 0.0000
# Epoch: 232, Total Loss: 1.6554, Feature Loss: 1.6554, Edge Loss: 0.0000
# Epoch: 233, Total Loss: 1.6571, Feature Loss: 1.6571, Edge Loss: 0.0000
# Epoch: 234, Total Loss: 1.6347, Feature Loss: 1.6347, Edge Loss: 0.0000
# Epoch: 235, Total Loss: 1.6545, Feature Loss: 1.6545, Edge Loss: 0.0000
# Epoch: 236, Total Loss: 1.6467, Feature Loss: 1.6467, Edge Loss: 0.0000
# Epoch: 237, Total Loss: 1.6072, Feature Loss: 1.6072, Edge Loss: 0.0000
# Epoch: 238, Total Loss: 1.6252, Feature Loss: 1.6252, Edge Loss: 0.0000
# Epoch: 239, Total Loss: 1.5999, Feature Loss: 1.5999, Edge Loss: 0.0000
# Epoch: 240, Total Loss: 1.6129, Feature Loss: 1.6129, Edge Loss: 0.0000
# Epoch: 241, Total Loss: 1.6156, Feature Loss: 1.6156, Edge Loss: 0.0000
# Epoch: 242, Total Loss: 1.6343, Feature Loss: 1.6343, Edge Loss: 0.0000
# Epoch: 243, Total Loss: 1.5984, Feature Loss: 1.5984, Edge Loss: 0.0000
# Epoch: 244, Total Loss: 1.6439, Feature Loss: 1.6439, Edge Loss: 0.0000
# Epoch: 245, Total Loss: 1.6342, Feature Loss: 1.6342, Edge Loss: 0.0000
# Epoch: 246, Total Loss: 1.6142, Feature Loss: 1.6142, Edge Loss: 0.0000
# Epoch: 247, Total Loss: 1.6043, Feature Loss: 1.6043, Edge Loss: 0.0000
# Epoch: 248, Total Loss: 1.5874, Feature Loss: 1.5874, Edge Loss: 0.0000
# Epoch: 249, Total Loss: 1.6099, Feature Loss: 1.6099, Edge Loss: 0.0000
# Epoch: 250, Total Loss: 1.6129, Feature Loss: 1.6129, Edge Loss: 0.0000
# Epoch: 251, Total Loss: 1.5844, Feature Loss: 1.5844, Edge Loss: 0.0000
# Epoch: 252, Total Loss: 1.5839, Feature Loss: 1.5839, Edge Loss: 0.0000
# Epoch: 253, Total Loss: 1.5887, Feature Loss: 1.5887, Edge Loss: 0.0000
# Epoch: 254, Total Loss: 1.5513, Feature Loss: 1.5513, Edge Loss: 0.0000
# Epoch: 255, Total Loss: 1.5982, Feature Loss: 1.5982, Edge Loss: 0.0000
# Epoch: 256, Total Loss: 1.6371, Feature Loss: 1.6371, Edge Loss: 0.0000
# Epoch: 257, Total Loss: 1.5637, Feature Loss: 1.5637, Edge Loss: 0.0000
# Epoch: 258, Total Loss: 1.5761, Feature Loss: 1.5761, Edge Loss: 0.0000
# Epoch: 259, Total Loss: 1.6041, Feature Loss: 1.6041, Edge Loss: 0.0000
# Epoch: 260, Total Loss: 1.5578, Feature Loss: 1.5578, Edge Loss: 0.0000
# Epoch: 261, Total Loss: 1.6028, Feature Loss: 1.6028, Edge Loss: 0.0000
# Epoch: 262, Total Loss: 1.6044, Feature Loss: 1.6044, Edge Loss: 0.0000
# Epoch: 263, Total Loss: 1.6047, Feature Loss: 1.6047, Edge Loss: 0.0000
# Epoch: 264, Total Loss: 1.5901, Feature Loss: 1.5901, Edge Loss: 0.0000
# Epoch: 265, Total Loss: 1.5547, Feature Loss: 1.5547, Edge Loss: 0.0000
# Epoch: 266, Total Loss: 1.5441, Feature Loss: 1.5441, Edge Loss: 0.0000
# Epoch: 267, Total Loss: 1.5591, Feature Loss: 1.5591, Edge Loss: 0.0000
# Epoch: 268, Total Loss: 1.5428, Feature Loss: 1.5428, Edge Loss: 0.0000
# Epoch: 269, Total Loss: 1.5247, Feature Loss: 1.5247, Edge Loss: 0.0000
# Epoch: 270, Total Loss: 1.5314, Feature Loss: 1.5314, Edge Loss: 0.0000
# Epoch: 271, Total Loss: 1.5716, Feature Loss: 1.5716, Edge Loss: 0.0000
# Epoch: 272, Total Loss: 1.5350, Feature Loss: 1.5350, Edge Loss: 0.0000
# Epoch: 273, Total Loss: 1.5860, Feature Loss: 1.5860, Edge Loss: 0.0000
# Epoch: 274, Total Loss: 1.5543, Feature Loss: 1.5543, Edge Loss: 0.0000
# Epoch: 275, Total Loss: 1.5182, Feature Loss: 1.5182, Edge Loss: 0.0000
# Epoch: 276, Total Loss: 1.4784, Feature Loss: 1.4784, Edge Loss: 0.0000
# Epoch: 277, Total Loss: 1.5380, Feature Loss: 1.5380, Edge Loss: 0.0000
# Epoch: 278, Total Loss: 1.5547, Feature Loss: 1.5547, Edge Loss: 0.0000
# Epoch: 279, Total Loss: 1.5181, Feature Loss: 1.5181, Edge Loss: 0.0000
# Epoch: 280, Total Loss: 1.5261, Feature Loss: 1.5261, Edge Loss: 0.0000
# Epoch: 281, Total Loss: 1.5258, Feature Loss: 1.5258, Edge Loss: 0.0000
# Epoch: 282, Total Loss: 1.4960, Feature Loss: 1.4960, Edge Loss: 0.0000
# Epoch: 283, Total Loss: 1.4599, Feature Loss: 1.4599, Edge Loss: 0.0000
# Epoch: 284, Total Loss: 1.5184, Feature Loss: 1.5184, Edge Loss: 0.0000
# Epoch: 285, Total Loss: 1.5028, Feature Loss: 1.5028, Edge Loss: 0.0000
# Epoch: 286, Total Loss: 1.4570, Feature Loss: 1.4570, Edge Loss: 0.0000
# Epoch: 287, Total Loss: 1.5268, Feature Loss: 1.5268, Edge Loss: 0.0000
# Epoch: 288, Total Loss: 1.5201, Feature Loss: 1.5201, Edge Loss: 0.0000
# Epoch: 289, Total Loss: 1.4855, Feature Loss: 1.4855, Edge Loss: 0.0000
# Epoch: 290, Total Loss: 1.4580, Feature Loss: 1.4580, Edge Loss: 0.0000
# Epoch: 291, Total Loss: 1.4915, Feature Loss: 1.4915, Edge Loss: 0.0000
# Epoch: 292, Total Loss: 1.4841, Feature Loss: 1.4841, Edge Loss: 0.0000
# Epoch: 293, Total Loss: 1.4542, Feature Loss: 1.4542, Edge Loss: 0.0000
# Epoch: 294, Total Loss: 1.4282, Feature Loss: 1.4282, Edge Loss: 0.0000
# Epoch: 295, Total Loss: 1.4499, Feature Loss: 1.4499, Edge Loss: 0.0000
# Epoch: 296, Total Loss: 1.4278, Feature Loss: 1.4278, Edge Loss: 0.0000
# Epoch: 297, Total Loss: 1.4441, Feature Loss: 1.4441, Edge Loss: 0.0000
# Epoch: 298, Total Loss: 1.4581, Feature Loss: 1.4581, Edge Loss: 0.0000
# Epoch: 299, Total Loss: 1.4421, Feature Loss: 1.4421, Edge Loss: 0.0000
# Epoch: 300, Total Loss: 1.4022, Feature Loss: 1.4022, Edge Loss: 0.0000
# Epoch: 301, Total Loss: 1.4202, Feature Loss: 1.4202, Edge Loss: 0.0000
# Epoch: 302, Total Loss: 1.4304, Feature Loss: 1.4304, Edge Loss: 0.0000
# Epoch: 303, Total Loss: 1.4268, Feature Loss: 1.4268, Edge Loss: 0.0000
# Epoch: 304, Total Loss: 1.4674, Feature Loss: 1.4674, Edge Loss: 0.0000
# Epoch: 305, Total Loss: 1.4485, Feature Loss: 1.4485, Edge Loss: 0.0000
# Epoch: 306, Total Loss: 1.4343, Feature Loss: 1.4343, Edge Loss: 0.0000
# Epoch: 307, Total Loss: 1.4322, Feature Loss: 1.4322, Edge Loss: 0.0000
# Epoch: 308, Total Loss: 1.4275, Feature Loss: 1.4275, Edge Loss: 0.0000
# Epoch: 309, Total Loss: 1.3936, Feature Loss: 1.3936, Edge Loss: 0.0000
# Epoch: 310, Total Loss: 1.3917, Feature Loss: 1.3917, Edge Loss: 0.0000
# Epoch: 311, Total Loss: 1.3869, Feature Loss: 1.3869, Edge Loss: 0.0000
# Epoch: 312, Total Loss: 1.4139, Feature Loss: 1.4139, Edge Loss: 0.0000
# Epoch: 313, Total Loss: 1.3458, Feature Loss: 1.3458, Edge Loss: 0.0000
# Epoch: 314, Total Loss: 1.3926, Feature Loss: 1.3926, Edge Loss: 0.0000
# Epoch: 315, Total Loss: 1.3720, Feature Loss: 1.3720, Edge Loss: 0.0000
# Epoch: 316, Total Loss: 1.4057, Feature Loss: 1.4057, Edge Loss: 0.0000
# Epoch: 317, Total Loss: 1.3275, Feature Loss: 1.3275, Edge Loss: 0.0000
# Epoch: 318, Total Loss: 1.4022, Feature Loss: 1.4022, Edge Loss: 0.0000
# Epoch: 319, Total Loss: 1.3757, Feature Loss: 1.3757, Edge Loss: 0.0000
# Epoch: 320, Total Loss: 1.3668, Feature Loss: 1.3668, Edge Loss: 0.0000
# Epoch: 321, Total Loss: 1.3647, Feature Loss: 1.3647, Edge Loss: 0.0000
# Epoch: 322, Total Loss: 1.3260, Feature Loss: 1.3260, Edge Loss: 0.0000
# Epoch: 323, Total Loss: 1.3850, Feature Loss: 1.3850, Edge Loss: 0.0000
# Epoch: 324, Total Loss: 1.3319, Feature Loss: 1.3319, Edge Loss: 0.0000
# Epoch: 325, Total Loss: 1.3646, Feature Loss: 1.3646, Edge Loss: 0.0000
# Epoch: 326, Total Loss: 1.3865, Feature Loss: 1.3865, Edge Loss: 0.0000
# Epoch: 327, Total Loss: 1.3322, Feature Loss: 1.3322, Edge Loss: 0.0000
# Epoch: 328, Total Loss: 1.3287, Feature Loss: 1.3287, Edge Loss: 0.0000
# Epoch: 329, Total Loss: 1.3761, Feature Loss: 1.3761, Edge Loss: 0.0000
# Epoch: 330, Total Loss: 1.3448, Feature Loss: 1.3448, Edge Loss: 0.0000
# Epoch: 331, Total Loss: 1.3366, Feature Loss: 1.3366, Edge Loss: 0.0000
# Epoch: 332, Total Loss: 1.2959, Feature Loss: 1.2959, Edge Loss: 0.0000
# Epoch: 333, Total Loss: 1.3012, Feature Loss: 1.3012, Edge Loss: 0.0000
# Epoch: 334, Total Loss: 1.3683, Feature Loss: 1.3683, Edge Loss: 0.0000
# Epoch: 335, Total Loss: 1.2663, Feature Loss: 1.2663, Edge Loss: 0.0000
# Epoch: 336, Total Loss: 1.3117, Feature Loss: 1.3117, Edge Loss: 0.0000
# Epoch: 337, Total Loss: 1.3636, Feature Loss: 1.3636, Edge Loss: 0.0000
# Epoch: 338, Total Loss: 1.2660, Feature Loss: 1.2660, Edge Loss: 0.0000
# Epoch: 339, Total Loss: 1.3100, Feature Loss: 1.3100, Edge Loss: 0.0000
# Epoch: 340, Total Loss: 1.3182, Feature Loss: 1.3182, Edge Loss: 0.0000
# Epoch: 341, Total Loss: 1.2855, Feature Loss: 1.2855, Edge Loss: 0.0000
# Epoch: 342, Total Loss: 1.2878, Feature Loss: 1.2878, Edge Loss: 0.0000
# Epoch: 343, Total Loss: 1.2651, Feature Loss: 1.2651, Edge Loss: 0.0000
# Epoch: 344, Total Loss: 1.2759, Feature Loss: 1.2759, Edge Loss: 0.0000
# Epoch: 345, Total Loss: 1.2534, Feature Loss: 1.2534, Edge Loss: 0.0000
# Epoch: 346, Total Loss: 1.2352, Feature Loss: 1.2352, Edge Loss: 0.0000
# Epoch: 347, Total Loss: 1.2623, Feature Loss: 1.2623, Edge Loss: 0.0000
# Epoch: 348, Total Loss: 1.2546, Feature Loss: 1.2546, Edge Loss: 0.0000
# Epoch: 349, Total Loss: 1.2704, Feature Loss: 1.2704, Edge Loss: 0.0000
# Epoch: 350, Total Loss: 1.2339, Feature Loss: 1.2339, Edge Loss: 0.0000
# Epoch: 351, Total Loss: 1.2690, Feature Loss: 1.2690, Edge Loss: 0.0000
# Epoch: 352, Total Loss: 1.2755, Feature Loss: 1.2755, Edge Loss: 0.0000
# Epoch: 353, Total Loss: 1.2281, Feature Loss: 1.2281, Edge Loss: 0.0000
# Epoch: 354, Total Loss: 1.2871, Feature Loss: 1.2871, Edge Loss: 0.0000
# Epoch: 355, Total Loss: 1.2400, Feature Loss: 1.2400, Edge Loss: 0.0000
# Epoch: 356, Total Loss: 1.2237, Feature Loss: 1.2237, Edge Loss: 0.0000
# Epoch: 357, Total Loss: 1.1792, Feature Loss: 1.1792, Edge Loss: 0.0000
# Epoch: 358, Total Loss: 1.2073, Feature Loss: 1.2073, Edge Loss: 0.0000
# Epoch: 359, Total Loss: 1.2219, Feature Loss: 1.2219, Edge Loss: 0.0000
# Epoch: 360, Total Loss: 1.2105, Feature Loss: 1.2105, Edge Loss: 0.0000
# Epoch: 361, Total Loss: 1.2257, Feature Loss: 1.2257, Edge Loss: 0.0000
# Epoch: 362, Total Loss: 1.1831, Feature Loss: 1.1831, Edge Loss: 0.0000
# Epoch: 363, Total Loss: 1.2093, Feature Loss: 1.2093, Edge Loss: 0.0000
# Epoch: 364, Total Loss: 1.2316, Feature Loss: 1.2316, Edge Loss: 0.0000
# Epoch: 365, Total Loss: 1.2111, Feature Loss: 1.2111, Edge Loss: 0.0000
# Epoch: 366, Total Loss: 1.1873, Feature Loss: 1.1873, Edge Loss: 0.0000
# Epoch: 367, Total Loss: 1.1951, Feature Loss: 1.1951, Edge Loss: 0.0000
# Epoch: 368, Total Loss: 1.1952, Feature Loss: 1.1952, Edge Loss: 0.0000
# Epoch: 369, Total Loss: 1.1614, Feature Loss: 1.1614, Edge Loss: 0.0000
# Epoch: 370, Total Loss: 1.2119, Feature Loss: 1.2119, Edge Loss: 0.0000
# Epoch: 371, Total Loss: 1.1975, Feature Loss: 1.1975, Edge Loss: 0.0000
# Epoch: 372, Total Loss: 1.1790, Feature Loss: 1.1790, Edge Loss: 0.0000
# Epoch: 373, Total Loss: 1.1762, Feature Loss: 1.1762, Edge Loss: 0.0000
# Epoch: 374, Total Loss: 1.1821, Feature Loss: 1.1821, Edge Loss: 0.0000
# Epoch: 375, Total Loss: 1.1610, Feature Loss: 1.1610, Edge Loss: 0.0000
# Epoch: 376, Total Loss: 1.1239, Feature Loss: 1.1239, Edge Loss: 0.0000
# Epoch: 377, Total Loss: 1.1701, Feature Loss: 1.1701, Edge Loss: 0.0000
# Epoch: 378, Total Loss: 1.1598, Feature Loss: 1.1598, Edge Loss: 0.0000
# Epoch: 379, Total Loss: 1.1217, Feature Loss: 1.1217, Edge Loss: 0.0000
# Epoch: 380, Total Loss: 1.1582, Feature Loss: 1.1582, Edge Loss: 0.0000
# Epoch: 381, Total Loss: 1.1437, Feature Loss: 1.1437, Edge Loss: 0.0000
# Epoch: 382, Total Loss: 1.1614, Feature Loss: 1.1614, Edge Loss: 0.0000
# Epoch: 383, Total Loss: 1.1138, Feature Loss: 1.1138, Edge Loss: 0.0000
# Epoch: 384, Total Loss: 1.0940, Feature Loss: 1.0940, Edge Loss: 0.0000
# Epoch: 385, Total Loss: 1.1350, Feature Loss: 1.1350, Edge Loss: 0.0000
# Epoch: 386, Total Loss: 1.1137, Feature Loss: 1.1137, Edge Loss: 0.0000
# Epoch: 387, Total Loss: 1.1448, Feature Loss: 1.1448, Edge Loss: 0.0000
# Epoch: 388, Total Loss: 1.0757, Feature Loss: 1.0757, Edge Loss: 0.0000
# Epoch: 389, Total Loss: 1.1082, Feature Loss: 1.1082, Edge Loss: 0.0000
# Epoch: 390, Total Loss: 1.0970, Feature Loss: 1.0970, Edge Loss: 0.0000
# Epoch: 391, Total Loss: 1.1621, Feature Loss: 1.1621, Edge Loss: 0.0000
# Epoch: 392, Total Loss: 1.0861, Feature Loss: 1.0861, Edge Loss: 0.0000
# Epoch: 393, Total Loss: 1.0718, Feature Loss: 1.0718, Edge Loss: 0.0000
# Epoch: 394, Total Loss: 1.0507, Feature Loss: 1.0507, Edge Loss: 0.0000
# Epoch: 395, Total Loss: 1.0662, Feature Loss: 1.0662, Edge Loss: 0.0000
# Epoch: 396, Total Loss: 1.1299, Feature Loss: 1.1299, Edge Loss: 0.0000
# Epoch: 397, Total Loss: 1.0864, Feature Loss: 1.0864, Edge Loss: 0.0000
# Epoch: 398, Total Loss: 1.0569, Feature Loss: 1.0569, Edge Loss: 0.0000
# Epoch: 399, Total Loss: 1.0756, Feature Loss: 1.0756, Edge Loss: 0.0000
# Epoch: 400, Total Loss: 1.0581, Feature Loss: 1.0581, Edge Loss: 0.0000
# Epoch: 401, Total Loss: 1.0540, Feature Loss: 1.0540, Edge Loss: 0.0000
# Epoch: 402, Total Loss: 1.0595, Feature Loss: 1.0595, Edge Loss: 0.0000
# Epoch: 403, Total Loss: 1.0741, Feature Loss: 1.0741, Edge Loss: 0.0000
# Epoch: 404, Total Loss: 1.1276, Feature Loss: 1.1276, Edge Loss: 0.0000
# Epoch: 405, Total Loss: 1.0971, Feature Loss: 1.0971, Edge Loss: 0.0000
# Epoch: 406, Total Loss: 1.0528, Feature Loss: 1.0528, Edge Loss: 0.0000
# Epoch: 407, Total Loss: 1.0562, Feature Loss: 1.0562, Edge Loss: 0.0000
# Epoch: 408, Total Loss: 1.0461, Feature Loss: 1.0461, Edge Loss: 0.0000
# Epoch: 409, Total Loss: 0.9996, Feature Loss: 0.9996, Edge Loss: 0.0000
# Epoch: 410, Total Loss: 1.0631, Feature Loss: 1.0631, Edge Loss: 0.0000
# Epoch: 411, Total Loss: 1.0032, Feature Loss: 1.0032, Edge Loss: 0.0000
# Epoch: 412, Total Loss: 1.0139, Feature Loss: 1.0139, Edge Loss: 0.0000
# Epoch: 413, Total Loss: 0.9739, Feature Loss: 0.9739, Edge Loss: 0.0000
# Epoch: 414, Total Loss: 0.9631, Feature Loss: 0.9631, Edge Loss: 0.0000
# Epoch: 415, Total Loss: 0.9914, Feature Loss: 0.9914, Edge Loss: 0.0000
# Epoch: 416, Total Loss: 0.9999, Feature Loss: 0.9999, Edge Loss: 0.0000
# Epoch: 417, Total Loss: 1.0055, Feature Loss: 1.0055, Edge Loss: 0.0000
# Epoch: 418, Total Loss: 0.9690, Feature Loss: 0.9690, Edge Loss: 0.0000
# Epoch: 419, Total Loss: 1.0232, Feature Loss: 1.0232, Edge Loss: 0.0000
# Epoch: 420, Total Loss: 0.9604, Feature Loss: 0.9604, Edge Loss: 0.0000
# Epoch: 421, Total Loss: 1.0011, Feature Loss: 1.0011, Edge Loss: 0.0000
# Epoch: 422, Total Loss: 1.0729, Feature Loss: 1.0729, Edge Loss: 0.0000
# Epoch: 423, Total Loss: 0.9796, Feature Loss: 0.9796, Edge Loss: 0.0000
# Epoch: 424, Total Loss: 1.0455, Feature Loss: 1.0455, Edge Loss: 0.0000
# Epoch: 425, Total Loss: 0.9990, Feature Loss: 0.9990, Edge Loss: 0.0000
# Epoch: 426, Total Loss: 1.0144, Feature Loss: 1.0144, Edge Loss: 0.0000
# Epoch: 427, Total Loss: 0.9824, Feature Loss: 0.9824, Edge Loss: 0.0000
# Epoch: 428, Total Loss: 0.9643, Feature Loss: 0.9643, Edge Loss: 0.0000
# Epoch: 429, Total Loss: 0.9490, Feature Loss: 0.9490, Edge Loss: 0.0000
# Epoch: 430, Total Loss: 0.9504, Feature Loss: 0.9504, Edge Loss: 0.0000
# Epoch: 431, Total Loss: 0.9486, Feature Loss: 0.9486, Edge Loss: 0.0000
# Epoch: 432, Total Loss: 0.9512, Feature Loss: 0.9512, Edge Loss: 0.0000
# Epoch: 433, Total Loss: 0.9656, Feature Loss: 0.9656, Edge Loss: 0.0000
# Epoch: 434, Total Loss: 0.9355, Feature Loss: 0.9355, Edge Loss: 0.0000
# Epoch: 435, Total Loss: 0.9405, Feature Loss: 0.9405, Edge Loss: 0.0000
# Epoch: 436, Total Loss: 0.9322, Feature Loss: 0.9322, Edge Loss: 0.0000
# Epoch: 437, Total Loss: 0.9847, Feature Loss: 0.9847, Edge Loss: 0.0000
# Epoch: 438, Total Loss: 0.9550, Feature Loss: 0.9550, Edge Loss: 0.0000
# Epoch: 439, Total Loss: 0.9506, Feature Loss: 0.9506, Edge Loss: 0.0000
# Epoch: 440, Total Loss: 0.9012, Feature Loss: 0.9012, Edge Loss: 0.0000
# Epoch: 441, Total Loss: 0.8769, Feature Loss: 0.8769, Edge Loss: 0.0000
# Epoch: 442, Total Loss: 0.9535, Feature Loss: 0.9535, Edge Loss: 0.0000
# Epoch: 443, Total Loss: 0.9314, Feature Loss: 0.9314, Edge Loss: 0.0000
# Epoch: 444, Total Loss: 0.8940, Feature Loss: 0.8940, Edge Loss: 0.0000
# Epoch: 445, Total Loss: 0.9662, Feature Loss: 0.9662, Edge Loss: 0.0000
# Epoch: 446, Total Loss: 0.9764, Feature Loss: 0.9764, Edge Loss: 0.0000
# Epoch: 447, Total Loss: 0.9068, Feature Loss: 0.9068, Edge Loss: 0.0000
# Epoch: 448, Total Loss: 0.9153, Feature Loss: 0.9153, Edge Loss: 0.0000
# Epoch: 449, Total Loss: 0.8575, Feature Loss: 0.8575, Edge Loss: 0.0000
# Epoch: 450, Total Loss: 0.8863, Feature Loss: 0.8863, Edge Loss: 0.0000
# Epoch: 451, Total Loss: 0.8732, Feature Loss: 0.8732, Edge Loss: 0.0000
# Epoch: 452, Total Loss: 0.8929, Feature Loss: 0.8929, Edge Loss: 0.0000
# Epoch: 453, Total Loss: 0.8856, Feature Loss: 0.8856, Edge Loss: 0.0000
# Epoch: 454, Total Loss: 0.8723, Feature Loss: 0.8723, Edge Loss: 0.0000
# Epoch: 455, Total Loss: 0.8914, Feature Loss: 0.8914, Edge Loss: 0.0000
# Epoch: 456, Total Loss: 0.8646, Feature Loss: 0.8646, Edge Loss: 0.0000
# Epoch: 457, Total Loss: 0.8090, Feature Loss: 0.8090, Edge Loss: 0.0000
# Epoch: 458, Total Loss: 0.8400, Feature Loss: 0.8400, Edge Loss: 0.0000
# Epoch: 459, Total Loss: 0.8635, Feature Loss: 0.8635, Edge Loss: 0.0000
# Epoch: 460, Total Loss: 0.8860, Feature Loss: 0.8860, Edge Loss: 0.0000
# Epoch: 461, Total Loss: 0.8915, Feature Loss: 0.8915, Edge Loss: 0.0000
# Epoch: 462, Total Loss: 0.9356, Feature Loss: 0.9356, Edge Loss: 0.0000
# Epoch: 463, Total Loss: 0.8493, Feature Loss: 0.8493, Edge Loss: 0.0000
# Epoch: 464, Total Loss: 0.8447, Feature Loss: 0.8447, Edge Loss: 0.0000
# Epoch: 465, Total Loss: 0.8329, Feature Loss: 0.8329, Edge Loss: 0.0000
# Epoch: 466, Total Loss: 0.8289, Feature Loss: 0.8289, Edge Loss: 0.0000
# Epoch: 467, Total Loss: 0.8242, Feature Loss: 0.8242, Edge Loss: 0.0000
# Epoch: 468, Total Loss: 0.8512, Feature Loss: 0.8512, Edge Loss: 0.0000
# Epoch: 469, Total Loss: 0.8155, Feature Loss: 0.8155, Edge Loss: 0.0000
# Epoch: 470, Total Loss: 0.8369, Feature Loss: 0.8369, Edge Loss: 0.0000
# Epoch: 471, Total Loss: 0.8387, Feature Loss: 0.8387, Edge Loss: 0.0000
# Epoch: 472, Total Loss: 0.8278, Feature Loss: 0.8278, Edge Loss: 0.0000
# Epoch: 473, Total Loss: 0.8407, Feature Loss: 0.8407, Edge Loss: 0.0000
# Epoch: 474, Total Loss: 0.8180, Feature Loss: 0.8180, Edge Loss: 0.0000
# Epoch: 475, Total Loss: 0.8200, Feature Loss: 0.8200, Edge Loss: 0.0000
# Epoch: 476, Total Loss: 0.8212, Feature Loss: 0.8212, Edge Loss: 0.0000
# Epoch: 477, Total Loss: 0.7595, Feature Loss: 0.7595, Edge Loss: 0.0000
# Epoch: 478, Total Loss: 0.8038, Feature Loss: 0.8038, Edge Loss: 0.0000
# Epoch: 479, Total Loss: 0.7801, Feature Loss: 0.7801, Edge Loss: 0.0000
# Epoch: 480, Total Loss: 0.8164, Feature Loss: 0.8164, Edge Loss: 0.0000
# Epoch: 481, Total Loss: 0.7796, Feature Loss: 0.7796, Edge Loss: 0.0000
# Epoch: 482, Total Loss: 0.7690, Feature Loss: 0.7690, Edge Loss: 0.0000
# Epoch: 483, Total Loss: 0.8043, Feature Loss: 0.8043, Edge Loss: 0.0000
# Epoch: 484, Total Loss: 0.8197, Feature Loss: 0.8197, Edge Loss: 0.0000
# Epoch: 485, Total Loss: 0.7786, Feature Loss: 0.7786, Edge Loss: 0.0000
# Epoch: 486, Total Loss: 0.7434, Feature Loss: 0.7434, Edge Loss: 0.0000
# Epoch: 487, Total Loss: 0.7916, Feature Loss: 0.7916, Edge Loss: 0.0000
# Epoch: 488, Total Loss: 0.7822, Feature Loss: 0.7822, Edge Loss: 0.0000
# Epoch: 489, Total Loss: 0.7704, Feature Loss: 0.7704, Edge Loss: 0.0000
# Epoch: 490, Total Loss: 0.7829, Feature Loss: 0.7829, Edge Loss: 0.0000
# Epoch: 491, Total Loss: 0.7352, Feature Loss: 0.7352, Edge Loss: 0.0000
# Epoch: 492, Total Loss: 0.7714, Feature Loss: 0.7714, Edge Loss: 0.0000
# Epoch: 493, Total Loss: 0.7590, Feature Loss: 0.7590, Edge Loss: 0.0000
# Epoch: 494, Total Loss: 0.7703, Feature Loss: 0.7703, Edge Loss: 0.0000
# Epoch: 495, Total Loss: 0.7144, Feature Loss: 0.7144, Edge Loss: 0.0000
# Epoch: 496, Total Loss: 0.7443, Feature Loss: 0.7443, Edge Loss: 0.0000
# Epoch: 497, Total Loss: 0.7279, Feature Loss: 0.7279, Edge Loss: 0.0000
# Epoch: 498, Total Loss: 0.7315, Feature Loss: 0.7315, Edge Loss: 0.0000
# Epoch: 499, Total Loss: 0.7820, Feature Loss: 0.7820, Edge Loss: 0.0000
# Epoch: 500, Total Loss: 0.7188, Feature Loss: 0.7188, Edge Loss: 0.0000

# %% [markdown]
# plt.figure(figsize=(14, 5))
# plt.plot(total_losses, label='Total Loss')
# plt.legend()
# plt.title('Total Loss')
# plt.show()

# %% [markdown]
# plt.figure(figsize=(14, 5))
# plt.plot(feature_losses, label='Feature Loss')
# plt.legend()
# plt.title('Feature Loss')
# plt.show()

# %%
if not model_loaded:
    plt.figure(figsize=(14, 5))
    plt.plot(total_losses, label='Total Loss')
    plt.legend()
    plt.title('Total Loss')
    plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
if not model_loaded:
    plt.figure(figsize=(14, 5))
    plt.plot(feature_losses, label='Feature Loss')
    plt.legend()
    plt.title('Feature Loss')
    plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
train_loader = DataLoader(graphs, batch_size=1)

# %%
decoded_data=[]
for data in train_loader:
    model.eval()
    z,encoded_edge_index = model.encode(data.x, data.edge_index)
    decoded_data.append(z.detach().numpy())

decoded_data = np.array(decoded_data)

# %%
decoded_data.shape
# Out:
# (51, 101, 2)

# %%
frame = 49
plt.figure(figsize=(14, 5))
data = decoded_data[frame]
plt.scatter(data[:,0], data[:,1])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
