# %%
import mdtraj as md
from ase import Atoms
import nglview as nv
import networkx as nx

import numpy as np
import matplotlib.pyplot as plt
import torch
from tqdm import tqdm

import torch_geometric.transforms as T
from torch_geometric.loader import DataLoader
from torch_geometric.nn import GCNConv, SAGPooling, InnerProductDecoder
import torch_geometric.data as data
from torch_geometric.utils.convert import to_networkx
import torch.optim.lr_scheduler as lr_scheduler
from torch.nn import Linear
import sys

# %%
all_frames_cry = md.load_xtc("../simulation/para_crystal.xtc", top="../simulation/para_crystal.gro")
all_frames_melt = md.load_xtc("../simulation/para_melt.xtc", top="../simulation/para_melt.gro")

# %%
all_frames_cry = all_frames_cry[::100]
all_frames_melt = all_frames_melt[::100]

# %%
n_frames = all_frames_cry.xyz.shape[0]
n_atoms = all_frames_cry.topology.residue(0).n_atoms
n_mols = all_frames_cry.topology.n_residues

# %%
def createGraph(all_frames,structure_type="crystal"):
    all_frames_fatures = []

    print("Creating Feature matrix")
    for i in tqdm(range(all_frames.xyz.shape[0])):
        mol_com_pos = []

        for res in all_frames.top.residues:
            pos = []
            for atom in res.atoms:
                pos.append(all_frames.xyz[i][atom.index])
            mol_com_pos.append(np.mean(pos,axis=0))
            
            # print()
        mol_com_pos = np.array(mol_com_pos).astype(np.float32)  
        all_frames_fatures.append(mol_com_pos)

    all_frames_fatures = np.array(all_frames_fatures).astype(np.float32)



    cutoff = 0.8

    print("Creating Edge list")
    all_edge_list = []
    # with open("edge_list.txt","w") as f:
    for frame_i in tqdm(range(n_frames)):
        from_list = []
        to_list = []

        for i in range(len(all_frames_fatures[frame_i])):
            for j in range(i+1,len(all_frames_fatures[frame_i])):
                if np.linalg.norm(all_frames_fatures[frame_i][i]-all_frames_fatures[frame_i][j]) < cutoff:
                    # f.write(str(i)+" "+str(j)+" "+str(np.linalg.norm(all_frames_fatures[frame_i][i]-all_frames_fatures[frame_i][j]))+"\n")
                    from_list.append(i)
                    to_list.append(j)

                    to_list.append(i)
                    from_list.append(j)

        edge_list = np.array([from_list,to_list]).astype(np.int64)
        all_edge_list.append(edge_list)
    print("creating Graphs")
    graphs = []
    for frame in tqdm(range(n_frames)):
        if structure_type == "crystal":
            g = data.Data(x=torch.tensor(all_frames_fatures[frame]).float(), edge_index=torch.tensor(all_edge_list[frame]).long(), y=torch.tensor([0]))
        else:
            g = data.Data(x=torch.tensor(all_frames_fatures[frame]).float(), edge_index=torch.tensor(all_edge_list[frame]).long(), y=torch.tensor([1]))
        graphs.append(g)
    return graphs

# %%
graphs_cry = createGraph(all_frames_cry,structure_type="crystal")
graphs_melt = createGraph(all_frames_melt,structure_type="melt")
# Out:
# Creating Feature matrix
# 100%|██████████| 51/51 [00:01<00:00, 47.51it/s]
# Creating Edge list
# 100%|██████████| 51/51 [02:19<00:00,  2.74s/it]
# creating Graphs
# 100%|██████████| 51/51 [00:00<00:00, 14272.05it/s]
# Creating Feature matrix
# 100%|██████████| 51/51 [00:01<00:00, 48.61it/s]
# Creating Edge list
# 100%|██████████| 51/51 [02:19<00:00,  2.74s/it]
# creating Graphs
# 100%|██████████| 51/51 [00:00<00:00, 13653.51it/s]

# %%
all_frame_positions = []
for i in range(n_frames):
    all_frame_positions.append(all_frames_cry.xyz[i])
all_frame_positions = np.array(all_frame_positions).astype(np.float32)
print(all_frame_positions)
# Out:
# [[[ 1.5200001   4.181       4.893     ]
#   [ 1.4070001   4.214       4.977     ]
#   [ 1.276       4.171       4.9360003 ]
#   ...
#   [ 5.9600005   0.284       8.767     ]
#   [ 6.0790005   0.41400003  8.779     ]
#   [ 5.6400003   0.76400006  8.121     ]]
#
#  [[ 1.243       4.421       4.637     ]
#   [ 1.12        4.4810004   4.6800003 ]
#   [ 1.006       4.465       4.5940003 ]
#   ...
#   [ 6.1740003   0.20300001  8.841001  ]
#   [ 6.2520003   0.34        8.786     ]
#   [ 5.848       0.60200006  8.101001  ]]
#
#  [[ 1.005       4.477       4.144     ]
#   [ 0.878       4.5400004   4.1730003 ]
#   [ 0.758       4.485       4.123     ]
#   ...
#   [ 6.175      -0.029       8.819     ]
#   [ 6.314      -0.012       8.704     ]
#   [ 5.952       0.323       8.021     ]]
#
#  ...
#
#  [[ 6.176       3.5700002   3.2170002 ]
#   [ 6.1330004   3.604       3.348     ]
#   [ 6.0220003   3.5390003   3.407     ]
#   ...
#   [ 5.7070003   0.67200005  6.26      ]
#   [ 5.5610003   0.58100003  6.3310003 ]
#   [ 5.6730003   0.054       5.662     ]]
#
#  [[ 6.13        3.5590003   3.206     ]
#   [ 6.1000004   3.5890002   3.341     ]
#   [ 5.986       3.5470002   3.4110003 ]
#   ...
#   [ 5.596       0.54700005  6.3450003 ]
#   [ 5.7400002   0.507       6.432     ]
#   [ 5.531      -0.078       5.762     ]]
#
#  [[ 6.2200003   3.571       3.226     ]
#   [ 6.1920004   3.5850003   3.3630002 ]
#   [ 6.0810003   3.522       3.4190001 ]
#   ...
#   [ 5.7770004   0.744       6.313     ]
#   [ 5.781       0.80500007  6.1480002 ]
#   [ 5.669       0.066       5.716     ]]]

# %%
def convert_to_adj(edge_index, num_nodes=None):
    if num_nodes is None:
        num_nodes = edge_index.max() + 1
    adj = torch.zeros(num_nodes, num_nodes)
    adj[edge_index[0], edge_index[1]] = 1
    return adj

def convert_to_edge_index(adj):
    edge_index = adj.nonzero().t()
    return edge_index

# %%
graphs = graphs_cry + graphs_melt

# %%
# shuffle the graphs
np.random.shuffle(graphs)

# %%
graphs
# Out:
# [Data(x=[864, 3], edge_index=[2, 7052], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7026], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7374], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7274], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6582], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7078], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6056], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6552], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7008], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7044], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5880], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6542], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7122], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7034], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7052], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7132], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5910], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7078], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6544], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7116], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6452], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6630], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7028], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5876], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6214], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6584], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6592], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7092], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6570], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6172], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7146], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6508], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6524], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6018], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6508], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5962], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7080], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5892], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7006], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7054], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7100], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6070], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6560], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7096], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6400], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6564], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6066], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6990], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6558], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7012], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7056], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7218], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6934], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5862], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7094], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7024], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5822], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6580], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6548], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6586], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7128], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7108], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7064], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6548], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6546], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6288], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7092], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6560], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6626], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6476], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6992], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6464], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6578], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7048], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7240], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6532], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6546], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7306], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7294], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6608], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7086], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6602], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7192], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7076], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7036], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7074], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7088], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7116], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6596], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6554], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7020], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7060], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6964], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7048], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6512], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6488], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7006], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7060], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6566], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6012], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5982], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7090], y=[1])]

# %% [markdown]
# ## model

# %%
from typing import Optional, Tuple

import torch
from torch import Tensor
from torch.nn import Module

from torch_geometric.nn.inits import reset
from torch_geometric.utils import negative_sampling

EPS = 1e-15
MAX_LOGSTD = 10
edgeShape = None
featureShape = None


class InnerProductDecoder(torch.nn.Module):
    r"""The inner product decoder from the `"Variational Graph Auto-Encoders"
    <https://arxiv.org/abs/1611.07308>`_ paper

    .. math::
        \sigma(\mathbf{Z}\mathbf{Z}^{\top})

    where :math:`\mathbf{Z} \in \mathbb{R}^{N \times d}` denotes the latent
    space produced by the encoder."""

    def forward(self, z: Tensor, edge_index: Tensor,
                sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into edge probabilities for
        the given node-pairs :obj:`edge_index`.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        value = (z[edge_index[0]] * z[edge_index[1]]).sum(dim=1)
        return torch.sigmoid(value) if sigmoid else value

    def forward_all(self, z: Tensor, sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into a probabilistic dense
        adjacency matrix.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        adj = torch.matmul(z, z.t())
        return torch.sigmoid(adj) if sigmoid else adj


class GAE(torch.nn.Module):
    r"""The Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper based on user-defined encoder and decoder models.

    Args:
        encoder (torch.nn.Module): The encoder module.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__()
        self.encoder = encoder
        self.decoder = InnerProductDecoder() if decoder is None else decoder
        GAE.reset_parameters(self)

    def reset_parameters(self):
        r"""Resets all learnable parameters of the module."""
        reset(self.encoder)
        reset(self.decoder)

    def forward(self, *args, **kwargs) -> Tensor:  # pragma: no cover
        r"""Alias for :meth:`encode`."""
        return self.encoder(*args, **kwargs)

    def encode(self, *args, **kwargs) -> Tensor:
        r"""Runs the encoder and computes node-wise latent variables."""
        return self.encoder(*args, **kwargs)

    def decode(self, *args, **kwargs) -> Tensor:
        r"""Runs the decoder and computes edge probabilities."""
        return self.decoder(*args, **kwargs)

    def recon_loss(self, z: Tensor, pos_edge_index: Tensor,
                   neg_edge_index: Optional[Tensor] = None) -> Tensor:
        r"""Given latent variables :obj:`z`, computes the binary cross
        entropy loss for positive edges :obj:`pos_edge_index` and negative
        sampled edges.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to train against.
            neg_edge_index (torch.Tensor, optional): The negative edges to
                train against. If not given, uses negative sampling to
                calculate negative edges. (default: :obj:`None`)
        """
        pos_loss = -torch.log(
            self.decoder(z, pos_edge_index, sigmoid=True)[0] + EPS).mean()

        if neg_edge_index is None:
            neg_edge_index = negative_sampling(pos_edge_index, z.size(0))
        neg_loss = -torch.log(1 -
                              self.decoder(z, neg_edge_index.long(), sigmoid=True)[0] +
                              EPS).mean()

        return pos_loss + neg_loss

    def test(self, z: Tensor, pos_edge_index: Tensor,
             neg_edge_index: Tensor) -> Tuple[Tensor, Tensor]:
        r"""Given latent variables :obj:`z`, positive edges
        :obj:`pos_edge_index` and negative edges :obj:`neg_edge_index`,
        computes area under the ROC curve (AUC) and average precision (AP)
        
        scores.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to evaluate
                against.
            neg_edge_index (torch.Tensor): The negative edges to evaluate
                against.
        """
        from sklearn.metrics import average_precision_score, roc_auc_score

        pos_y = z.new_ones(pos_edge_index.size(1))
        neg_y = z.new_zeros(neg_edge_index.size(1))
        y = torch.cat([pos_y, neg_y], dim=0)

        pos_pred = self.decoder(z, pos_edge_index, sigmoid=True)
        neg_pred = self.decoder(z, neg_edge_index, sigmoid=True)
        pred = torch.cat([pos_pred, neg_pred], dim=0)

        y, pred = y.detach().cpu().numpy(), pred.detach().cpu().numpy()

        return roc_auc_score(y, pred), average_precision_score(y, pred)


class VGAE(GAE):
    r"""The Variational Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper.

    Args:
        encoder (torch.nn.Module): The encoder module to compute :math:`\mu`
            and :math:`\log\sigma^2`.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__(encoder, decoder)

    def reparametrize(self, mu: Tensor, logstd: Tensor) -> Tensor:
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def encode(self, *args, **kwargs) -> Tensor:
        """"""
        z, self.edge_index = self.encoder(
            *args, **kwargs)
        
        return z, self.edge_index

    def kl_loss(self, mu: Optional[Tensor] = None,
                logstd: Optional[Tensor] = None) -> Tensor:
        r"""Computes the KL loss, either for the passed arguments :obj:`mu`
        and :obj:`logstd`, or based on latent variables from last encoding.

        Args:
            mu (torch.Tensor, optional): The latent space for :math:`\mu`. If
                set to :obj:`None`, uses the last computation of :math:`\mu`.
                (default: :obj:`None`)
            logstd (torch.Tensor, optional): The latent space for
                :math:`\log\sigma`.  If set to :obj:`None`, uses the last
                computation of :math:`\log\sigma^2`. (default: :obj:`None`)
        """
        mu = self.__mu__ if mu is None else mu
        logstd = self.__logstd__ if logstd is None else logstd.clamp(
            max=MAX_LOGSTD)
        return -0.5 * torch.mean(
            torch.sum(1 + 2 * logstd - mu**2 - logstd.exp()**2, dim=1))

# %%
import torch.nn.functional as F



class VariationalGCNEncoder(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.conv1 = GCNConv(in_channels, 2 * out_channels)
        self.conv2 = GCNConv(2*out_channels, 1 * out_channels)
        self.pool = SAGPooling(out_channels, 0.5)
        
        self.conv_mu = GCNConv(1 * out_channels, out_channels)
        self.conv_logstd = GCNConv(1 * out_channels, out_channels)
        self.conv_mu_crystal = GCNConv(1 * out_channels, out_channels)
        self.conv_logstd_crystal = GCNConv(1 * out_channels, out_channels)
        self.conv_mu_melt = GCNConv(1 * out_channels, out_channels)
        self.conv_logstd_melt = GCNConv(1 * out_channels, out_channels)
    
    def reparametrize(self, mu: Tensor, logstd: Tensor) -> Tensor:
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def forward(self, x, edge_index,class_label):
        # print("input:",x.shape, edge_index.shape)
        x = self.conv1(x, edge_index)
        x = F.silu(x)
        # print("conv1:",x.shape, edge_index.shape)
        x = self.conv2(x, edge_index)
        x = F.silu(x)
        # print("conv2:",x.shape, edge_index.shape)

        sample = self.reparametrize(self.conv_mu(x, edge_index), self.conv_logstd(x, edge_index))
        
        sample_crystal = self.reparametrize(self.conv_mu_crystal(sample, edge_index), self.conv_logstd_crystal(sample, edge_index))
        sample_melt = self.reparametrize(self.conv_mu_melt(sample, edge_index), self.conv_logstd_melt(sample, edge_index))

        self.conv_mu_crystal.train(True)
        self.conv_logstd_crystal.train(True)
        self.conv_mu_melt.train(True)
        self.conv_logstd_melt.train(True)


        if class_label == 0:
            self.conv_mu_melt.train(False)
            self.conv_logstd_melt.train(False)
            return sample_crystal, edge_index
        else:
            self.conv_mu_crystal.train(False)
            self.conv_logstd_crystal.train(False)
            return sample_melt, edge_index

# %%
class VariationalGCNDecoder(torch.nn.Module):
    def __init__(self,in_channels,out_channels):
        super().__init__()
        self.type_layer1 = Linear(1728,200)
        self.dropout = torch.nn.Dropout(0.5)
        self.type_layer2 = Linear(200,2)

        self.conv1 = GCNConv(in_channels, 2 * out_channels)
        self.conv2 = GCNConv(2 * out_channels, 1 * out_channels)
    def forward(self, x, edge_index, sigmoid=True):
        # print("input:",x.shape, edge_index.shape)
        flat = x.flatten()
        flat = self.type_layer1(flat).relu()
        flat = self.dropout(flat)
        str_type = F.softmax(self.type_layer2(flat).relu(),dim=0)
         
        x = self.conv1(x, edge_index)
        x = F.silu(x)
        # print("conv1:",x.shape, edge_index.shape)
        x = self.conv2(x, edge_index)
        x = F.silu(x)
        # print("conv2:",x.shape, edge_index.shape)
        return x, edge_index,str_type

# %%
import os
in_channels = graphs[0].num_features
out_channels = 2
lr = 1e-4
n_epochs = 200
batch_size=1
test_train_split = 0.8
model_name = "mse.pt"
model_loaded = False
force_train = False

if os.path.exists("./models/"+model_name) and not force_train:
    model = torch.load("./models/"+model_name)
    model_loaded = True
else:
    model = VGAE(VariationalGCNEncoder(in_channels, out_channels),
                VariationalGCNDecoder(out_channels, in_channels))

optimizer = torch.optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, step_size=300, gamma=0.5)

# %%
train_loader = DataLoader(graphs[:int(n_frames*test_train_split)], batch_size=batch_size, shuffle=True)
test_loader = DataLoader(graphs[int(n_frames*test_train_split):], batch_size=batch_size, shuffle=True)

# %%
lossFxn = torch.nn.MSELoss()
typeLossFxn = torch.nn.CrossEntropyLoss()
# mseloss_position=[]
def train():
    model.train()
    model.zero_grad()
    model.float()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0
    type_loss_all = 0
    mseloss_position_0=0
    for data in train_loader:
        optimizer.zero_grad()
        z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
        decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)

     
        MSEloss = lossFxn(decoded_x,data.x)
        # TypeLoss = typeLossFxn(str_type.unsqueeze(0), data.y)
        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        loss = FeatureLoss + EdgeLoss 
        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        mseloss_position_0 += float(MSEloss)
        # type_loss_all += float(TypeLoss)

        loss.backward()
        optimizer.step()
        # mseloss_position.append(mseloss_position_0)
        

    return loss_all / len(train_loader), feature_loss_all / len(train_loader), edge_loss_all / len(train_loader), kl_loss_all / len(train_loader), type_loss_all / len(train_loader), mseloss_position_0/ len(train_loader)

# %%
lossFxn = torch.nn.MSELoss()
def test():
    model.eval()
    model.zero_grad()
    model.float()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0
    type_loss_all = 0
    mse_loss_all=0
    for data in test_loader:
        optimizer.zero_grad()
        z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
        decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
        
        # TypeLoss = typeLossFxn(str_type.unsqueeze(0), data.y)
        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        loss = FeatureLoss + EdgeLoss 
        MSELoss = lossFxn(decoded_x, data.x)

        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        mse_loss_all += float(MSELoss)
        # type_loss_all += float(TypeLoss)
        
        
        

    return loss_all / len(test_loader), feature_loss_all / len(test_loader), edge_loss_all / len(test_loader), kl_loss_all / len(test_loader), type_loss_all / len(test_loader), mse_loss_all/ len(test_loader)

# %%
train_total_losses = []
train_feature_losses = []
train_edge_losses = []
train_kl_losses = []
train_type_losses = []
train_mse_losses = []
test_total_losses = []
test_feature_losses = []
test_edge_losses = []
test_kl_losses = []
test_type_losses = []
test_mse_losses = []
if model_loaded:        
    print("Pretrained Model Loaded, no training required")
else:
    for epoch in range(1, n_epochs + 1):
        
        train_total_loss, train_feature_loss, train_edge_loss, train_kl_loss,train_type_loss,train_mse_loss = train()
        test_total_loss, test_feature_loss, test_edge_loss, test_kl_loss, test_type_loss, test_mse_loss= test()
        
        print(f"Epoch: {epoch:03d}")
        print(f'\tTrain:\tTotal Loss: {train_total_loss:.4f}, Feature Loss: {train_feature_loss:.4f}, Type Loss: {train_type_loss:.4f} ,  LR: {scheduler.get_last_lr()[0]:.6f}, \tMSE loss in postions: {train_mse_loss:.4f}')
        print(f'\tTest: \tTotal Loss: {test_total_loss:.4f}, Feature Loss: {test_feature_loss:.4f}, Type Loss: {test_type_loss:.4f} , LR: {scheduler.get_last_lr()[0]:.6f}, \tMSE loss in positions: {test_mse_loss:.4f}')
        
        train_total_losses.append(train_total_loss)
        train_feature_losses.append(train_feature_loss)
        train_edge_losses.append(train_edge_loss)
        train_kl_losses.append(train_kl_loss)
        train_type_losses.append(train_type_loss)
        train_mse_losses.append(train_mse_loss)


        test_total_losses.append(test_total_loss)
        test_feature_losses.append(test_feature_loss)
        test_edge_losses.append(test_edge_loss)
        test_kl_losses.append(test_kl_loss)
        test_type_losses.append(test_type_loss)
        test_mse_losses.append(test_mse_loss)
        
        scheduler.step()
    torch.save(model,"./models/"+model_name)
# Out:
# Epoch: 001
# 	Train:	Total Loss: 10.8062, Feature Loss: 10.8062, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 10.8062
# 	Test: 	Total Loss: 10.0333, Feature Loss: 10.0333, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 10.0333
# Epoch: 002
# 	Train:	Total Loss: 10.6244, Feature Loss: 10.6244, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 10.6244
# 	Test: 	Total Loss: 9.8531, Feature Loss: 9.8531, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 9.8531
# Epoch: 003
# 	Train:	Total Loss: 10.4611, Feature Loss: 10.4611, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 10.4611
# 	Test: 	Total Loss: 9.6772, Feature Loss: 9.6772, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 9.6772
# Epoch: 004
# 	Train:	Total Loss: 10.2454, Feature Loss: 10.2454, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 10.2454
# 	Test: 	Total Loss: 9.5017, Feature Loss: 9.5017, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 9.5017
# Epoch: 005
# 	Train:	Total Loss: 10.0769, Feature Loss: 10.0769, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 10.0769
# 	Test: 	Total Loss: 9.3271, Feature Loss: 9.3271, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 9.3271
# Epoch: 006
# 	Train:	Total Loss: 9.8655, Feature Loss: 9.8655, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 9.8655
# 	Test: 	Total Loss: 9.1542, Feature Loss: 9.1542, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 9.1542
# Epoch: 007
# 	Train:	Total Loss: 9.6984, Feature Loss: 9.6984, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 9.6984
# 	Test: 	Total Loss: 8.9851, Feature Loss: 8.9851, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 8.9851
# Epoch: 008
# 	Train:	Total Loss: 9.5292, Feature Loss: 9.5292, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 9.5292
# 	Test: 	Total Loss: 8.8200, Feature Loss: 8.8200, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 8.8200
# Epoch: 009
# 	Train:	Total Loss: 9.3354, Feature Loss: 9.3354, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 9.3354
# 	Test: 	Total Loss: 8.6602, Feature Loss: 8.6602, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 8.6602
# Epoch: 010
# 	Train:	Total Loss: 9.1737, Feature Loss: 9.1737, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 9.1737
# 	Test: 	Total Loss: 8.5016, Feature Loss: 8.5016, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 8.5016
# Epoch: 011
# 	Train:	Total Loss: 9.0090, Feature Loss: 9.0090, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 9.0090
# 	Test: 	Total Loss: 8.3485, Feature Loss: 8.3485, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 8.3485
# Epoch: 012
# 	Train:	Total Loss: 8.8633, Feature Loss: 8.8633, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 8.8633
# 	Test: 	Total Loss: 8.2000, Feature Loss: 8.2000, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 8.2000
# Epoch: 013
# 	Train:	Total Loss: 8.7110, Feature Loss: 8.7110, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 8.7110
# 	Test: 	Total Loss: 8.0578, Feature Loss: 8.0578, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 8.0578
# Epoch: 014
# 	Train:	Total Loss: 8.5738, Feature Loss: 8.5738, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 8.5738
# 	Test: 	Total Loss: 7.9168, Feature Loss: 7.9168, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 7.9168
# Epoch: 015
# 	Train:	Total Loss: 8.4339, Feature Loss: 8.4339, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 8.4339
# 	Test: 	Total Loss: 7.7772, Feature Loss: 7.7772, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 7.7772
# Epoch: 016
# 	Train:	Total Loss: 8.2951, Feature Loss: 8.2951, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 8.2951
# 	Test: 	Total Loss: 7.6411, Feature Loss: 7.6411, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 7.6411
# Epoch: 017
# 	Train:	Total Loss: 8.1611, Feature Loss: 8.1611, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 8.1611
# 	Test: 	Total Loss: 7.5085, Feature Loss: 7.5085, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 7.5085
# Epoch: 018
# 	Train:	Total Loss: 8.0334, Feature Loss: 8.0334, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 8.0334
# 	Test: 	Total Loss: 7.3753, Feature Loss: 7.3753, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 7.3753
# Epoch: 019
# 	Train:	Total Loss: 7.9055, Feature Loss: 7.9055, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 7.9055
# 	Test: 	Total Loss: 7.2478, Feature Loss: 7.2478, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 7.2478
# Epoch: 020
# 	Train:	Total Loss: 7.7825, Feature Loss: 7.7825, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 7.7825
# 	Test: 	Total Loss: 7.1188, Feature Loss: 7.1188, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 7.1188
# Epoch: 021
# 	Train:	Total Loss: 7.6559, Feature Loss: 7.6559, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 7.6559
# 	Test: 	Total Loss: 6.9966, Feature Loss: 6.9966, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 6.9966
# Epoch: 022
# 	Train:	Total Loss: 7.5378, Feature Loss: 7.5378, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 7.5378
# 	Test: 	Total Loss: 6.8739, Feature Loss: 6.8739, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 6.8739
# Epoch: 023
# 	Train:	Total Loss: 7.4202, Feature Loss: 7.4202, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 7.4202
# 	Test: 	Total Loss: 6.7449, Feature Loss: 6.7449, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 6.7449
# Epoch: 024
# 	Train:	Total Loss: 7.2990, Feature Loss: 7.2990, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 7.2990
# 	Test: 	Total Loss: 6.6260, Feature Loss: 6.6260, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 6.6260
# Epoch: 025
# 	Train:	Total Loss: 7.1879, Feature Loss: 7.1879, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 7.1879
# 	Test: 	Total Loss: 6.5133, Feature Loss: 6.5133, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 6.5133
# Epoch: 026
# 	Train:	Total Loss: 7.0824, Feature Loss: 7.0824, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 7.0824
# 	Test: 	Total Loss: 6.3941, Feature Loss: 6.3941, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 6.3941
# Epoch: 027
# 	Train:	Total Loss: 6.9669, Feature Loss: 6.9669, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 6.9669
# 	Test: 	Total Loss: 6.2816, Feature Loss: 6.2816, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 6.2816
# Epoch: 028
# 	Train:	Total Loss: 6.8635, Feature Loss: 6.8635, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 6.8635
# 	Test: 	Total Loss: 6.1720, Feature Loss: 6.1720, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 6.1720
# Epoch: 029
# 	Train:	Total Loss: 6.7601, Feature Loss: 6.7601, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 6.7601
# 	Test: 	Total Loss: 6.0617, Feature Loss: 6.0617, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 6.0617
# Epoch: 030
# 	Train:	Total Loss: 6.6585, Feature Loss: 6.6585, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 6.6585
# 	Test: 	Total Loss: 5.9609, Feature Loss: 5.9609, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 5.9609
# Epoch: 031
# 	Train:	Total Loss: 6.5682, Feature Loss: 6.5682, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 6.5682
# 	Test: 	Total Loss: 5.8629, Feature Loss: 5.8629, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 5.8629
# Epoch: 032
# 	Train:	Total Loss: 6.4800, Feature Loss: 6.4800, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 6.4800
# 	Test: 	Total Loss: 5.7715, Feature Loss: 5.7715, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 5.7715
# Epoch: 033
# 	Train:	Total Loss: 6.3956, Feature Loss: 6.3956, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 6.3956
# 	Test: 	Total Loss: 5.6822, Feature Loss: 5.6822, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 5.6822
# Epoch: 034
# 	Train:	Total Loss: 6.3145, Feature Loss: 6.3145, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 6.3145
# 	Test: 	Total Loss: 5.6056, Feature Loss: 5.6056, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 5.6056
# Epoch: 035
# 	Train:	Total Loss: 6.2394, Feature Loss: 6.2394, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 6.2394
# 	Test: 	Total Loss: 5.5290, Feature Loss: 5.5290, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 5.5290
# Epoch: 036
# 	Train:	Total Loss: 6.1743, Feature Loss: 6.1743, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 6.1743
# 	Test: 	Total Loss: 5.4611, Feature Loss: 5.4611, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 5.4611
# Epoch: 037
# 	Train:	Total Loss: 6.1109, Feature Loss: 6.1109, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 6.1109
# 	Test: 	Total Loss: 5.3977, Feature Loss: 5.3977, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 5.3977
# Epoch: 038
# 	Train:	Total Loss: 6.0426, Feature Loss: 6.0426, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 6.0426
# 	Test: 	Total Loss: 5.3400, Feature Loss: 5.3400, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 5.3400
# Epoch: 039
# 	Train:	Total Loss: 5.9951, Feature Loss: 5.9951, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.9951
# 	Test: 	Total Loss: 5.2868, Feature Loss: 5.2868, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 5.2868
# Epoch: 040
# 	Train:	Total Loss: 5.9454, Feature Loss: 5.9454, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.9454
# 	Test: 	Total Loss: 5.2407, Feature Loss: 5.2407, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 5.2407
# Epoch: 041
# 	Train:	Total Loss: 5.9041, Feature Loss: 5.9041, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.9041
# 	Test: 	Total Loss: 5.1983, Feature Loss: 5.1983, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 5.1983
# Epoch: 042
# 	Train:	Total Loss: 5.8691, Feature Loss: 5.8691, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.8691
# 	Test: 	Total Loss: 5.1589, Feature Loss: 5.1589, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 5.1589
# Epoch: 043
# 	Train:	Total Loss: 5.8300, Feature Loss: 5.8300, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.8300
# 	Test: 	Total Loss: 5.1231, Feature Loss: 5.1231, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 5.1231
# Epoch: 044
# 	Train:	Total Loss: 5.7966, Feature Loss: 5.7966, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.7966
# 	Test: 	Total Loss: 5.0917, Feature Loss: 5.0917, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 5.0917
# Epoch: 045
# 	Train:	Total Loss: 5.7707, Feature Loss: 5.7707, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.7707
# 	Test: 	Total Loss: 5.0620, Feature Loss: 5.0620, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 5.0620
# Epoch: 046
# 	Train:	Total Loss: 5.7414, Feature Loss: 5.7414, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.7414
# 	Test: 	Total Loss: 5.0372, Feature Loss: 5.0372, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 5.0372
# Epoch: 047
# 	Train:	Total Loss: 5.7164, Feature Loss: 5.7164, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.7164
# 	Test: 	Total Loss: 5.0125, Feature Loss: 5.0125, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 5.0125
# Epoch: 048
# 	Train:	Total Loss: 5.6950, Feature Loss: 5.6950, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.6950
# 	Test: 	Total Loss: 4.9911, Feature Loss: 4.9911, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.9911
# Epoch: 049
# 	Train:	Total Loss: 5.6738, Feature Loss: 5.6738, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.6738
# 	Test: 	Total Loss: 4.9709, Feature Loss: 4.9709, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.9709
# Epoch: 050
# 	Train:	Total Loss: 5.6480, Feature Loss: 5.6480, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.6480
# 	Test: 	Total Loss: 4.9523, Feature Loss: 4.9523, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.9523
# Epoch: 051
# 	Train:	Total Loss: 5.6340, Feature Loss: 5.6340, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.6340
# 	Test: 	Total Loss: 4.9339, Feature Loss: 4.9339, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.9339
# Epoch: 052
# 	Train:	Total Loss: 5.6182, Feature Loss: 5.6182, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.6182
# 	Test: 	Total Loss: 4.9177, Feature Loss: 4.9177, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.9177
# Epoch: 053
# 	Train:	Total Loss: 5.5976, Feature Loss: 5.5976, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.5976
# 	Test: 	Total Loss: 4.9025, Feature Loss: 4.9025, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.9025
# Epoch: 054
# 	Train:	Total Loss: 5.5846, Feature Loss: 5.5846, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.5846
# 	Test: 	Total Loss: 4.8870, Feature Loss: 4.8870, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.8870
# Epoch: 055
# 	Train:	Total Loss: 5.5706, Feature Loss: 5.5706, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.5706
# 	Test: 	Total Loss: 4.8735, Feature Loss: 4.8735, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.8735
# Epoch: 056
# 	Train:	Total Loss: 5.5520, Feature Loss: 5.5520, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.5520
# 	Test: 	Total Loss: 4.8602, Feature Loss: 4.8602, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.8602
# Epoch: 057
# 	Train:	Total Loss: 5.5420, Feature Loss: 5.5420, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.5420
# 	Test: 	Total Loss: 4.8467, Feature Loss: 4.8467, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.8467
# Epoch: 058
# 	Train:	Total Loss: 5.5296, Feature Loss: 5.5296, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.5296
# 	Test: 	Total Loss: 4.8342, Feature Loss: 4.8342, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.8342
# Epoch: 059
# 	Train:	Total Loss: 5.5215, Feature Loss: 5.5215, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.5215
# 	Test: 	Total Loss: 4.8224, Feature Loss: 4.8224, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.8224
# Epoch: 060
# 	Train:	Total Loss: 5.5037, Feature Loss: 5.5037, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.5037
# 	Test: 	Total Loss: 4.8104, Feature Loss: 4.8104, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.8104
# Epoch: 061
# 	Train:	Total Loss: 5.4957, Feature Loss: 5.4957, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.4957
# 	Test: 	Total Loss: 4.7994, Feature Loss: 4.7994, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.7994
# Epoch: 062
# 	Train:	Total Loss: 5.4843, Feature Loss: 5.4843, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.4843
# 	Test: 	Total Loss: 4.7885, Feature Loss: 4.7885, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.7885
# Epoch: 063
# 	Train:	Total Loss: 5.4692, Feature Loss: 5.4692, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.4692
# 	Test: 	Total Loss: 4.7777, Feature Loss: 4.7777, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.7777
# Epoch: 064
# 	Train:	Total Loss: 5.4600, Feature Loss: 5.4600, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.4600
# 	Test: 	Total Loss: 4.7673, Feature Loss: 4.7673, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.7673
# Epoch: 065
# 	Train:	Total Loss: 5.4483, Feature Loss: 5.4483, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.4483
# 	Test: 	Total Loss: 4.7574, Feature Loss: 4.7574, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.7574
# Epoch: 066
# 	Train:	Total Loss: 5.4385, Feature Loss: 5.4385, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.4385
# 	Test: 	Total Loss: 4.7475, Feature Loss: 4.7475, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.7475
# Epoch: 067
# 	Train:	Total Loss: 5.4255, Feature Loss: 5.4255, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.4255
# 	Test: 	Total Loss: 4.7378, Feature Loss: 4.7378, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.7378
# Epoch: 068
# 	Train:	Total Loss: 5.4160, Feature Loss: 5.4160, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.4160
# 	Test: 	Total Loss: 4.7285, Feature Loss: 4.7285, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.7285
# Epoch: 069
# 	Train:	Total Loss: 5.4075, Feature Loss: 5.4075, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.4075
# 	Test: 	Total Loss: 4.7195, Feature Loss: 4.7195, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.7195
# Epoch: 070
# 	Train:	Total Loss: 5.3996, Feature Loss: 5.3996, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.3996
# 	Test: 	Total Loss: 4.7105, Feature Loss: 4.7105, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.7105
# Epoch: 071
# 	Train:	Total Loss: 5.3922, Feature Loss: 5.3922, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.3922
# 	Test: 	Total Loss: 4.7018, Feature Loss: 4.7018, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.7018
# Epoch: 072
# 	Train:	Total Loss: 5.3802, Feature Loss: 5.3802, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.3802
# 	Test: 	Total Loss: 4.6933, Feature Loss: 4.6933, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.6933
# Epoch: 073
# 	Train:	Total Loss: 5.3716, Feature Loss: 5.3716, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.3716
# 	Test: 	Total Loss: 4.6850, Feature Loss: 4.6850, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.6850
# Epoch: 074
# 	Train:	Total Loss: 5.3651, Feature Loss: 5.3651, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.3651
# 	Test: 	Total Loss: 4.6768, Feature Loss: 4.6768, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.6768
# Epoch: 075
# 	Train:	Total Loss: 5.3541, Feature Loss: 5.3541, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.3541
# 	Test: 	Total Loss: 4.6688, Feature Loss: 4.6688, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.6688
# Epoch: 076
# 	Train:	Total Loss: 5.3470, Feature Loss: 5.3470, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.3470
# 	Test: 	Total Loss: 4.6611, Feature Loss: 4.6611, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.6611
# Epoch: 077
# 	Train:	Total Loss: 5.3382, Feature Loss: 5.3382, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.3382
# 	Test: 	Total Loss: 4.6534, Feature Loss: 4.6534, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.6534
# Epoch: 078
# 	Train:	Total Loss: 5.3273, Feature Loss: 5.3273, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.3273
# 	Test: 	Total Loss: 4.6459, Feature Loss: 4.6459, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.6459
# Epoch: 079
# 	Train:	Total Loss: 5.3177, Feature Loss: 5.3177, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.3177
# 	Test: 	Total Loss: 4.6384, Feature Loss: 4.6384, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.6384
# Epoch: 080
# 	Train:	Total Loss: 5.3119, Feature Loss: 5.3119, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.3119
# 	Test: 	Total Loss: 4.6312, Feature Loss: 4.6312, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.6312
# Epoch: 081
# 	Train:	Total Loss: 5.3072, Feature Loss: 5.3072, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.3072
# 	Test: 	Total Loss: 4.6241, Feature Loss: 4.6241, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.6241
# Epoch: 082
# 	Train:	Total Loss: 5.2959, Feature Loss: 5.2959, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.2959
# 	Test: 	Total Loss: 4.6171, Feature Loss: 4.6171, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.6171
# Epoch: 083
# 	Train:	Total Loss: 5.2851, Feature Loss: 5.2851, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.2851
# 	Test: 	Total Loss: 4.6101, Feature Loss: 4.6101, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.6101
# Epoch: 084
# 	Train:	Total Loss: 5.2796, Feature Loss: 5.2796, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.2796
# 	Test: 	Total Loss: 4.6033, Feature Loss: 4.6033, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.6033
# Epoch: 085
# 	Train:	Total Loss: 5.2749, Feature Loss: 5.2749, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.2749
# 	Test: 	Total Loss: 4.5966, Feature Loss: 4.5966, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.5966
# Epoch: 086
# 	Train:	Total Loss: 5.2645, Feature Loss: 5.2645, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.2645
# 	Test: 	Total Loss: 4.5899, Feature Loss: 4.5899, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.5899
# Epoch: 087
# 	Train:	Total Loss: 5.2583, Feature Loss: 5.2583, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.2583
# 	Test: 	Total Loss: 4.5833, Feature Loss: 4.5833, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.5833
# Epoch: 088
# 	Train:	Total Loss: 5.2540, Feature Loss: 5.2540, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.2540
# 	Test: 	Total Loss: 4.5770, Feature Loss: 4.5770, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.5770
# Epoch: 089
# 	Train:	Total Loss: 5.2440, Feature Loss: 5.2440, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.2440
# 	Test: 	Total Loss: 4.5706, Feature Loss: 4.5706, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.5706
# Epoch: 090
# 	Train:	Total Loss: 5.2373, Feature Loss: 5.2373, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.2373
# 	Test: 	Total Loss: 4.5643, Feature Loss: 4.5643, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.5643
# Epoch: 091
# 	Train:	Total Loss: 5.2286, Feature Loss: 5.2286, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.2286
# 	Test: 	Total Loss: 4.5581, Feature Loss: 4.5581, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.5581
# Epoch: 092
# 	Train:	Total Loss: 5.2225, Feature Loss: 5.2225, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.2225
# 	Test: 	Total Loss: 4.5519, Feature Loss: 4.5519, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.5519
# Epoch: 093
# 	Train:	Total Loss: 5.2161, Feature Loss: 5.2161, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.2161
# 	Test: 	Total Loss: 4.5458, Feature Loss: 4.5458, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.5458
# Epoch: 094
# 	Train:	Total Loss: 5.2087, Feature Loss: 5.2087, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.2087
# 	Test: 	Total Loss: 4.5398, Feature Loss: 4.5398, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.5398
# Epoch: 095
# 	Train:	Total Loss: 5.2045, Feature Loss: 5.2045, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.2045
# 	Test: 	Total Loss: 4.5339, Feature Loss: 4.5339, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.5339
# Epoch: 096
# 	Train:	Total Loss: 5.1938, Feature Loss: 5.1938, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.1938
# 	Test: 	Total Loss: 4.5281, Feature Loss: 4.5281, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.5281
# Epoch: 097
# 	Train:	Total Loss: 5.1895, Feature Loss: 5.1895, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.1895
# 	Test: 	Total Loss: 4.5222, Feature Loss: 4.5222, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.5222
# Epoch: 098
# 	Train:	Total Loss: 5.1850, Feature Loss: 5.1850, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.1850
# 	Test: 	Total Loss: 4.5164, Feature Loss: 4.5164, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.5164
# Epoch: 099
# 	Train:	Total Loss: 5.1734, Feature Loss: 5.1734, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.1734
# 	Test: 	Total Loss: 4.5107, Feature Loss: 4.5107, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.5107
# Epoch: 100
# 	Train:	Total Loss: 5.1693, Feature Loss: 5.1693, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.1693
# 	Test: 	Total Loss: 4.5050, Feature Loss: 4.5050, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.5050
# Epoch: 101
# 	Train:	Total Loss: 5.1659, Feature Loss: 5.1659, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.1659
# 	Test: 	Total Loss: 4.4993, Feature Loss: 4.4993, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.4993
# Epoch: 102
# 	Train:	Total Loss: 5.1555, Feature Loss: 5.1555, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.1555
# 	Test: 	Total Loss: 4.4937, Feature Loss: 4.4937, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.4937
# Epoch: 103
# 	Train:	Total Loss: 5.1507, Feature Loss: 5.1507, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.1507
# 	Test: 	Total Loss: 4.4882, Feature Loss: 4.4882, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.4882
# Epoch: 104
# 	Train:	Total Loss: 5.1466, Feature Loss: 5.1466, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.1466
# 	Test: 	Total Loss: 4.4828, Feature Loss: 4.4828, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.4828
# Epoch: 105
# 	Train:	Total Loss: 5.1416, Feature Loss: 5.1416, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.1416
# 	Test: 	Total Loss: 4.4774, Feature Loss: 4.4774, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.4774
# Epoch: 106
# 	Train:	Total Loss: 5.1330, Feature Loss: 5.1330, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.1330
# 	Test: 	Total Loss: 4.4720, Feature Loss: 4.4720, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.4720
# Epoch: 107
# 	Train:	Total Loss: 5.1289, Feature Loss: 5.1289, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.1289
# 	Test: 	Total Loss: 4.4667, Feature Loss: 4.4667, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.4667
# Epoch: 108
# 	Train:	Total Loss: 5.1178, Feature Loss: 5.1178, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.1178
# 	Test: 	Total Loss: 4.4614, Feature Loss: 4.4614, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.4614
# Epoch: 109
# 	Train:	Total Loss: 5.1144, Feature Loss: 5.1144, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.1144
# 	Test: 	Total Loss: 4.4561, Feature Loss: 4.4561, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.4561
# Epoch: 110
# 	Train:	Total Loss: 5.1085, Feature Loss: 5.1085, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.1085
# 	Test: 	Total Loss: 4.4510, Feature Loss: 4.4510, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.4510
# Epoch: 111
# 	Train:	Total Loss: 5.1055, Feature Loss: 5.1055, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.1055
# 	Test: 	Total Loss: 4.4457, Feature Loss: 4.4457, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.4457
# Epoch: 112
# 	Train:	Total Loss: 5.0965, Feature Loss: 5.0965, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.0965
# 	Test: 	Total Loss: 4.4406, Feature Loss: 4.4406, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.4406
# Epoch: 113
# 	Train:	Total Loss: 5.0935, Feature Loss: 5.0935, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.0935
# 	Test: 	Total Loss: 4.4355, Feature Loss: 4.4355, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.4355
# Epoch: 114
# 	Train:	Total Loss: 5.0878, Feature Loss: 5.0878, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.0878
# 	Test: 	Total Loss: 4.4305, Feature Loss: 4.4305, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.4305
# Epoch: 115
# 	Train:	Total Loss: 5.0792, Feature Loss: 5.0792, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.0792
# 	Test: 	Total Loss: 4.4256, Feature Loss: 4.4256, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.4256
# Epoch: 116
# 	Train:	Total Loss: 5.0774, Feature Loss: 5.0774, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.0774
# 	Test: 	Total Loss: 4.4207, Feature Loss: 4.4207, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.4207
# Epoch: 117
# 	Train:	Total Loss: 5.0707, Feature Loss: 5.0707, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.0707
# 	Test: 	Total Loss: 4.4157, Feature Loss: 4.4157, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.4157
# Epoch: 118
# 	Train:	Total Loss: 5.0648, Feature Loss: 5.0648, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.0648
# 	Test: 	Total Loss: 4.4109, Feature Loss: 4.4109, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.4109
# Epoch: 119
# 	Train:	Total Loss: 5.0589, Feature Loss: 5.0589, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.0589
# 	Test: 	Total Loss: 4.4059, Feature Loss: 4.4059, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.4059
# Epoch: 120
# 	Train:	Total Loss: 5.0546, Feature Loss: 5.0546, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.0546
# 	Test: 	Total Loss: 4.4011, Feature Loss: 4.4011, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.4011
# Epoch: 121
# 	Train:	Total Loss: 5.0486, Feature Loss: 5.0486, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.0486
# 	Test: 	Total Loss: 4.3966, Feature Loss: 4.3966, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.3966
# Epoch: 122
# 	Train:	Total Loss: 5.0432, Feature Loss: 5.0432, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.0432
# 	Test: 	Total Loss: 4.3919, Feature Loss: 4.3919, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.3919
# Epoch: 123
# 	Train:	Total Loss: 5.0390, Feature Loss: 5.0390, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.0390
# 	Test: 	Total Loss: 4.3871, Feature Loss: 4.3871, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.3871
# Epoch: 124
# 	Train:	Total Loss: 5.0343, Feature Loss: 5.0343, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.0343
# 	Test: 	Total Loss: 4.3824, Feature Loss: 4.3824, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.3824
# Epoch: 125
# 	Train:	Total Loss: 5.0279, Feature Loss: 5.0279, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.0279
# 	Test: 	Total Loss: 4.3779, Feature Loss: 4.3779, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.3779
# Epoch: 126
# 	Train:	Total Loss: 5.0259, Feature Loss: 5.0259, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.0259
# 	Test: 	Total Loss: 4.3732, Feature Loss: 4.3732, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.3732
# Epoch: 127
# 	Train:	Total Loss: 5.0195, Feature Loss: 5.0195, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.0195
# 	Test: 	Total Loss: 4.3687, Feature Loss: 4.3687, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.3687
# Epoch: 128
# 	Train:	Total Loss: 5.0136, Feature Loss: 5.0136, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.0136
# 	Test: 	Total Loss: 4.3641, Feature Loss: 4.3641, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.3641
# Epoch: 129
# 	Train:	Total Loss: 5.0104, Feature Loss: 5.0104, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.0104
# 	Test: 	Total Loss: 4.3596, Feature Loss: 4.3596, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.3596
# Epoch: 130
# 	Train:	Total Loss: 5.0041, Feature Loss: 5.0041, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.0041
# 	Test: 	Total Loss: 4.3549, Feature Loss: 4.3549, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.3549
# Epoch: 131
# 	Train:	Total Loss: 5.0006, Feature Loss: 5.0006, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 5.0006
# 	Test: 	Total Loss: 4.3506, Feature Loss: 4.3506, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.3506
# Epoch: 132
# 	Train:	Total Loss: 4.9952, Feature Loss: 4.9952, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.9952
# 	Test: 	Total Loss: 4.3460, Feature Loss: 4.3460, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.3460
# Epoch: 133
# 	Train:	Total Loss: 4.9879, Feature Loss: 4.9879, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.9879
# 	Test: 	Total Loss: 4.3415, Feature Loss: 4.3415, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.3415
# Epoch: 134
# 	Train:	Total Loss: 4.9848, Feature Loss: 4.9848, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.9848
# 	Test: 	Total Loss: 4.3370, Feature Loss: 4.3370, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.3370
# Epoch: 135
# 	Train:	Total Loss: 4.9792, Feature Loss: 4.9792, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.9792
# 	Test: 	Total Loss: 4.3323, Feature Loss: 4.3323, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.3323
# Epoch: 136
# 	Train:	Total Loss: 4.9749, Feature Loss: 4.9749, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.9749
# 	Test: 	Total Loss: 4.3277, Feature Loss: 4.3277, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.3277
# Epoch: 137
# 	Train:	Total Loss: 4.9693, Feature Loss: 4.9693, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.9693
# 	Test: 	Total Loss: 4.3235, Feature Loss: 4.3235, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.3235
# Epoch: 138
# 	Train:	Total Loss: 4.9654, Feature Loss: 4.9654, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.9654
# 	Test: 	Total Loss: 4.3188, Feature Loss: 4.3188, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.3188
# Epoch: 139
# 	Train:	Total Loss: 4.9612, Feature Loss: 4.9612, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.9612
# 	Test: 	Total Loss: 4.3143, Feature Loss: 4.3143, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.3143
# Epoch: 140
# 	Train:	Total Loss: 4.9557, Feature Loss: 4.9557, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.9557
# 	Test: 	Total Loss: 4.3097, Feature Loss: 4.3097, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.3097
# Epoch: 141
# 	Train:	Total Loss: 4.9517, Feature Loss: 4.9517, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.9517
# 	Test: 	Total Loss: 4.3049, Feature Loss: 4.3049, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.3049
# Epoch: 142
# 	Train:	Total Loss: 4.9458, Feature Loss: 4.9458, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.9458
# 	Test: 	Total Loss: 4.3002, Feature Loss: 4.3002, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.3002
# Epoch: 143
# 	Train:	Total Loss: 4.9420, Feature Loss: 4.9420, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.9420
# 	Test: 	Total Loss: 4.2954, Feature Loss: 4.2954, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.2954
# Epoch: 144
# 	Train:	Total Loss: 4.9349, Feature Loss: 4.9349, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.9349
# 	Test: 	Total Loss: 4.2907, Feature Loss: 4.2907, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.2907
# Epoch: 145
# 	Train:	Total Loss: 4.9304, Feature Loss: 4.9304, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.9304
# 	Test: 	Total Loss: 4.2858, Feature Loss: 4.2858, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.2858
# Epoch: 146
# 	Train:	Total Loss: 4.9265, Feature Loss: 4.9265, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.9265
# 	Test: 	Total Loss: 4.2808, Feature Loss: 4.2808, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.2808
# Epoch: 147
# 	Train:	Total Loss: 4.9209, Feature Loss: 4.9209, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.9209
# 	Test: 	Total Loss: 4.2758, Feature Loss: 4.2758, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.2758
# Epoch: 148
# 	Train:	Total Loss: 4.9152, Feature Loss: 4.9152, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.9152
# 	Test: 	Total Loss: 4.2707, Feature Loss: 4.2707, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.2707
# Epoch: 149
# 	Train:	Total Loss: 4.9111, Feature Loss: 4.9111, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.9111
# 	Test: 	Total Loss: 4.2656, Feature Loss: 4.2656, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.2656
# Epoch: 150
# 	Train:	Total Loss: 4.9048, Feature Loss: 4.9048, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.9048
# 	Test: 	Total Loss: 4.2600, Feature Loss: 4.2600, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.2600
# Epoch: 151
# 	Train:	Total Loss: 4.8993, Feature Loss: 4.8993, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.8993
# 	Test: 	Total Loss: 4.2547, Feature Loss: 4.2547, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.2547
# Epoch: 152
# 	Train:	Total Loss: 4.8937, Feature Loss: 4.8937, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.8937
# 	Test: 	Total Loss: 4.2493, Feature Loss: 4.2493, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.2493
# Epoch: 153
# 	Train:	Total Loss: 4.8883, Feature Loss: 4.8883, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.8883
# 	Test: 	Total Loss: 4.2436, Feature Loss: 4.2436, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.2436
# Epoch: 154
# 	Train:	Total Loss: 4.8806, Feature Loss: 4.8806, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.8806
# 	Test: 	Total Loss: 4.2381, Feature Loss: 4.2381, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.2381
# Epoch: 155
# 	Train:	Total Loss: 4.8754, Feature Loss: 4.8754, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.8754
# 	Test: 	Total Loss: 4.2320, Feature Loss: 4.2320, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.2320
# Epoch: 156
# 	Train:	Total Loss: 4.8691, Feature Loss: 4.8691, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.8691
# 	Test: 	Total Loss: 4.2260, Feature Loss: 4.2260, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.2260
# Epoch: 157
# 	Train:	Total Loss: 4.8619, Feature Loss: 4.8619, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.8619
# 	Test: 	Total Loss: 4.2197, Feature Loss: 4.2197, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.2197
# Epoch: 158
# 	Train:	Total Loss: 4.8564, Feature Loss: 4.8564, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.8564
# 	Test: 	Total Loss: 4.2135, Feature Loss: 4.2135, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.2135
# Epoch: 159
# 	Train:	Total Loss: 4.8496, Feature Loss: 4.8496, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.8496
# 	Test: 	Total Loss: 4.2068, Feature Loss: 4.2068, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.2068
# Epoch: 160
# 	Train:	Total Loss: 4.8416, Feature Loss: 4.8416, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.8416
# 	Test: 	Total Loss: 4.2000, Feature Loss: 4.2000, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.2000
# Epoch: 161
# 	Train:	Total Loss: 4.8335, Feature Loss: 4.8335, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.8335
# 	Test: 	Total Loss: 4.1932, Feature Loss: 4.1932, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.1932
# Epoch: 162
# 	Train:	Total Loss: 4.8285, Feature Loss: 4.8285, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.8285
# 	Test: 	Total Loss: 4.1862, Feature Loss: 4.1862, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.1862
# Epoch: 163
# 	Train:	Total Loss: 4.8206, Feature Loss: 4.8206, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.8206
# 	Test: 	Total Loss: 4.1788, Feature Loss: 4.1788, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.1788
# Epoch: 164
# 	Train:	Total Loss: 4.8126, Feature Loss: 4.8126, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.8126
# 	Test: 	Total Loss: 4.1714, Feature Loss: 4.1714, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.1714
# Epoch: 165
# 	Train:	Total Loss: 4.8049, Feature Loss: 4.8049, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.8049
# 	Test: 	Total Loss: 4.1639, Feature Loss: 4.1639, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.1639
# Epoch: 166
# 	Train:	Total Loss: 4.7976, Feature Loss: 4.7976, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.7976
# 	Test: 	Total Loss: 4.1559, Feature Loss: 4.1559, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.1559
# Epoch: 167
# 	Train:	Total Loss: 4.7890, Feature Loss: 4.7890, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.7890
# 	Test: 	Total Loss: 4.1479, Feature Loss: 4.1479, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.1479
# Epoch: 168
# 	Train:	Total Loss: 4.7795, Feature Loss: 4.7795, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.7795
# 	Test: 	Total Loss: 4.1395, Feature Loss: 4.1395, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.1395
# Epoch: 169
# 	Train:	Total Loss: 4.7707, Feature Loss: 4.7707, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.7707
# 	Test: 	Total Loss: 4.1310, Feature Loss: 4.1310, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.1310
# Epoch: 170
# 	Train:	Total Loss: 4.7616, Feature Loss: 4.7616, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.7616
# 	Test: 	Total Loss: 4.1222, Feature Loss: 4.1222, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.1222
# Epoch: 171
# 	Train:	Total Loss: 4.7533, Feature Loss: 4.7533, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.7533
# 	Test: 	Total Loss: 4.1132, Feature Loss: 4.1132, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.1132
# Epoch: 172
# 	Train:	Total Loss: 4.7434, Feature Loss: 4.7434, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.7434
# 	Test: 	Total Loss: 4.1040, Feature Loss: 4.1040, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.1040
# Epoch: 173
# 	Train:	Total Loss: 4.7332, Feature Loss: 4.7332, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.7332
# 	Test: 	Total Loss: 4.0946, Feature Loss: 4.0946, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.0946
# Epoch: 174
# 	Train:	Total Loss: 4.7245, Feature Loss: 4.7245, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.7245
# 	Test: 	Total Loss: 4.0850, Feature Loss: 4.0850, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.0850
# Epoch: 175
# 	Train:	Total Loss: 4.7131, Feature Loss: 4.7131, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.7131
# 	Test: 	Total Loss: 4.0752, Feature Loss: 4.0752, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.0752
# Epoch: 176
# 	Train:	Total Loss: 4.7040, Feature Loss: 4.7040, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.7040
# 	Test: 	Total Loss: 4.0651, Feature Loss: 4.0651, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.0651
# Epoch: 177
# 	Train:	Total Loss: 4.6938, Feature Loss: 4.6938, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.6938
# 	Test: 	Total Loss: 4.0549, Feature Loss: 4.0549, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.0549
# Epoch: 178
# 	Train:	Total Loss: 4.6822, Feature Loss: 4.6822, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.6822
# 	Test: 	Total Loss: 4.0444, Feature Loss: 4.0444, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.0444
# Epoch: 179
# 	Train:	Total Loss: 4.6705, Feature Loss: 4.6705, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.6705
# 	Test: 	Total Loss: 4.0337, Feature Loss: 4.0337, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.0337
# Epoch: 180
# 	Train:	Total Loss: 4.6593, Feature Loss: 4.6593, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.6593
# 	Test: 	Total Loss: 4.0228, Feature Loss: 4.0228, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.0228
# Epoch: 181
# 	Train:	Total Loss: 4.6495, Feature Loss: 4.6495, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.6495
# 	Test: 	Total Loss: 4.0117, Feature Loss: 4.0117, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.0117
# Epoch: 182
# 	Train:	Total Loss: 4.6373, Feature Loss: 4.6373, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.6373
# 	Test: 	Total Loss: 4.0004, Feature Loss: 4.0004, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 4.0004
# Epoch: 183
# 	Train:	Total Loss: 4.6257, Feature Loss: 4.6257, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.6257
# 	Test: 	Total Loss: 3.9891, Feature Loss: 3.9891, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 3.9891
# Epoch: 184
# 	Train:	Total Loss: 4.6145, Feature Loss: 4.6145, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.6145
# 	Test: 	Total Loss: 3.9774, Feature Loss: 3.9774, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 3.9774
# Epoch: 185
# 	Train:	Total Loss: 4.6024, Feature Loss: 4.6024, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.6024
# 	Test: 	Total Loss: 3.9656, Feature Loss: 3.9656, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 3.9656
# Epoch: 186
# 	Train:	Total Loss: 4.5893, Feature Loss: 4.5893, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.5893
# 	Test: 	Total Loss: 3.9536, Feature Loss: 3.9536, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 3.9536
# Epoch: 187
# 	Train:	Total Loss: 4.5769, Feature Loss: 4.5769, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.5769
# 	Test: 	Total Loss: 3.9416, Feature Loss: 3.9416, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 3.9416
# Epoch: 188
# 	Train:	Total Loss: 4.5652, Feature Loss: 4.5652, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.5652
# 	Test: 	Total Loss: 3.9293, Feature Loss: 3.9293, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 3.9293
# Epoch: 189
# 	Train:	Total Loss: 4.5523, Feature Loss: 4.5523, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.5523
# 	Test: 	Total Loss: 3.9170, Feature Loss: 3.9170, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 3.9170
# Epoch: 190
# 	Train:	Total Loss: 4.5400, Feature Loss: 4.5400, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.5400
# 	Test: 	Total Loss: 3.9047, Feature Loss: 3.9047, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 3.9047
# Epoch: 191
# 	Train:	Total Loss: 4.5267, Feature Loss: 4.5267, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.5267
# 	Test: 	Total Loss: 3.8922, Feature Loss: 3.8922, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 3.8922
# Epoch: 192
# 	Train:	Total Loss: 4.5141, Feature Loss: 4.5141, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.5141
# 	Test: 	Total Loss: 3.8796, Feature Loss: 3.8796, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 3.8796
# Epoch: 193
# 	Train:	Total Loss: 4.5009, Feature Loss: 4.5009, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.5009
# 	Test: 	Total Loss: 3.8668, Feature Loss: 3.8668, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 3.8668
# Epoch: 194
# 	Train:	Total Loss: 4.4883, Feature Loss: 4.4883, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.4883
# 	Test: 	Total Loss: 3.8541, Feature Loss: 3.8541, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 3.8541
# Epoch: 195
# 	Train:	Total Loss: 4.4748, Feature Loss: 4.4748, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.4748
# 	Test: 	Total Loss: 3.8413, Feature Loss: 3.8413, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 3.8413
# Epoch: 196
# 	Train:	Total Loss: 4.4628, Feature Loss: 4.4628, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.4628
# 	Test: 	Total Loss: 3.8286, Feature Loss: 3.8286, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 3.8286
# Epoch: 197
# 	Train:	Total Loss: 4.4501, Feature Loss: 4.4501, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.4501
# 	Test: 	Total Loss: 3.8156, Feature Loss: 3.8156, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 3.8156
# Epoch: 198
# 	Train:	Total Loss: 4.4359, Feature Loss: 4.4359, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.4359
# 	Test: 	Total Loss: 3.8029, Feature Loss: 3.8029, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 3.8029
# Epoch: 199
# 	Train:	Total Loss: 4.4235, Feature Loss: 4.4235, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.4235
# 	Test: 	Total Loss: 3.7900, Feature Loss: 3.7900, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 3.7900
# Epoch: 200
# 	Train:	Total Loss: 4.4113, Feature Loss: 4.4113, Type Loss: 0.0000 ,  LR: 0.000100, 	MSE loss in postions: 4.4113
# 	Test: 	Total Loss: 3.7772, Feature Loss: 3.7772, Type Loss: 0.0000 , LR: 0.000100, 	MSE loss in positions: 3.7772

# %%
if not model_loaded:
    plt.figure(figsize=(14, 5))
    plt.plot(test_total_losses, label='Total Test Loss')
    plt.plot(train_total_losses, label='Total Train Loss')
    plt.legend()
    plt.title('Total Loss')
    plt.savefig("mse_totalloss.png")
    plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
if not model_loaded:
    plt.figure(figsize=(14, 5))
    plt.plot(test_feature_losses, label='Test Feature Loss')
    plt.plot(train_feature_losses, label='Train Feature Loss')
    plt.legend()
    plt.title('Feature Loss')
    plt.savefig("mse_feature_loss.png")
    plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
test_loader_melt = DataLoader(graphs_melt, batch_size=1)
encoded_data_melt=[]
type_data_melt = []
for data in test_loader:
    model.eval()
    z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
    decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
    encoded_data_melt.append(z.detach().numpy())
    type_data_melt.append(str_type.detach().numpy())

encoded_data_melt = np.array(encoded_data_melt)
type_data_melt = np.array(type_data_melt)

# %%
test_loader_cry = DataLoader(graphs_cry, batch_size=1)
encoded_data_cry=[]
type_data_cry = []
for data in test_loader:
    model.eval()
    z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
    decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
    encoded_data_cry.append(z.detach().numpy())
    type_data_cry.append(str_type.detach().numpy())

encoded_data_cry = np.array(encoded_data_cry)
type_data_cry = np.array(type_data_cry)

# %%
# %matplotlib widget

frame = 10

fig = plt.figure(figsize=(15,4))
data_melt = encoded_data_melt[frame]

data_cry = encoded_data_cry[frame]
plt.scatter(data_melt[:,0],data_melt[:,1],c="r",label="melt")
plt.scatter(data_cry[:,0],data_cry[:,1],c="b",label="crystal")
plt.savefig("mse_scatter.png")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
