# %%
import mdtraj as md
from ase import Atoms
import nglview as nv
import networkx as nx

import numpy as np
import matplotlib.pyplot as plt
import torch
from tqdm import tqdm

import torch_geometric.transforms as T
from torch_geometric.loader import DataLoader
from torch_geometric.nn import GCNConv, SAGPooling, InnerProductDecoder
import torch_geometric.data as data
from torch_geometric.utils.convert import to_networkx
import torch.optim.lr_scheduler as lr_scheduler
from torch.nn import Linear
import sys

# %%
all_frames_cry = md.load_xtc("../simulation/para_crystal.xtc", top="../simulation/para_crystal.gro")
all_frames_melt = md.load_xtc("../simulation/para_melt.xtc", top="../simulation/para_melt.gro")

# %%
all_frames_cry = all_frames_cry[::100]
all_frames_melt = all_frames_melt[::100]

# %%
n_frames = all_frames_cry.xyz.shape[0]
n_atoms = all_frames_cry.topology.residue(0).n_atoms
n_mols = all_frames_cry.topology.n_residues

# %%
def createGraph(all_frames,structure_type="crystal"):
    all_frames_fatures = []

    print("Creating Feature matrix")
    for i in tqdm(range(all_frames.xyz.shape[0])):
        mol_com_pos = []

        for res in all_frames.top.residues:
            pos = []
            for atom in res.atoms:
                pos.append(all_frames.xyz[i][atom.index])
            mol_com_pos.append(np.mean(pos,axis=0))
            
            # print()
        mol_com_pos = np.array(mol_com_pos).astype(np.float32)  
        all_frames_fatures.append(mol_com_pos)

    all_frames_fatures = np.array(all_frames_fatures).astype(np.float32)



    cutoff = 0.8

    print("Creating Edge list")
    all_edge_list = []
    # with open("edge_list.txt","w") as f:
    for frame_i in tqdm(range(n_frames)):
        from_list = []
        to_list = []

        for i in range(len(all_frames_fatures[frame_i])):
            for j in range(i+1,len(all_frames_fatures[frame_i])):
                if np.linalg.norm(all_frames_fatures[frame_i][i]-all_frames_fatures[frame_i][j]) < cutoff:
                    # f.write(str(i)+" "+str(j)+" "+str(np.linalg.norm(all_frames_fatures[frame_i][i]-all_frames_fatures[frame_i][j]))+"\n")
                    from_list.append(i)
                    to_list.append(j)

                    to_list.append(i)
                    from_list.append(j)

        edge_list = np.array([from_list,to_list]).astype(np.int64)
        all_edge_list.append(edge_list)
    print("creating Graphs")
    graphs = []
    for frame in tqdm(range(n_frames)):
        if structure_type == "crystal":
            g = data.Data(x=torch.tensor(all_frames_fatures[frame]).float(), edge_index=torch.tensor(all_edge_list[frame]).long(), y=torch.tensor([0]))
        else:
            g = data.Data(x=torch.tensor(all_frames_fatures[frame]).float(), edge_index=torch.tensor(all_edge_list[frame]).long(), y=torch.tensor([1]))
        graphs.append(g)
    return graphs

# %%
graphs_cry = createGraph(all_frames_cry,structure_type="crystal")
graphs_melt = createGraph(all_frames_melt,structure_type="melt")
# Out:
# Creating Feature matrix
# 100%|██████████| 51/51 [00:00<00:00, 93.95it/s]
# Creating Edge list
# 100%|██████████| 51/51 [00:49<00:00,  1.03it/s]
# creating Graphs
# 100%|██████████| 51/51 [00:00<00:00, 703.05it/s]
# Creating Feature matrix
# 100%|██████████| 51/51 [00:00<00:00, 92.39it/s]
# Creating Edge list
# 100%|██████████| 51/51 [02:06<00:00,  2.48s/it]
# creating Graphs
# 100%|██████████| 51/51 [00:00<00:00, 9834.47it/s]

# %%
def convert_to_adj(edge_index, num_nodes=None):
    if num_nodes is None:
        num_nodes = edge_index.max() + 1
    adj = torch.zeros(num_nodes, num_nodes)
    adj[edge_index[0], edge_index[1]] = 1
    return adj

def convert_to_edge_index(adj):
    edge_index = adj.nonzero().t()
    return edge_index

# %%
graphs = graphs_cry + graphs_melt
# graphs = graphs_melt

# %%
# shuffle the graphs
np.random.shuffle(graphs)

# %%
graphs
# Out:
# [Data(x=[864, 3], edge_index=[2, 7052], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6214], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7122], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7078], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6070], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7090], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7020], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7274], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7008], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6548], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7060], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7092], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6508], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5876], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6464], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6400], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7048], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6512], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7116], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6288], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7374], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5862], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6578], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6592], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6992], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7048], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7240], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6558], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6964], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6582], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7054], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6172], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6586], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7088], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5910], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7192], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7092], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6584], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7128], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7064], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6552], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6488], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5822], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7006], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7146], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6560], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6546], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7074], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5962], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7096], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5892], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7094], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6990], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7044], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6608], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7006], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7052], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6508], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7294], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5982], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6630], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6602], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7036], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7026], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6546], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6554], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7108], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7132], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7086], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6596], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6566], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6012], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6066], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 5880], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7056], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7116], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7060], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7218], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6476], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6018], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7024], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6524], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6580], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6532], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6570], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6056], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6564], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6548], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7080], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6542], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7028], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6544], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6626], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7306], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7034], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7100], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7078], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6452], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6560], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7012], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 7076], y=[1]),
#  Data(x=[864, 3], edge_index=[2, 6934], y=[1])]

# %% [markdown]
# ## model

# %%
from typing import Optional, Tuple

import torch
from torch import Tensor
from torch.nn import Module

from torch_geometric.nn.inits import reset
from torch_geometric.utils import negative_sampling

EPS = 1e-15
MAX_LOGSTD = 10
edgeShape = None
featureShape = None


class InnerProductDecoder(torch.nn.Module):
    r"""The inner product decoder from the `"Variational Graph Auto-Encoders"
    <https://arxiv.org/abs/1611.07308>`_ paper

    .. math::
        \sigma(\mathbf{Z}\mathbf{Z}^{\top})

    where :math:`\mathbf{Z} \in \mathbb{R}^{N \times d}` denotes the latent
    space produced by the encoder."""

    def forward(self, z: Tensor, edge_index: Tensor,
                sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into edge probabilities for
        the given node-pairs :obj:`edge_index`.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        value = (z[edge_index[0]] * z[edge_index[1]]).sum(dim=1)
        return torch.sigmoid(value) if sigmoid else value

    def forward_all(self, z: Tensor, sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into a probabilistic dense
        adjacency matrix.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        adj = torch.matmul(z, z.t())
        return torch.sigmoid(adj) if sigmoid else adj


class GAE(torch.nn.Module):
    r"""The Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper based on user-defined encoder and decoder models.

    Args:
        encoder (torch.nn.Module): The encoder module.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__()
        self.encoder = encoder
        self.decoder = InnerProductDecoder() if decoder is None else decoder
        GAE.reset_parameters(self)

    def reset_parameters(self):
        r"""Resets all learnable parameters of the module."""
        reset(self.encoder)
        reset(self.decoder)

    def forward(self, *args, **kwargs) -> Tensor:  # pragma: no cover
        r"""Alias for :meth:`encode`."""
        return self.encoder(*args, **kwargs)

    def encode(self, *args, **kwargs) -> Tensor:
        r"""Runs the encoder and computes node-wise latent variables."""
        return self.encoder(*args, **kwargs)

    def decode(self, *args, **kwargs) -> Tensor:
        r"""Runs the decoder and computes edge probabilities."""
        return self.decoder(*args, **kwargs)

    def recon_loss(self, z: Tensor, pos_edge_index: Tensor,
                   neg_edge_index: Optional[Tensor] = None) -> Tensor:
        r"""Given latent variables :obj:`z`, computes the binary cross
        entropy loss for positive edges :obj:`pos_edge_index` and negative
        sampled edges.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to train against.
            neg_edge_index (torch.Tensor, optional): The negative edges to
                train against. If not given, uses negative sampling to
                calculate negative edges. (default: :obj:`None`)
        """
        pos_loss = -torch.log(
            self.decoder(z, pos_edge_index, sigmoid=True)[0] + EPS).mean()

        if neg_edge_index is None:
            neg_edge_index = negative_sampling(pos_edge_index, z.size(0))
        neg_loss = -torch.log(1 -
                              self.decoder(z, neg_edge_index.long(), sigmoid=True)[0] +
                              EPS).mean()

        return pos_loss + neg_loss

    def test(self, z: Tensor, pos_edge_index: Tensor,
             neg_edge_index: Tensor) -> Tuple[Tensor, Tensor]:
        r"""Given latent variables :obj:`z`, positive edges
        :obj:`pos_edge_index` and negative edges :obj:`neg_edge_index`,
        computes area under the ROC curve (AUC) and average precision (AP)
        
        scores.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to evaluate
                against.
            neg_edge_index (torch.Tensor): The negative edges to evaluate
                against.
        """
        from sklearn.metrics import average_precision_score, roc_auc_score

        pos_y = z.new_ones(pos_edge_index.size(1))
        neg_y = z.new_zeros(neg_edge_index.size(1))
        y = torch.cat([pos_y, neg_y], dim=0)

        pos_pred = self.decoder(z, pos_edge_index, sigmoid=True)
        neg_pred = self.decoder(z, neg_edge_index, sigmoid=True)
        pred = torch.cat([pos_pred, neg_pred], dim=0)

        y, pred = y.detach().cpu().numpy(), pred.detach().cpu().numpy()

        return roc_auc_score(y, pred), average_precision_score(y, pred)


class VGAE(GAE):
    r"""The Variational Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper.

    Args:
        encoder (torch.nn.Module): The encoder module to compute :math:`\mu`
            and :math:`\log\sigma^2`.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__(encoder, decoder)

    def reparametrize(self, mu: Tensor, logstd: Tensor) -> Tensor:
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def encode(self, *args, **kwargs) -> Tensor:
        """"""
        z, self.edge_index = self.encoder(
            *args, **kwargs)
        
        return z, self.edge_index

    def kl_loss(self, mu: Optional[Tensor] = None,
                logstd: Optional[Tensor] = None) -> Tensor:
        r"""Computes the KL loss, either for the passed arguments :obj:`mu`
        and :obj:`logstd`, or based on latent variables from last encoding.

        Args:
            mu (torch.Tensor, optional): The latent space for :math:`\mu`. If
                set to :obj:`None`, uses the last computation of :math:`\mu`.
                (default: :obj:`None`)
            logstd (torch.Tensor, optional): The latent space for
                :math:`\log\sigma`.  If set to :obj:`None`, uses the last
                computation of :math:`\log\sigma^2`. (default: :obj:`None`)
        """
        mu = self.__mu__ if mu is None else mu
        logstd = self.__logstd__ if logstd is None else logstd.clamp(
            max=MAX_LOGSTD)
        return -0.5 * torch.mean(
            torch.sum(1 + 2 * logstd - mu**2 - logstd.exp()**2, dim=1))

# %%
import torch.nn.functional as F



class VariationalGCNEncoder(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__() # changes made such that guassian is 1 
        self.conv1 = GCNConv(in_channels, 2*out_channels)
        self.conv2 = GCNConv(2*out_channels, 1 * out_channels)
        self.pool = SAGPooling(out_channels, 0.5)
        
        self.conv_mu = GCNConv(1 * out_channels, out_channels)
        self.conv_logstd = GCNConv(1 * out_channels, out_channels)
    def reparametrize(self, mu: Tensor, logstd: Tensor) -> Tensor:
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def forward(self, x, edge_index,class_label):
        # print("input:",x.shape, edge_index.shape)
        x = self.conv1(x, edge_index)
        x = F.silu(x)
        # print("conv1:",x.shape, edge_index.shape)
        x = self.conv2(x, edge_index)
        x = F.silu(x)
        # print("conv2:",x.shape, edge_index.shape)

        sample = self.reparametrize(self.conv_mu(x, edge_index), self.conv_logstd(x, edge_index))
        sample = self.reparametrize(self.conv_mu(sample, edge_index), self.conv_logstd(sample, edge_index))
        # self.conv_mu_crystal.train(True)
        # self.conv_logstd_crystal.train(True)
        # self.conv_mu_melt.train(True)
        # self.conv_logstd_melt.train(True)
        self.conv_mu.train(True)
        self.conv_logstd.train(True)
        return sample, edge_index

# %%
class VariationalGCNDecoder(torch.nn.Module):
    def __init__(self,in_channels,out_channels):
        super().__init__()
        self.type_layer1 = Linear(1728,200)
        self.dropout = torch.nn.Dropout(0.5)
        self.type_layer2 = Linear(200,2)
        self.conv1 = GCNConv(in_channels,2*out_channels)
        self.conv2 = GCNConv(2*out_channels, 1 * out_channels)
    def forward(self, x, edge_index, sigmoid=True):
        # print("input:",x.shape, edge_index.shape)
        flat = x.flatten()
        flat = self.type_layer1(flat).relu()
        flat = self.dropout(flat)
        str_type = F.softmax(self.type_layer2(flat).relu(),dim=0)
         
        x = self.conv1(x, edge_index)
        x = F.silu(x)
        # print("conv1:",x.shape, edge_index.shape)
        x = self.conv2(x, edge_index)
        x = F.silu(x)
        # print("conv2:",x.shape, edge_index.shape)
        return x, edge_index,str_type

# %%
import os
in_channels = graphs[0].num_features
out_channels = 2
lr = 1e-4
n_epochs = 200
batch_size=1
test_train_split = 0.8
model_name = "model3.pt"
model_loaded = False
force_train = True  

if os.path.exists("./models/"+model_name) and not force_train:
    model = torch.load("./models/"+model_name)
    model_loaded = True
else:
    model = VGAE(VariationalGCNEncoder(in_channels, out_channels),
                VariationalGCNDecoder(out_channels, in_channels))

optimizer = torch.optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, step_size=300, gamma=0.5)

# %%
train_loader = DataLoader(graphs_melt[:int(n_frames*test_train_split)], batch_size=batch_size, shuffle=True)
test_loader = DataLoader(graphs_melt[int(n_frames*test_train_split):], batch_size=batch_size, shuffle=True)

# %%
lossFxn = torch.nn.MSELoss()
typeLossFxn = torch.nn.CrossEntropyLoss()

def train():
    model.train()
    model.zero_grad()
    model.float()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0
    type_loss_all = 0
    for data in train_loader:
        optimizer.zero_grad()
        z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
        decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)

     
        # TypeLoss = typeLossFxn(str_type.unsqueeze(0), data.y)
        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        loss = FeatureLoss + EdgeLoss 

        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        # type_loss_all += float(TypeLoss)

        loss.backward()
        optimizer.step()
        

    return loss_all / len(train_loader), feature_loss_all / len(train_loader), edge_loss_all / len(train_loader), kl_loss_all / len(train_loader), type_loss_all / len(train_loader)

# %%
lossFxn = torch.nn.MSELoss()
def test():
    model.eval()
    model.zero_grad()
    model.float()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0
    type_loss_all = 0

    for data in test_loader:
        optimizer.zero_grad()
        z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
        decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
        
        # TypeLoss = typeLossFxn(str_type.unsqueeze(0), data.y)
        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        loss = FeatureLoss + EdgeLoss 

        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        # type_loss_all += float(TypeLoss)
        
        
        

    return loss_all / len(test_loader), feature_loss_all / len(test_loader), edge_loss_all / len(test_loader), kl_loss_all / len(test_loader), type_loss_all / len(test_loader)

# %%
train_total_losses = []
train_feature_losses = []
train_edge_losses = []
train_kl_losses = []
train_type_losses = []

test_total_losses = []
test_feature_losses = []
test_edge_losses = []
test_kl_losses = []
test_type_losses = []

if model_loaded:        
    print("Pretrained Model Loaded, no training required")
else:
    for epoch in range(1, n_epochs + 1):
        
        train_total_loss, train_feature_loss, train_edge_loss, train_kl_loss,train_type_loss = train()
        test_total_loss, test_feature_loss, test_edge_loss, test_kl_loss, test_type_loss= test()
        
        print(f"Epoch: {epoch:03d}")
        print(f'\tTrain:\tTotal Loss: {train_total_loss:.4f}, Feature Loss: {train_feature_loss:.4f}, Type Loss: {train_type_loss:.4f} ,  LR: {scheduler.get_last_lr()[0]:.6f}')
        print(f'\tTest: \tTotal Loss: {test_total_loss:.4f}, Feature Loss: {test_feature_loss:.4f}, Type Loss: {test_type_loss:.4f} , LR: {scheduler.get_last_lr()[0]:.6f}')
        
        
        train_total_losses.append(train_total_loss)
        train_feature_losses.append(train_feature_loss)
        train_edge_losses.append(train_edge_loss)
        train_kl_losses.append(train_kl_loss)
        train_type_losses.append(train_type_loss)


        test_total_losses.append(test_total_loss)
        test_feature_losses.append(test_feature_loss)
        test_edge_losses.append(test_edge_loss)
        test_kl_losses.append(test_kl_loss)
        test_type_losses.append(test_type_loss)
        
        scheduler.step()
    torch.save(model,"./models/"+model_name)
# Out:
# Epoch: 001
# 	Train:	Total Loss: 14.5316, Feature Loss: 14.5316, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.0681, Feature Loss: 11.0681, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 002
# 	Train:	Total Loss: 14.5018, Feature Loss: 14.5018, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.0441, Feature Loss: 11.0441, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 003
# 	Train:	Total Loss: 14.4686, Feature Loss: 14.4686, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 11.0202, Feature Loss: 11.0202, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 004
# 	Train:	Total Loss: 14.4380, Feature Loss: 14.4380, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.9955, Feature Loss: 10.9955, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 005
# 	Train:	Total Loss: 14.4099, Feature Loss: 14.4099, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.9707, Feature Loss: 10.9707, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 006
# 	Train:	Total Loss: 14.3811, Feature Loss: 14.3811, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.9444, Feature Loss: 10.9444, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 007
# 	Train:	Total Loss: 14.3727, Feature Loss: 14.3727, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.9190, Feature Loss: 10.9190, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 008
# 	Train:	Total Loss: 14.3140, Feature Loss: 14.3140, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.8923, Feature Loss: 10.8923, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 009
# 	Train:	Total Loss: 14.2894, Feature Loss: 14.2894, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.8641, Feature Loss: 10.8641, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 010
# 	Train:	Total Loss: 14.2510, Feature Loss: 14.2510, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.8340, Feature Loss: 10.8340, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 011
# 	Train:	Total Loss: 17.4515, Feature Loss: 17.4515, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.8058, Feature Loss: 10.8058, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 012
# 	Train:	Total Loss: 14.2453, Feature Loss: 14.2453, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.7814, Feature Loss: 10.7814, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 013
# 	Train:	Total Loss: 14.1739, Feature Loss: 14.1739, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.7561, Feature Loss: 10.7561, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 014
# 	Train:	Total Loss: 14.1296, Feature Loss: 14.1296, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.7308, Feature Loss: 10.7308, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 015
# 	Train:	Total Loss: 14.1000, Feature Loss: 14.1000, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.7050, Feature Loss: 10.7050, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 016
# 	Train:	Total Loss: 14.0701, Feature Loss: 14.0701, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.6793, Feature Loss: 10.6793, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 017
# 	Train:	Total Loss: 14.2269, Feature Loss: 14.2269, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.6522, Feature Loss: 10.6522, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 018
# 	Train:	Total Loss: 14.0192, Feature Loss: 14.0192, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.6254, Feature Loss: 10.6254, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 019
# 	Train:	Total Loss: 14.0038, Feature Loss: 14.0038, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.5987, Feature Loss: 10.5987, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 020
# 	Train:	Total Loss: 13.9419, Feature Loss: 13.9419, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.5708, Feature Loss: 10.5708, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 021
# 	Train:	Total Loss: 13.9954, Feature Loss: 13.9954, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.5432, Feature Loss: 10.5432, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 022
# 	Train:	Total Loss: 13.8886, Feature Loss: 13.8886, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.5147, Feature Loss: 10.5147, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 023
# 	Train:	Total Loss: 13.8546, Feature Loss: 13.8546, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.4859, Feature Loss: 10.4859, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 024
# 	Train:	Total Loss: 13.8233, Feature Loss: 13.8233, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.4566, Feature Loss: 10.4566, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 025
# 	Train:	Total Loss: 13.7851, Feature Loss: 13.7851, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.4264, Feature Loss: 10.4264, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 026
# 	Train:	Total Loss: 13.7736, Feature Loss: 13.7736, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.3953, Feature Loss: 10.3953, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 027
# 	Train:	Total Loss: 13.7689, Feature Loss: 13.7689, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.3637, Feature Loss: 10.3637, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 028
# 	Train:	Total Loss: 13.6874, Feature Loss: 13.6874, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.3321, Feature Loss: 10.3321, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 029
# 	Train:	Total Loss: 13.6474, Feature Loss: 13.6474, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.2994, Feature Loss: 10.2994, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 030
# 	Train:	Total Loss: 13.6050, Feature Loss: 13.6050, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.2658, Feature Loss: 10.2658, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 031
# 	Train:	Total Loss: 13.5654, Feature Loss: 13.5654, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.2311, Feature Loss: 10.2311, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 032
# 	Train:	Total Loss: 13.5313, Feature Loss: 13.5313, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.1959, Feature Loss: 10.1959, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 033
# 	Train:	Total Loss: 13.4897, Feature Loss: 13.4897, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.1604, Feature Loss: 10.1604, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 034
# 	Train:	Total Loss: 13.4566, Feature Loss: 13.4566, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.1232, Feature Loss: 10.1232, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 035
# 	Train:	Total Loss: 13.4137, Feature Loss: 13.4137, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.0856, Feature Loss: 10.0856, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 036
# 	Train:	Total Loss: 13.3564, Feature Loss: 13.3564, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.0465, Feature Loss: 10.0465, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 037
# 	Train:	Total Loss: 13.3125, Feature Loss: 13.3125, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 10.0071, Feature Loss: 10.0071, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 038
# 	Train:	Total Loss: 13.2673, Feature Loss: 13.2673, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.9655, Feature Loss: 9.9655, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 039
# 	Train:	Total Loss: 13.2152, Feature Loss: 13.2152, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.9230, Feature Loss: 9.9230, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 040
# 	Train:	Total Loss: 13.1686, Feature Loss: 13.1686, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.8794, Feature Loss: 9.8794, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 041
# 	Train:	Total Loss: 13.1221, Feature Loss: 13.1221, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.8348, Feature Loss: 9.8348, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 042
# 	Train:	Total Loss: 13.0912, Feature Loss: 13.0912, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.7882, Feature Loss: 9.7882, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 043
# 	Train:	Total Loss: 13.0524, Feature Loss: 13.0524, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.7408, Feature Loss: 9.7408, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 044
# 	Train:	Total Loss: 12.9798, Feature Loss: 12.9798, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.6916, Feature Loss: 9.6916, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 045
# 	Train:	Total Loss: 12.9329, Feature Loss: 12.9329, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.6404, Feature Loss: 9.6404, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 046
# 	Train:	Total Loss: 12.8541, Feature Loss: 12.8541, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.5878, Feature Loss: 9.5878, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 047
# 	Train:	Total Loss: 12.7791, Feature Loss: 12.7791, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.5337, Feature Loss: 9.5337, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 048
# 	Train:	Total Loss: 12.7504, Feature Loss: 12.7504, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.4776, Feature Loss: 9.4776, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 049
# 	Train:	Total Loss: 12.6561, Feature Loss: 12.6561, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.4191, Feature Loss: 9.4191, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 050
# 	Train:	Total Loss: 12.5951, Feature Loss: 12.5951, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.3594, Feature Loss: 9.3594, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 051
# 	Train:	Total Loss: 12.5268, Feature Loss: 12.5268, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.2958, Feature Loss: 9.2958, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 052
# 	Train:	Total Loss: 12.4612, Feature Loss: 12.4612, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.2322, Feature Loss: 9.2322, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 053
# 	Train:	Total Loss: 12.3639, Feature Loss: 12.3639, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.1643, Feature Loss: 9.1643, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 054
# 	Train:	Total Loss: 12.2977, Feature Loss: 12.2977, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.0955, Feature Loss: 9.0955, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 055
# 	Train:	Total Loss: 12.2097, Feature Loss: 12.2097, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 9.0226, Feature Loss: 9.0226, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 056
# 	Train:	Total Loss: 12.1455, Feature Loss: 12.1455, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.9482, Feature Loss: 8.9482, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 057
# 	Train:	Total Loss: 12.0340, Feature Loss: 12.0340, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.8711, Feature Loss: 8.8711, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 058
# 	Train:	Total Loss: 11.9520, Feature Loss: 11.9520, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.7917, Feature Loss: 8.7917, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 059
# 	Train:	Total Loss: 11.8810, Feature Loss: 11.8810, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.7089, Feature Loss: 8.7089, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 060
# 	Train:	Total Loss: 14.6258, Feature Loss: 14.6258, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.6545, Feature Loss: 8.6545, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 061
# 	Train:	Total Loss: 11.7064, Feature Loss: 11.7064, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.5822, Feature Loss: 8.5822, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 062
# 	Train:	Total Loss: 11.6321, Feature Loss: 11.6321, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.5082, Feature Loss: 8.5082, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 063
# 	Train:	Total Loss: 11.5309, Feature Loss: 11.5309, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.4306, Feature Loss: 8.4306, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 064
# 	Train:	Total Loss: 11.4335, Feature Loss: 11.4335, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.3527, Feature Loss: 8.3527, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 065
# 	Train:	Total Loss: 11.3512, Feature Loss: 11.3512, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.2735, Feature Loss: 8.2735, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 066
# 	Train:	Total Loss: 11.3197, Feature Loss: 11.3197, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.1908, Feature Loss: 8.1908, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 067
# 	Train:	Total Loss: 11.2119, Feature Loss: 11.2119, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.1087, Feature Loss: 8.1087, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 068
# 	Train:	Total Loss: 11.1084, Feature Loss: 11.1084, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 8.0238, Feature Loss: 8.0238, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 069
# 	Train:	Total Loss: 11.0535, Feature Loss: 11.0535, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.9354, Feature Loss: 7.9354, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 070
# 	Train:	Total Loss: 10.9176, Feature Loss: 10.9176, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.8486, Feature Loss: 7.8486, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 071
# 	Train:	Total Loss: 10.7702, Feature Loss: 10.7702, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.7590, Feature Loss: 7.7590, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 072
# 	Train:	Total Loss: 10.7292, Feature Loss: 10.7292, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.6656, Feature Loss: 7.6656, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 073
# 	Train:	Total Loss: 10.5580, Feature Loss: 10.5580, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.5729, Feature Loss: 7.5729, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 074
# 	Train:	Total Loss: 10.4980, Feature Loss: 10.4980, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.4757, Feature Loss: 7.4757, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 075
# 	Train:	Total Loss: 10.3423, Feature Loss: 10.3423, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.3782, Feature Loss: 7.3782, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 076
# 	Train:	Total Loss: 10.2704, Feature Loss: 10.2704, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.2790, Feature Loss: 7.2790, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 077
# 	Train:	Total Loss: 12.1034, Feature Loss: 12.1034, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.2059, Feature Loss: 7.2059, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 078
# 	Train:	Total Loss: 10.0332, Feature Loss: 10.0332, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.1089, Feature Loss: 7.1089, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 079
# 	Train:	Total Loss: 9.9195, Feature Loss: 9.9195, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 7.0106, Feature Loss: 7.0106, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 080
# 	Train:	Total Loss: 9.8291, Feature Loss: 9.8291, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.9124, Feature Loss: 6.9124, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 081
# 	Train:	Total Loss: 9.7563, Feature Loss: 9.7563, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.8136, Feature Loss: 6.8136, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 082
# 	Train:	Total Loss: 9.6507, Feature Loss: 9.6507, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.7130, Feature Loss: 6.7130, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 083
# 	Train:	Total Loss: 9.4700, Feature Loss: 9.4700, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.6107, Feature Loss: 6.6107, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 084
# 	Train:	Total Loss: 9.3403, Feature Loss: 9.3403, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.5088, Feature Loss: 6.5088, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 085
# 	Train:	Total Loss: 9.1964, Feature Loss: 9.1964, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.4023, Feature Loss: 6.4023, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 086
# 	Train:	Total Loss: 9.0853, Feature Loss: 9.0853, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.2973, Feature Loss: 6.2973, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 087
# 	Train:	Total Loss: 9.0199, Feature Loss: 9.0199, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.1928, Feature Loss: 6.1928, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 088
# 	Train:	Total Loss: 8.8717, Feature Loss: 8.8717, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 6.0870, Feature Loss: 6.0870, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 089
# 	Train:	Total Loss: 8.7562, Feature Loss: 8.7562, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.9812, Feature Loss: 5.9812, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 090
# 	Train:	Total Loss: 8.6722, Feature Loss: 8.6722, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.8714, Feature Loss: 5.8714, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 091
# 	Train:	Total Loss: 8.4091, Feature Loss: 8.4091, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.7645, Feature Loss: 5.7645, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 092
# 	Train:	Total Loss: 8.3750, Feature Loss: 8.3750, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.6591, Feature Loss: 5.6591, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 093
# 	Train:	Total Loss: 8.1854, Feature Loss: 8.1854, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.5531, Feature Loss: 5.5531, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 094
# 	Train:	Total Loss: 8.1126, Feature Loss: 8.1126, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.4457, Feature Loss: 5.4457, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 095
# 	Train:	Total Loss: 7.9877, Feature Loss: 7.9877, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.3428, Feature Loss: 5.3428, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 096
# 	Train:	Total Loss: 7.8990, Feature Loss: 7.8990, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.2372, Feature Loss: 5.2372, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 097
# 	Train:	Total Loss: 7.7007, Feature Loss: 7.7007, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.1324, Feature Loss: 5.1324, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 098
# 	Train:	Total Loss: 7.6968, Feature Loss: 7.6968, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 5.0276, Feature Loss: 5.0276, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 099
# 	Train:	Total Loss: 7.5049, Feature Loss: 7.5049, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.9266, Feature Loss: 4.9266, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 100
# 	Train:	Total Loss: 7.3233, Feature Loss: 7.3233, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.8301, Feature Loss: 4.8301, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 101
# 	Train:	Total Loss: 7.2644, Feature Loss: 7.2644, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.7287, Feature Loss: 4.7287, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 102
# 	Train:	Total Loss: 7.1197, Feature Loss: 7.1197, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.6303, Feature Loss: 4.6303, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 103
# 	Train:	Total Loss: 7.0421, Feature Loss: 7.0421, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.5363, Feature Loss: 4.5363, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 104
# 	Train:	Total Loss: 6.9180, Feature Loss: 6.9180, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.4425, Feature Loss: 4.4425, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 105
# 	Train:	Total Loss: 6.8011, Feature Loss: 6.8011, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.3512, Feature Loss: 4.3512, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 106
# 	Train:	Total Loss: 6.6519, Feature Loss: 6.6519, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.2597, Feature Loss: 4.2597, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 107
# 	Train:	Total Loss: 6.6264, Feature Loss: 6.6264, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.1738, Feature Loss: 4.1738, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 108
# 	Train:	Total Loss: 6.4632, Feature Loss: 6.4632, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.0885, Feature Loss: 4.0885, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 109
# 	Train:	Total Loss: 6.3325, Feature Loss: 6.3325, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 4.0038, Feature Loss: 4.0038, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 110
# 	Train:	Total Loss: 6.2248, Feature Loss: 6.2248, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.9246, Feature Loss: 3.9246, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 111
# 	Train:	Total Loss: 6.1349, Feature Loss: 6.1349, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.8455, Feature Loss: 3.8455, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 112
# 	Train:	Total Loss: 5.9875, Feature Loss: 5.9875, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.7706, Feature Loss: 3.7706, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 113
# 	Train:	Total Loss: 5.9765, Feature Loss: 5.9765, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6983, Feature Loss: 3.6983, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 114
# 	Train:	Total Loss: 5.7990, Feature Loss: 5.7990, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.6310, Feature Loss: 3.6310, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 115
# 	Train:	Total Loss: 5.7134, Feature Loss: 5.7134, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5659, Feature Loss: 3.5659, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 116
# 	Train:	Total Loss: 5.6279, Feature Loss: 5.6279, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.5041, Feature Loss: 3.5041, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 117
# 	Train:	Total Loss: 5.4961, Feature Loss: 5.4961, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.4430, Feature Loss: 3.4430, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 118
# 	Train:	Total Loss: 9.3123, Feature Loss: 9.3123, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.4100, Feature Loss: 3.4100, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 119
# 	Train:	Total Loss: 5.4619, Feature Loss: 5.4619, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.3693, Feature Loss: 3.3693, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 120
# 	Train:	Total Loss: 5.3756, Feature Loss: 5.3756, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.3255, Feature Loss: 3.3255, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 121
# 	Train:	Total Loss: 5.3141, Feature Loss: 5.3141, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2876, Feature Loss: 3.2876, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 122
# 	Train:	Total Loss: 5.2475, Feature Loss: 5.2475, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2507, Feature Loss: 3.2507, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 123
# 	Train:	Total Loss: 5.2010, Feature Loss: 5.2010, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.2152, Feature Loss: 3.2152, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 124
# 	Train:	Total Loss: 5.1518, Feature Loss: 5.1518, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.1811, Feature Loss: 3.1811, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 125
# 	Train:	Total Loss: 5.1004, Feature Loss: 5.1004, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.1490, Feature Loss: 3.1490, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 126
# 	Train:	Total Loss: 5.0991, Feature Loss: 5.0991, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.1195, Feature Loss: 3.1195, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 127
# 	Train:	Total Loss: 4.9884, Feature Loss: 4.9884, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.0927, Feature Loss: 3.0927, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 128
# 	Train:	Total Loss: 4.9761, Feature Loss: 4.9761, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.0666, Feature Loss: 3.0666, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 129
# 	Train:	Total Loss: 4.8971, Feature Loss: 4.8971, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.0430, Feature Loss: 3.0430, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 130
# 	Train:	Total Loss: 4.8544, Feature Loss: 4.8544, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.0212, Feature Loss: 3.0212, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 131
# 	Train:	Total Loss: 4.7324, Feature Loss: 4.7324, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 3.0008, Feature Loss: 3.0008, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 132
# 	Train:	Total Loss: 4.7524, Feature Loss: 4.7524, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.9821, Feature Loss: 2.9821, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 133
# 	Train:	Total Loss: 4.7594, Feature Loss: 4.7594, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.9642, Feature Loss: 2.9642, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 134
# 	Train:	Total Loss: 4.7178, Feature Loss: 4.7178, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.9487, Feature Loss: 2.9487, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 135
# 	Train:	Total Loss: 4.6434, Feature Loss: 4.6434, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.9348, Feature Loss: 2.9348, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 136
# 	Train:	Total Loss: 4.6538, Feature Loss: 4.6538, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.9219, Feature Loss: 2.9219, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 137
# 	Train:	Total Loss: 4.5588, Feature Loss: 4.5588, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.9112, Feature Loss: 2.9112, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 138
# 	Train:	Total Loss: 4.5279, Feature Loss: 4.5279, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.9011, Feature Loss: 2.9011, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 139
# 	Train:	Total Loss: 4.5727, Feature Loss: 4.5727, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8912, Feature Loss: 2.8912, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 140
# 	Train:	Total Loss: 4.5298, Feature Loss: 4.5298, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8829, Feature Loss: 2.8829, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 141
# 	Train:	Total Loss: 4.4645, Feature Loss: 4.4645, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8757, Feature Loss: 2.8757, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 142
# 	Train:	Total Loss: 4.4844, Feature Loss: 4.4844, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8695, Feature Loss: 2.8695, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 143
# 	Train:	Total Loss: 4.4280, Feature Loss: 4.4280, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8643, Feature Loss: 2.8643, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 144
# 	Train:	Total Loss: 4.4571, Feature Loss: 4.4571, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8595, Feature Loss: 2.8595, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 145
# 	Train:	Total Loss: 4.5127, Feature Loss: 4.5127, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8556, Feature Loss: 2.8556, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 146
# 	Train:	Total Loss: 4.3937, Feature Loss: 4.3937, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8521, Feature Loss: 2.8521, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 147
# 	Train:	Total Loss: 4.4161, Feature Loss: 4.4161, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8493, Feature Loss: 2.8493, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 148
# 	Train:	Total Loss: 4.4348, Feature Loss: 4.4348, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8470, Feature Loss: 2.8470, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 149
# 	Train:	Total Loss: 4.3667, Feature Loss: 4.3667, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8453, Feature Loss: 2.8453, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 150
# 	Train:	Total Loss: 4.3631, Feature Loss: 4.3631, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8438, Feature Loss: 2.8438, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 151
# 	Train:	Total Loss: 4.3149, Feature Loss: 4.3149, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8429, Feature Loss: 2.8429, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 152
# 	Train:	Total Loss: 4.2938, Feature Loss: 4.2938, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8416, Feature Loss: 2.8416, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 153
# 	Train:	Total Loss: 4.2794, Feature Loss: 4.2794, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8411, Feature Loss: 2.8411, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 154
# 	Train:	Total Loss: 4.2990, Feature Loss: 4.2990, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8407, Feature Loss: 2.8407, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 155
# 	Train:	Total Loss: 4.2749, Feature Loss: 4.2749, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8401, Feature Loss: 2.8401, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 156
# 	Train:	Total Loss: 4.3713, Feature Loss: 4.3713, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8397, Feature Loss: 2.8397, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 157
# 	Train:	Total Loss: 4.2168, Feature Loss: 4.2168, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8404, Feature Loss: 2.8404, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 158
# 	Train:	Total Loss: 4.2402, Feature Loss: 4.2402, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8404, Feature Loss: 2.8404, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 159
# 	Train:	Total Loss: 4.2206, Feature Loss: 4.2206, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8404, Feature Loss: 2.8404, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 160
# 	Train:	Total Loss: 4.2088, Feature Loss: 4.2088, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8404, Feature Loss: 2.8404, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 161
# 	Train:	Total Loss: 4.2300, Feature Loss: 4.2300, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8415, Feature Loss: 2.8415, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 162
# 	Train:	Total Loss: 4.2019, Feature Loss: 4.2019, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8410, Feature Loss: 2.8410, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 163
# 	Train:	Total Loss: 4.2373, Feature Loss: 4.2373, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8412, Feature Loss: 2.8412, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 164
# 	Train:	Total Loss: 4.2052, Feature Loss: 4.2052, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8420, Feature Loss: 2.8420, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 165
# 	Train:	Total Loss: 4.1848, Feature Loss: 4.1848, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8421, Feature Loss: 2.8421, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 166
# 	Train:	Total Loss: 4.1637, Feature Loss: 4.1637, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8417, Feature Loss: 2.8417, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 167
# 	Train:	Total Loss: 4.1904, Feature Loss: 4.1904, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8433, Feature Loss: 2.8433, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 168
# 	Train:	Total Loss: 4.1781, Feature Loss: 4.1781, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8435, Feature Loss: 2.8435, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 169
# 	Train:	Total Loss: 4.1565, Feature Loss: 4.1565, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8438, Feature Loss: 2.8438, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 170
# 	Train:	Total Loss: 4.1299, Feature Loss: 4.1299, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8440, Feature Loss: 2.8440, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 171
# 	Train:	Total Loss: 4.1590, Feature Loss: 4.1590, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8455, Feature Loss: 2.8455, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 172
# 	Train:	Total Loss: 4.1218, Feature Loss: 4.1218, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8445, Feature Loss: 2.8445, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 173
# 	Train:	Total Loss: 4.1394, Feature Loss: 4.1394, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8463, Feature Loss: 2.8463, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 174
# 	Train:	Total Loss: 4.1451, Feature Loss: 4.1451, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8442, Feature Loss: 2.8442, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 175
# 	Train:	Total Loss: 4.0955, Feature Loss: 4.0955, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8458, Feature Loss: 2.8458, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 176
# 	Train:	Total Loss: 4.1111, Feature Loss: 4.1111, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8455, Feature Loss: 2.8455, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 177
# 	Train:	Total Loss: 4.1083, Feature Loss: 4.1083, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8434, Feature Loss: 2.8434, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 178
# 	Train:	Total Loss: 4.1214, Feature Loss: 4.1214, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8437, Feature Loss: 2.8437, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 179
# 	Train:	Total Loss: 4.1092, Feature Loss: 4.1092, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8431, Feature Loss: 2.8431, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 180
# 	Train:	Total Loss: 4.1176, Feature Loss: 4.1176, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8443, Feature Loss: 2.8443, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 181
# 	Train:	Total Loss: 4.1740, Feature Loss: 4.1740, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8444, Feature Loss: 2.8444, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 182
# 	Train:	Total Loss: 4.0387, Feature Loss: 4.0387, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8433, Feature Loss: 2.8433, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 183
# 	Train:	Total Loss: 4.0184, Feature Loss: 4.0184, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8418, Feature Loss: 2.8418, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 184
# 	Train:	Total Loss: 4.1529, Feature Loss: 4.1529, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8411, Feature Loss: 2.8411, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 185
# 	Train:	Total Loss: 4.0905, Feature Loss: 4.0905, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8403, Feature Loss: 2.8403, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 186
# 	Train:	Total Loss: 4.0825, Feature Loss: 4.0825, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8392, Feature Loss: 2.8392, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 187
# 	Train:	Total Loss: 4.0898, Feature Loss: 4.0898, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8377, Feature Loss: 2.8377, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 188
# 	Train:	Total Loss: 4.0965, Feature Loss: 4.0965, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8397, Feature Loss: 2.8397, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 189
# 	Train:	Total Loss: 4.0664, Feature Loss: 4.0664, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8387, Feature Loss: 2.8387, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 190
# 	Train:	Total Loss: 4.0287, Feature Loss: 4.0287, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8336, Feature Loss: 2.8336, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 191
# 	Train:	Total Loss: 4.0493, Feature Loss: 4.0493, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8335, Feature Loss: 2.8335, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 192
# 	Train:	Total Loss: 4.0245, Feature Loss: 4.0245, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8303, Feature Loss: 2.8303, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 193
# 	Train:	Total Loss: 4.0274, Feature Loss: 4.0274, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8286, Feature Loss: 2.8286, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 194
# 	Train:	Total Loss: 4.0644, Feature Loss: 4.0644, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8279, Feature Loss: 2.8279, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 195
# 	Train:	Total Loss: 4.0385, Feature Loss: 4.0385, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8242, Feature Loss: 2.8242, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 196
# 	Train:	Total Loss: 4.0258, Feature Loss: 4.0258, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8252, Feature Loss: 2.8252, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 197
# 	Train:	Total Loss: 4.0454, Feature Loss: 4.0454, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8230, Feature Loss: 2.8230, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 198
# 	Train:	Total Loss: 4.0052, Feature Loss: 4.0052, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8213, Feature Loss: 2.8213, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 199
# 	Train:	Total Loss: 4.0116, Feature Loss: 4.0116, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8182, Feature Loss: 2.8182, Type Loss: 0.0000 , LR: 0.000100
# Epoch: 200
# 	Train:	Total Loss: 4.0639, Feature Loss: 4.0639, Type Loss: 0.0000 ,  LR: 0.000100
# 	Test: 	Total Loss: 2.8190, Feature Loss: 2.8190, Type Loss: 0.0000 , LR: 0.000100

# %%
if not model_loaded:
    plt.figure(figsize=(14, 5))
    plt.plot(test_total_losses, label='Total Test Loss')
    plt.plot(train_total_losses, label='Total Train Loss')
    plt.legend()
    plt.title('Total Loss')
    plt.savefig("model2_totalloss.png")
    plt.show()

# %%
if not model_loaded:
    plt.figure(figsize=(14, 5))
    plt.plot(test_feature_losses, label='Test Feature Loss')
    plt.plot(train_feature_losses, label='Train Feature Loss')
    plt.legend()
    plt.title('Feature Loss')
    plt.savefig("model3_feature_loss.png")
    plt.show()

# %%
test_loader_melt = DataLoader(graphs_melt, batch_size=1)
encoded_data_melt=[]
type_data_melt = []
for data in test_loader:
    model.eval()
    z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
    decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
    encoded_data_melt.append(z.detach().numpy())
    type_data_melt.append(str_type.detach().numpy())

encoded_data_melt = np.array(encoded_data_melt)
type_data_melt = np.array(type_data_melt)

# %%
test_loader_cry = DataLoader(graphs_cry, batch_size=1)
encoded_data_cry=[]
type_data_cry = []
for data in test_loader:
    model.eval()
    z,encoded_edge_index = model.encode(data.x, data.edge_index,data.y)
    decoded_x, decoded_edge_index ,str_type= model.decode(z, encoded_edge_index)
    encoded_data_cry.append(z.detach().numpy())
    type_data_cry.append(str_type.detach().numpy())

encoded_data_cry = np.array(encoded_data_cry)
type_data_cry = np.array(type_data_cry)

# %%
# %matplotlib widget

frame = 10

fig = plt.figure(figsize=(15,4))
data_melt = encoded_data_melt[frame]

data_cry = encoded_data_cry[frame]
plt.scatter(data_melt[:,0],data_melt[:,1],c="r",label="melt")
plt.scatter(data_cry[:,0],data_cry[:,1],c="b",label="crystal")
plt.savefig("model3_scatterplot.png")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget

frame = 10

fig = plt.figure(figsize=(15,4))
data_melt = encoded_data_melt[frame]

data_cry = encoded_data_cry[frame]
plt.scatter(data_melt[:,0],data_melt[:,1],c="r",label="melt")
# plt.scatter(data_cry[:,0],data_cry[:,1],c="b",label="crystal")
plt.savefig("model3_scatterplot.png")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
