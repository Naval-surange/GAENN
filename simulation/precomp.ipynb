# %%
f = "./H2O_crystal.gro"

# Read the file
with open(f, "r") as file:
    lines = file.readlines()


new_lines = []
i = 1
j = 1
for line in lines:
    new_lines.append(str(i)+line)
    if(j%4 == 0):
        i += 1
    j += 1

for line in new_lines:
    print(line,end="")
# Out:
# 1HO4  H0     -0.312   2.150   3.380
# 1HO4  O3     -1.248   2.161   3.040
# 1HO4 He1     -1.135   1.966   3.390
# 1HO4  H0     -1.705   1.345   3.380
# 2HO4  H0     -0.312   2.150  10.442
# 2HO4  O3     -1.248   2.161  10.102
# 2HO4 He1     -1.135   1.966  10.453
# 2HO4  H0     -1.705   1.345  10.442
# 3HO4  H0     -4.065   8.648   3.380
# 3HO4  O3     -5.000   8.660   3.040
# 3HO4 He1     -4.887   8.465   3.390
# 3HO4  H0     -5.457   7.844   3.380
# 4HO4  H0     -4.065   8.648  10.442
# 4HO4  O3     -5.000   8.660  10.102
# 4HO4 He1     -4.887   8.465  10.453
# 4HO4  H0     -5.457   7.844  10.442
# 5HO4  H0      7.192   2.150   3.380
# 5HO4  O3      6.256   2.161   3.040
# 5HO4 He1      6.369   1.966   3.390
# 5HO4  H0      5.799   1.345   3.380
# 6HO4  H0      7.192   2.150  10.442
# 6HO4  O3      6.256   2.161  10.102
# 6HO4 He1      6.369   1.966  10.453
# 6HO4  H0      5.799   1.345  10.442
# 7HO4  H0      3.440   8.648   3.380
# 7HO4  O3      2.504   8.660   3.040
# ...
